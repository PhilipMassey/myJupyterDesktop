# %% [markdown]
# http://theautomatic.net/2019/12/16/updates-to-yahoo_fin-package/

# %%
from yahoo_fin import stock_info as si
#dow_tickers = si.tickers_dow()
#si.get_analysts_info('SPG')
si.get_day_most_active()
# Out:
#    Symbol                                  Name  Price (Intraday)  Change  \
# 0      GE              General Electric Company              6.51   -0.33
# 1     OXY      Occidental Petroleum Corporation             12.59   -1.04
# 2     AMD          Advanced Micro Devices, Inc.             56.97    0.37
# 3     BAC           Bank of America Corporation             22.50   -0.78
# 4       F                    Ford Motor Company              4.98   -0.14
# 5     AAL          American Airlines Group Inc.             11.06   -0.51
# 6     PBR  Petroleo Brasileiro S.A. - Petrobras              6.27   -0.18
# 7     MRO              Marathon Oil Corporation              4.21   -0.14
# 8     DAL                 Delta Air Lines, Inc.             23.64   -0.63
# 9     HAL                   Halliburton Company              7.63    0.05
# 10    WFC                 Wells Fargo & Company             27.68   -0.70
# 11    TGE                  Tallgrass Energy, LP             22.39    0.00
# ...

# %%
si.get_analysts_info('AAPL')
# Out:
# {'Earnings Estimate':   Earnings Estimate  Current Qtr. (Mar 2020)  Next Qtr. (Jun 2020)  \
#  0   No. of Analysts                    28.00                 27.00
#  1     Avg. Estimate                     2.28                  2.06
#  2      Low Estimate                     1.73                  1.27
#  3     High Estimate                     2.73                  2.78
#  4      Year Ago EPS                     2.46                  2.18
#
#     Current Year (2020)  Next Year (2021)
#  0                35.00             35.00
#  1                12.40             14.85
#  2                10.86             12.71
#  3                13.99             16.93
#  4                11.89             12.40  ,
#  'Revenue Estimate':           Revenue Estimate Current Qtr. (Mar 2020) Next Qtr. (Jun 2020)  \
#  0          No. of Analysts                      24                   24
#  1            Avg. Estimate                   54.8B               51.02B
# ...
