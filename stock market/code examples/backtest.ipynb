# %%
from fastquant import get_stock_data, backtest
jfc = get_stock_data('AAPL', '2018-01-01', '2019-01-01')
backtest('smac',jfc,fast_period=15,slow_period=40)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Starting Portfolio Value: 100000.00
# ===Global level arguments===
# init_cash : 100000
# buy_prop : 1
# sell_prop : 1
# ===Strategy level arguments===
# fast_period : 15
# slow_period : 40
# 2018-03-02, BUY CREATE, 176.21
# 2018-03-02, Cash: 100000.0
# 2018-03-02, Price: 176.2100067138672
# 2018-03-02, Buy prop size: 562
# 2018-03-02, Afforded size: 562
# 2018-03-02, Final size: 562
# 2018-03-05, BUY EXECUTED, Price: 176.21, Cost: 99030.02, Comm 742.73
# 2018-04-04, SELL CREATE, 172.80
# 2018-04-05, SELL EXECUTED, Price: 172.80, Cost: 99030.02, Comm 728.35
# 2018-04-05, OPERATION PROFIT, GROSS -1916.42, NET -3387.50
# 2018-05-09, BUY CREATE, 187.36
# 2018-05-09, Cash: 96612.50075073242
# 2018-05-09, Price: 187.36000061035156
# 2018-05-09, Buy prop size: 511
# 2018-05-09, Afforded size: 511
# 2018-05-09, Final size: 511
# 2018-05-10, BUY EXECUTED, Price: 187.36, Cost: 95740.96, Comm 718.06
# 2018-06-28, SELL CREATE, 185.11
# 2018-06-29, SELL EXECUTED, Price: 185.11, Cost: 95740.96, Comm 709.43
# 2018-06-29, OPERATION PROFIT, GROSS -1149.75, NET -2577.24
# 2018-07-19, BUY CREATE, 191.88
# 2018-07-19, Cash: 94035.25947105407
# 2018-07-19, Price: 191.8800048828125
# 2018-07-19, Buy prop size: 485
# 2018-07-19, Afforded size: 485
# 2018-07-19, Final size: 485
# 2018-07-20, BUY EXECUTED, Price: 191.88, Cost: 93061.80, Comm 697.96
# 2018-10-22, SELL CREATE, 222.73
# 2018-10-23, SELL EXECUTED, Price: 222.73, Cost: 93061.80, Comm 810.18
# 2018-10-23, OPERATION PROFIT, GROSS 14962.25, NET 13454.10
# Final PnL: 7489.36
# ==================================================
# Number of strat runs: 1
# Number of strats per run: 1
# Strat names: [<class 'fastquant.strategies.SMACStrategy'>]
# **************************************************
# --------------------------------------------------
# {'init_cash': 100000, 'buy_prop': 1, 'sell_prop': 1, 'execution_type': 'close', 'fast_period': 15, 'slow_period': 40}
# OrderedDict([('rtot', 0.0722216906684582), ('ravg', 0.0002877358193962478), ('rnorm', 0.07520294142985302), ('rnorm100', 7.5202941429853025)])
# OrderedDict([('sharperatio', None)])
# Time used (seconds): 0.06179499626159668
# Optimal parameters: {'init_cash': 100000, 'buy_prop': 1, 'sell_prop': 1, 'execution_type': 'close', 'fast_period': 15, 'slow_period': 40}
# Optimal metrics: {'rtot': 0.0722216906684582, 'ravg': 0.0002877358193962478, 'rnorm': 0.07520294142985302, 'rnorm100': 7.5202941429853025, 'sharperatio': None, 'pnl': 7489.36, 'final_value': 107489.36115352629}
# <img src="data:image/png;base64,..." width="432">
#    init_cash  buy_prop  sell_prop execution_type  fast_period  slow_period  \
# 0     100000         1          1          close           15           40
#
#        rtot      ravg     rnorm  rnorm100 sharperatio      pnl    final_value
# 0  0.072222  0.000288  0.075203  7.520294        None  7489.36  107489.361154
