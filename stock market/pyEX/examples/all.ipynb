# %%
import os
os.environ["IEX_TOKEN"] = "pk_9ba866a9c4824ada84d5d51f5042ce41" 

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import pyEX
c = pyEX.Client()
# c = pyEX.Client(version='sandbox')

# %% [markdown]
# # Symbols data

# %%
c.symbolsDF().head()
# Out:
#        exchange                                 name       date type  \
# symbol
# A           NYS            Agilent Technologies Inc. 2020-09-06   cs
# AA          NYS                          Alcoa Corp. 2020-09-06   cs
# AAAU        PSE         Perth Mint Physical Gold ETF 2020-09-06   et
# AACG        NAS  ATA Creativity Global Sponsored ADR 2020-09-06   ad
# AACQ        NAS       Artius Acquisition Inc Class A 2020-09-06   cs
#
#                        iexId region currency  isEnabled          figi      cik
# symbol
# A       IEX_46574843354B2D52     US      USD       True  BBG000C2V3D6  1090872
# AA      IEX_4238333734532D52     US      USD       True  BBG00B3T3HD3  1675149
# AAAU    IEX_474B433136332D52     US      USD       True  BBG00LPXX872     None
# AACG    IEX_44595A4C53392D52     US      USD       True  BBG000V2S3P6     None
# AACQ    IEX_5230483539302D52     US      USD       True  BBG00VR487K7     None

# %% [markdown]
# ## Symbols

# %%
c.symbols()[:1]
# Out:
# [{'symbol': 'A',
#   'exchange': 'NYS',
#   'name': 'Agilent Technologies Inc.',
#   'date': '2020-09-06',
#   'type': 'cs',
#   'iexId': 'IEX_46574843354B2D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000C2V3D6',
#   'cik': '1090872'}]

# %%
c.symbolsDF().head()
# Out:
#        exchange                                 name       date type  \
# symbol
# A           NYS            Agilent Technologies Inc. 2020-09-06   cs
# AA          NYS                          Alcoa Corp. 2020-09-06   cs
# AAAU        PSE         Perth Mint Physical Gold ETF 2020-09-06   et
# AACG        NAS  ATA Creativity Global Sponsored ADR 2020-09-06   ad
# AACQ        NAS       Artius Acquisition Inc Class A 2020-09-06   cs
#
#                        iexId region currency  isEnabled          figi      cik
# symbol
# A       IEX_46574843354B2D52     US      USD       True  BBG000C2V3D6  1090872
# AA      IEX_4238333734532D52     US      USD       True  BBG00B3T3HD3  1675149
# AAAU    IEX_474B433136332D52     US      USD       True  BBG00LPXX872     None
# AACG    IEX_44595A4C53392D52     US      USD       True  BBG000V2S3P6     None
# AACQ    IEX_5230483539302D52     US      USD       True  BBG00VR487K7     None

# %%
c.symbolsList()[:5]
# Out:
# ['A', 'AA', 'AAAU', 'AACG', 'AACQ']

# %% [markdown]
# ## IEX Symbols

# %%
c.iexSymbols()[:5]
# Out:
# [{'symbol': 'A', 'date': '2020-09-04', 'isEnabled': True},
#  {'symbol': 'AA', 'date': '2020-09-04', 'isEnabled': True},
#  {'symbol': 'AAAU', 'date': '2020-09-04', 'isEnabled': True},
#  {'symbol': 'AACG', 'date': '2020-09-04', 'isEnabled': True},
#  {'symbol': 'AACQ', 'date': '2020-09-04', 'isEnabled': True}]

# %%
c.iexSymbolsDF().head()
# Out:
#              date  isEnabled
# symbol
# A      2020-09-04       True
# AA     2020-09-04       True
# AAAU   2020-09-04       True
# AACG   2020-09-04       True
# AACQ   2020-09-04       True

# %%
c.iexSymbolsList()[:10]
# Out:
# ['A', 'AA', 'AAAU', 'AACG', 'AACQ', 'AACQU', 'AACQW', 'AADR', 'AAL', 'AAMC']

# %% [markdown]
# ## International Symbols

# %%
c.internationalSymbols()[:1]
# Out:
# [{'symbol': 'A',
#   'exchange': 'NYS',
#   'name': 'Agilent Technologies Inc.',
#   'date': '2020-09-06',
#   'type': 'cs',
#   'iexId': 'IEX_46574843354B2D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000C2V3D6',
#   'cik': '1090872'}]

# %%
c.internationalSymbolsDF().head()
# Out:
#        exchange                                           name       date  \
# symbol
# A           NYS                      Agilent Technologies Inc. 2020-09-06
# AA          NYS                                    Alcoa Corp. 2020-09-06
# AAAAX       NAS  DWS Alternative Asset Allocation Fund Class A 2020-09-06
# AAACX       NAS                     A3 Alternative Credit Fund 2020-09-06
# AAAEX       NAS         AllianzGI Health Sciences Fund Class P 2020-09-06
#
#        type                 iexId region currency  isEnabled          figi  \
# symbol
# A        cs  IEX_46574843354B2D52     US      USD       True  BBG000C2V3D6
# AA       cs  IEX_4238333734532D52     US      USD       True  BBG00B3T3HD3
# AAAAX   oef  IEX_4258444437432D52     US      USD       True  BBG000RSJVZ1
# AAACX   oef  IEX_5757373651462D52     US      USD       True          None
# AAAEX   oef  IEX_4C31343742472D52     US      USD       True          None
#
#             cik
# symbol
# A       1090872
# AA      1675149
# AAAAX      None
# AAACX      None
# AAAEX      None

# %%
c.internationalSymbolsList()[:5]
# Out:
# ['A', 'AA', 'AAAAX', 'AAACX', 'AAAEX']

# %% [markdown]
# ## FX Symbols

# %%
c.fxSymbols()
# Out:
# {'currencies': [{'code': 'AUD', 'name': 'Australian Dollar'},
#   {'code': 'USD', 'name': 'U.S. Dollar'},
#   {'code': 'CAD', 'name': 'Canadian Dollar'},
#   {'code': 'CHF', 'name': 'Swiss Franc'},
#   {'code': 'EUR', 'name': 'Euro'},
#   {'code': 'GBP', 'name': 'British Pound'},
#   {'code': 'JPY', 'name': 'Japanese Yen'},
#   {'code': 'NOK', 'name': 'Norwegian Krone'},
#   {'code': 'NZD', 'name': 'New Zealand Dollar'},
#   {'code': 'SEK', 'name': 'Swedish Krona'},
#   {'code': 'AED', 'name': 'U.A.E. Dirham'},
#   {'code': 'BGN', 'name': 'Bulgarian Lev'},
#   {'code': 'BHD', 'name': 'Bahraini Dinar'},
#   {'code': 'CNH', 'name': 'Chinese Yuan Renminbi (HK)'},
#   {'code': 'CNY', 'name': 'Chinese Yuan Renminbi'},
#   {'code': 'CZK', 'name': 'Czech Koruna'},
#   {'code': 'DKK', 'name': 'Danish Krone'},
#   {'code': 'HKD', 'name': 'Hong Kong Dollar'},
#   {'code': 'HUF', 'name': 'Hungarian Forint'},
#   {'code': 'IDR', 'name': 'Indonesian Rupiah'},
#   {'code': 'ILS', 'name': 'Israeli New Shekel'},
#   {'code': 'INR', 'name': 'Indian Rupee'},
#   {'code': 'KRW', 'name': 'Korean Won'},
#   {'code': 'KWD', 'name': 'Kuwaiti Dinar'},
#   {'code': 'MXN', 'name': 'Mexican Peso'},
#   {'code': 'MYR', 'name': 'Malaysian Ringgit'},
#   {'code': 'PLN', 'name': 'Polish Zloty'},
#   {'code': 'RON', 'name': 'Romanian Leu'},
#   {'code': 'RUB', 'name': 'Russian Ruble'},
#   {'code': 'SAR', 'name': 'Saudi Arabian Riyal'},
#   {'code': 'SGD', 'name': 'Singapore Dollar'},
#   {'code': 'THB', 'name': 'Thai Baht'},
#   {'code': 'TRY', 'name': 'Turkish Lira'},
#   {'code': 'TWD', 'name': 'Taiwan Dollar'},
#   {'code': 'ZAR', 'name': 'South African Rand'},
#   {'code': 'BTC', 'name': ''},
#   {'code': 'XRP', 'name': ''},
#   {'code': 'LTC', 'name': ''},
#   {'code': 'ETH', 'name': ''},
#   {'code': 'BCH', 'name': ''}],
#  'pairs': [{'fromCurrency': 'AUD', 'toCurrency': 'USD', 'symbol': 'AUDUSD'},
#   {'fromCurrency': 'CAD', 'toCurrency': 'CHF', 'symbol': 'CADCHF'},
#   {'fromCurrency': 'EUR', 'toCurrency': 'AUD', 'symbol': 'EURAUD'},
#   {'fromCurrency': 'EUR', 'toCurrency': 'CAD', 'symbol': 'EURCAD'},
#   {'fromCurrency': 'EUR', 'toCurrency': 'CHF', 'symbol': 'EURCHF'},
#   {'fromCurrency': 'EUR', 'toCurrency': 'GBP', 'symbol': 'EURGBP'},
#   {'fromCurrency': 'EUR', 'toCurrency': 'JPY', 'symbol': 'EURJPY'},
#   {'fromCurrency': 'EUR', 'toCurrency': 'NOK', 'symbol': 'EURNOK'},
#   {'fromCurrency': 'EUR', 'toCurrency': 'NZD', 'symbol': 'EURNZD'},
#   {'fromCurrency': 'EUR', 'toCurrency': 'SEK', 'symbol': 'EURSEK'},
#   {'fromCurrency': 'EUR', 'toCurrency': 'USD', 'symbol': 'EURUSD'},
#   {'fromCurrency': 'GBP', 'toCurrency': 'AUD', 'symbol': 'GBPAUD'},
#   {'fromCurrency': 'GBP', 'toCurrency': 'CAD', 'symbol': 'GBPCAD'},
#   {'fromCurrency': 'GBP', 'toCurrency': 'CHF', 'symbol': 'GBPCHF'},
#   {'fromCurrency': 'GBP', 'toCurrency': 'JPY', 'symbol': 'GBPJPY'},
#   {'fromCurrency': 'GBP', 'toCurrency': 'NOK', 'symbol': 'GBPNOK'},
#   {'fromCurrency': 'GBP', 'toCurrency': 'NZD', 'symbol': 'GBPNZD'},
#   {'fromCurrency': 'GBP', 'toCurrency': 'SEK', 'symbol': 'GBPSEK'},
#   {'fromCurrency': 'GBP', 'toCurrency': 'USD', 'symbol': 'GBPUSD'},
#   {'fromCurrency': 'JPY', 'toCurrency': 'CAD', 'symbol': 'JPYCAD'},
#   {'fromCurrency': 'JPY', 'toCurrency': 'CHF', 'symbol': 'JPYCHF'},
#   {'fromCurrency': 'NZD', 'toCurrency': 'USD', 'symbol': 'NZDUSD'},
#   {'fromCurrency': 'USD', 'toCurrency': 'AED', 'symbol': 'USDAED'},
#   {'fromCurrency': 'USD', 'toCurrency': 'BGN', 'symbol': 'USDBGN'},
#   {'fromCurrency': 'USD', 'toCurrency': 'BHD', 'symbol': 'USDBHD'},
#   {'fromCurrency': 'USD', 'toCurrency': 'CAD', 'symbol': 'USDCAD'},
#   {'fromCurrency': 'USD', 'toCurrency': 'CHF', 'symbol': 'USDCHF'},
#   {'fromCurrency': 'USD', 'toCurrency': 'CNH', 'symbol': 'USDCNH'},
#   {'fromCurrency': 'USD', 'toCurrency': 'CNY', 'symbol': 'USDCNY'},
#   {'fromCurrency': 'USD', 'toCurrency': 'CZK', 'symbol': 'USDCZK'},
#   {'fromCurrency': 'USD', 'toCurrency': 'DKK', 'symbol': 'USDDKK'},
#   {'fromCurrency': 'USD', 'toCurrency': 'HKD', 'symbol': 'USDHKD'},
#   {'fromCurrency': 'USD', 'toCurrency': 'HUF', 'symbol': 'USDHUF'},
#   {'fromCurrency': 'USD', 'toCurrency': 'IDR', 'symbol': 'USDIDR'},
#   {'fromCurrency': 'USD', 'toCurrency': 'ILS', 'symbol': 'USDILS'},
#   {'fromCurrency': 'USD', 'toCurrency': 'INR', 'symbol': 'USDINR'},
#   {'fromCurrency': 'USD', 'toCurrency': 'JPY', 'symbol': 'USDJPY'},
#   {'fromCurrency': 'USD', 'toCurrency': 'KRW', 'symbol': 'USDKRW'},
#   {'fromCurrency': 'USD', 'toCurrency': 'KWD', 'symbol': 'USDKWD'},
#   {'fromCurrency': 'USD', 'toCurrency': 'MXN', 'symbol': 'USDMXN'},
#   {'fromCurrency': 'USD', 'toCurrency': 'MYR', 'symbol': 'USDMYR'},
#   {'fromCurrency': 'USD', 'toCurrency': 'NOK', 'symbol': 'USDNOK'},
#   {'fromCurrency': 'USD', 'toCurrency': 'PLN', 'symbol': 'USDPLN'},
#   {'fromCurrency': 'USD', 'toCurrency': 'RON', 'symbol': 'USDRON'},
#   {'fromCurrency': 'USD', 'toCurrency': 'RUB', 'symbol': 'USDRUB'},
#   {'fromCurrency': 'USD', 'toCurrency': 'SAR', 'symbol': 'USDSAR'},
#   {'fromCurrency': 'USD', 'toCurrency': 'SEK', 'symbol': 'USDSEK'},
#   {'fromCurrency': 'USD', 'toCurrency': 'SGD', 'symbol': 'USDSGD'},
#   {'fromCurrency': 'USD', 'toCurrency': 'THB', 'symbol': 'USDTHB'},
#   {'fromCurrency': 'USD', 'toCurrency': 'TRY', 'symbol': 'USDTRY'},
#   {'fromCurrency': 'USD', 'toCurrency': 'TWD', 'symbol': 'USDTWD'},
#   {'fromCurrency': 'USD', 'toCurrency': 'ZAR', 'symbol': 'USDZAR'},
#   {'fromCurrency': 'BTC', 'toCurrency': 'USD', 'symbol': 'BTCUSD'},
#   {'fromCurrency': 'BTC', 'toCurrency': 'EUR', 'symbol': 'BTCEUR'},
#   {'fromCurrency': 'EUR', 'toCurrency': 'USD', 'symbol': 'EURUSD'},
#   {'fromCurrency': 'XRP', 'toCurrency': 'USD', 'symbol': 'XRPUSD'},
#   {'fromCurrency': 'XRP', 'toCurrency': 'EUR', 'symbol': 'XRPEUR'},
#   {'fromCurrency': 'XRP', 'toCurrency': 'BTC', 'symbol': 'XRPBTC'},
#   {'fromCurrency': 'LTC', 'toCurrency': 'USD', 'symbol': 'LTCUSD'},
#   {'fromCurrency': 'LTC', 'toCurrency': 'EUR', 'symbol': 'LTCEUR'},
#   {'fromCurrency': 'LTC', 'toCurrency': 'BTC', 'symbol': 'LTCBTC'},
#   {'fromCurrency': 'ETH', 'toCurrency': 'USD', 'symbol': 'ETHUSD'},
#   {'fromCurrency': 'ETH', 'toCurrency': 'EUR', 'symbol': 'ETHEUR'},
#   {'fromCurrency': 'ETH', 'toCurrency': 'BTC', 'symbol': 'ETHBTC'},
#   {'fromCurrency': 'BCH', 'toCurrency': 'USD', 'symbol': 'BCHUSD'},
#   {'fromCurrency': 'BCH', 'toCurrency': 'EUR', 'symbol': 'BCHEUR'},
#   {'fromCurrency': 'BCH', 'toCurrency': 'BTC', 'symbol': 'BCHBTC'}]}

# %%
dfs = c.fxSymbolsDF()
dfs[0].head()
# Out:
#                    name
# code
# AUD   Australian Dollar
# USD         U.S. Dollar
# CAD     Canadian Dollar
# CHF         Swiss Franc
# EUR                Euro

# %%
dfs[1].head()
# Out:
#   fromCurrency toCurrency  symbol
# 0          AUD        USD  AUDUSD
# 1          CAD        CHF  CADCHF
# 2          EUR        AUD  EURAUD
# 3          EUR        CAD  EURCAD
# 4          EUR        CHF  EURCHF

# %%
l = c.fxSymbolsList()
l[0][:5]
# Out:
# ['AUD', 'USD', 'CAD', 'CHF', 'EUR']

# %%
l[1][:5]
# Out:
# ['AUDUSD', 'CADCHF', 'EURAUD', 'EURCAD', 'EURCHF']

# %% [markdown]
# ## Options Symbols

# %%
d = c.optionsSymbols()
list(d.keys())[:5]
# Out:
# ['HOV', 'GLIN', 'OEC', 'AHC', 'DE']

# %%
c.optionsSymbolsDF().head()
# Out:
#                                            expirations
# HOV                                           [201911]
# GLIN                                  [202010, 202103]
# OEC                   [202009, 202010, 202101, 202104]
# AHC                   [202009, 202010, 202011, 202102]
# DE    [202009, 202010, 202012, 202101, 202103, 202201]

# %%
c.optionsSymbolsList()[:5]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-6673b3605163> in <module>
# ----> 1 c.optionsSymbolsList()[:5]
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pyEX/client.py in bind(self, *args, **kwargs)
#     670         if not meth:
#     671             raise PyEXception('Must provide method!')
# --> 672         return meth(token=self._token, version=self._version, *args, **kwargs)
#     673
#     674     def account(self):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pyEX/refdata/symbols.py in optionsSymbolsList(token, version)
#     397         list: result
#     398     '''
# --> 399     return [x['symbol'] for x in optionsSymbols(token, version, filter='symbol')]
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pyEX/refdata/symbols.py in <listcomp>(.0)
#     397         list: result
#     398     '''
# --> 399     return [x['symbol'] for x in optionsSymbols(token, version, filter='symbol')]
#
# TypeError: string indices must be integers

# %% [markdown]
# ## International Exchanges

# %%
c.internationalExchanges()[:5]
# Out:
# [{'exchange': 'ADS',
#   'region': 'AE',
#   'description': 'Abu Dhabi Securities Exchange',
#   'mic': 'XADS',
#   'exchangeSuffix': '-DH'},
#  {'exchange': 'TAE',
#   'region': 'IL',
#   'description': 'Tel Aviv Stock Exchange',
#   'mic': 'XTAE',
#   'exchangeSuffix': '-IT'},
#  {'exchange': 'BOM',
#   'region': 'IN',
#   'description': 'BSE Ltd.',
#   'mic': 'XBOM',
#   'exchangeSuffix': '-IB'},
#  {'exchange': 'KRX',
#   'region': 'KR',
#   'description': 'Korea Exchange',
#   'mic': 'XKRX',
#   'exchangeSuffix': '-KP'},
#  {'exchange': 'BRU',
#   'region': 'BE',
#   'description': 'Euronext Brussels',
#   'mic': 'XBRU',
#   'exchangeSuffix': '-BB'}]

# %%
c.internationalExchangesDF().head()
# Out:
#   exchange region                    description   mic exchangeSuffix
# 0      ADS     AE  Abu Dhabi Securities Exchange  XADS            -DH
# 1      TAE     IL        Tel Aviv Stock Exchange  XTAE            -IT
# 2      BOM     IN                       BSE Ltd.  XBOM            -IB
# 3      KRX     KR                 Korea Exchange  XKRX            -KP
# 4      BRU     BE              Euronext Brussels  XBRU            -BB

# %% [markdown]
# ## US Exchanges

# %%
c.exchanges()[:1]
# Out:
# [{'mic': 'ARCX',
#   'name': 'NYSE Arca',
#   'longName': 'NYSE ARCA',
#   'tapeId': 'P',
#   'oatsId': 'XP',
#   'refId': 'PSE',
#   'type': 'equities'}]

# %%
c.exchangesDF().head()
# Out:
#     mic       name                        longName tapeId oatsId refId  \
# 0  ARCX  NYSE Arca                       NYSE ARCA      P     XP   PSE
# 1  EDGX  Cboe EDGX  Cboe EDGX US Equities Exchange      K     XK  EDGX
# 2  BATS   Cboe BZX   Cboe BZX US Equities Exchange      Z     XZ  BATS
# 3  BATY   Cboe BYX   Cboe BYX US Equities Exchange      Y     XY  BATY
# 4  EDGA  Cboe EDGA  Cboe EDGA US Equities Exchange      J     XJ  EDGA
#
#        type
# 0  equities
# 1  equities
# 2  equities
# 3  equities
# 4  equities

# %% [markdown]
# ## US Holidays

# %%
c.holidays()
# Out:
# [{'date': '2020-09-07', 'settlementDate': '2020-09-09'}]

# %%
c.holidaysDF().head()
# Out:
#         date settlementDate
# 0 2020-09-07     2020-09-09

# %% [markdown]
# ## Sectors

# %%
c.sectors()[:5]
# Out:
# [{'name': 'Electronic Technology'},
#  {'name': 'Distribution Services'},
#  {'name': 'Health Technology'},
#  {'name': 'Commercial Services'},
#  {'name': 'Industrial Services'}]

# %%
c.sectorsDF().head()
# Out:
#                     name
# 0  Electronic Technology
# 1  Distribution Services
# 2      Health Technology
# 3    Commercial Services
# 4    Industrial Services

# %% [markdown]
# ## Tags

# %%
c.tags()[:5]
# Out:
# [{'name': 'Electronic Technology'},
#  {'name': 'Distribution Services'},
#  {'name': 'Commercial Services'},
#  {'name': 'Health Technology'},
#  {'name': 'Industrial Services'}]

# %%
c.tagsDF().head()
# Out:
#                     name
# 0  Electronic Technology
# 1  Distribution Services
# 2    Commercial Services
# 3      Health Technology
# 4    Industrial Services

# %% [markdown]
# # Data Points API

# %%
c.points()[:2]
# Out:
# [{'key': 'DGS1MO',
#   'weight': 1000,
#   'description': '1-Month Treasury Rate (daily)',
#   'lastUpdated': '2020-09-06T18:00:14+00:00'},
#  {'key': 'DGS1',
#   'weight': 1000,
#   'description': '1-Year Treasury Rate (daily)',
#   'lastUpdated': '2020-09-06T18:00:05+00:00'}]

# %%
c.pointsDF().head()
# Out:
#       key  weight                    description               lastUpdated
# 0  DGS1MO    1000  1-Month Treasury Rate (daily) 2020-09-06 18:00:14+00:00
# 1    DGS1    1000   1-Year Treasury Rate (daily) 2020-09-06 18:00:05+00:00
# 2   DGS10    1000  10-Year Treasury Rate (daily) 2020-09-06 18:00:03+00:00
# 3    DGS2    1000   2-Year Treasury Rate (daily) 2020-09-06 18:00:07+00:00
# 4   DGS20    1000  20-Year Treasury Rate (daily) 2020-09-06 18:00:19+00:00

# %%
c.points(key='DGS10')
# Out:
# 0.63

# %%
c.pointsDF('aapl').head()
# Out:
#                 key  weight                     description  \
# 0  NEXTDIVIDENDDATE       1
# 1         EMPLOYEES       1
# 2   ACCOUNTSPAYABLE    3000  Balance Sheet: accountsPayable
# 3    CAPITALSURPLUS    3000   Balance Sheet: capitalSurplus
# 4       COMMONSTOCK    3000      Balance Sheet: commonStock
#
#                 lastUpdated
# 0 2020-08-31 10:25:18+00:00
# 1 2020-09-06 09:00:16+00:00
# 2 2020-09-06 07:06:46+00:00
# 3 2020-09-06 07:06:46+00:00
# 4 2020-09-06 07:06:46+00:00

# %%
c.points('aapl', 'QUOTE-LATESTPRICE')
# Out:
# ---------------------------------------------------------------------------
# PyEXception                               Traceback (most recent call last)
# <ipython-input-24-ec24edd78d85> in <module>
# ----> 1 c.points('aapl', 'QUOTE-LATESTPRICE')
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pyEX/client.py in bind(self, *args, **kwargs)
#     670         if not meth:
#     671             raise PyEXception('Must provide method!')
# --> 672         return meth(token=self._token, version=self._version, *args, **kwargs)
#     673
#     674     def account(self):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pyEX/points/points.py in points(symbol, key, token, version, filter)
#      24     _raiseIfNotStr(symbol)
#      25     if key:
# ---> 26         return _getJson('data-points/{symbol}/{key}'.format(symbol=symbol, key=key), token, version, filter)
#      27     return _getJson('data-points/{symbol}'.format(symbol=symbol), token, version, filter)
#      28
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pyEX/common.py in _getJson(url, token, version, filter)
#     383         if version == 'sandbox':
#     384             return _getJsonIEXCloudSandbox(url, token, version, filter)
# --> 385         return _getJsonIEXCloud(url, token, version, filter)
#     386     return _getJsonOrig(url)
#     387
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pyEX/common.py in _getJsonIEXCloud(url, token, version, filter)
#     400     if resp.status_code == 200:
#     401         return resp.json()
# --> 402     raise PyEXception('Response %d - ' % resp.status_code, resp.text)
#     403
#     404
#
# PyEXception: ('Response 404 - ', 'Not found')

# %% [markdown]
# # Stock API

# %%
symbol = 'AAPL'

# %% [markdown]
# ## Advanced Stats

# %%
c.advancedStats(symbol)
# Out:
# {'week52change': 1.268567,
#  'week52high': 137.98,
#  'week52low': 52.77,
#  'marketcap': 2068718400000,
#  'employees': 137000,
#  'day200MovingAvg': 82.15,
#  'day50MovingAvg': 106.86,
#  'float': 17086047395,
#  'avg10Volume': 223213674.8,
#  'avg30Volume': 195357803.87,
#  'ttmEPS': 3.3183,
#  'ttmDividendRate': 0.7825,
#  'companyName': 'Apple, Inc.',
#  'sharesOutstanding': 17102500000,
#  'maxChangePercent': 477.2918,
#  'year5ChangePercent': 3.3842,
#  'year2ChangePercent': 1.1188,
#  'year1ChangePercent': 1.3519,
#  'ytdChangePercent': 0.6333,
#  'month6ChangePercent': 0.6723,
#  'month3ChangePercent': 0.4882,
#  'month1ChangePercent': 0.1103,
#  'day30ChangePercent': 0.2758,
#  'day5ChangePercent': -0.0626,
#  'nextDividendDate': None,
#  'dividendYield': 0.006469080687830688,
#  'nextEarningsDate': '2020-10-29',
#  'exDividendDate': '2020-08-31',
#  'peRatio': 36.45,
#  'beta': 1.1218009347361093,
#  'totalCash': 100580000000,
#  'currentDebt': 16240000000,
#  'revenue': 259968000000,
#  'grossProfit': 97704000000,
#  'totalRevenue': 259968000000,
#  'EBITDA': 74542000000,
#  'revenuePerShare': 15.2,
#  'revenuePerEmployee': 1897576.64,
#  'debtToEquity': 1.19,
#  'profitMargin': 0.2125492368291482,
#  'enterpriseValue': 2076185400000,
#  'enterpriseValueToRevenue': 7.99,
#  'priceToSales': 7.96,
#  'priceToBook': 22.861798249491645,
#  'forwardPERatio': 37.33,
#  'pegRatio': 1.99,
#  'peHigh': 41.97110266159695,
#  'peLow': 15.765779467680607,
#  'week52highDate': '2020-09-02',
#  'week52lowDate': '2019-09-09',
#  'putCallRatio': 50.43832614688627}

# %%
c.advancedStatsDF(symbol)
# Out:
#    week52change  week52high  week52low      marketcap  employees  \
# 0      1.268567      137.98      52.77  2068718400000     137000
#
#    day200MovingAvg  day50MovingAvg        float  avg10Volume   avg30Volume  \
# 0            82.15          106.86  17086047395  223213674.8  1.953578e+08
#
#    ...  enterpriseValueToRevenue  priceToSales priceToBook  forwardPERatio  \
# 0  ...                      7.99          7.96   22.861798           37.33
#
#    pegRatio     peHigh      peLow  week52highDate  week52lowDate  putCallRatio
# 0      1.99  41.971103  15.765779      2020-09-02     2019-09-09     50.438326
#
# [1 rows x 51 columns]

# %% [markdown]
# ## Balance Sheet

# %%
c.balanceSheet(symbol)
# Out:
# {'symbol': 'AAPL',
#  'balancesheet': [{'reportDate': '2020-06-30',
#    'fiscalDate': '2020-06-27',
#    'currency': 'USD',
#    'currentCash': 27295000000,
#    'shortTermInvestments': 65759000000,
#    'receivables': 17882000000,
#    'inventory': 3978000000,
#    'otherCurrentAssets': 10958000000,
#    'currentAssets': 140065000000,
#    'longTermInvestments': 102219000000,
#    'propertyPlantEquipment': 43851000000,
#    'goodwill': None,
#    'intangibleAssets': None,
#    'otherAssets': 31209000000,
#    'totalAssets': 317344000000,
#    'accountsPayable': 35325000000,
#    'currentLongTermDebt': 7529000000,
#    'otherCurrentLiabilities': 39945000000,
#    'totalCurrentLiabilities': 95318000000,
#    'longTermDebt': 102138000000,
#    'otherLiabilities': 19418000000,
#    'minorityInterest': 0,
#    'totalLiabilities': 245062000000,
#    'commonStock': 17135756000,
#    'retainedEarnings': 24136000000,
#    'treasuryStock': None,
#    'capitalSurplus': None,
#    'shareholderEquity': 72282000000,
#    'netTangibleAssets': 72282000000}]}

# %%
c.balanceSheetDF(symbol)
# Out:
#             fiscalDate currency  currentCash  shortTermInvestments  \
# reportDate
# 2020-06-30  2020-06-27      USD  27295000000           65759000000
#
#             receivables   inventory  otherCurrentAssets  currentAssets  \
# reportDate
# 2020-06-30  17882000000  3978000000         10958000000   140065000000
#
#             longTermInvestments  propertyPlantEquipment  ... otherLiabilities  \
# reportDate                                               ...
# 2020-06-30         102219000000             43851000000  ...      19418000000
#
#            minorityInterest  totalLiabilities  commonStock  retainedEarnings  \
# reportDate
# 2020-06-30                0      245062000000  17135756000       24136000000
#
#             treasuryStock  capitalSurplus  shareholderEquity  \
# reportDate
# 2020-06-30           None            None        72282000000
#
#             netTangibleAssets  symbol
# reportDate
# 2020-06-30        72282000000    AAPL
#
# [1 rows x 29 columns]

# %% [markdown]
# ## Book

# %%
c.book(symbol)
# Out:
# {'quote': {'symbol': 'AAPL',
#   'companyName': 'Apple, Inc.',
#   'primaryExchange': 'NASDAQ',
#   'calculationPrice': 'close',
#   'open': 120,
#   'openTime': 1599226202030,
#   'openSource': 'official',
#   'close': 120.96,
#   'closeTime': 1599249600801,
#   'closeSource': 'official',
#   'high': 123.7,
#   'highTime': 1599263998145,
#   'highSource': '15 minute delayed price',
#   'low': 110.89,
#   'lowTime': 1599230668001,
#   'lowSource': '15 minute delayed price',
#   'latestPrice': 120.96,
#   'latestSource': 'Close',
#   'latestTime': 'September 4, 2020',
#   'latestUpdate': 1599249600801,
#   'latestVolume': 332607163,
#   'iexRealtimePrice': None,
#   'iexRealtimeSize': None,
#   'iexLastUpdated': None,
#   'delayedPrice': 120,
#   'delayedPriceTime': 1599263998145,
#   'oddLotDelayedPrice': 453.263,
#   'oddLotDelayedPriceTime': 1599252382500,
#   'extendedPrice': 120.01,
#   'extendedChange': -0.95,
#   'extendedChangePercent': -0.00785,
#   'extendedPriceTime': 1599263998144,
#   'previousClose': 120.88,
#   'previousVolume': 257599640,
#   'change': 0.08,
#   'changePercent': 0.00066,
#   'volume': 332607163,
#   'iexMarketPercent': None,
#   'iexVolume': None,
#   'avgTotalVolume': 195357804,
#   'iexBidPrice': None,
#   'iexBidSize': None,
#   'iexAskPrice': None,
#   'iexAskSize': None,
#   'iexOpen': None,
#   'iexOpenTime': None,
#   'iexClose': 121.11,
#   'iexCloseTime': 1599249591040,
#   'marketCap': 2068718400000,
#   'peRatio': 36.45,
#   'week52High': 137.98,
#   'week52Low': 52.77,
#   'ytdChange': 0.63396,
#   'lastTradeTime': 1599249600801,
#   'isUSMarketOpen': False},
#  'bids': [],
#  'asks': [],
#  'systemEvent': {}}

# %%
c.bookDF(symbol).head()
# Out:
#    avgTotalVolume calculationPrice  change  changePercent   close closeSource  \
# 0     195357804.0            close    0.08        0.00066  120.96    official
#
#                 closeTime  companyName  delayedPrice        delayedPriceTime  \
# 0 2020-09-04 20:00:00.801  Apple, Inc.         120.0 2020-09-04 23:59:58.145
#
#    ...  peRatio  previousClose  previousVolume primaryExchange  symbol   type  \
# 0  ...    36.45         120.88     257599640.0          NASDAQ    AAPL  quote
#
#         volume week52High week52Low ytdChange
# 0  332607163.0     137.98     52.77   0.63396
#
# [1 rows x 56 columns]

# %% [markdown]
# ## Cashflow

# %%
c.cashFlow(symbol)
# Out:
# {'symbol': 'AAPL',
#  'cashflow': [{'reportDate': '2020-06-30',
#    'fiscalDate': '2020-06-27',
#    'currency': 'USD',
#    'netIncome': 11253000000,
#    'depreciation': 2752000000,
#    'changesInReceivables': -2160000000,
#    'changesInInventories': -689000000,
#    'cashChange': -8010000000,
#    'cashFlow': 16271000000,
#    'capitalExpenditures': -1565000000,
#    'investments': -2998000000,
#    'investingActivityOther': -263000000,
#    'totalInvestingCashFlows': -5165000000,
#    'dividendsPaid': -3656000000,
#    'netBorrowings': 2168000000,
#    'otherFinancingCashFlows': -1737000000,
#    'cashFlowFinancing': -19116000000,
#    'exchangeRateEffect': None}]}

# %%
c.cashFlowDF(symbol)
# Out:
#             fiscalDate currency    netIncome  depreciation  \
# reportDate
# 2020-06-30  2020-06-27      USD  11253000000    2752000000
#
#             changesInReceivables  changesInInventories  cashChange  \
# reportDate
# 2020-06-30           -2160000000            -689000000 -8010000000
#
#                cashFlow  capitalExpenditures  investments  \
# reportDate
# 2020-06-30  16271000000          -1565000000  -2998000000
#
#             investingActivityOther  totalInvestingCashFlows  dividendsPaid  \
# reportDate
# 2020-06-30              -263000000              -5165000000    -3656000000
#
#             netBorrowings  otherFinancingCashFlows  cashFlowFinancing  \
# reportDate
# 2020-06-30     2168000000              -1737000000       -19116000000
#
#             exchangeRateEffect symbol
# reportDate
# 2020-06-30                 NaN   AAPL

# %% [markdown]
# ## Collections

# %%
c.collections?

# %%
c.collectionsDF?

# %% [markdown]
# ## Company

# %%
c.company(symbol)
# Out:
# {'symbol': 'AAPL',
#  'companyName': 'Apple, Inc.',
#  'exchange': 'NASDAQ',
#  'industry': 'Telecommunications Equipment',
#  'website': 'http://www.apple.com',
#  'description': 'Apple, Inc. engages in the design, manufacture, and sale of smartphones, personal computers, tablets, wearables and accessories, and other variety of related services. It operates through the following geographical segments: Americas, Europe, Greater China, Japan, and Rest of Asia Pacific. The Americas segment includes North and South America. The Europe segment consists of European countries, as well as India, the Middle East, and Africa. The Greater China segment comprises of China, Hong Kong, and Taiwan. The Rest of Asia Pacific segment includes Australia and Asian countries. Its products and services include iPhone, Mac, iPad, AirPods, Apple TV, Apple Watch, Beats products, Apple Care, iCloud, digital content stores, streaming, and licensing services. The company was founded by Steven Paul Jobs, Ronald Gerald Wayne, and Stephen G. Wozniak on April 1, 1976 and is headquartered in Cupertino, CA.',
#  'CEO': 'Timothy Donald Cook',
#  'securityName': 'Apple Inc.',
#  'issueType': 'cs',
#  'sector': 'Electronic Technology',
#  'primarySicCode': 3663,
#  'employees': 137000,
#  'tags': ['Electronic Technology', 'Telecommunications Equipment'],
#  'address': 'One Apple Park Way',
#  'address2': None,
#  'state': 'CA',
#  'city': 'Cupertino',
#  'zip': '95014-2083',
#  'country': 'US',
#  'phone': '1.408.996.1010'}

# %%
c.companyDF(symbol)
# Out:
#         companyName exchange                      industry  \
# symbol
# AAPL    Apple, Inc.   NASDAQ  Telecommunications Equipment
#
#                      website  \
# symbol
# AAPL    http://www.apple.com
#
#                                               description  \
# symbol
# AAPL    Apple, Inc. engages in the design, manufacture...
#
#                         CEO securityName issueType                 sector  \
# symbol
# AAPL    Timothy Donald Cook   Apple Inc.        cs  Electronic Technology
#
#         primarySicCode  employees  \
# symbol
# AAPL              3663     137000
#
#                                                      tags             address  \
# symbol
# AAPL    [Electronic Technology, Telecommunications Equ...  One Apple Park Way
#
#        address2 state       city         zip country           phone
# symbol
# AAPL       None    CA  Cupertino  95014-2083      US  1.408.996.1010

# %% [markdown]
# ## Delayed Quote

# %%
c.delayedQuote(symbol)
# Out:
# {}

# %%
c.delayedQuoteDF(symbol)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0]

# %% [markdown]
# ## Dividends

# %%
c.dividends(symbol)
# Out:
# [{'exDate': '2020-08-31',
#   'paymentDate': '2020-08-28',
#   'recordDate': '2020-08-24',
#   'declaredDate': '2020-07-30',
#   'amount': '',
#   'flag': 'Stock',
#   'currency': '',
#   'description': 'Ordinary Shares',
#   'frequency': 'quarterly',
#   'date': '2020-09-06'},
#  {'exDate': '2020-08-07',
#   'paymentDate': '2020-08-13',
#   'recordDate': '2020-08-10',
#   'declaredDate': '2020-07-30',
#   'amount': '0.82',
#   'flag': 'Cash',
#   'currency': 'USD',
#   'description': 'Ordinary Shares',
#   'frequency': 'quarterly',
#   'date': '2020-09-06'},
#  {'exDate': '2020-05-08',
#   'paymentDate': '2020-05-14',
#   'recordDate': '2020-05-11',
#   'declaredDate': '2020-04-30',
#   'amount': '0.82',
#   'flag': 'Cash',
#   'currency': 'USD',
#   'description': 'Ordinary Shares',
#   'frequency': 'quarterly',
#   'date': '2020-09-06'},
#  {'exDate': '2020-02-07',
#   'paymentDate': '2020-02-13',
#   'recordDate': '2020-02-10',
#   'declaredDate': '2020-01-28',
#   'amount': '0.77',
#   'flag': 'Cash',
#   'currency': 'USD',
#   'description': 'Ordinary Shares',
#   'frequency': 'quarterly',
#   'date': '2020-09-06'}]

# %%
c.dividendsDF(symbol)
# Out:
#            paymentDate recordDate declaredDate amount   flag currency  \
# exDate
# 2020-08-31  2020-08-28 2020-08-24   2020-07-30         Stock
# 2020-08-07  2020-08-13 2020-08-10   2020-07-30   0.82   Cash      USD
# 2020-05-08  2020-05-14 2020-05-11   2020-04-30   0.82   Cash      USD
# 2020-02-07  2020-02-13 2020-02-10   2020-01-28   0.77   Cash      USD
#
#                 description  frequency       date
# exDate
# 2020-08-31  Ordinary Shares  quarterly 2020-09-06
# 2020-08-07  Ordinary Shares  quarterly 2020-09-06
# 2020-05-08  Ordinary Shares  quarterly 2020-09-06
# 2020-02-07  Ordinary Shares  quarterly 2020-09-06

# %% [markdown]
# ## Earnings

# %%
c.earnings(symbol)
# Out:
# {'symbol': 'AAPL',
#  'earnings': [{'actualEPS': 0.645,
#    'consensusEPS': 0.51,
#    'announceTime': 'AMC',
#    'numberOfEstimates': 33,
#    'EPSSurpriseDollar': 0.14,
#    'EPSReportDate': '2020-07-30',
#    'fiscalPeriod': 'Q2 2020',
#    'fiscalEndDate': '2020-06-30',
#    'yearAgo': 0.545,
#    'yearAgoChangePercent': 0.1835,
#    'currency': 'USD'}]}

# %%
c.earningsDF(symbol)
# Out:
#                actualEPS  consensusEPS announceTime  numberOfEstimates  \
# EPSReportDate
# 2020-07-30         0.645          0.51          AMC                 33
#
#                EPSSurpriseDollar fiscalPeriod fiscalEndDate  yearAgo  \
# EPSReportDate
# 2020-07-30                  0.14      Q2 2020    2020-06-30    0.545
#
#                yearAgoChangePercent currency symbol
# EPSReportDate
# 2020-07-30                   0.1835      USD   AAPL

# %% [markdown]
# ## Earnings Today

# %%
c.earningsToday()
# Out:
# {'bto': [], 'amc': [], 'other': []}

# %%
c.earningsTodayDF().head()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pyEX/stocks/marketInfo.py:93: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   df = pd.io.json.json_normalize(z)
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## Effective Spread

# %%
c.spread(symbol)
# Out:
# ---------------------------------------------------------------------------
# PyEXception                               Traceback (most recent call last)
# <ipython-input-117-e3761beeeffa> in <module>
# ----> 1 c.spread(symbol)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pyEX/client.py in bind(self, *args, **kwargs)
#     670         if not meth:
#     671             raise PyEXception('Must provide method!')
# --> 672         return meth(token=self._token, version=self._version, *args, **kwargs)
#     673
#     674     def account(self):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/temporalcache/expire.py in _wrapped_foo(*args, **kwargs)
#      77             kwargs = {k: frozendict(v) if isinstance(v, dict) else tuple(v) if isinstance(v, list) else v for k, v in kwargs.items()}
#      78
# ---> 79             return foo(*args, **kwargs)
#      80         return _wrapped_foo
#      81     return _wrapper
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/temporalcache/persistent_lru_cache.py in wrapper(*args, **kwds)
#     202                         hits += 1
#     203                         return result
# --> 204                 result = user_function(*args, **kwds)
#     205                 with lock:
#     206                     if key in cache:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pyEX/stocks/prices.py in spread(symbol, token, version, filter)
#     484     '''
#     485     _raiseIfNotStr(symbol)
# --> 486     return _getJson('stock/' + symbol + '/effective-spread', token, version, filter)
#     487
#     488
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pyEX/common.py in _getJson(url, token, version, filter)
#     383         if version == 'sandbox':
#     384             return _getJsonIEXCloudSandbox(url, token, version, filter)
# --> 385         return _getJsonIEXCloud(url, token, version, filter)
#     386     return _getJsonOrig(url)
#     387
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pyEX/common.py in _getJsonIEXCloud(url, token, version, filter)
#     400     if resp.status_code == 200:
#     401         return resp.json()
# --> 402     raise PyEXception('Response %d - ' % resp.status_code, resp.text)
#     403
#     404
#
# PyEXception: ('Response 403 - ', 'The API key provided is not valid.')

# %%
c.spreadDF(symbol)
# Out:
# ---------------------------------------------------------------------------
# PyEXception                               Traceback (most recent call last)
# <ipython-input-118-cfac350caf85> in <module>
# ----> 1 c.spreadDF(symbol)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pyEX/client.py in bind(self, *args, **kwargs)
#     670         if not meth:
#     671             raise PyEXception('Must provide method!')
# --> 672         return meth(token=self._token, version=self._version, *args, **kwargs)
#     673
#     674     def account(self):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pyEX/stocks/prices.py in spreadDF(symbol, token, version, filter)
#     512         DataFrame: result
#     513     '''
# --> 514     df = pd.DataFrame(spread(symbol, token, version, filter))
#     515     _toDatetime(df)
#     516     _reindex(df, 'venue')
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/temporalcache/expire.py in _wrapped_foo(*args, **kwargs)
#      77             kwargs = {k: frozendict(v) if isinstance(v, dict) else tuple(v) if isinstance(v, list) else v for k, v in kwargs.items()}
#      78
# ---> 79             return foo(*args, **kwargs)
#      80         return _wrapped_foo
#      81     return _wrapper
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/temporalcache/persistent_lru_cache.py in wrapper(*args, **kwds)
#     202                         hits += 1
#     203                         return result
# --> 204                 result = user_function(*args, **kwds)
#     205                 with lock:
#     206                     if key in cache:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pyEX/stocks/prices.py in spread(symbol, token, version, filter)
#     484     '''
#     485     _raiseIfNotStr(symbol)
# --> 486     return _getJson('stock/' + symbol + '/effective-spread', token, version, filter)
#     487
#     488
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pyEX/common.py in _getJson(url, token, version, filter)
#     383         if version == 'sandbox':
#     384             return _getJsonIEXCloudSandbox(url, token, version, filter)
# --> 385         return _getJsonIEXCloud(url, token, version, filter)
#     386     return _getJsonOrig(url)
#     387
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pyEX/common.py in _getJsonIEXCloud(url, token, version, filter)
#     400     if resp.status_code == 200:
#     401         return resp.json()
# --> 402     raise PyEXception('Response %d - ' % resp.status_code, resp.text)
#     403
#     404
#
# PyEXception: ('Response 403 - ', 'The API key provided is not valid.')

# %% [markdown]
# ## Estimates

# %%
c.estimates(symbol)
# Out:
# {'symbol': 'AAPL',
#  'estimates': [{'consensusEPS': 0.71,
#    'announceTime': 'AMC',
#    'numberOfEstimates': 34,
#    'reportDate': '2020-10-29',
#    'fiscalPeriod': 'Q3 2020',
#    'fiscalEndDate': '2020-09-30',
#    'currency': 'USD'}]}

# %%
c.estimatesDF(symbol)
# Out:
#                consensusEPS announceTime  numberOfEstimates reportDate  \
# fiscalEndDate
# 2020-09-30             0.71          AMC                 34 2020-10-29
#
#               fiscalPeriod currency symbol
# fiscalEndDate
# 2020-09-30         Q3 2020      USD   AAPL

# %% [markdown]
# ## Financials

# %%
c.financials(symbol)
# Out:
# {'symbol': 'AAPL',
#  'financials': [{'reportDate': '2020-06-30',
#    'fiscalDate': '2020-06-27',
#    'currency': 'USD',
#    'grossProfit': 22048000000,
#    'costOfRevenue': 37367000000,
#    'operatingRevenue': 59415000000,
#    'totalRevenue': 59415000000,
#    'operatingIncome': 12459000000,
#    'netIncome': 11253000000,
#    'researchAndDevelopment': 4758000000,
#    'operatingExpense': 46956000000,
#    'currentAssets': 140065000000,
#    'totalAssets': 317344000000,
#    'totalLiabilities': 245062000000,
#    'currentCash': 27295000000,
#    'currentDebt': 20048000000,
#    'shortTermDebt': 20048000000,
#    'longTermDebt': 102138000000,
#    'totalCash': 93054000000,
#    'totalDebt': 122186000000,
#    'shareholderEquity': 72282000000,
#    'cashChange': -8010000000,
#    'cashFlow': 16271000000}]}

# %%
c.financialsDF(symbol)
# Out:
#             fiscalDate currency  grossProfit  costOfRevenue  operatingRevenue  \
# reportDate
# 2020-06-30  2020-06-27      USD  22048000000    37367000000       59415000000
#
#             totalRevenue  operatingIncome    netIncome  \
# reportDate
# 2020-06-30   59415000000      12459000000  11253000000
#
#             researchAndDevelopment  operatingExpense  ...  currentCash  \
# reportDate                                            ...
# 2020-06-30              4758000000       46956000000  ...  27295000000
#
#             currentDebt  shortTermDebt  longTermDebt    totalCash  \
# reportDate
# 2020-06-30  20048000000    20048000000  102138000000  93054000000
#
#                totalDebt  shareholderEquity  cashChange     cashFlow  symbol
# reportDate
# 2020-06-30  122186000000        72282000000 -8010000000  16271000000    AAPL
#
# [1 rows x 23 columns]

# %% [markdown]
# ## Fund Ownership

# %%
c.fundOwnership(symbol)
# Out:
# [{'report_date': 1598832000000,
#   'entityProperName': 'Spdr S&p 500 Etf',
#   'adjHolding': 172500016,
#   'adjMv': 22259402065,
#   'reportedHolding': 172500016,
#   'reportedMv': 22259402065},
#  {'report_date': 1598832000000,
#   'entityProperName': 'Invesco Qqq Trust',
#   'adjHolding': 155751288,
#   'adjMv': 20098146204,
#   'reportedHolding': 155751288,
#   'reportedMv': 20098146204},
#  {'report_date': 1598832000000,
#   'entityProperName': 'Ishares Core S&p 500 Etf',
#   'adjHolding': 123563780,
#   'adjMv': 15944670171,
#   'reportedHolding': 123563780,
#   'reportedMv': 15944670171},
#  {'report_date': 1596153600000,
#   'entityProperName': 'Vanguard Total Stock Market Index Fund',
#   'adjHolding': 110877068,
#   'adjMv': 47127188983,
#   'reportedHolding': 110877068,
#   'reportedMv': 47127188983},
#  {'report_date': 1596153600000,
#   'entityProperName': 'Vanguard 500 Index Fund',
#   'adjHolding': 84018598,
#   'adjMv': 35711264894,
#   'reportedHolding': 84018598,
#   'reportedMv': 35711264894},
#  {'report_date': 1598832000000,
#   'entityProperName': 'Spdr Series - Technology Select Sector Spdr Fund',
#   'adjHolding': 73425168,
#   'adjMv': 9474783679,
#   'reportedHolding': 73425168,
#   'reportedMv': 9474783679},
#  {'report_date': 1598832000000,
#   'entityProperName': 'Ishares Russell 1000 Growth Etf',
#   'adjHolding': 58415060,
#   'adjMv': 7537879342,
#   'reportedHolding': 58415060,
#   'reportedMv': 7537879342},
#  {'report_date': 1577750400000,
#   'entityProperName': 'Government Pension Fund - Global (the)',
#   'adjHolding': 45329151,
#   'adjMv': 13310905191,
#   'reportedHolding': 45329151,
#   'reportedMv': 13310905192},
#  {'report_date': 1596153600000,
#   'entityProperName': 'Fidelity 500 Index Fund',
#   'adjHolding': 36291456,
#   'adjMv': 15425320458,
#   'reportedHolding': 36291456,
#   'reportedMv': 15425320458},
#  {'report_date': 1596153600000,
#   'entityProperName': 'Vanguard Institutional Index Fund',
#   'adjHolding': 35166223,
#   'adjMv': 14947051424,
#   'reportedHolding': 35166223,
#   'reportedMv': 14947051424}]

# %%
c.fundOwnershipDF(symbol)
# Out:
#   report_date                                  entityProperName  adjHolding  \
# 0  2020-08-31                                  Spdr S&p 500 Etf   172500016
# 1  2020-08-31                                 Invesco Qqq Trust   155751288
# 2  2020-08-31                          Ishares Core S&p 500 Etf   123563780
# 3  2020-07-31            Vanguard Total Stock Market Index Fund   110877068
# 4  2020-07-31                           Vanguard 500 Index Fund    84018598
# 5  2020-08-31  Spdr Series - Technology Select Sector Spdr Fund    73425168
# 6  2020-08-31                   Ishares Russell 1000 Growth Etf    58415060
# 7  2019-12-31            Government Pension Fund - Global (the)    45329151
# 8  2020-07-31                           Fidelity 500 Index Fund    36291456
# 9  2020-07-31                 Vanguard Institutional Index Fund    35166223
#
#          adjMv  reportedHolding   reportedMv
# 0  22259402065        172500016  22259402065
# 1  20098146204        155751288  20098146204
# 2  15944670171        123563780  15944670171
# 3  47127188983        110877068  47127188983
# 4  35711264894         84018598  35711264894
# 5   9474783679         73425168   9474783679
# 6   7537879342         58415060   7537879342
# 7  13310905191         45329151  13310905192
# 8  15425320458         36291456  15425320458
# 9  14947051424         35166223  14947051424

# %% [markdown]
# ## Historical Prices

# %%
c.chart(symbol)
# Out:
# [{'date': '2020-08-05',
#   'open': 109.38,
#   'close': 110.06,
#   'high': 110.39,
#   'low': 108.9,
#   'volume': 121991952,
#   'uOpen': 437.51,
#   'uClose': 440.25,
#   'uHigh': 441.57,
#   'uLow': 435.59,
#   'uVolume': 30497988,
#   'change': 0,
#   'changePercent': 0,
#   'label': 'Aug 5',
#   'changeOverTime': 0},
#  {'date': '2020-08-06',
#   'open': 110.41,
#   'close': 113.9,
#   'high': 114.41,
#   'low': 109.8,
#   'volume': 202428900,
#   'uOpen': 441.62,
#   'uClose': 455.61,
#   'uHigh': 457.65,
#   'uLow': 439.19,
#   'uVolume': 50607225,
#   'change': 3.84,
#   'changePercent': 3.4889,
#   'label': 'Aug 6',
#   'changeOverTime': 0.034889},
#  {'date': '2020-08-07',
#   'open': 113.21,
#   'close': 111.11,
#   'high': 113.68,
#   'low': 110.29,
#   'volume': 198045612,
#   'uOpen': 452.82,
#   'uClose': 444.45,
#   'uHigh': 454.7,
#   'uLow': 441.17,
#   'uVolume': 49511403,
#   'change': -2.79,
#   'changePercent': -2.4495,
#   'label': 'Aug 7',
#   'changeOverTime': 0.00954},
#  {'date': '2020-08-10',
#   'open': 112.6,
#   'close': 112.73,
#   'high': 113.78,
#   'low': 110,
#   'volume': 212403424,
#   'uOpen': 450.4,
#   'uClose': 450.91,
#   'uHigh': 455.1,
#   'uLow': 440,
#   'uVolume': 53100856,
#   'change': 1.62,
#   'changePercent': 1.4535,
#   'label': 'Aug 10',
#   'changeOverTime': 0.024213},
#  {'date': '2020-08-11',
#   'open': 111.97,
#   'close': 109.38,
#   'high': 112.48,
#   'low': 109.11,
#   'volume': 187902376,
#   'uOpen': 447.88,
#   'uClose': 437.5,
#   'uHigh': 449.93,
#   'uLow': 436.43,
#   'uVolume': 46975594,
#   'change': -3.35,
#   'changePercent': -2.9744,
#   'label': 'Aug 11',
#   'changeOverTime': -0.006251},
#  {'date': '2020-08-12',
#   'open': 110.5,
#   'close': 113.01,
#   'high': 113.28,
#   'low': 110.3,
#   'volume': 165944820,
#   'uOpen': 441.99,
#   'uClose': 452.04,
#   'uHigh': 453.1,
#   'uLow': 441.19,
#   'uVolume': 41486205,
#   'change': 3.64,
#   'changePercent': 3.3234,
#   'label': 'Aug 12',
#   'changeOverTime': 0.026776},
#  {'date': '2020-08-13',
#   'open': 114.43,
#   'close': 115.01,
#   'high': 116.04,
#   'low': 113.93,
#   'volume': 210082064,
#   'uOpen': 457.72,
#   'uClose': 460.04,
#   'uHigh': 464.17,
#   'uLow': 455.71,
#   'uVolume': 52520516,
#   'change': 2,
#   'changePercent': 1.7698,
#   'label': 'Aug 13',
#   'changeOverTime': 0.044947},
#  {'date': '2020-08-14',
#   'open': 114.83,
#   'close': 114.91,
#   'high': 115,
#   'low': 113.05,
#   'volume': 165565208,
#   'uOpen': 459.32,
#   'uClose': 459.63,
#   'uHigh': 460,
#   'uLow': 452.18,
#   'uVolume': 41391302,
#   'change': -0.1,
#   'changePercent': -0.0896,
#   'label': 'Aug 14',
#   'changeOverTime': 0.044011},
#  {'date': '2020-08-17',
#   'open': 116.06,
#   'close': 114.61,
#   'high': 116.09,
#   'low': 113.96,
#   'volume': 119561444,
#   'uOpen': 464.25,
#   'uClose': 458.43,
#   'uHigh': 464.35,
#   'uLow': 455.85,
#   'uVolume': 29890361,
#   'change': -0.3,
#   'changePercent': -0.2602,
#   'label': 'Aug 17',
#   'changeOverTime': 0.041295},
#  {'date': '2020-08-18',
#   'open': 114.35,
#   'close': 115.56,
#   'high': 116,
#   'low': 114.01,
#   'volume': 105633540,
#   'uOpen': 457.41,
#   'uClose': 462.25,
#   'uHigh': 464,
#   'uLow': 456.03,
#   'uVolume': 26408385,
#   'change': 0.95,
#   'changePercent': 0.8324,
#   'label': 'Aug 18',
#   'changeOverTime': 0.049962},
#  {'date': '2020-08-19',
#   'open': 115.98,
#   'close': 115.71,
#   'high': 117.16,
#   'low': 115.61,
#   'volume': 145538008,
#   'uOpen': 463.93,
#   'uClose': 462.83,
#   'uHigh': 468.65,
#   'uLow': 462.44,
#   'uVolume': 36384502,
#   'change': 0.15,
#   'changePercent': 0.1263,
#   'label': 'Aug 19',
#   'changeOverTime': 0.051289},
#  {'date': '2020-08-20',
#   'open': 115.75,
#   'close': 118.28,
#   'high': 118.39,
#   'low': 115.73,
#   'volume': 126907188,
#   'uOpen': 463,
#   'uClose': 473.1,
#   'uHigh': 473.57,
#   'uLow': 462.93,
#   'uVolume': 31726797,
#   'change': 2.57,
#   'changePercent': 2.2185,
#   'label': 'Aug 20',
#   'changeOverTime': 0.074612},
#  {'date': '2020-08-21',
#   'open': 119.26,
#   'close': 124.37,
#   'high': 124.87,
#   'low': 119.25,
#   'volume': 338054640,
#   'uOpen': 477.05,
#   'uClose': 497.48,
#   'uHigh': 499.47,
#   'uLow': 477,
#   'uVolume': 84513660,
#   'change': 6.1,
#   'changePercent': 5.1532,
#   'label': 'Aug 21',
#   'changeOverTime': 0.129989},
#  {'date': '2020-08-24',
#   'open': 128.7,
#   'close': 125.86,
#   'high': 128.79,
#   'low': 123.94,
#   'volume': 345937768,
#   'uOpen': 514.79,
#   'uClose': 503.43,
#   'uHigh': 515.14,
#   'uLow': 495.75,
#   'uVolume': 86484442,
#   'change': 1.49,
#   'changePercent': 1.1964,
#   'label': 'Aug 24',
#   'changeOverTime': 0.143509},
#  {'date': '2020-08-25',
#   'open': 124.7,
#   'close': 124.83,
#   'high': 125.18,
#   'low': 123.05,
#   'volume': 211495788,
#   'uOpen': 498.79,
#   'uClose': 499.3,
#   'uHigh': 500.72,
#   'uLow': 492.21,
#   'uVolume': 52873947,
#   'change': -1.03,
#   'changePercent': -0.8208,
#   'label': 'Aug 25',
#   'changeOverTime': 0.134123},
#  {'date': '2020-08-26',
#   'open': 126.18,
#   'close': 126.52,
#   'high': 126.99,
#   'low': 125.08,
#   'volume': 163022268,
#   'uOpen': 504.72,
#   'uClose': 506.09,
#   'uHigh': 507.97,
#   'uLow': 500.33,
#   'uVolume': 40755567,
#   'change': 1.7,
#   'changePercent': 1.3603,
#   'label': 'Aug 26',
#   'changeOverTime': 0.149551},
#  {'date': '2020-08-27',
#   'open': 127.14,
#   'close': 125.01,
#   'high': 127.49,
#   'low': 123.83,
#   'volume': 155552384,
#   'uOpen': 508.57,
#   'uClose': 500.04,
#   'uHigh': 509.94,
#   'uLow': 495.33,
#   'uVolume': 38888096,
#   'change': -1.51,
#   'changePercent': -1.1958,
#   'label': 'Aug 27',
#   'changeOverTime': 0.135804},
#  {'date': '2020-08-28',
#   'open': 126.01,
#   'close': 124.81,
#   'high': 126.44,
#   'low': 124.58,
#   'volume': 187629916,
#   'uOpen': 504.05,
#   'uClose': 499.23,
#   'uHigh': 505.77,
#   'uLow': 498.31,
#   'uVolume': 46907479,
#   'change': -0.2,
#   'changePercent': -0.1616,
#   'label': 'Aug 28',
#   'changeOverTime': 0.133969},
#  {'date': '2020-08-31',
#   'open': 127.58,
#   'close': 129.04,
#   'high': 131,
#   'low': 126,
#   'volume': 225702688,
#   'uOpen': 127.58,
#   'uClose': 129.04,
#   'uHigh': 131,
#   'uLow': 126,
#   'uVolume': 225702688,
#   'change': 4.23,
#   'changePercent': 3.3908,
#   'label': 'Aug 31',
#   'changeOverTime': 0.172419},
#  {'date': '2020-09-01',
#   'open': 132.76,
#   'close': 134.18,
#   'high': 134.8,
#   'low': 130.53,
#   'volume': 152470142,
#   'uOpen': 132.76,
#   'uClose': 134.18,
#   'uHigh': 134.8,
#   'uLow': 130.53,
#   'uVolume': 152470142,
#   'change': 5.14,
#   'changePercent': 3.9833,
#   'label': 'Sep 1',
#   'changeOverTime': 0.21912},
#  {'date': '2020-09-02',
#   'open': 137.59,
#   'close': 131.4,
#   'high': 137.98,
#   'low': 127,
#   'volume': 200118991,
#   'uOpen': 137.59,
#   'uClose': 131.4,
#   'uHigh': 137.98,
#   'uLow': 127,
#   'uVolume': 200118991,
#   'change': -2.78,
#   'changePercent': -2.0718,
#   'label': 'Sep 2',
#   'changeOverTime': 0.193862},
#  {'date': '2020-09-03',
#   'open': 126.91,
#   'close': 120.88,
#   'high': 128.84,
#   'low': 120.5,
#   'volume': 257599640,
#   'uOpen': 126.91,
#   'uClose': 120.88,
#   'uHigh': 128.84,
#   'uLow': 120.5,
#   'uVolume': 257599640,
#   'change': -10.52,
#   'changePercent': -8.0061,
#   'label': 'Sep 3',
#   'changeOverTime': 0.09828},
#  {'date': '2020-09-04',
#   'open': 120.07,
#   'close': 120.96,
#   'high': 123.7,
#   'low': 110.89,
#   'volume': 332607163,
#   'uOpen': 120.07,
#   'uClose': 120.96,
#   'uHigh': 123.7,
#   'uLow': 110.89,
#   'uVolume': 332607163,
#   'change': 0.08,
#   'changePercent': 0.0662,
#   'label': 'Sep 4',
#   'changeOverTime': 0.099007}]

# %%
c.chartDF(symbol)
# Out:
#               open   close    high     low     volume   uOpen  uClose   uHigh  \
# date
# 2020-08-05  109.38  110.06  110.39  108.90  121991952  437.51  440.25  441.57
# 2020-08-06  110.41  113.90  114.41  109.80  202428900  441.62  455.61  457.65
# 2020-08-07  113.21  111.11  113.68  110.29  198045612  452.82  444.45  454.70
# 2020-08-10  112.60  112.73  113.78  110.00  212403424  450.40  450.91  455.10
# 2020-08-11  111.97  109.38  112.48  109.11  187902376  447.88  437.50  449.93
# 2020-08-12  110.50  113.01  113.28  110.30  165944820  441.99  452.04  453.10
# 2020-08-13  114.43  115.01  116.04  113.93  210082064  457.72  460.04  464.17
# 2020-08-14  114.83  114.91  115.00  113.05  165565208  459.32  459.63  460.00
# 2020-08-17  116.06  114.61  116.09  113.96  119561444  464.25  458.43  464.35
# 2020-08-18  114.35  115.56  116.00  114.01  105633540  457.41  462.25  464.00
# 2020-08-19  115.98  115.71  117.16  115.61  145538008  463.93  462.83  468.65
# 2020-08-20  115.75  118.28  118.39  115.73  126907188  463.00  473.10  473.57
# 2020-08-21  119.26  124.37  124.87  119.25  338054640  477.05  497.48  499.47
# 2020-08-24  128.70  125.86  128.79  123.94  345937768  514.79  503.43  515.14
# 2020-08-25  124.70  124.83  125.18  123.05  211495788  498.79  499.30  500.72
# 2020-08-26  126.18  126.52  126.99  125.08  163022268  504.72  506.09  507.97
# 2020-08-27  127.14  125.01  127.49  123.83  155552384  508.57  500.04  509.94
# 2020-08-28  126.01  124.81  126.44  124.58  187629916  504.05  499.23  505.77
# 2020-08-31  127.58  129.04  131.00  126.00  225702688  127.58  129.04  131.00
# 2020-09-01  132.76  134.18  134.80  130.53  152470142  132.76  134.18  134.80
# 2020-09-02  137.59  131.40  137.98  127.00  200118991  137.59  131.40  137.98
# 2020-09-03  126.91  120.88  128.84  120.50  257599640  126.91  120.88  128.84
# 2020-09-04  120.07  120.96  123.70  110.89  332607163  120.07  120.96  123.70
#
#               uLow    uVolume  change  changePercent   label  changeOverTime
# date
# 2020-08-05  435.59   30497988    0.00         0.0000   Aug 5        0.000000
# 2020-08-06  439.19   50607225    3.84         3.4889   Aug 6        0.034889
# 2020-08-07  441.17   49511403   -2.79        -2.4495   Aug 7        0.009540
# 2020-08-10  440.00   53100856    1.62         1.4535  Aug 10        0.024213
# 2020-08-11  436.43   46975594   -3.35        -2.9744  Aug 11       -0.006251
# 2020-08-12  441.19   41486205    3.64         3.3234  Aug 12        0.026776
# 2020-08-13  455.71   52520516    2.00         1.7698  Aug 13        0.044947
# 2020-08-14  452.18   41391302   -0.10        -0.0896  Aug 14        0.044011
# 2020-08-17  455.85   29890361   -0.30        -0.2602  Aug 17        0.041295
# 2020-08-18  456.03   26408385    0.95         0.8324  Aug 18        0.049962
# 2020-08-19  462.44   36384502    0.15         0.1263  Aug 19        0.051289
# 2020-08-20  462.93   31726797    2.57         2.2185  Aug 20        0.074612
# 2020-08-21  477.00   84513660    6.10         5.1532  Aug 21        0.129989
# 2020-08-24  495.75   86484442    1.49         1.1964  Aug 24        0.143509
# 2020-08-25  492.21   52873947   -1.03        -0.8208  Aug 25        0.134123
# 2020-08-26  500.33   40755567    1.70         1.3603  Aug 26        0.149551
# 2020-08-27  495.33   38888096   -1.51        -1.1958  Aug 27        0.135804
# 2020-08-28  498.31   46907479   -0.20        -0.1616  Aug 28        0.133969
# 2020-08-31  126.00  225702688    4.23         3.3908  Aug 31        0.172419
# 2020-09-01  130.53  152470142    5.14         3.9833   Sep 1        0.219120
# 2020-09-02  127.00  200118991   -2.78        -2.0718   Sep 2        0.193862
# 2020-09-03  120.50  257599640  -10.52        -8.0061   Sep 3        0.098280
# 2020-09-04  110.89  332607163    0.08         0.0662   Sep 4        0.099007

# %% [markdown]
# ## Income Statement

# %%
c.incomeStatement(symbol)
# Out:
# {'symbol': 'AAPL',
#  'income': [{'reportDate': '2020-06-30',
#    'fiscalDate': '2020-06-27',
#    'currency': 'USD',
#    'totalRevenue': 59415000000,
#    'costOfRevenue': 37367000000,
#    'grossProfit': 22048000000,
#    'researchAndDevelopment': 4758000000,
#    'sellingGeneralAndAdmin': 4831000000,
#    'operatingExpense': 46956000000,
#    'operatingIncome': 12459000000,
#    'otherIncomeExpenseNet': 678000000,
#    'ebit': 12459000000,
#    'interestIncome': 697000000,
#    'pretaxIncome': 13137000000,
#    'incomeTax': 1884000000,
#    'minorityInterest': 0,
#    'netIncome': 11253000000,
#    'netIncomeBasic': 11253000000}]}

# %%
c.incomeStatementDF(symbol)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pyEX/stocks/fundamentals.py:309: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   df = pd.io.json.json_normalize(val, 'income', 'symbol')
#             fiscalDate currency  totalRevenue  costOfRevenue  grossProfit  \
# reportDate
# 2020-06-30  2020-06-27      USD   59415000000    37367000000  22048000000
#
#             researchAndDevelopment  sellingGeneralAndAdmin  operatingExpense  \
# reportDate
# 2020-06-30              4758000000              4831000000       46956000000
#
#             operatingIncome  otherIncomeExpenseNet         ebit  \
# reportDate
# 2020-06-30      12459000000              678000000  12459000000
#
#             interestIncome  pretaxIncome   incomeTax  minorityInterest  \
# reportDate
# 2020-06-30       697000000   13137000000  1884000000                 0
#
#               netIncome  netIncomeBasic symbol
# reportDate
# 2020-06-30  11253000000     11253000000   AAPL

# %% [markdown]
# ## Insider Roster

# %%
c.insiderRoster(symbol)
# Out:
# [{'position': 1300000,
#   'reportDate': 1593475200000,
#   'entityName': 'WELLCOME TRUST LTD /DIRECT INVESTMENTS/'},
#  {'position': 1147283,
#   'reportDate': 1582675200000,
#   'entityName': 'Arthur D. Levinson'},
#  {'position': 837374,
#   'reportDate': 1598313600000,
#   'entityName': 'Timothy Donald Cook'},
#  {'position': 378226,
#   'reportDate': 1593475200000,
#   'entityName': 'NOVO VENTURES US INC'},
#  {'position': 122315,
#   'reportDate': 1585785600000,
#   'entityName': 'Jeffrey E. Williams'},
#  {'position': 115014,
#   'reportDate': 1582675200000,
#   'entityName': 'Albert Arnold Gore'},
#  {'position': 33972,
#   'reportDate': 1586995200000,
#   'entityName': "Deirdre O'Brien"},
#  {'position': 33548, 'reportDate': 1588032000000, 'entityName': 'Andrea Jung'},
#  {'position': 30848,
#   'reportDate': 1577923200000,
#   'entityName': 'Angela J. Ahrendts'},
#  {'position': 27568,
#   'reportDate': 1586217600000,
#   'entityName': 'Luca Maestri'}]

# %%
c.insiderRosterDF(symbol)
# Out:
#    position reportDate                               entityName
# 0   1300000 2020-06-30  WELLCOME TRUST LTD /DIRECT INVESTMENTS/
# 1   1147283 2020-02-26                       Arthur D. Levinson
# 2    837374 2020-08-25                      Timothy Donald Cook
# 3    378226 2020-06-30                     NOVO VENTURES US INC
# 4    122315 2020-04-02                      Jeffrey E. Williams
# 5    115014 2020-02-26                       Albert Arnold Gore
# 6     33972 2020-04-16                          Deirdre O'Brien
# 7     33548 2020-04-28                              Andrea Jung
# 8     30848 2020-01-02                       Angela J. Ahrendts
# 9     27568 2020-04-07                             Luca Maestri

# %% [markdown]
# ## Insider Summary

# %%
c.insiderSummary(symbol)
# Out:
# [{'reportedTitle': 'Principal Accounting Officer',
#   'netTransacted': -6836,
#   'totalBought': 5916,
#   'totalSold': -12752,
#   'fullName': 'Chris Kondo'},
#  {'reportedTitle': 'COO',
#   'netTransacted': -85678,
#   'totalBought': 85678,
#   'totalSold': -171356,
#   'fullName': 'Jeffrey E. Williams'},
#  {'reportedTitle': 'Director',
#   'netTransacted': 0,
#   'totalBought': 9590,
#   'totalSold': -9590,
#   'fullName': 'Andrea Jung'},
#  {'reportedTitle': 'Chief Executive Officer; Director',
#   'netTransacted': -570715,
#   'totalBought': 560000,
#   'totalSold': -1130715,
#   'fullName': 'Timothy Donald Cook'},
#  {'reportedTitle': 'Senior Vice President, CFO',
#   'netTransacted': -85678,
#   'totalBought': 85678,
#   'totalSold': -171356,
#   'fullName': 'Luca Maestri'},
#  {'reportedTitle': 'Senior Vice President',
#   'netTransacted': -16634,
#   'totalBought': 16634,
#   'totalSold': -33268,
#   'fullName': "Deirdre O'Brien"}]

# %%
c.insiderSummaryDF(symbol)
# Out:
#                        reportedTitle  netTransacted  totalBought  totalSold  \
# 0       Principal Accounting Officer          -6836         5916     -12752
# 1                                COO         -85678        85678    -171356
# 2                           Director              0         9590      -9590
# 3  Chief Executive Officer; Director        -570715       560000   -1130715
# 4         Senior Vice President, CFO         -85678        85678    -171356
# 5              Senior Vice President         -16634        16634     -33268
#
#               fullName
# 0          Chris Kondo
# 1  Jeffrey E. Williams
# 2          Andrea Jung
# 3  Timothy Donald Cook
# 4         Luca Maestri
# 5      Deirdre O'Brien

# %% [markdown]
# ## Insider Transactions

# %%
c.insiderTransactions(symbol)[:5]
# Out:
# [{'fullName': 'Timothy Donald Cook',
#   'reportedTitle': 'Chief Executive Officer; Director',
#   'effectiveDate': 1598313600000,
#   'tranShares': -990,
#   'tranPrice': 500.11,
#   'tranValue': -495108.9,
#   'directIndirect': 'D',
#   'tranCode': 'S'},
#  {'fullName': 'Timothy Donald Cook',
#   'reportedTitle': 'Chief Executive Officer; Director',
#   'effectiveDate': 1598313600000,
#   'tranShares': -58710,
#   'tranPrice': 499.42,
#   'tranValue': -29320948.2,
#   'directIndirect': 'D',
#   'tranCode': 'S'},
#  {'fullName': 'Timothy Donald Cook',
#   'reportedTitle': 'Chief Executive Officer; Director',
#   'effectiveDate': 1598313600000,
#   'tranShares': -32447,
#   'tranPrice': 498.54,
#   'tranValue': -16176127.38,
#   'directIndirect': 'D',
#   'tranCode': 'S'},
#  {'fullName': 'Timothy Donald Cook',
#   'reportedTitle': 'Chief Executive Officer; Director',
#   'effectiveDate': 1598313600000,
#   'tranShares': -19650,
#   'tranPrice': 497.54,
#   'tranValue': -9776661,
#   'directIndirect': 'D',
#   'tranCode': 'S'},
#  {'fullName': 'Timothy Donald Cook',
#   'reportedTitle': 'Chief Executive Officer; Director',
#   'effectiveDate': 1598313600000,
#   'tranShares': -30814,
#   'tranPrice': 496.45,
#   'tranValue': -15297610.3,
#   'directIndirect': 'D',
#   'tranCode': 'S'}]

# %%
c.insiderTransactionsDF(symbol)
# Out:
#                 fullName                      reportedTitle  effectiveDate  \
# 0    Timothy Donald Cook  Chief Executive Officer; Director  1598313600000
# 1    Timothy Donald Cook  Chief Executive Officer; Director  1598313600000
# 2    Timothy Donald Cook  Chief Executive Officer; Director  1598313600000
# 3    Timothy Donald Cook  Chief Executive Officer; Director  1598313600000
# 4    Timothy Donald Cook  Chief Executive Officer; Director  1598313600000
# ..                   ...                                ...            ...
# 116   Katherine L. Adams              SVP, GC and Secretary  1569715200000
# 117   Katherine L. Adams              SVP, GC and Secretary  1569715200000
# 118  Jeffrey E. Williams                                COO  1569715200000
# 119  Jeffrey E. Williams                                COO  1569715200000
# 120          Chris Kondo       Principal Accounting Officer  1569715200000
#
#      tranShares  tranPrice    tranValue directIndirect tranCode
# 0          -990     500.11   -495108.90              D        S
# 1        -58710     499.42 -29320948.20              D        S
# 2        -32447     498.54 -16176127.38              D        S
# 3        -19650     497.54  -9776661.00              D        S
# 4        -30814     496.45 -15297610.30              D        S
# ..          ...        ...          ...            ...      ...
# 116       45700        NaN          NaN              D        A
# 117       45700        NaN          NaN              D        A
# 118       45700        NaN          NaN              D        A
# 119       45700        NaN          NaN              D        A
# 120        9140        NaN          NaN              D        A
#
# [121 rows x 8 columns]

# %% [markdown]
# ## Institutional Ownership

# %%
c.institutionalOwnership(symbol)
# Out:
# [{'reportDate': 1593475200000,
#   'entityProperName': 'Vanguard Group, Inc. (Subfiler)',
#   'adjHolding': 308791855,
#   'reportedHolding': 308791855,
#   'adjMv': 112647268704},
#  {'reportDate': 1593475200000,
#   'entityProperName': 'Berkshire Hathaway, Inc.',
#   'adjHolding': 245155566,
#   'reportedHolding': 245155566,
#   'adjMv': 89432750477},
#  {'reportDate': 1593475200000,
#   'entityProperName': 'State Street Corp.',
#   'adjHolding': 177264368,
#   'reportedHolding': 177264368,
#   'adjMv': 64666041446},
#  {'reportDate': 1593475200000,
#   'entityProperName': 'BlackRock Institutional Trust Co. NA',
#   'adjHolding': 100014743,
#   'reportedHolding': 100014743,
#   'adjMv': 36485378246},
#  {'reportDate': 1593475200000,
#   'entityProperName': 'Fidelity Management & Research Co. LLC',
#   'adjHolding': 88024424,
#   'reportedHolding': 88024424,
#   'adjMv': 32111309875},
#  {'reportDate': 1593475200000,
#   'entityProperName': 'BlackRock Fund Advisors',
#   'adjHolding': 87415880,
#   'reportedHolding': 87415880,
#   'adjMv': 31889313024},
#  {'reportDate': 1593475200000,
#   'entityProperName': 'Geode Capital Management LLC',
#   'adjHolding': 62923854,
#   'reportedHolding': 62923854,
#   'adjMv': 22954621939},
#  {'reportDate': 1593475200000,
#   'entityProperName': 'T. Rowe Price Associates, Inc. (Investment Management)',
#   'adjHolding': 58271885,
#   'reportedHolding': 58271885,
#   'adjMv': 21257583648},
#  {'reportDate': 1593475200000,
#   'entityProperName': 'Northern Trust Corp.',
#   'adjHolding': 53536023,
#   'reportedHolding': 53536023,
#   'adjMv': 19529941190},
#  {'reportDate': 1577750400000,
#   'entityProperName': 'Norges Bank (13F)',
#   'adjHolding': 46856273,
#   'reportedHolding': 46856273,
#   'adjMv': 13759344566}]

# %%
c.institutionalOwnershipDF(symbol)
# Out:
#   reportDate                                   entityProperName  adjHolding  \
# 0 2020-06-30                    Vanguard Group, Inc. (Subfiler)   308791855
# 1 2020-06-30                           Berkshire Hathaway, Inc.   245155566
# 2 2020-06-30                                 State Street Corp.   177264368
# 3 2020-06-30               BlackRock Institutional Trust Co. NA   100014743
# 4 2020-06-30             Fidelity Management & Research Co. LLC    88024424
# 5 2020-06-30                            BlackRock Fund Advisors    87415880
# 6 2020-06-30                       Geode Capital Management LLC    62923854
# 7 2020-06-30  T. Rowe Price Associates, Inc. (Investment Man...    58271885
# 8 2020-06-30                               Northern Trust Corp.    53536023
# 9 2019-12-31                                  Norges Bank (13F)    46856273
#
#    reportedHolding         adjMv
# 0        308791855  112647268704
# 1        245155566   89432750477
# 2        177264368   64666041446
# 3        100014743   36485378246
# 4         88024424   32111309875
# 5         87415880   31889313024
# 6         62923854   22954621939
# 7         58271885   21257583648
# 8         53536023   19529941190
# 9         46856273   13759344566

# %% [markdown]
# ## Intraday Prices

# %%
c.intraday(symbol)[:5]
# Out:
# [{'date': '2020-09-04',
#   'minute': '09:30',
#   'label': '09:30 AM',
#   'high': 120.32,
#   'low': 118.46,
#   'average': 119.556,
#   'volume': 32034,
#   'notional': 3829861.055,
#   'numberOfTrades': 384,
#   'marketHigh': 120.36,
#   'marketLow': 118.38,
#   'marketAverage': 119.799,
#   'marketVolume': 6673485,
#   'marketNotional': 799479125.7419,
#   'marketNumberOfTrades': 13190,
#   'open': 120.07,
#   'close': 120.285,
#   'marketOpen': 120.07,
#   'marketClose': 120.349,
#   'changeOverTime': 0,
#   'marketChangeOverTime': 0},
#  {'date': '2020-09-04',
#   'minute': '09:31',
#   'label': '09:31 AM',
#   'high': 121.7,
#   'low': 120.395,
#   'average': 121.363,
#   'volume': 83775,
#   'notional': 10167183.83,
#   'numberOfTrades': 135,
#   'marketHigh': 121.73,
#   'marketLow': 120.334,
#   'marketAverage': 121.052,
#   'marketVolume': 1646915,
#   'marketNotional': 199362208.3096,
#   'marketNumberOfTrades': 6815,
#   'open': 120.41,
#   'close': 121.7,
#   'marketOpen': 120.36,
#   'marketClose': 121.65,
#   'changeOverTime': 0.015114256080832432,
#   'marketChangeOverTime': 0.010459185802886501},
#  {'date': '2020-09-04',
#   'minute': '09:32',
#   'label': '09:32 AM',
#   'high': 122.6,
#   'low': 121,
#   'average': 121.544,
#   'volume': 64282,
#   'notional': 7813110.375,
#   'numberOfTrades': 106,
#   'marketHigh': 122.62,
#   'marketLow': 121,
#   'marketAverage': 121.839,
#   'marketVolume': 1560264,
#   'marketNotional': 190101142.8383,
#   'marketNumberOfTrades': 6600,
#   'open': 121.63,
#   'close': 122.6,
#   'marketOpen': 121.65,
#   'marketClose': 122.58,
#   'changeOverTime': 0.016628190973267756,
#   'marketChangeOverTime': 0.017028522775649146},
#  {'date': '2020-09-04',
#   'minute': '09:33',
#   'label': '09:33 AM',
#   'high': 122.9,
#   'low': 122.24,
#   'average': 122.533,
#   'volume': 128370,
#   'notional': 15729527.675,
#   'numberOfTrades': 356,
#   'marketHigh': 122.99,
#   'marketLow': 122.17,
#   'marketAverage': 122.59,
#   'marketVolume': 1594271,
#   'marketNotional': 195442080.3421,
#   'marketNumberOfTrades': 6589,
#   'open': 122.595,
#   'close': 122.62,
#   'marketOpen': 122.59,
#   'marketClose': 122.644,
#   'changeOverTime': 0.02490046505403329,
#   'marketChangeOverTime': 0.023297356405312202},
#  {'date': '2020-09-04',
#   'minute': '09:34',
#   'label': '09:34 AM',
#   'high': 122.62,
#   'low': 121.775,
#   'average': 122.344,
#   'volume': 22885,
#   'notional': 2799842.39,
#   'numberOfTrades': 181,
#   'marketHigh': 122.66,
#   'marketLow': 121.7,
#   'marketAverage': 122.281,
#   'marketVolume': 1278043,
#   'marketNotional': 156280780.3117,
#   'marketNumberOfTrades': 5184,
#   'open': 122.53,
#   'close': 121.82,
#   'marketOpen': 122.61,
#   'marketClose': 121.84,
#   'changeOverTime': 0.023319615912208477,
#   'marketChangeOverTime': 0.020718036043706534}]

# %%
c.intradayDF(symbol).head()
# Out:
#                       label    high      low  average  volume      notional  \
# date       minute
# 2020-09-04 09:30   09:30 AM  120.32  118.460  119.556   32034  3.829861e+06
#            09:31   09:31 AM  121.70  120.395  121.363   83775  1.016718e+07
#            09:32   09:32 AM  122.60  121.000  121.544   64282  7.813110e+06
#            09:33   09:33 AM  122.90  122.240  122.533  128370  1.572953e+07
#            09:34   09:34 AM  122.62  121.775  122.344   22885  2.799842e+06
#
#                    numberOfTrades  marketHigh  marketLow  marketAverage  \
# date       minute
# 2020-09-04 09:30              384      120.36    118.380        119.799
#            09:31              135      121.73    120.334        121.052
#            09:32              106      122.62    121.000        121.839
#            09:33              356      122.99    122.170        122.590
#            09:34              181      122.66    121.700        122.281
#
#                    marketVolume  marketNotional  marketNumberOfTrades  \
# date       minute
# 2020-09-04 09:30        6673485    7.994791e+08                 13190
#            09:31        1646915    1.993622e+08                  6815
#            09:32        1560264    1.901011e+08                  6600
#            09:33        1594271    1.954421e+08                  6589
#            09:34        1278043    1.562808e+08                  5184
#
#                       open    close  marketOpen  marketClose  changeOverTime  \
# date       minute
# 2020-09-04 09:30   120.070  120.285      120.07      120.349        0.000000
#            09:31   120.410  121.700      120.36      121.650        0.015114
#            09:32   121.630  122.600      121.65      122.580        0.016628
#            09:33   122.595  122.620      122.59      122.644        0.024900
#            09:34   122.530  121.820      122.61      121.840        0.023320
#
#                    marketChangeOverTime
# date       minute
# 2020-09-04 09:30               0.000000
#            09:31               0.010459
#            09:32               0.017029
#            09:33               0.023297
#            09:34               0.020718

# %% [markdown]
# ## IPO Calendar

# %%
c.ipoToday()
# Out:
# {'rawData': [{'symbol': 'FTOCU',
#    'companyName': 'FTAC OLYMPUS ACQUISITION CORP.',
#    'expectedDate': '2020-08-26',
#    'leadUnderwriters': ['Cantor Fitzgerald & Co.',
#     'Citigroup Global Markets Inc'],
#    'underwriters': [],
#    'companyCounsel': ['Ledgewood, P.C'],
#    'underwriterCounsel': ['Ellenoff Grossman & Schole LLP'],
#    'auditor': 'Continental Stock Transfer & Trust Company',
#    'market': 'NASDAQ Capital',
#    'cik': '0001816090',
#    'address': '2929 ARCH STREET STE 1703',
#    'city': 'PHILADELPHIA',
#    'state': 'PA',
#    'zip': '19104',
#    'phone': '(484) 459-3476',
#    'ceo': 'Ryan M. Gilbert',
#    'employees': 3,
#    'url': '',
#    'status': 'Filed',
#    'sharesOffered': 75000000,
#    'priceLow': 10,
#    'priceHigh': None,
#    'offerAmount': None,
#    'totalExpenses': 1400000,
#    'sharesOverAlloted': 0,
#    'shareholderShares': None,
#    'sharesOutstanding': 96462500,
#    'lockupPeriodExpiration': '',
#    'quietPeriodExpiration': '',
#    'revenue': 0,
#    'netIncome': -5015,
#    'totalAssets': 76674,
#    'totalLiabilities': 56689,
#    'stockholderEquity': 19985,
#    'companyDescription': 'We are a newly incorporated blank check company incorporated on June 2, 2020 as &#10; a Cayman Islands exempted company and incorporated for the purpose of effecting &#10; a merger, share exchange, asset acquisition, share purchase, reorganization or &#10; other similar business combination, involving one or more businesses or assets, &#10; which we refer to throughout this prospectus as our initial business &#10; combination. To date, our efforts have been limited to organizational activities &#10; as well as activities related to this offering. We have not identified any &#10; acquisition target and we have not, nor has anyone on our behalf, initiated any &#10; discussions, directly or indirectly, with respect to identifying any acquisition &#10; target. We have generated no operating revenues to date and we do not expect &#10; that we will generate operating revenues until we consummate our initial &#10; business combination. &#10;  &#10; We currently intend to concentrate our efforts on identifying technology and &#10; financial services technology, or fintech, companies that power transformation &#10; and innovation. Our expertise lends itself well to pursuing platforms related to &#10; the financial services, real estate, insurance, ecommerce and related technology &#10; infrastructure sectors, but we are not required to complete our initial business &#10; combination with a business in these industries and, as a result, we may pursue &#10; a business combination outside of these industries. We expect to pursue global &#10; businesses but may also acquire a domestic company. We do not intend to acquire &#10; companies that have speculative business plans or are excessively leveraged. &#10; --- &#10;  &#10; We are a Cayman Islands exempted company incorporated on June 2, 2020. Our &#10; executive offices are located at 2929 Arch Street, Suite 1703, Philadelphia, PA &#10; 19104, and our telephone number is (215) 701-9555.',
#    'businessDescription': 'We are a newly incorporated blank check company incorporated on June 2, 2020 as &#10; a Cayman Islands exempted company and incorporated for the purpose of effecting &#10; a merger, share exchange, asset acquisition, share purchase, reorganization or &#10; other similar business combination, involving one or more businesses or assets, &#10; which we refer to throughout this prospectus as our initial business &#10; combination. To date, our efforts have been limited to organizational activities &#10; as well as activities related to this offering. We have not identified any &#10; acquisition target and we have not, nor has anyone on our behalf, initiated any &#10; discussions, directly or indirectly, with respect to identifying any acquisition &#10; target. We have generated no operating revenues to date and we do not expect &#10; that we will generate operating revenues until we consummate our initial &#10; business combination. &#10;  &#10; We currently intend to concentrate our efforts on identifying technology and &#10; financial services technology, or fintech, companies that power transformation &#10; and innovation. Our expertise lends itself well to pursuing platforms related to &#10; the financial services, real estate, insurance, ecommerce and related technology &#10; infrastructure sectors, but we are not required to complete our initial business &#10; combination with a business in these industries and, as a result, we may pursue &#10; a business combination outside of these industries. We expect to pursue global &#10; businesses but may also acquire a domestic company. We do not intend to acquire &#10; companies that have speculative business plans or are excessively leveraged. &#10;  &#10; We believe our management team has the skills and experience to identify, &#10; evaluate and consummate a business combination and is positioned to assist &#10; businesses we acquire. However, our management team’s network and investing and &#10; operating experience do not guarantee a successful initial business combination. &#10; The members of our management team are not required to devote any significant &#10; amount of time to our business and are concurrently involved with other &#10; businesses. There is no guarantee that our current officers and directors will &#10; continue in their respective roles, or in any other role, after our initial &#10; business combination, and their expertise may only be of benefit to us until our &#10; initial business combination is completed. Past performance by our management &#10; team is not a guarantee of success with respect to any business combination we &#10; may consummate. &#10; --- &#10;  &#10; We are a Cayman Islands exempted company incorporated on June 2, 2020. Our &#10; executive offices are located at 2929 Arch Street, Suite 1703, Philadelphia, PA &#10; 19104, and our telephone number is (215) 701-9555.',
#    'useOfProceeds': 'We are offering 75,000,000 units at an offering price of $10.00 per unit. We &#10; estimate that the net proceeds of this offering together with the funds we will &#10; receive from the sale of the placement units will be used as set forth in the &#10; following table. &#10;  &#10;                                                            Without         Over-Allotment  &#10;                                                         Over-Allotment         Option      &#10;                                                             Option           Exercised     &#10; Gross proceeds                                                                             &#10; Gross proceeds from units offered to public(1)         $  750,000,000     $  862,500,000   &#10; Gross proceeds from placement units offered in the                                        &#10; private placement                                          21,700,000         21,700,000   &#10; Total gross proceeds                                   $  771,700,000     $  884,200,000   &#10;                                                                                            &#10; Offering expenses(2)                                                                       &#10; Underwriting commissions (2% of gross proceeds from                                       &#10; units offered to public, excluding deferred                                               &#10; portion)(3)                                            $   15,000,000     $   15,000,000   &#10; Legal fees and expenses                                       350,000            350,000   &#10; Accounting fees and expenses                                   45,000             45,000   &#10; SEC/FINRA Expenses                                            241,828            241,828   &#10; Travel and road show                                           20,000             20,000   &#10; NASDAQ listing and filing fees                                 75,000             75,000   &#10; Director and Officer liability insurance premiums             300,000            300,000   &#10; Printing and engraving expenses                                40,000             40,000   &#10; Miscellaneous(4)                                              328,172            328,172   &#10; Total offering expenses (other than underwriting                                          &#10; commissions)                                           $    1,400,000     $    1,400,000   &#10; Proceeds after offering expenses                       $  755,300,000     $  867,800,000   &#10; Held in trust account(3)                               $  750,000,000     $  862,500,000   &#10; % of public offering size                                         100 %              100 % &#10; Not held in trust account(2)                           $    5,300,000     $    5,300,000  &#10;  &#10; The following table shows the use of the approximately $5,300,000 of net &#10; proceeds not held in the trust account(5). &#10;  &#10;                                                           Amount       % of Total   &#10; Legal, accounting, due diligence, travel, and other                                &#10; expenses in connection with any business                                           &#10; combination(6)                                         $  4,000,000          75.5 % &#10; Legal and accounting fees related to regulatory                                    &#10; reporting obligations                                       250,000           4.7 % &#10; Payment for office space, administrative and shared                                &#10; personnel support services ($25,000 per month for up                               &#10; to 24 months)                                               600,000          11.3 % &#10; Reserve for liquidation expenses                            100,000           1.9 % &#10; NASDAQ continued listing fees                 ...
#    'competition': 'In identifying, evaluating and selecting a target business for our initial &#10; business combination, we may encounter intense competition from other entities &#10; having a business objective similar to ours, including other blank check &#10; companies, private equity groups and leveraged buyout funds, and operating &#10; businesses seeking strategic acquisitions. Many of these entities are well &#10; established and have extensive experience identifying and effecting business &#10; combinations directly or through affiliates. Moreover, many of these competitors &#10; possess greater financial, technical, human and other resources than us. Our &#10; ability to acquire larger target businesses will be limited by our available &#10; financial resources. This inherent limitation gives others an advantage in &#10; pursuing the acquisition of a target business. Furthermore, our obligation to &#10; pay cash in connection with our public shareholders who exercise their &#10; redemption rights may reduce the resources available to us for our initial &#10; business combination and our outstanding warrants, and the future dilution they &#10; potentially represent, may not be viewed favorably by certain target businesses. &#10; This may make it more difficult for us to consummate an initial business &#10; combination with a target business. Any of these factors may place us at a &#10; competitive disadvantage in successfully negotiating an initial business &#10; combination.',
#    'amount': 375000000,
#    'percentOffered': '77.75'}],
#  'viewData': [{'Company': 'FTAC OLYMPUS ACQUISITION CORP.',
#    'Symbol': 'FTOCU',
#    'Price': '$10.00',
#    'Shares': '75,000,000',
#    'Amount': '375,000,000',
#    'Float': '96,462,500',
#    'Percent': '77.75%',
#    'Market': 'NASDAQ Capital',
#    'Expected': '2020-08-26',
#    'quote': {'latestPrice': 10.01, 'changePercent': 0.0009999999999999788}}],
#  'lastUpdate': '2020-08-26'}

# %%
c.ipoTodayDF()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pyEX/stocks/marketInfo.py:139: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   df = pd.io.json.json_normalize(val, 'rawData')
#                            companyName expectedDate  \
# symbol
# FTOCU   FTAC OLYMPUS ACQUISITION CORP.   2020-08-26
#
#                                          leadUnderwriters underwriters  \
# symbol
# FTOCU   [Cantor Fitzgerald & Co., Citigroup Global Mar...           []
#
#           companyCounsel                underwriterCounsel  \
# symbol
# FTOCU   [Ledgewood, P.C]  [Ellenoff Grossman & Schole LLP]
#
#                                            auditor          market  \
# symbol
# FTOCU   Continental Stock Transfer & Trust Company  NASDAQ Capital
#
#                cik                    address  ... netIncome totalAssets  \
# symbol                                         ...
# FTOCU   0001816090  2929 ARCH STREET STE 1703  ...     -5015       76674
#
#        totalLiabilities stockholderEquity  \
# symbol
# FTOCU             56689             19985
#
#                                        companyDescription  \
# symbol
# FTOCU   We are a newly incorporated blank check compan...
#
#                                       businessDescription  \
# symbol
# FTOCU   We are a newly incorporated blank check compan...
#
#                                             useOfProceeds  \
# symbol
# FTOCU   We are offering 75,000,000 units at an offerin...
#
#                                               competition     amount  \
# symbol
# FTOCU   In identifying, evaluating and selecting a tar...  375000000
#
#         percentOffered
# symbol
# FTOCU            77.75
#
# [1 rows x 39 columns]

# %%
c.ipoUpcoming()
# Out:
# {'rawData': [{'symbol': 'XPEV',
#    'companyName': 'XPENG INC.',
#    'expectedDate': '2020-08-27',
#    'leadUnderwriters': ['BofA Securities, Inc',
#     'Credit Suisse Securities (USA) LLC',
#     'J.P. Morgan Securities LLC'],
#    'underwriters': ['ABCI Securities Company Limited',
#     'BOCI Asia Limited',
#     'Futu Inc',
#     'Haitong International Securities Company Limited',
#     'Tiger Brokers (NZ) Limited'],
#    'companyCounsel': ['Simpson Thacher & Bartlett LLP'],
#    'underwriterCounsel': ['Latham & Watkins LLP'],
#    'auditor': 'Not Specified',
#    'market': 'NYSE',
#    'cik': '0001810997',
#    'address': 'NO. 8 SONGGANG ROAD, CHANGXING STREET',
#    'city': 'GUANGZHOU, GUANGDONG 510640',
#    'state': '',
#    'zip': '',
#    'phone': '86-020-6680-6680',
#    'ceo': 'Xiaopeng He',
#    'employees': 3676,
#    'url': 'www.xiaopeng.com',
#    'status': 'Filed',
#    'sharesOffered': 85000000,
#    'priceLow': 11,
#    'priceHigh': 13,
#    'offerAmount': None,
#    'totalExpenses': 7235000,
#    'sharesOverAlloted': 12750000,
#    'shareholderShares': None,
#    'sharesOutstanding': 85000000,
#    'lockupPeriodExpiration': '',
#    'quietPeriodExpiration': '',
#    'revenue': 141944000,
#    'netIncome': -112639000,
#    'totalAssets': 1319847000,
#    'totalLiabilities': 941359000,
#    'stockholderEquity': -1263173000,
#    'companyDescription': 'Mission &#10;  &#10; Driving Smart EV transformation with technology and data, shaping the mobility &#10; experience of the future. &#10;  &#10; We are one of China’s leading smart electric vehicle, or Smart EV, companies. We &#10; design, develop, manufacture and market Smart EVs in China. Xpeng was founded in &#10; 2015 with a vision to bring Smart EVs to Chinese consumers through innovation in &#10; autonomous driving, smart connectivity and core vehicle systems. Today, we are a &#10; proven leader in the rapidly growing Smart EV market, producing popular and &#10; environmentally-friendly vehicles, namely an SUV (the G3) and a four-door sports &#10; sedan (the P7). Our Smart EVs offer attractive design and high performance, &#10; coupled with safety and reliability. According to the IHS Markit Report, the G3 &#10; was among the top-three best-selling electric SUVs in China in 2019. The P7 &#10; offers an NEDC range of up to 706 km (439 miles) on a single charge, which is &#10; the longest among EVs that are available in China, based on the MIIT NEV &#10; Catalogues. &#10; --- &#10;  &#10; Our principal executive offices are located at No. 8 Songgang Road, Changxing &#10; Street, Cencun, Tianhe District, Guangzhou, Guangdong 510640, People’s Republic &#10; of China. Our telephone number at this address is +86-020-6680-6680. Our &#10; registered office in the Cayman Islands is located at the offices of Harneys &#10; Fiduciary (Cayman) Limited, 4th Floor, Harbour Place, 103 South Church Street, &#10; P.O. Box 10240, Grand Cayman KY1-1002, Cayman Islands. Our main website is &#10; www.xiaopeng.com.   &#10;  &#10; Our agent for service of process in the United States is Cogency Global Inc., &#10; located at 122 East 42nd Street, 18th Floor, New York, N.Y. 10168.',
#    'businessDescription': 'Mission &#10;  &#10; Driving Smart EV transformation with technology and data, shaping the mobility &#10; experience of the future.   &#10;  &#10; We are one of China’s leading smart electric vehicle, or Smart EV, companies. We &#10; design, develop, manufacture and market Smart EVs in China. Xpeng was founded in &#10; 2015 with a vision to bring Smart EVs to Chinese consumers through innovation in &#10; autonomous driving, smart connectivity and core vehicle systems. Today, we are a &#10; proven leader in the rapidly growing Smart EV market, producing popular and &#10; environmentally-friendly vehicles, namely an SUV (the G3) and a four-door sports &#10; sedan (the P7). Our Smart EVs offer attractive design and high performance, &#10; coupled with safety and reliability. According to the IHS Markit Report, the G3 &#10; was among the top-three best-selling electric SUVs in China in 2019. The P7 &#10; offers an NEDC range of up to 706 km (439 miles) on a single charge, which is &#10; the longest among EVs that are available in China, based on the MIIT NEV &#10; Catalogues. &#10;  &#10; Our Smart EVs appeal to the large and growing base of technology-savvy &#10; middle-class consumers in China. We primarily target the mid- to high-end &#10; segment in China’s passenger vehicle market, with prices ranging from RMB150,000 &#10; to RMB300,000, for our Smart EVs. According to the IHS Markit Report, the mid- &#10; to high-end segment represented 30.6% of China’s passenger vehicle market by &#10; sales volume in 2019 and had a higher EV penetration rate than other price &#10; segments. Consumers choose our products primarily because of attractive design, &#10; smart mobility experience, advanced technology and compelling value proposition. &#10; As of June 30, 2020, over 90% of purchasers of the G3 chose the versions with &#10; autonomous driving capabilities. As of the same date, approximately 50% of &#10; customers ordered the versions of the P7 that can support XPILOT 3.0, our &#10; upcoming advanced autonomous driving system. &#10;  &#10; In order to optimize our customers’ mobility experience, we have strategically &#10; chosen to focus on developing full-stack autonomous driving technology and &#10; in-car intelligent operating system, as well as core vehicle systems, including &#10; powertrain and the electrical and electronic architecture, or the E/E &#10; architecture, in-house. According to the IHS Markit Report, our XPILOT 3.0 is &#10; expected to offer the highest level of autonomous driving capabilities in &#10; commercially available passenger vehicles today. Through our proprietary &#10; software, core hardware and data technologies, we are able to develop and deploy &#10; innovative products rapidly and efficiently, which gives us an advantage over &#10; our competitors in China.  &#10;  &#10; We started production of the G3 in November 2018, and as of July 31, 2020, we &#10; had delivered 18,741 units of the G3 to customers. We started production of the &#10; P7 and began delivery in May 2020, and as of July 31, 2020, we had delivered &#10; 1,966 units of the P7 to customers. We plan to launch our third Smart EV, a &#10; sedan, in 2021. The table below sets forth certain features of the G3 and the  &#10; P7. &#10; --- &#10;  &#10; Model                       G3 (SUV)                  P7 (Sports Sedan)   &#10;      &#10; Wheelbase (mm)              2,625                     2,998                   &#10; NEDC range (km)             460 / 520                 562 / 586 / 670 / 706   &#10; Battery capacity (kWh)      57.5 / 66.7               70.8 / 80.9             &#10; 0-100km/hacceleration (s)   8.6                       4.4 / 6.8 / 6.9(1)      &#10; Post-subsidy price (RMB)    146,800 – 199,800         229,900 – 349,900(2)    &#10;  &#10; (1) The P7’s four-wheel drive, rear-wheel drive super long range and rear-wheel   &#10;     drive long range configurations can accelerate from zero to 100 ...
#    'useOfProceeds': 'We estimate that we will receive net proceeds from this offering of &#10; approximately US$972.0 million, or approximately US$1,118.8 million if the &#10; underwriters exercise their over-allotment option in full, after deducting &#10; underwriting discounts and commissions and the estimated offering expenses &#10; payable by us and based upon an assumed initial public offering price of &#10; US$12.00 per ADS (the mid-point of the estimated initial public offering price &#10; range shown on the front cover of this prospectus). A US$1.00 increase &#10; (decrease) in the assumed initial public offering price of US$12.00 per ADS &#10; would increase (decrease) the net proceeds to us from this offering by US$81.6 &#10; million, after deducting the estimated underwriting discounts and commissions &#10; and estimated aggregate offering expenses payable by us and assuming no change &#10; to the number of ADSs offered by us as set forth on the cover page of this &#10; prospectus. &#10;  &#10; We plan to use the net proceeds of this offering as follows: &#10;  &#10; • 50% of the net proceeds (approximately US$486.0 million) for research and &#10;   development of our Smart EVs and technologies;                            &#10;  &#10; • 30% of the net proceeds (approximately US$291.6 million) for selling and  &#10;   marketing and expansion of sales channels; and                            &#10;  &#10; • 20% of the net proceeds (approximately US$194.4 million) for general      &#10;   corporate purposes, including working capital needs.                      &#10;  &#10; The foregoing represents our intentions as of the date of this prospectus with &#10; respect of the use and allocation of the net proceeds of this offering based &#10; upon our present plans and business conditions, but our management will have &#10; significant flexibility and discretion in applying the net proceeds of the &#10; offering. The occurrence of unforeseen events or changed business conditions may &#10; result in application of the proceeds of this offering in a manner other than as &#10; described in this prospectus. &#10;  &#10; To the extent that the net proceeds we receive from this offering are not &#10; immediately applied for the above purposes, we intend to invest our net proceeds &#10; in short-term, interest bearing, debt instruments or bank deposits. &#10;  &#10; In utilizing the proceeds of this offering, we, as an offshore holding company, &#10; are permitted under PRC laws and regulations to provide funding to our PRC &#10; subsidiaries only through loans or capital contributions and to our consolidated &#10; VIEs only through loans. Subject to satisfaction of applicable government &#10; registration and approval requirements, we may extend inter-company loans to our &#10; PRC subsidiaries or make additional capital contributions to our PRC &#10; subsidiaries to fund their capital expenditures or working capital. We cannot &#10; assure you that we will be able to obtain these government registrations or &#10; approvals on a timely basis, if at all.',
#    'competition': 'We have strategically focused on offering Smart EVs for the mid- to high-end &#10; segment of China’s passenger vehicle market. We directly compete with other &#10; pure-play EV companies, especially those targeting the mid- to high-end segment. &#10; To a lesser extent, our Smart EVs also compete with ICE vehicles in the mid- to &#10; high-end segment offered by traditional OEMs. Furthermore, traditional OEMs that &#10; have strong brand recognition, substantial financial resources, sophisticated &#10; engineering capabilities and established sales channels may shift their focus &#10; towards the EV market in the future. We believe that our competitive advantage &#10; over existing and potential competitors lies in our innovative product offerings &#10; localized for Chinese consumers, ability to offer a great-to-drive and &#10; great-to-be-drivenexperience, deep software, hardware and data technologies, &#10; innovative software and content subscription model, scalable and efficient &#10; platforms and winning team for Smart EV.',
#    'amount': 1020000000,
#    'percentOffered': '100.00'},
#   {'symbol': 'AUVI',
#    'companyName': 'APPLIED UV, INC.',
#    'expectedDate': '2020-08-27',
#    'leadUnderwriters': ['Network 1 Financial Securities, Inc.'],
#    'underwriters': [],
#    'companyCounsel': ['Carmel, Milazzo & Feil LLP'],
#    'underwriterCounsel': ['Gordon Rees Scully & Mansukhani LLP'],
#    'auditor': 'VStock Transfer, LLC',
#    'market': 'NASDAQ Capital',
#    'cik': '0001811109',
#    'address': '150 N. MACQUESTEN PKWY',
#    'city': 'MOUNT VERNON',
#    'state': 'NY',
#    'zip': '10550',
#    'phone': '(929) 207-3751',
#    'ceo': 'Keyoumars Saeed',
#    'employees': 26,
#    'url': 'www.applieduvinc.com',
#    'status': 'Filed',
#    'sharesOffered': 1000000,
#    'priceLow': 5,
#    'priceHigh': None,
#    'offerAmount': None,
#    'totalExpenses': 290000,
#    'sharesOverAlloted': 150000,
#    'shareholderShares': None,
#    'sharesOutstanding': 6393129,
#    'lockupPeriodExpiration': '',
#    'quietPeriodExpiration': '',
#    'revenue': 2932428,
#    'netIncome': -319139,
#    'totalAssets': 4460491,
#    'totalLiabilities': 2785428,
#    'stockholderEquity': 1675063,
#    'companyDescription': 'The Company was formed on February 26, 2019, for the purpose of acquiring all of &#10; the equity of SteriLumen and Munn Works. The Company acquired all of the capital &#10; stock of SteriLumen in March of 2019. The Company acquired all of the membership &#10; interests of Munn Works in July of 2019. The Company conducts all of its &#10; operations through SteriLumen and Munn Works.  &#10;  &#10; SteriLumen. SteriLumen was incorporated on December 8, 2016 in New York for the &#10; purpose of developing, designing and manufacturing disinfection systems, that &#10; eliminate pathogens that may cause healthcare-acquired infections (“HAIs”), for &#10; distribution and sale to facilities that have high customer or patient turnover &#10; such as hospitals, assisted living facilities, doctors’ offices and walk-in &#10; clinics as well as hotels, cruise lines, airplanes, schools, government &#10; buildings, commercial offices and other facilities that offer access to the &#10; public. SteriLumen has developed, designed and manufactured a unique, patented &#10; and automated disinfecting system that will be embedded into certain bathroom &#10; fixtures (in each case, a “SteriLumen Disinfecting System”), which we believe &#10; will be effective in reducing HAIs caused by viruses, bacteria, fungi, and other &#10; pathogens, including SARS-CoV-2, the virus that causes COVID-19 (referred to &#10; herein as the “Coronavirus”) and human coronaviruses in general. The SteriLumen &#10; Disinfecting System currently has five product lines: (i) disinfecting back-lit &#10; mirror that replaces the typical mirror (and wall lighting) found above the sink &#10; in a public facility bathroom; (ii) disinfecting drain device; (iii) &#10; disinfecting shelf that would be installed above the sink in cases where there &#10; is not enough room for a bathroom mirror or beneath an existing bathroom mirror; &#10; (iv) disinfecting mirrored medicine cabinet for residential use and (v) retrofit &#10; kit. The Company has received confirmation from the U.S. Food & Drug &#10; Administration that the SteriLumen Disinfecting System is not a “device” under &#10; Section 201(h) of the Federal Food, Drug, and Cosmetic Act (the “FDA Act”) and &#10; therefore the Company is not required to comply with the requirements of the FDA &#10; Act. &#10; --- &#10;  &#10; Munn Works. Munn Works was formed on November 9, 2012, as a New York limited &#10; liability company. It manufactures and supplies custom designed decorative &#10; framed mirrors, framed art, and bathroom vanities primarily to the hospitality &#10; market. Max Munn, the President of Applied UV, is also the Chief Executive &#10; Officer of Munn Works and has been involved in related businesses for over 35 &#10; years. Munn Works manufactures its products domestically and overseas. Its &#10; domestic manufacturing operations are located in its headquarters in Mount &#10; Vernon, New York. Munn Works supplies the major hotel brands in North America &#10; with its products. These brands include Hilton Hotels & Resorts, the various &#10; Hyatt branded hotels, the various Marriott branded hotels, Four Seasons Hotels &#10; and Resorts and the subsidiary hotel brands for each of these major brands. Munn &#10; Works has a national sales force and an established distribution network for &#10; hotels and restaurants in every major market in the United States and has begun &#10; to develop a distribution network for the assisted living market. These &#10; distribution networks will also be a significant asset for SteriLumen, as those &#10; networks will be utilized for the marketing and sales of the SteriLumen &#10; Disinfecting System. Additionally, Munn Works advertises its products in hotel &#10; design magazines and participates in major national trade shows. During the last &#10; three years, Munn Works has significantly expanded its sales force, including &#10; hiring a vice president of sales ...
#    'businessDescription': 'The Company was formed on February 26, 2019, for the purpose of acquiring all of &#10; the equity of SteriLumen and Munn Works. The Company acquired all of the capital &#10; stock of SteriLumen in March of 2019 pursuant to two exchange agreements in &#10; which the shareholders of SteriLumen exchanged all of their shares in SteriLumen &#10; for shares of common stock in the Company. The Company acquired all of the &#10; membership interests of Munn Works in July of 2019 pursuant to an exchange &#10; agreement in exchange for shares of common stock in the Company. The Company &#10; conducts all of its operations through SteriLumen and Munn Works.  &#10;  &#10; SteriLumen. SteriLumen was incorporated on December 8, 2016 in New York for the &#10; purpose of developing, designing and manufacturing disinfection systems, that &#10; eliminate pathogens that may cause healthcare-acquired infections (“HAIs”), for &#10; distribution and sale to facilities that have high customer or patient turnover &#10; such as hospitals, assisted living facilities, doctors’ offices and walk-in &#10; clinics as well as hotels, cruise lines, airplanes, schools, government &#10; buildings, commercial offices and other facilities that offer access to the &#10; public. SteriLumen has developed, designed and manufactured a unique, patented &#10; and automated disinfecting system that will be embedded into certain bathroom &#10; fixtures (in each case, a “SteriLumen Disinfecting System”), which we believe &#10; will be effective in reducing HAIs caused by viruses, bacteria, fungi, and other &#10; pathogens, including SARS-CoV-2, the virus that causes COVID-19 (referred to &#10; herein as the “Coronavirus”) and human coronaviruses in general. The SteriLumen &#10; Disinfecting System currently has five product lines: (i) disinfecting back-lit &#10; mirror that replaces the typical mirror (and wall lighting) found above the sink &#10; in a public facility bathroom; (ii) disinfecting drain device; (iii) &#10; disinfecting shelf that would be installed above the sink in cases where there &#10; is not enough room for a bathroom mirror or beneath an existing bathroom mirror; &#10; (iv) disinfecting mirrored medicine cabinet for residential use and (v) retrofit &#10; kit. The Company has received confirmation from the U.S. Food & Drug &#10; Administration that the SteriLumen Disinfecting System is not a “device” under &#10; Section 201(h) of the Federal Food, Drug, and Cosmetic Act (the “FDA Act”) and &#10; therefore the Company is not required to comply with the requirements of the FDA &#10; Act. &#10;  &#10; The SteriLumen Disinfecting System has previously been submitted to ResInnova &#10; Laboratories (“ResInnova”), a laboratory that tests products that reduce &#10; pathogens on solid and porous surfaces, for an analysis of its effectiveness in &#10; killing certain pathogens such as Clostridium difficile spores (“C diff”), &#10; Escherichia coli (“E coli”) and Staphylococcus aureus (“MRSA”). ResInnova &#10; provided SteriLumen with their findings in a report dated September 8, 2017, &#10; which were updated on May 8, 2020 (the “Initial ResInnova Report”) which found &#10; the SteriLumen Disinfecting System to be effective in dramatically reducing &#10; pathogens in the bathroom vanity/sink area. In a Report dated June 30, 2020, &#10; ResInnova found the SteriLumen Disinfecting System to be effective in killing &#10; OC43 human coronavirus (“OC43”), which according to ResInnova is a common &#10; surrogate for SARS-CoV-2. The ResInnova study did not test the SteriLumen &#10; Disinfecting System against SARS-CoV-2. Furthermore, SteriLumen has an agreement &#10; (the “Mount Sinai Agreement”) with Icahn School of Medicine at Mount Sinai &#10; (“Mount Sinai”) dated April 20, 2020, in which the Company will sponsor an &#10; evaluation by Mount Sinai of the effectiveness of the SteriLumen Disinfecting &#10; System in 17 patient bathrooms in M ...
#    'useOfProceeds': 'We estimate that we will receive net proceeds of approximately $4,550,000 (or &#10; approximately $5,232,500 if the underwriters’ option to purchase additional &#10; shares is exercised in full) from the sale of the common stock offered by us in &#10; this offering, based on public offering price of $5.00 per share, and after &#10; deducting the estimated underwriting discounts and commissions and estimated &#10; offering expenses payable by us. &#10;  &#10; The principal purposes of this offering are to increase our capitalization and &#10; financial flexibility, increase our visibility in the marketplace and create a &#10; public market for our common stock. As of the date of this prospectus, we cannot &#10; specify with certainty all of the particular uses for the net proceeds to us &#10; from this offering. However, we currently intend to use the net proceeds to us &#10; from this offering to hire additional employees, including executive officers &#10; and sales professionals and for general corporate purposes, including working &#10; capital and sales and marketing activities. &#10;  &#10; We will retain broad discretion in the allocation of the net proceeds from this &#10; offering and could utilize the proceeds in ways that do not necessarily improve &#10; our results of operations or enhance the value of our common stock. &#10;  &#10; The table below sets forth the manner in which we expect to use the net proceeds &#10; we receive from this offering. All amounts included in the table below are &#10; estimates. &#10;  &#10; Description                                        Amount      &#10; Research and Development                         $   250,000   &#10; Hiring Staff                                         800,000   &#10; Sales and Marketing                              $   500,000   &#10; Working Capital and General Corporate Purposes   $ 3,000,000   &#10; Total                                            $ 4,550,000   &#10;  &#10; The foregoing information is an estimate based on our current business plan. We &#10; may find it necessary or advisable to re-allocate portions of the net proceeds &#10; reserved for one category to another, and we will have broad discretion in doing &#10; so. Pending these uses, we intend to invest the net proceeds of this offering in &#10; a money market or other interest-bearing account.',
#    'competition': 'Given the uniqueness of the SteriLumen Disinfecting System, we are not aware of &#10; any direct competition, including other manufacturers of mirrors and surface &#10; disinfection systems. &#10;  &#10; Competitive mirrors. Hospitals have been frequent buyers of mirrors not only &#10; in-patient bathrooms, but also other areas, none of which currently have &#10; disinfection capabilities. The same architects that specify other kinds of &#10; mirrors will specify the SteriLumen Disinfecting System. We believe that other &#10; mirror manufacturers will not be the most significant competition for &#10; SteriLumen, as most decision makers will view SteriLumen’s products as &#10; disinfection systems and overlook the current cost of buying a plain mirror, &#10; which in a hospital bathroom are priced in the $100-$300 range. For backlit &#10; (electrified) mirrors the range is wider, from $300-$700. Backlit mirrors are &#10; often sold to enhance design and create a healing environment. They are not &#10; common in hospitals, although that is rapidly changing. We anticipate that the &#10; unit price of the SteriLumen Disinfecting System will be more than these backlit &#10; mirrors, but initially less than $1,000. Because of this price differential, the &#10; SteriLumen Disinfecting System will be positioned in the market as an essential &#10; disinfecting tool, but as a mirror with supplemental lighting that also provides &#10; disinfection. &#10;  &#10; Disinfecting Systems. While we are not aware of any disinfecting systems that &#10; are directly comparable to the SteriLumen Disinfecting System, no-touch &#10; disinfecting systems and Systems &#10;  &#10; No-touch Systems. No-touch systems have increased in popularity in recent years &#10; as complimentary and add on systems for addressing infection prevention issues &#10; following required cleaning and disinfection protocols. These have proven to be &#10; effective with a few major drawbacks. They are used only following patient &#10; transfer or discharge and cannot be used while the patient room is occupied. Due &#10; to the high cost for no touch systems, healthcare facilities generally choose &#10; one of several no-touch options, either UVC robots or peroxide vapor. An &#10; additional issue exists based on the available time for terminal disinfection if &#10; patients are waiting for a room or if staff is simply too busy to move this &#10; technology into the room and turn it on and off. Depending on the technology, &#10; the disinfecting system may need to be moved into the bathroom (additional cycle &#10; time) due to the constraints of the technology. &#10;  &#10; This system requires approximately 2 hours’ time. The applicable room is &#10; completely closed and sealed off. All vents are sealed, doors with the equipment &#10; inside to be run. Following the running of the machine, there is a specified &#10; time for the air to clear before anyone can go back into the room and remove all &#10; of the seals put in place. There is concern about potential residual effects and &#10; potential patient safety as well. &#10;  &#10; UVC systems. UVC disinfection is fast and very effective on surfaces in line of &#10; sight. Products on the market include but are not limited to ceiling mounted, &#10; wall-mounted, upper air UV disinfection units as well as UVC robots. Larger &#10; robot units recommend that their units be moved periodically to address critical &#10; areas that may be limited by shadowing or areas outside of the direct line of &#10; sight. Typically, the larger robots are used for terminal cleaning when the &#10; patient is discharged as a room must be empty to run these units. There are &#10; several manufacturers currently developing other products including smaller &#10; portable units that could be put in a patient room while the patient is &#10; receiving treatment elsewhere in the hospital. The competitive advantage of the &#10; SteriL ...
#    'amount': 2500000,
#    'percentOffered': '15.64'},
#   {'symbol': 'PAICU',
#    'companyName': 'PETRA ACQUISITION INC.',
#    'expectedDate': '2020-08-27',
#    'leadUnderwriters': ['Ladenburg Thalmann & Co. Inc.',
#     'LifeSci Capital, LLC'],
#    'underwriters': [],
#    'companyCounsel': ['Horwitz + Armstrong, PLC'],
#    'underwriterCounsel': ['Ellenoff Grossman & Schole LLP'],
#    'auditor': 'Continental Stock Transfer & Trust Company',
#    'market': 'NASDAQ Capital',
#    'cik': '0001810560',
#    'address': '5 WEST 21ST STREET',
#    'city': 'NEW YORK',
#    'state': 'NY',
#    'zip': '10010',
#    'phone': '971-622-5800',
#    'ceo': 'Andreas Typaldos',
#    'employees': 2,
#    'url': '',
#    'status': 'Filed',
#    'sharesOffered': 12500000,
#    'priceLow': 10,
#    'priceHigh': None,
#    'offerAmount': None,
#    'totalExpenses': 350000,
#    'sharesOverAlloted': 1875000,
#    'shareholderShares': None,
#    'sharesOutstanding': 15625000,
#    'lockupPeriodExpiration': '',
#    'quietPeriodExpiration': '',
#    'revenue': 0,
#    'netIncome': -7681,
#    'totalAssets': 93030,
#    'totalLiabilities': 79349,
#    'stockholderEquity': 13681,
#    'companyDescription': 'We are a blank check company formed under the laws of the State of Delaware on &#10; November 20, 2019. We were formed for the purpose of entering into a merger, &#10; share exchange, asset acquisition, stock purchase, recapitalization, &#10; reorganization or other similar business combination with one or more businesses &#10; or entities, which we refer to as a “target business.” To date, our efforts have &#10; been limited to organizational activities as well as activities related to this &#10; offering. None of our officers, directors, promoters and other affiliates has &#10; engaged in any substantive discussions on our behalf with representatives of &#10; other companies regarding the possibility of a potential merger, capital stock &#10; exchange, asset acquisition or other similar business combination with us. Our &#10; initial business combination and value creation strategy will be to identify, &#10; acquire and, after our initial business combination, assist in the growth of a &#10; business in the cannabis industry. However, we are not limited to this industry &#10; and we may pursue a business combination opportunity in any business or industry &#10; we choose and we may pursue a company with operations or opportunities outside &#10; of the United States. &#10; --- &#10;  &#10; Our executive offices are located at 5West 21st Street, New York, NY 10010 and &#10; our telephone number is (917) 622-5800.',
#    'businessDescription': 'We are a blank check company formed under the laws of the State of Delaware on &#10; November 20, 2019. We were formed for the purpose of entering into a merger, &#10; share exchange, asset acquisition, stock purchase, recapitalization, &#10; reorganization or other similar business combination with one or more businesses &#10; or entities, which we refer to as a “target business.” To date, our efforts have &#10; been limited to organizational activities as well as activities related to this &#10; offering. None of our officers, directors, promoters and other affiliates has &#10; engaged in any substantive discussions on our behalf with representatives of &#10; other companies regarding the possibility of a potential merger, capital stock &#10; exchange, asset acquisition or other similar business combination with us. Our &#10; initial business combination and value creation strategy will be to identify, &#10; acquire and, after our initial business combination, assist in the growth of a &#10; business in the cannabis industry. However, we are not limited to this industry &#10; and we may pursue a business combination opportunity in any business or industry &#10; we choose and we may pursue a company with operations or opportunities outside &#10; of the United States. &#10;  &#10; While the cannabis industry continues to mature, and has certainly evolved since &#10; the first days of legalization, we believe the industry is still &#10; undercapitalized and companies operating across multiple verticals consistently &#10; have had difficulty accessing capital from traditional sources. Businesses &#10; operating within the legal cannabis industry in the U.S. have historically &#10; relied heavily on private money — friends and family, high net-worth individuals &#10; and small-to- medium-sized private investment firms, as institutional investors &#10; have shied away from companies in the cannabis industry, especially those that &#10; are directly involved in the production, distribution and sale of cannabis &#10; (businesses that “touch the plant”). Even those that do not “touch the plant” &#10; and instead provide ancillary services to the industry, have found it difficult &#10; to access institutional capital. As a result, we believe there is an opportunity &#10; to create a compelling structure that will enable a target company to go public &#10; resulting in access to capital for both organic growth and for acquisitions of &#10; synergistic and often undercapitalized assets. Given the rapid and continued &#10; growth of the legal cannabis market, management believes that the ability to &#10; move quickly to capitalize on new opportunities will be critical to success in &#10; creating stakeholder value. Areas of interest in the cannabis industry include &#10; but are not limited to domestic and international businesses that are ancillary &#10; to the production, distribution and sale of cannabis as well as businesses that &#10; legally cultivate, process and/or aid in the retail distribution of cannabis. &#10; Notwithstanding the foregoing, we will not invest in or consummate a business &#10; combination with a target business that we determine has been operating in &#10; violation of U.S. federal laws, including the Controlled Substances Act. &#10; --- &#10;  &#10; Our executive offices are located at 5West 21st Street, New York, NY 10010 and &#10; our telephone number is (917) 622-5800.',
#    'useOfProceeds': 'We estimate that the net proceeds of this offering, in addition to the funds we &#10; will receive from the sale of the private warrants (all of which will be &#10; deposited into the trust account), will be as set forth in the following table: &#10;  &#10;                                                               Without           Over-Allotment   &#10;                                                            Over-Allotment           Option       &#10;                                                                Option             Exercised      &#10; Gross proceeds                                                                                   &#10; From offering                                            $ 125,000,000        $ 143,750,000      &#10; From private placement                                       2,250,000            2,437,500      &#10; Total gross proceeds                                       127,250,000          146,187,500      &#10;                                                                                                  &#10; Offering expenses(1)                                                                             &#10; Underwriting discount (1.0% of gross proceeds from                                           &#10; offering)                                                    1,250,000  (2)       1,437,500  (2) &#10; Legal fees and expenses                                        100,000              100,000      &#10; Nasdaq Listing Fees                                             75,000               75,000      &#10; Printing and engraving expenses                                 40,000               40,000      &#10; Accounting fees and expenses                                    40,000               40,000      &#10; FINRA filing fee                                                22,100               22,100      &#10; SEC registration fee                                            18,659               18,659      &#10; Miscellaneous expenses                                          54,241               54,241      &#10; Total expenses                                               1,600,000            1,787,500      &#10;                                                                                                  &#10; Net proceeds                                                                                     &#10; Held in trust                                              125,000,000          143,750,000      &#10; Not held in trust                                              650,000              650,000      &#10; Total net proceeds                                       $ 125,650,000        $ 144,400,000      &#10;  &#10;                                                            Amount       Percentage  &#10; Use of net proceeds not held in trust(3)(4) (assuming                              &#10; no exercise of underwriter’s overallotment option)                                  &#10; Legal, accounting and other third party expenses                                   &#10; attendant to the search for target businesses and to                               &#10; the due diligence investigation, structuring and                                   &#10; negotiation of a business combination                    $   200,000         30.8 % &#10; Due diligence of prospective target businesses by                                  &#10; officers,                                                                          &#10; directors and sponsor                                        100,000         15.4 % &#10; Legal and accounting fees relating to SEC reporting                                &#10; obligations                                                  100,000         15.4 % &#10; Working capital to cover miscellaneous expenses,                                   &#10; including D&O insurance                                      250,000         38.5 %  ...
#    'competition': 'We may encounter intense competition from other entities having a business &#10; objective similar to ours when identifying, evaluating and selecting a target &#10; business. Many of these entities are well established and have extensive &#10; experience identifying and effecting business combinations directly or through &#10; affiliates. Many of these competitors possess greater technical, human and other &#10; resources than us and our financial resources will be relatively limited when &#10; contrasted with those of many of these competitors. While we believe there may &#10; be numerous potential target businesses that we could acquire with the net &#10; proceeds of this offering, our ability to compete in acquiring certain sizable &#10; target businesses may be limited by our available financial resources. &#10;  &#10; The following also may not be viewed favorably by certain target businesses: &#10;  &#10; • our obligation to seek stockholder approval of a business combination or &#10;   engage in a tender offer may delay the completion of a transaction; &#10;  &#10; • our obligation to convert or repurchase shares of common stock held by our &#10;   public stockholders may reduce the resources available to us for a business &#10;   combination; and &#10;  &#10; • our outstanding warrants, and the potential future dilution they represent. &#10;  &#10; Any of these factors may place us at a competitive disadvantage in successfully &#10; negotiating a business combination. Our management believes, however, that our &#10; status as a public entity and potential access to the United States public &#10; equity markets may give us a competitive advantage over privately-held entities &#10; having a similar business objective as ours in acquiring a target business with &#10; significant growth potential on favorable terms. &#10;  &#10; If we succeed in effecting a business combination, there will be, in all &#10; likelihood, intense competition from competitors of the target business. We &#10; cannot assure you that, subsequent to a business combination, we will have the &#10; resources or ability to compete effectively.',
#    'amount': 62500000,
#    'percentOffered': '80.00'},
#   {'symbol': 'CFIIU',
#    'companyName': 'CF FINANCE ACQUISITION CORP II',
#    'expectedDate': '2020-08-27',
#    'leadUnderwriters': ['Cantor Fitzgerald & Co.'],
#    'underwriters': [],
#    'companyCounsel': ['Ellenoff Grossman & Schole LLP'],
#    'underwriterCounsel': ['Graubard Miller'],
#    'auditor': 'Continental Stock Transfer & Trust Company',
#    'market': 'NASDAQ Capital',
#    'cik': '0001811856',
#    'address': '110 EAST 59TH STREET',
#    'city': 'NEW YORK',
#    'state': 'NY',
#    'zip': '10022',
#    'phone': '212-938-5000',
#    'ceo': 'Howard W. Lutnick',
#    'employees': 3,
#    'url': '',
#    'status': 'Filed',
#    'sharesOffered': 52500000,
#    'priceLow': 10,
#    'priceHigh': None,
#    'offerAmount': None,
#    'totalExpenses': 750000,
#    'sharesOverAlloted': 7875000,
#    'shareholderShares': None,
#    'sharesOutstanding': 53650000,
#    'lockupPeriodExpiration': '',
#    'quietPeriodExpiration': '',
#    'revenue': 0,
#    'netIncome': 0,
#    'totalAssets': 131513,
#    'totalLiabilities': 107018,
#    'stockholderEquity': 24495,
#    'companyDescription': 'We are a blank check company formed on September 27, 2019 as a Delaware &#10; corporation for the purpose of effecting a merger, capital stock exchange, asset &#10; acquisition, stock purchase, reorganization or similar business combination with &#10; one or more businesses, which we refer to throughout this prospectus as our &#10; initial business combination. We have not selected any specific business &#10; combination target and we have not, nor has anyone on our behalf, initiated any &#10; substantive discussions, directly or indirectly, with any business combination &#10; target regarding an initial business combination with our company. &#10;  &#10; We intend to focus our search on businesses that may provide significant &#10; opportunities for attractive investor returns. Our efforts to identify a &#10; prospective target business will not be limited to a particular industry or &#10; geographic region, although we expect to focus on a target in an industry where &#10; we believe our management team and founders’ expertise will provide us with a &#10; competitive advantage, including the financial services, healthcare, real estate &#10; services, technology and software industries. &#10; --- &#10;  &#10; Our executive offices are located at 110 East 59th Street, New York, New York  &#10; 10022 and our telephone number is (212) 938-5000.',
#    'businessDescription': 'We are a blank check company formed on September 27, 2019 as a Delaware &#10; corporation for the purpose of effecting a merger, capital stock exchange, asset &#10; acquisition, stock purchase, reorganization or similar business combination with &#10; one or more businesses, which we refer to throughout this prospectus as our &#10; initial business combination. We have not selected any specific business &#10; combination target and we have not, nor has anyone on our behalf, initiated any &#10; substantive discussions, directly or indirectly, with any business combination &#10; target regarding an initial business combination with our company. &#10;  &#10; We intend to focus our search on businesses that may provide significant &#10; opportunities for attractive investor returns. Our efforts to identify a &#10; prospective target business will not be limited to a particular industry or &#10; geographic region, although we expect to focus on a target in an industry where &#10; we believe our management team and founders’ expertise will provide us with a &#10; competitive advantage, including the financial services, healthcare, real estate &#10; services, technology and software industries. &#10; --- &#10;  &#10; We, our sponsor, and CF&Co are all affiliates of Cantor. Cantor is a diversified &#10; company specializing in financial and real estate services for customers &#10; operating in the global financial and commercial real estate markets, whose &#10; businesses include CF&Co, a leading independent middle market investment bank &#10; and primary dealer; BGC Partners, Inc., or BGC, whose common stock trades on the &#10; Nasdaq Global Select Market under the ticker symbol “BGCP”, a leading global &#10; financial technology and brokerage business primarily servicing the global &#10; financial markets; and Newmark Group, Inc., or Newmark, whose Class A common &#10; stock trades on the Nasdaq Global Select Market under the ticker symbol “NMRK”, &#10; a fast growing, full-service commercial real estate services business. We &#10; believe that the combination of our management team’s and our affiliates’ &#10; financial services, financial and real estate technology, and real estate &#10; industry expertise and proven ability to grow businesses through acquisitions &#10; make us uniquely qualified to pursue acquisitions. &#10;  &#10; Cantor was founded 75 years ago and has been led by Mr. Lutnick since 1992. Over &#10; the past several decades Cantor has successfully built a well-capitalized &#10; business across multiple and growing business lines, with numerous &#10; market-leading financial services products and large and growing commercial real &#10; estate businesses. Cantor has been at the forefront of financial and &#10; technological innovation in its industries, developing new markets, new &#10; technologies and providing superior service to thousands of customers globally. &#10; --- &#10;  &#10; Our executive offices are located at 110 East 59th Street, New York, New York  &#10; 10022 and our telephone number is (212) 938-5000.',
#    'useOfProceeds': 'We are offering 52,500,000 units at an offering price of $10.00 per unit. We &#10; estimate that the net proceeds of this offering together with the funds we will &#10; receive from the sale of the private placement units will be used as set forth &#10; in the following table. &#10;  &#10;                                                              Without          Over-Allotment    &#10;                                                           Over-Allotment       Option Fully     &#10;                                                               Option             Exercised      &#10; Gross proceeds                                                                                  &#10; Gross proceeds from units offered to public(1)           $  525,000,000     $   603,750,000     &#10; Gross proceeds from private placement units offered in                                       &#10; the private placement                                        11,500,000          11,500,000     &#10; Total gross proceeds                                        536,500,000         615,250,000     &#10; Offering expenses(2)                                                                            &#10; Underwriting commissions (2% of gross proceeds from                                          &#10; units offered to public, other than units sold                                               &#10; pursuant to the underwriters’ overallotment option)(3)   $   10,500,000     $    10,500,000     &#10; Payment to qualified independent underwriter                    100,000             100,000     &#10; Legal fees and expenses                                         250,000             250,000     &#10; Accounting fees and expenses                                     37,500              37,500     &#10; SEC/FINRA Expenses                                              171,500             171,500     &#10; Travel and road show                                             25,000              25,000     &#10; Nasdaq listing and filing fees                                   75,000              75,000     &#10; Printing and engraving expenses                                  40,000              40,000     &#10; Miscellaneous                                            $       51,000     $        51,000     &#10; Total offering expenses (excluding underwriting                                              &#10; commissions)                                             $      750,000     $       750,000     &#10; Proceeds after offering expenses                         $  525,250,000     $   604,000,000     &#10; Held in trust account(3)                                 $  525,000,000     $   603,750,000     &#10; % of public offering size                                           100 %               100 %   &#10; Not held in trust account                                $      250,000     $       250,000     &#10;  &#10; The following table shows the use of the approximately $250,000 of net proceeds &#10; not held in the trust account, as well as up to $750,000 in working capital &#10; loans committed by our sponsor, its affiliates or designees.(4) &#10;  &#10;                                                            Amount       % of Total  &#10; Legal, accounting, due diligence, travel, and other                                &#10; expenses in connection with any business combination     $   450,000         45.0 % &#10; Legal and accounting fees related to regulatory                                    &#10; reporting obligations                                        150,000         15.0 % &#10; Director and Officer liability insurance premiums            220,000         22.0 % &#10; Working capital to cover miscellaneous expenses              180,000         18.0 % &#10; Total                                                    $ 1,000,000        100.0 % &#10;  &#10; (1) Includes gross proceeds from this offering of $525,000,000 (or $603 ...
#    'competition': 'In identifying, evaluating and selecting a target business for our initial &#10; business combination, we may encounter intense competition from other entities &#10; having a business objective similar to ours, including other blank check &#10; companies, private equity groups and leveraged buyout funds, public companies &#10; and operating businesses seeking strategic business combinations, including &#10; affiliates of our sponsor. Many of these entities are well established and have &#10; extensive experience identifying and effecting business combinations directly or &#10; through affiliates. Moreover, many of these competitors possess greater &#10; financial, technical, human and other resources than we do. Our ability to &#10; acquire larger target businesses will be limited by our available financial &#10; resources. This inherent limitation gives others an advantage in pursuing the &#10; initial business combination of a target business. Furthermore, our obligation &#10; to pay cash in connection with our public stockholders who exercise their &#10; redemption rights may reduce the resources available to us for our initial &#10; business combination and our outstanding warrants, and the future dilution they &#10; potentially represent, may not be viewed favorably by certain target businesses. &#10; Either of these factors may place us at a competitive disadvantage in &#10; successfully negotiating an initial business combination.',
#    'amount': 262500000,
#    'percentOffered': '97.86'}],
#  'viewData': [{'Company': 'XPENG INC.',
#    'Symbol': 'XPEV',
#    'Price': '$11.00 - 13.00',
#    'Shares': '85,000,000',
#    'Amount': '1,020,000,000',
#    'Float': '85,000,000',
#    'Percent': '100.00%',
#    'Market': 'NYSE',
#    'Expected': '2020-08-27'},
#   {'Company': 'APPLIED UV, INC.',
#    'Symbol': 'AUVI',
#    'Price': '$5.00',
#    'Shares': '1,000,000',
#    'Amount': '2,500,000',
#    'Float': '6,393,129',
#    'Percent': '15.64%',
#    'Market': 'NASDAQ Capital',
#    'Expected': '2020-08-27'},
#   {'Company': 'PETRA ACQUISITION INC.',
#    'Symbol': 'PAICU',
#    'Price': '$10.00',
#    'Shares': '12,500,000',
#    'Amount': '62,500,000',
#    'Float': '15,625,000',
#    'Percent': '80.00%',
#    'Market': 'NASDAQ Capital',
#    'Expected': '2020-08-27'},
#   {'Company': 'CF FINANCE ACQUISITION CORP II',
#    'Symbol': 'CFIIU',
#    'Price': '$10.00',
#    'Shares': '52,500,000',
#    'Amount': '262,500,000',
#    'Float': '53,650,000',
#    'Percent': '97.86%',
#    'Market': 'NASDAQ Capital',
#    'Expected': '2020-08-27'}]}

# %%
c.ipoUpcomingDF()
# Out:
#                                     address      amount  \
# symbol
# PSN                  5875 TRINITY PKWY #300   499999500
# HHR                DOSITHEOU, 42, STROVOLOS   199728263
# APLT                     340 MADISON AVENUE    60000000
# NXTC    9000 VIRGINIA MANOR ROAD, SUITE 200    75000000
# SPFI                 5219 CITY BANK PARKWAY    62530000
# MEC                        715 SOUTH STREET   125000000
# CRTX                     269 EAST GRAND AVE    75004000
# AXLA                     840 MEMORIAL DRIVE    74999988
# MIST         1111 DR. FREDERIK-PHILIPS BLVD    75000000
# DEACU              2121 AVENUE OF THE STARS   175000000
# UBER             1455 MARKET ST., 4TH FLOOR  8460000000
# PSTL                        75 COLUMBIA AVE   100000000
# SONM                1875 SOUTH GRANT STREET    50000006
# HSACU                    412 W. 15TH STREET    50000000
# CPTI    840 NEWPORT CENTER DRIVE, SUITE 450    39999999
# BEER              14504 HERTZ QUAIL PARKWAY    15000000
# PMTG    C/O PIMCO, 650 NEWPORT CENTER DRIVE   500000000
# AVTR                BUILDING ONE, SUITE 200  3003000000
# FSLY                            475 BRANNAN   168750000
# LK        17F BLOCK A, TEFANG PORTMAN TOWER   480000000
#
#                                               auditor  \
# symbol
# PSN      American Stock Transfer & Trust Company, LLC
# HHR                                     Not Specified
# APLT                 Computershare Trust Company, N.A
# NXTC     American Stock Transfer & Trust Company, LLC
# SPFI       Broadridge Corporate Issuer Solutions, Inc
# MEC      American Stock Transfer & Trust Company, LLC
# CRTX     American Stock Transfer & Trust Company, LLC
# AXLA                 Computershare Trust Company, N.A
# MIST            Computer Share Investor Services, Inc
# DEACU      Continental Stock Transfer & Trust Company
# UBER                 Computershare Trust Company, N.A
# PSTL     American Stock Transfer & Trust Company, LLC
# SONM    American Stock Transfer and Trust Company LLC
# HSACU      Continental Stock Transfer & Trust Company
# CPTI                 Colonial Stock Transfer Co., Inc
# BEER                             VStock Transfer, LLC
# PMTG     American Stock Transfer & Trust Company, LLC
# AVTR     American Stock Transfer & Trust Company, LLC
# FSLY     American Stock Transfer & Trust Company, LLC
# LK                                      Not Specified
#
#                                       businessDescription  \
# symbol
# PSN     We are a leading provider of technology-driven...
# HHR     We are the leading online recruitment platform...
# APLT    We are a clinical-stage biopharmaceutical comp...
# NXTC    We are a clinical-stage biopharmaceutical comp...
# SPFI    We are a bank holding company headquartered in...
# MEC     MEC is a leading U.S.-based value-added manufa...
# CRTX    We are a clinical stage biopharmaceutical comp...
# AXLA    We are a biotechnology company pioneering the ...
# MIST    We are a Phase 3 clinical-stage biopharmaceuti...
# DEACU   We are a blank check company whose business pu...
# UBER    Our mission is to ignite opportunity by settin...
# PSTL    We are an internally managed real estate corpo...
# SONM    We are a leading U.S. provider of ultra-rugged...
# HSACU   We are a blank check company formed under the ...
# CPTI    Upon the completion of this offering and the c...
# BEER    We are engaged in the business of developing, ...
# PMTG    We are a newly organized real estate finance c...
# AVTR    We are a leading global provider of mission cr...
# FSLY    Developers are reinventing the way we live, wo...
# LK      Our mission is to be part of everyone's everyd...
#
#                           ceo         cik                   city  \
# symbol
# PSN     Charles L. Harrington  0000275880            CENTREVILLE
# HHR            Mikhail Zhukov  0001721181           NICOSIA 2028
# APLT      Shoshana Shendelman  0001697532               NEW YORK
# NXTC          Michael Richman  0001661059             BELTSVILLE
# SPFI       Curtis C. Griffith  0001163668                LUBBOCK
# MEC        Robert D. Kamphuis  0001766368               MAYVILLE
# CRTX           Casey C. Lynch  0001662774    SOUTH SAN FRANCISCO
# AXLA          William Hinshaw  0001633070              CAMBRIDGE
# MIST           Joseph Oliveto  0001408443       MONTREAL H4M 2X6
# DEACU           Jeff Sagansky  0001772757            LOS ANGELES
# UBER        Dara Khosrowshahi  0001543151          SAN FRANCISCO
# PSTL            Andrew Spodek  0001759774             CEDARHURST
# SONM          Robert Plaschke  0001178697              SAN MATEO
# HSACU           Roderick Wong  0001764013               NEW YORK
# CPTI           Robert Tallack  0001761369          NEWPORT BEACH
# BEER       W.G. Buck Warfield  0001758951          OKLAHOMA CITY
# PMTG             Casey Newell  0001742691          NEWPORT BEACH
# AVTR     Michael Stubblefield  0001722482                 RADNOR
# FSLY            Artur Bergman  0001517413          SAN FRANCISCO
# LK           Jenny Zhiya Qian  0001767582  XIAMEN, FUJIAN 361008
#
#                                     companyCounsel  \
# symbol
# PSN                         [Latham & Watkins LLP]
# HHR                [Latham & Watkins (London) LLP]
# APLT                                  [Cooley LLP]
# NXTC                        [Hogan Lovells US LLP]
# SPFI                    [Hunton Andrews Kurth LLP]
# MEC                          [Foley & Lardner LLP]
# CRTX          [Orrick, Herrington & Sutcliffe LLP]
# AXLA                         [Goodwin Procter LLP]
# MIST                                  [Cooley LLP]
# DEACU                       [Winston & Strawn LLP]
# UBER      [Cooley LLP and Covington & Burling LLP]
# PSTL    [Venable LLP and Hunton Andrews Kurth LLP]
# SONM                                  [Cooley LLP]
# HSACU                          [Loeb and Loeb LLP]
# CPTI                        [Troutman Sanders LLP]
# BEER              [Ellenoff Grossman & Schole LLP]
# PMTG        [Latham & Watkins LLP and Venable LLP]
# AVTR              [Simpson Thacher & Bartlett LLP]
# FSLY                                  [Cooley LLP]
# LK                     [Davis Polk & Wardwell LLP]
#
#                                        companyDescription  \
# symbol
# PSN     We are a leading provider of technology-driven...
# HHR     We are the leading online recruitment platform...
# APLT    We are a clinical-stage biopharmaceutical comp...
# NXTC    We are a clinical-stage biopharmaceutical comp...
# SPFI    We are a bank holding company headquartered in...
# MEC     MEC is a leading U.S.-based value-added manufa...
# CRTX    We are a clinical stage biopharmaceutical comp...
# AXLA    We are a biotechnology company pioneering the ...
# MIST    We are a Phase 3 clinical-stage biopharmaceuti...
# DEACU   We are a blank check company whose business pu...
# UBER    Our mission is to ignite opportunity by settin...
# PSTL    We are an internally managed real estate corpo...
# SONM    We are a leading U.S. provider of ultra-rugged...
# HSACU   We are a blank check company formed under the ...
# CPTI    Upon the completion of this offering and the c...
# BEER    We are engaged in the business of developing, ...
# PMTG    We are a newly organized real estate finance c...
# AVTR    We are a leading global provider of mission cr...
# FSLY    Developers are reinventing the way we live, wo...
# LK      Our mission is to be part of everyone's everyd...
#
#                                  companyName  ... status  stockholderEquity  \
# symbol                                        ...
# PSN                             PARSONS CORP  ...  Filed         -967537000
# HHR                     HEADHUNTER GROUP PLC  ...  Filed           42809000
# APLT               APPLIED THERAPEUTICS INC.  ...  Filed          -19592000
# NXTC                          NEXTCURE, INC.  ...  Filed          -46944000
# SPFI            SOUTH PLAINS FINANCIAL, INC.  ...  Filed          154580000
# MEC       MAYVILLE ENGINEERING COMPANY, INC.  ...  Filed          -30817000
# CRTX                         CORTEXYME, INC.  ...  Filed          -32626000
# AXLA                     AXCELLA HEALTH INC.  ...  Filed         -149753000
# MIST          MILESTONE PHARMACEUTICALS INC.  ...  Filed          -55210000
# DEACU   DIAMOND EAGLE ACQUISITION CORP. \ DE  ...  Filed              24325
# UBER                  UBER TECHNOLOGIES, INC  ...  Filed        -7385000000
# PSTL               POSTAL REALTY TRUST, INC.  ...  Filed           -5658006
# SONM                  SONIM TECHNOLOGIES INC  ...  Filed            5129000
# HSACU      HEALTH SCIENCES ACQUISITIONS CORP  ...  Filed              24552
# CPTI          CONVERSIONPOINT HOLDINGS, INC.  ...  Filed           36009430
# BEER       BRICKTOWN BREWERY RESTAURANTS LLC  ...  Filed          -10019782
# PMTG        PIMCO MORTGAGE INCOME TRUST INC.  ...  Filed              10000
# AVTR                           AVANTOR, INC.  ...  Filed        -3138400000
# FSLY                            FASTLY, INC.  ...  Filed         -133598000
# LK                        LUCKIN COFFEE INC.  ...  Filed         -374341000
#
#         totalAssets totalExpenses totalLiabilities  \
# symbol
# PSN      2612578000     9551215.0       1657345000
# HHR       192013000     4369364.0        148780000
# APLT       20246000     3200000.0          4428000
# NXTC      147628000     3200000.0         32349000
# SPFI     2712745000     1092187.0       2499970000
# MEC       391725000     2700000.0        288736000
# CRTX       72877000     2113507.0          1457000
# AXLA       81844000     1940000.0         33755000
# MIST       88081000     2700000.0          4533000
# DEACU         26733      750000.0             2408
# UBER    23988000000    15000000.0      17196000000
# PSTL       35684432     6764688.0         41297845
# SONM       67345000     4200000.0         62216000
# HSACU        405000      900000.0           380448
# CPTI       48961064     1500000.0         12951634
# BEER        8328615      568543.0         18017910
# PMTG          10000     4075852.0                0
# AVTR    10013900000    10400000.0       9221200000
# FSLY      163735000     6000000.0         77749000
# LK        432221000     6366788.6        160899000
#
#                                  underwriterCounsel  \
# symbol
# PSN                  [Gibson Dunn and Crutcher LLP]
# HHR                            [White and Case LLP]
# APLT                    [Davis Polk & Wardwell LLP]
# NXTC                                   [Cooley LLP]
# SPFI         [Fenimore, Kay, Harrison & Ford, LLP.]
# MEC                          [Latham & Watkins LLP]
# CRTX                         [Latham & Watkins LLP]
# AXLA                         [Latham & Watkins LLP]
# MIST    [Wilmer Cutler Pickering Hale and Dorr LLP]
# DEACU    [Skadden, Arps, Slate, Meagher & Flom LLP]
# UBER                    [Davis Polk & Wardwell LLP]
# PSTL                         [Winston & Strawn LLP]
# SONM                          [Goodwin Procter LLP]
# HSACU                        [Kirkland & Ellis LLP]
# CPTI                           [White and Case LLP]
# BEER                            [Loeb and Loeb LLP]
# PMTG                       [Clifford Chance US LLP]
# AVTR                             [Ropes & Gray LLP]
# FSLY                    [Davis Polk & Wardwell LLP]
# LK           [Cleary Gottlieb Steen & Hamilton LLP]
#
#                                              underwriters  \
# symbol
# PSN     [Cowen and Company, LLC, Jefferies LLC, Morgan...
# HHR       [BofA Merrill Lynch, Sberbank CIB (UK) Limited]
# APLT                 [Robert W. Baird & Co. Incorporated]
# NXTC                                                   []
# SPFI                                                   []
# MEC     [UBS Investment Bank, William Blair and Co., L...
# CRTX          [Canaccord Genuity LLC, JMP Securities LLC]
# AXLA                                                   []
# MIST                             [Oppenheimer & Co. Inc.]
# DEACU                         [Northland Securities, Inc]
# UBER    [Academy Securities, Inc, Allen & Company LLC,...
# PSTL            [B. Riley FBR, Inc, D.A. Davidson and Co]
# SONM                           [National Securities Corp]
# HSACU                                                  []
# CPTI                               [D.A. Davidson and Co]
# BEER                                                   []
# PMTG    [BofA Merrill Lynch, Citigroup Global Markets ...
# AVTR    [Barclays Capital Inc, BofA Merrill Lynch, Cit...
# FSLY    [Craig-Hallum Capital Group LLC, D.A. Davidson...
# LK      [KeyBanc Capital Markets Inc, Needham & Compan...
#
#                                 url  \
# symbol
# PSN                 www.parsons.com
# HHR                       www.hh.ru
# APLT    www.appliedtherapeutics.com
# NXTC               www.nextcure.com
# SPFI                  www.city.bank
# MEC                  www.mecinc.com
# CRTX              www.cortexyme.com
# AXLA          www.axcellahealth.com
# MIST        www.milestonepharma.com
# DEACU
# UBER                   www.uber.com
# PSTL      www.postalrealtytrust.com
# SONM              www.sonimtech.com
# HSACU
# CPTI        www.conversionpoint.com
# BEER       www.bricktownbrewery.com
# PMTG              www.pimcoreit.com
# AVTR              ww.avantorinc.com
# FSLY                 www.fastly.com
# LK             www.luckincoffee.com
#
#                                             useOfProceeds         zip
# symbol
# PSN     We estimate that the net proceeds to us from t...       20120
# HHR     The Selling Shareholders are selling all of th...
# APLT    We estimate that the net proceeds to us from t...       10173
# NXTC    We estimate that the net proceeds from the sal...       20705
# SPFI    We estimate that the net proceeds to us from t...  79407-3544
# MEC     We estimate that our net proceeds from this of...       53050
# CRTX    We estimate that the net proceeds from our iss...       94080
# AXLA    We estimate that the net proceeds to us from t...       02139
# MIST    We estimate that the net proceeds to us from t...
# DEACU   We are offering 35,000,000 units at an offerin...       90067
# UBER    We estimate that net proceeds to us from the s...       94103
# PSTL    After deducting the underwriting discount and ...       11516
# SONM    We estimate that the net proceeds from our iss...       94402
# HSACU   We estimate that the net proceeds of this offe...       10011
# CPTI    We estimate that the net proceeds from our iss...       92660
# BEER    We estimate that the net proceeds from the sal...       73134
# PMTG    We estimate that our net proceeds from the ini...       92660
# AVTR    We estimate that the net proceeds to us from t...       19087
# FSLY    We estimate that the net proceeds from our iss...       94107
# LK      We estimate that we will receive net proceeds ...
#
# [20 rows x 39 columns]

# %% [markdown]
# ## Key Stats

# %%
c.keyStats(symbol)
# Out:
# {'week52change': 1.268567,
#  'week52high': 137.98,
#  'week52low': 52.77,
#  'marketcap': 2068718400000,
#  'employees': 137000,
#  'day200MovingAvg': 82.15,
#  'day50MovingAvg': 106.86,
#  'float': 17086047395,
#  'avg10Volume': 223213674.8,
#  'avg30Volume': 195357803.87,
#  'ttmEPS': 3.3183,
#  'ttmDividendRate': 0.7825,
#  'companyName': 'Apple, Inc.',
#  'sharesOutstanding': 17102500000,
#  'maxChangePercent': 477.2918,
#  'year5ChangePercent': 3.3842,
#  'year2ChangePercent': 1.1188,
#  'year1ChangePercent': 1.3519,
#  'ytdChangePercent': 0.6333,
#  'month6ChangePercent': 0.6723,
#  'month3ChangePercent': 0.4882,
#  'month1ChangePercent': 0.1103,
#  'day30ChangePercent': 0.2758,
#  'day5ChangePercent': -0.0626,
#  'nextDividendDate': None,
#  'dividendYield': 0.006469080687830688,
#  'nextEarningsDate': '2020-10-29',
#  'exDividendDate': '2020-08-31',
#  'peRatio': 36.45,
#  'beta': 1.1218009347361093}

# %%
c.keyStatsDF(symbol)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pyEX/stocks/research.py:287: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   df = pd.io.json.json_normalize(s)
#    week52change  week52high  week52low      marketcap  employees  \
# 0      1.268567      137.98      52.77  2068718400000     137000
#
#    day200MovingAvg  day50MovingAvg        float  avg10Volume   avg30Volume  \
# 0            82.15          106.86  17086047395  223213674.8  1.953578e+08
#
#    ...  month3ChangePercent  month1ChangePercent day30ChangePercent  \
# 0  ...               0.4882               0.1103             0.2758
#
#    day5ChangePercent  nextDividendDate  dividendYield  nextEarningsDate  \
# 0            -0.0626              None       0.006469        2020-10-29
#
#    exDividendDate  peRatio      beta
# 0      2020-08-31    36.45  1.121801
#
# [1 rows x 30 columns]

# %% [markdown]
# ## Largest Trades

# %%
c.largestTrades(symbol)
# Out:
# []

# %%
c.largestTradesDF(symbol)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## List

# %%
c.list()[:5]
# Out:
# [{'symbol': 'AAPL',
#   'companyName': 'Apple, Inc.',
#   'primaryExchange': 'NASDAQ',
#   'calculationPrice': 'close',
#   'open': 120,
#   'openTime': 1599226202030,
#   'openSource': 'official',
#   'close': 120.96,
#   'closeTime': 1599249600801,
#   'closeSource': 'official',
#   'high': 123.7,
#   'highTime': 1599263998145,
#   'highSource': '15 minute delayed price',
#   'low': 110.89,
#   'lowTime': 1599230668001,
#   'lowSource': '15 minute delayed price',
#   'latestPrice': 120.96,
#   'latestSource': 'Close',
#   'latestTime': 'September 4, 2020',
#   'latestUpdate': 1599249600801,
#   'latestVolume': 332607163,
#   'iexRealtimePrice': None,
#   'iexRealtimeSize': None,
#   'iexLastUpdated': None,
#   'delayedPrice': 120,
#   'delayedPriceTime': 1599263998145,
#   'oddLotDelayedPrice': 453.263,
#   'oddLotDelayedPriceTime': 1599252382500,
#   'extendedPrice': 120.01,
#   'extendedChange': -0.95,
#   'extendedChangePercent': -0.00785,
#   'extendedPriceTime': 1599263998144,
#   'previousClose': 120.88,
#   'previousVolume': 257599640,
#   'change': 0.08,
#   'changePercent': 0.00066,
#   'volume': 332607163,
#   'iexMarketPercent': None,
#   'iexVolume': None,
#   'avgTotalVolume': 195357804,
#   'iexBidPrice': None,
#   'iexBidSize': None,
#   'iexAskPrice': None,
#   'iexAskSize': None,
#   'iexOpen': None,
#   'iexOpenTime': None,
#   'iexClose': 121.11,
#   'iexCloseTime': 1599249591040,
#   'marketCap': 2068718400000,
#   'peRatio': 36.45,
#   'week52High': 137.98,
#   'week52Low': 52.77,
#   'ytdChange': 0.63396,
#   'lastTradeTime': 1599249600801,
#   'isUSMarketOpen': False},
#  {'symbol': 'TSLA',
#   'companyName': 'Tesla, Inc.',
#   'primaryExchange': 'NASDAQ',
#   'calculationPrice': 'close',
#   'open': 402.7,
#   'openTime': 1599226201365,
#   'openSource': 'official',
#   'close': 418.32,
#   'closeTime': 1599249600552,
#   'closeSource': 'official',
#   'high': 428,
#   'highTime': 1599263999770,
#   'highSource': '15 minute delayed price',
#   'low': 372.02,
#   'lowTime': 1599230693213,
#   'lowSource': '15 minute delayed price',
#   'latestPrice': 418.32,
#   'latestSource': 'Close',
#   'latestTime': 'September 4, 2020',
#   'latestUpdate': 1599249600552,
#   'latestVolume': 110321885,
#   'iexRealtimePrice': None,
#   'iexRealtimeSize': None,
#   'iexLastUpdated': None,
#   'delayedPrice': 391.33,
#   'delayedPriceTime': 1599263999770,
#   'oddLotDelayedPrice': 478.7,
#   'oddLotDelayedPriceTime': 1599252377383,
#   'extendedPrice': 391.5,
#   'extendedChange': -26.82,
#   'extendedChangePercent': -0.06411,
#   'extendedPriceTime': 1599263999712,
#   'previousClose': 407,
#   'previousVolume': 87596086,
#   'change': 11.32,
#   'changePercent': 0.02781,
#   'volume': 110321885,
#   'iexMarketPercent': None,
#   'iexVolume': None,
#   'avgTotalVolume': 74928400,
#   'iexBidPrice': None,
#   'iexBidSize': None,
#   'iexAskPrice': None,
#   'iexAskSize': None,
#   'iexOpen': None,
#   'iexOpenTime': None,
#   'iexClose': 418.5,
#   'iexCloseTime': 1599249597622,
#   'marketCap': 389794340880,
#   'peRatio': 1030.85,
#   'week52High': 502.49,
#   'week52Low': 43.67,
#   'ytdChange': 3.889057,
#   'lastTradeTime': 1599249600552,
#   'isUSMarketOpen': False},
#  {'symbol': 'PLM',
#   'companyName': 'PolyMet Mining Corp.',
#   'primaryExchange': 'NYSE American',
#   'calculationPrice': 'close',
#   'open': 3.2,
#   'openTime': 1599226200033,
#   'openSource': 'official',
#   'close': 4.4,
#   'closeTime': 1599249600057,
#   'closeSource': 'official',
#   'high': 6.38,
#   'highTime': 1599264000004,
#   'highSource': '15 minute delayed price',
#   'low': 3.01,
#   'lowTime': 1599226769032,
#   'lowSource': '15 minute delayed price',
#   'latestPrice': 4.4,
#   'latestSource': 'Close',
#   'latestTime': 'September 4, 2020',
#   'latestUpdate': 1599249600057,
#   'latestVolume': 101636395,
#   'iexRealtimePrice': None,
#   'iexRealtimeSize': None,
#   'iexLastUpdated': None,
#   'delayedPrice': 4.4,
#   'delayedPriceTime': 1599264000004,
#   'oddLotDelayedPrice': 4.3,
#   'oddLotDelayedPriceTime': 1599249599708,
#   'extendedPrice': 4.4,
#   'extendedChange': 0,
#   'extendedChangePercent': 0,
#   'extendedPriceTime': 1599264000004,
#   'previousClose': 2.69,
#   'previousVolume': 593789,
#   'change': 1.71,
#   'changePercent': 0.63569,
#   'volume': 101636395,
#   'iexMarketPercent': None,
#   'iexVolume': None,
#   'avgTotalVolume': 4076042,
#   'iexBidPrice': None,
#   'iexBidSize': None,
#   'iexAskPrice': None,
#   'iexAskSize': None,
#   'iexOpen': None,
#   'iexOpenTime': None,
#   'iexClose': 4.33,
#   'iexCloseTime': 1599249579281,
#   'marketCap': 443080000,
#   'peRatio': -6.84,
#   'week52High': 9.7,
#   'week52Low': 1.5,
#   'ytdChange': 1.3345319999999998,
#   'lastTradeTime': 1599249600053,
#   'isUSMarketOpen': False},
#  {'symbol': 'BAC',
#   'companyName': 'Bank of America Corp.',
#   'primaryExchange': 'New York Stock Exchange',
#   'calculationPrice': 'close',
#   'open': 26.24,
#   'openTime': 1599226200972,
#   'openSource': 'official',
#   'close': 26.54,
#   'closeTime': 1599249601908,
#   'closeSource': 'official',
#   'high': 26.76,
#   'highTime': 1599263999743,
#   'highSource': '15 minute delayed price',
#   'low': 25.8,
#   'lowTime': 1599234230770,
#   'lowSource': '15 minute delayed price',
#   'latestPrice': 26.54,
#   'latestSource': 'Close',
#   'latestTime': 'September 4, 2020',
#   'latestUpdate': 1599249601908,
#   'latestVolume': 101139984,
#   'iexRealtimePrice': None,
#   'iexRealtimeSize': None,
#   'iexLastUpdated': None,
#   'delayedPrice': 26.52,
#   'delayedPriceTime': 1599263999743,
#   'oddLotDelayedPrice': 26.53,
#   'oddLotDelayedPriceTime': 1599249600330,
#   'extendedPrice': 26.52,
#   'extendedChange': -0.02,
#   'extendedChangePercent': -0.00075,
#   'extendedPriceTime': 1599263999743,
#   'previousClose': 25.66,
#   'previousVolume': 86192495,
#   'change': 0.88,
#   'changePercent': 0.03429,
#   'volume': 101139984,
#   'iexMarketPercent': None,
#   'iexVolume': None,
#   'avgTotalVolume': 57770820,
#   'iexBidPrice': None,
#   'iexBidSize': None,
#   'iexAskPrice': None,
#   'iexAskSize': None,
#   'iexOpen': None,
#   'iexOpenTime': None,
#   'iexClose': 26.535,
#   'iexCloseTime': 1599249594321,
#   'marketCap': 229945214000,
#   'peRatio': 12.68,
#   'week52High': 35.72,
#   'week52Low': 17.95,
#   'ytdChange': -0.221041,
#   'lastTradeTime': 1599249601795,
#   'isUSMarketOpen': False},
#  {'symbol': 'GE',
#   'companyName': 'General Electric Co.',
#   'primaryExchange': 'New York Stock Exchange',
#   'calculationPrice': 'close',
#   'open': 6.43,
#   'openTime': 1599226201029,
#   'openSource': 'official',
#   'close': 6.42,
#   'closeTime': 1599249601997,
#   'closeSource': 'official',
#   'high': 6.56,
#   'highTime': 1599263999875,
#   'highSource': '15 minute delayed price',
#   'low': 6.26,
#   'lowTime': 1599234557849,
#   'lowSource': '15 minute delayed price',
#   'latestPrice': 6.42,
#   'latestSource': 'Close',
#   'latestTime': 'September 4, 2020',
#   'latestUpdate': 1599249601997,
#   'latestVolume': 89675872,
#   'iexRealtimePrice': None,
#   'iexRealtimeSize': None,
#   'iexLastUpdated': None,
#   'delayedPrice': 6.41,
#   'delayedPriceTime': 1599263999875,
#   'oddLotDelayedPrice': 6.42,
#   'oddLotDelayedPriceTime': 1599249599977,
#   'extendedPrice': 6.41,
#   'extendedChange': -0.01,
#   'extendedChangePercent': -0.00156,
#   'extendedPriceTime': 1599263999875,
#   'previousClose': 6.32,
#   'previousVolume': 94124921,
#   'change': 0.1,
#   'changePercent': 0.01582,
#   'volume': 89675872,
#   'iexMarketPercent': None,
#   'iexVolume': None,
#   'avgTotalVolume': 83063665,
#   'iexBidPrice': None,
#   'iexBidSize': None,
#   'iexAskPrice': None,
#   'iexAskSize': None,
#   'iexOpen': None,
#   'iexOpenTime': None,
#   'iexClose': 6.415,
#   'iexCloseTime': 1599249593167,
#   'marketCap': 56196121800,
#   'peRatio': 15.68,
#   'week52High': 13.26,
#   'week52Low': 5.48,
#   'ytdChange': -0.446041,
#   'lastTradeTime': 1599249601852,
#   'isUSMarketOpen': False}]

# %%
c.listDF().head()
# Out:
#                   companyName          primaryExchange calculationPrice  \
# symbol
# AAPL              Apple, Inc.                   NASDAQ            close
# TSLA              Tesla, Inc.                   NASDAQ            close
# PLM      PolyMet Mining Corp.            NYSE American            close
# BAC     Bank of America Corp.  New York Stock Exchange            close
# GE       General Electric Co.  New York Stock Exchange            close
#
#           open                openTime openSource   close  \
# symbol
# AAPL    120.00 2020-09-04 13:30:02.030   official  120.96
# TSLA    402.70 2020-09-04 13:30:01.365   official  418.32
# PLM       3.20 2020-09-04 13:30:00.033   official    4.40
# BAC      26.24 2020-09-04 13:30:00.972   official   26.54
# GE        6.43 2020-09-04 13:30:01.029   official    6.42
#
#                      closeTime closeSource    high  ...  iexOpenTime iexClose  \
# symbol                                              ...
# AAPL   2020-09-04 20:00:00.801    official  123.70  ...         None  121.110
# TSLA   2020-09-04 20:00:00.552    official  428.00  ...         None  418.500
# PLM    2020-09-04 20:00:00.057    official    6.38  ...         None    4.330
# BAC    2020-09-04 20:00:01.908    official   26.76  ...         None   26.535
# GE     2020-09-04 20:00:01.997    official    6.56  ...         None    6.415
#
#          iexCloseTime      marketCap  peRatio  week52High week52Low ytdChange  \
# symbol
# AAPL    1599249591040  2068718400000    36.45      137.98     52.77  0.633960
# TSLA    1599249597622   389794340880  1030.85      502.49     43.67  3.889057
# PLM     1599249579281      443080000    -6.84        9.70      1.50  1.334532
# BAC     1599249594321   229945214000    12.68       35.72     17.95 -0.221041
# GE      1599249593167    56196121800    15.68       13.26      5.48 -0.446041
#
#         lastTradeTime  isUSMarketOpen
# symbol
# AAPL    1599249600801           False
# TSLA    1599249600552           False
# PLM     1599249600053           False
# BAC     1599249601795           False
# GE      1599249601852           False
#
# [5 rows x 54 columns]

# %% [markdown]
# ## Logo

# %%
c.logo(symbol)
# Out:
# {'url': 'https://storage.googleapis.com/iexcloud-hl37opg/api/logos/AAPL.png'}

# %%
c.logoPNG(symbol) # Not available for sandbox
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=128x128 at 0x7FA2DEC22630>

# %%
c.logoNotebook(symbol) # Not available for sandbox
# Out:
# <img src="https://storage.googleapis.com/iexcloud-hl37opg/api/logos/AAPL.png"/>

# %% [markdown]
# ## Market Volume

# %%
c.marketVolume()[:5]
# Out:
# [{'mic': 'TRF',
#   'tapeId': '',
#   'venueName': 'TRF Volume',
#   'volume': 4405921094,
#   'tapeA': 1566329134,
#   'tapeB': 931974888,
#   'tapeC': 1907617072,
#   'marketPercent': 0.38789,
#   'lastUpdated': 1599254116626},
#  {'mic': 'XNGS',
#   'tapeId': 'Q',
#   'venueName': 'NASDAQ',
#   'volume': 2199925988,
#   'tapeA': 690400369,
#   'tapeB': 379226893,
#   'tapeC': 1130298726,
#   'marketPercent': 0.19368,
#   'lastUpdated': 1599254116778},
#  {'mic': 'XNYS',
#   'tapeId': 'N',
#   'venueName': 'NYSE',
#   'volume': 1119043739,
#   'tapeA': 959731955,
#   'tapeB': 92406736,
#   'tapeC': 66905048,
#   'marketPercent': 0.09852,
#   'lastUpdated': 1599250200010},
#  {'mic': 'ARCX',
#   'tapeId': 'P',
#   'venueName': 'NYSE Arca',
#   'volume': 1111290915,
#   'tapeA': 247871437,
#   'tapeB': 488335318,
#   'tapeC': 375084160,
#   'marketPercent': 0.09784,
#   'lastUpdated': 1599254116071},
#  {'mic': 'EDGX',
#   'tapeId': 'K',
#   'venueName': 'EDGX',
#   'volume': 809332480,
#   'tapeA': 316326650,
#   'tapeB': 204815184,
#   'tapeC': 288190646,
#   'marketPercent': 0.07125,
#   'lastUpdated': 1599254117058}]

# %%
c.marketVolumeDF()
# Out:
# ---------------------------------------------------------------------------
# PyEXception                               Traceback (most recent call last)
# <ipython-input-81-7e314b8d6b33> in <module>
# ----> 1 c.marketVolumeDF()
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pyEX/client.py in bind(self, *args, **kwargs)
#     670         if not meth:
#     671             raise PyEXception('Must provide method!')
# --> 672         return meth(token=self._token, version=self._version, *args, **kwargs)
#     673
#     674     def account(self):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pyEX/stocks/marketInfo.py in marketVolumeDF(token, version, filter)
#     263         DataFrame: result
#     264     '''
# --> 265     df = pd.DataFrame(marketVolume())
#     266     _toDatetime(df, cols=[], tcols=['lastUpdated'])
#     267     return df
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pyEX/stocks/marketInfo.py in marketVolume(token, version, filter)
#     246         dict: result
#     247     '''
# --> 248     return _getJson('market/', token, version, filter)
#     249
#     250
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pyEX/common.py in _getJson(url, token, version, filter)
#     383         if version == 'sandbox':
#     384             return _getJsonIEXCloudSandbox(url, token, version, filter)
# --> 385         return _getJsonIEXCloud(url, token, version, filter)
#     386     return _getJsonOrig(url)
#     387
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pyEX/common.py in _getJsonIEXCloud(url, token, version, filter)
#     400     if resp.status_code == 200:
#     401         return resp.json()
# --> 402     raise PyEXception('Response %d - ' % resp.status_code, resp.text)
#     403
#     404
#
# PyEXception: ('Response 404 - ', 'Not Found')

# %% [markdown]
# ## News

# %%
c.news(symbol)[:5]
# Out:
# [{'datetime': 1599413705000,
#   'headline': 'Connecting The Dots: How SoftBank Made Billions Using The Biggest "Gamma Squeeze" In History',
#   'source': 'Zero Hedge',
#   'url': 'https://cloud.iexapis.com/v1/news/article/72b2e836-4961-476b-bb29-5ef403d5a550',
#   'summary': 'Connecting The Dots: How SoftBank Made Billions Using The Biggest "Gamma Squeeze" In History Tyler Durden Sun, 09/06/2020 - 13:35 It was back in July when we first reported that Goldman had observed a "historic inversion" in the stcok market: for the first time ever, the average daily value of options traded has exceeded shares for the first time, with July single stock options volumes tracking 114% of shares volumes. This followed a May report in which we discussed "how retail investors took over the stock market", pointing out the "recent surge in options trading - which has far more impact on market flows due to embedded leverage" and cited Goldman data which showed that " individual investor active trading is playing an increased role in market volatility, particularly in select stocks. In the shares market, 2.3% of all volume is made up of trades for $2,000 or less. The increase in small trades has been even more notable in the options market, where 13% of all trades are for 1 contract ." We also pointed out that "a significant portion of this increase has been driven by higher volumes in short dated contracts , as investors are literally using massive leverage to wager on near-term momentum moves such as those often highlighted OTM calls traded in Tesla stock." The last clue that an entire generation of investors were flooding into options - read calls - was the surge in individual investor option activity in both the top 50 and the top 500 US names, which has continued a steady climb since the start of the year (with a larger recent increase in the proportion of volume among the top 50.) To be sure, this option frenzy was a goldmine for retail brokerages such as Robinhood, Schwab and Etrade, which reported options trading activity surging 129% YTD (up 35% from June levels), which helped explain why various HFT outfits are paying so much to frontrun Robinhood option trades.',
#   'related': 'AAPL',
#   'image': 'https://cloud.iexapis.com/v1/news/image/72b2e836-4961-476b-bb29-5ef403d5a550',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1599409505000,
#   'headline': 'Apple Watch 6 and iPad Air 4 look even more likely for September 8 unveiling',
#   'source': 'TechRadar',
#   'url': 'https://cloud.iexapis.com/v1/news/article/a505d8db-f622-45ac-afb3-9c6ee3f72d63',
#   'summary': "A new leak further suggests we'll be seeing new products from Apple on September 8.",
#   'related': 'AAPL',
#   'image': 'https://cloud.iexapis.com/v1/news/image/a505d8db-f622-45ac-afb3-9c6ee3f72d63',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1599400206000,
#   'headline': 'Which FAANG Stock Will Grow The Most By 2025?',
#   'source': 'Benzinga',
#   'url': 'https://cloud.iexapis.com/v1/news/article/9f0b5889-a45e-4794-a369-6d65368020c3',
#   'summary': 'Every week, Benzinga conducts a survey to collect sentiment on what traders are most excited about; interested in; or thinking about when they are managing and building their personal portfolios. What Are FAANG Stocks? The term FAANG stocks refers to five of the most popular tech stocks traded on the NASDAQ and NYSE. This week we posed the following question related to FAANG stocks: Over the next five years, which stock will have the largest percentage gain? Facebook, Inc. (NASDAQ: FB ) Amazon.com, Inc. (NASDAQ: AMZN ) Apple Inc. (NASDAQ: … Full story available on Benzinga.com',
#   'related': 'AAPL',
#   'image': 'https://cloud.iexapis.com/v1/news/image/9f0b5889-a45e-4794-a369-6d65368020c3',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1599396604000,
#   'headline': "Tony Zhang's Apple Options Trade",
#   'source': 'Benzinga',
#   'url': 'https://cloud.iexapis.com/v1/news/article/3533445d-7672-4d2e-b410-944b7b7c7205',
#   'summary': 'On CNBC\'s "Options Action," Tony Zhang suggested that investors should consider a bullish options strategy in Apple Inc. (NASDAQ: AAPL ). He believes that the sell-off is going to be contained with the volatility we have seen over the past couple of days. Zhang thinks Apple\'s chart is strong, relative to the market and to … Full story available on Benzinga.com',
#   'related': 'AAPL',
#   'image': 'https://cloud.iexapis.com/v1/news/image/3533445d-7672-4d2e-b410-944b7b7c7205',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1599396451000,
#   'headline': "Epic makes another attempt at reversing 'Fortnite' App Store ban (NASDAQ:AAPL)",
#   'source': 'Seeking Alpha',
#   'url': 'https://cloud.iexapis.com/v1/news/article/7dc6b249-9734-40ee-9b08-4b7b6d142604',
#   'summary': "Fornite creator Epic Games is taking another stab at getting U.S. District Judge Yvonne Gonzalez Rogers to bring the popular game back to Apple's (NASDAQ:A",
#   'related': 'AAPL',
#   'image': 'https://cloud.iexapis.com/v1/news/image/7dc6b249-9734-40ee-9b08-4b7b6d142604',
#   'lang': 'en',
#   'hasPaywall': False}]

# %%
c.newsDF(symbol).head()
# Out:
#                                                               headline  \
# datetime
# 2020-09-06 17:35:05  Connecting The Dots: How SoftBank Made Billion...
# 2020-09-06 16:25:05  Apple Watch 6 and iPad Air 4 look even more li...
# 2020-09-06 13:50:06      Which FAANG Stock Will Grow The Most By 2025?
# 2020-09-06 12:50:04                   Tony Zhang's Apple Options Trade
# 2020-09-06 12:47:31  Epic makes another attempt at reversing 'Fortn...
#
#                             source  \
# datetime
# 2020-09-06 17:35:05     Zero Hedge
# 2020-09-06 16:25:05      TechRadar
# 2020-09-06 13:50:06       Benzinga
# 2020-09-06 12:50:04       Benzinga
# 2020-09-06 12:47:31  Seeking Alpha
#
#                                                                    url  \
# datetime
# 2020-09-06 17:35:05  https://cloud.iexapis.com/v1/news/article/72b2...
# 2020-09-06 16:25:05  https://cloud.iexapis.com/v1/news/article/a505...
# 2020-09-06 13:50:06  https://cloud.iexapis.com/v1/news/article/9f0b...
# 2020-09-06 12:50:04  https://cloud.iexapis.com/v1/news/article/3533...
# 2020-09-06 12:47:31  https://cloud.iexapis.com/v1/news/article/7dc6...
#
#                                                                summary  \
# datetime
# 2020-09-06 17:35:05  Connecting The Dots: How SoftBank Made Billion...
# 2020-09-06 16:25:05  A new leak further suggests we'll be seeing ne...
# 2020-09-06 13:50:06  Every week, Benzinga conducts a survey to coll...
# 2020-09-06 12:50:04  On CNBC's "Options Action," Tony Zhang suggest...
# 2020-09-06 12:47:31  Fornite creator Epic Games is taking another s...
#
#                     related  \
# datetime
# 2020-09-06 17:35:05    AAPL
# 2020-09-06 16:25:05    AAPL
# 2020-09-06 13:50:06    AAPL
# 2020-09-06 12:50:04    AAPL
# 2020-09-06 12:47:31    AAPL
#
#                                                                  image lang  \
# datetime
# 2020-09-06 17:35:05  https://cloud.iexapis.com/v1/news/image/72b2e8...   en
# 2020-09-06 16:25:05  https://cloud.iexapis.com/v1/news/image/a505d8...   en
# 2020-09-06 13:50:06  https://cloud.iexapis.com/v1/news/image/9f0b58...   en
# 2020-09-06 12:50:04  https://cloud.iexapis.com/v1/news/image/353344...   en
# 2020-09-06 12:47:31  https://cloud.iexapis.com/v1/news/image/7dc6b2...   en
#
#                      hasPaywall
# datetime
# 2020-09-06 17:35:05       False
# 2020-09-06 16:25:05       False
# 2020-09-06 13:50:06       False
# 2020-09-06 12:50:04       False
# 2020-09-06 12:47:31       False

# %%
c.marketNews()[:5]
# Out:
# [{'datetime': 1599413705000,
#   'headline': 'Connecting The Dots: How SoftBank Made Billions Using The Biggest "Gamma Squeeze" In History',
#   'source': 'Zero Hedge',
#   'url': 'https://cloud.iexapis.com/v1/news/article/72b2e836-4961-476b-bb29-5ef403d5a550',
#   'summary': 'Connecting The Dots: How SoftBank Made Billions Using The Biggest "Gamma Squeeze" In History Tyler Durden Sun, 09/06/2020 - 13:35 It was back in July when we first reported that Goldman had observed a "historic inversion" in the stcok market: for the first time ever, the average daily value of options traded has exceeded shares for the first time, with July single stock options volumes tracking 114% of shares volumes. This followed a May report in which we discussed "how retail investors took over the stock market", pointing out the "recent surge in options trading - which has far more impact on market flows due to embedded leverage" and cited Goldman data which showed that " individual investor active trading is playing an increased role in market volatility, particularly in select stocks. In the shares market, 2.3% of all volume is made up of trades for $2,000 or less. The increase in small trades has been even more notable in the options market, where 13% of all trades are for 1 contract ." We also pointed out that "a significant portion of this increase has been driven by higher volumes in short dated contracts , as investors are literally using massive leverage to wager on near-term momentum moves such as those often highlighted OTM calls traded in Tesla stock." The last clue that an entire generation of investors were flooding into options - read calls - was the surge in individual investor option activity in both the top 50 and the top 500 US names, which has continued a steady climb since the start of the year (with a larger recent increase in the proportion of volume among the top 50.) To be sure, this option frenzy was a goldmine for retail brokerages such as Robinhood, Schwab and Etrade, which reported options trading activity surging 129% YTD (up 35% from June levels), which helped explain why various HFT outfits are paying so much to frontrun Robinhood option trades.',
#   'related': 'SP500',
#   'image': 'https://cloud.iexapis.com/v1/news/image/72b2e836-4961-476b-bb29-5ef403d5a550',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1599407280000,
#   'headline': 'Tesla-Aktie knickt nachbörslich ein: Tesla schafft Sprung in S&P 500 nicht',
#   'source': 'Finanzen CH',
#   'url': 'https://cloud.iexapis.com/v1/news/article/3d50328e-ca1a-471a-bdef-002365476de2',
#   'summary': 'Am Kapitalmarkt hatten viele damit gerechnet, dass der Elektroautobauer den Sprung in den S&P 500 schafft. Nachbörslich schickten enttäuschte Investoren die Aktie am Freitag auf Talfahrt. An der NASDAQ ging es nachbörslich zeitweise um 6,45 Prozent auf 391,33 US-Dollar runter.',
#   'related': 'SP500',
#   'image': 'https://cloud.iexapis.com/v1/news/image/3d50328e-ca1a-471a-bdef-002365476de2',
#   'lang': 'de',
#   'hasPaywall': False},
#  {'datetime': 1599406920000,
#   'headline': 'Tesla-Aktie sackt nachbörslich ab: Tesla schafft Sprung in S&P 500 nicht',
#   'source': 'Finanzen AT',
#   'url': 'https://cloud.iexapis.com/v1/news/article/f4f5ab69-dec2-4c71-81ab-fd6616a92f6d',
#   'summary': 'Am Kapitalmarkt hatten viele damit gerechnet, dass der Elektroautobauer den Sprung in den S&P 500 schafft. Nachbörslich schickten enttäuschte Investoren die Aktie am Freitag auf Talfahrt. An der NASDAQ ging es nachbörslich zeitweise um 6,45 Prozent auf 391,33 US-Dollar runter.',
#   'related': 'SP500',
#   'image': 'https://cloud.iexapis.com/v1/news/image/f4f5ab69-dec2-4c71-81ab-fd6616a92f6d',
#   'lang': 'de',
#   'hasPaywall': False},
#  {'datetime': 1599406226000,
#   'headline': 'Rationales For S&P 500 Valuation (SP500)',
#   'source': 'Seeking Alpha',
#   'url': 'https://cloud.iexapis.com/v1/news/article/289e87b7-5501-4bbe-a1f0-a5528c9c1a60',
#   'summary': 'In this video I make a brief overview of fair value of the S&P 500 based on DCF and comparable estimates. Fundamental gravity does not apply for time being.',
#   'related': 'SP500',
#   'image': 'https://cloud.iexapis.com/v1/news/image/289e87b7-5501-4bbe-a1f0-a5528c9c1a60',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1599406020000,
#   'headline': 'Reflections After An Exceptional Month Within An Extraordinary Year - Stock Market Update, September 2, 2020',
#   'source': 'Seeking Alpha',
#   'url': 'https://cloud.iexapis.com/v1/news/article/7158836d-0cb4-4cd6-a6c5-0532f46b64a8',
#   'summary': 'More than half of the days in August saw more S&P 500 stocks down than up, yet the index itself posted a 7% gain for the month.',
#   'related': 'SP500',
#   'image': 'https://cloud.iexapis.com/v1/news/image/7158836d-0cb4-4cd6-a6c5-0532f46b64a8',
#   'lang': 'en',
#   'hasPaywall': False}]

# %%
c.marketNewsDF().head()
# Out:
#                                                                      headline  \
# datetime
# 1970-01-01 00:26:39.413705  Connecting The Dots: How SoftBank Made Billion...
# 1970-01-01 00:26:39.407280  Tesla-Aktie knickt nachbörslich ein: Tesla sch...
# 1970-01-01 00:26:39.406920  Tesla-Aktie sackt nachbörslich ab: Tesla schaf...
# 1970-01-01 00:26:39.406226           Rationales For S&P 500 Valuation (SP500)
# 1970-01-01 00:26:39.406020  Reflections After An Exceptional Month Within ...
#
#                                    source  \
# datetime
# 1970-01-01 00:26:39.413705     Zero Hedge
# 1970-01-01 00:26:39.407280    Finanzen CH
# 1970-01-01 00:26:39.406920    Finanzen AT
# 1970-01-01 00:26:39.406226  Seeking Alpha
# 1970-01-01 00:26:39.406020  Seeking Alpha
#
#                                                                           url  \
# datetime
# 1970-01-01 00:26:39.413705  https://cloud.iexapis.com/v1/news/article/72b2...
# 1970-01-01 00:26:39.407280  https://cloud.iexapis.com/v1/news/article/3d50...
# 1970-01-01 00:26:39.406920  https://cloud.iexapis.com/v1/news/article/f4f5...
# 1970-01-01 00:26:39.406226  https://cloud.iexapis.com/v1/news/article/289e...
# 1970-01-01 00:26:39.406020  https://cloud.iexapis.com/v1/news/article/7158...
#
#                                                                       summary  \
# datetime
# 1970-01-01 00:26:39.413705  Connecting The Dots: How SoftBank Made Billion...
# 1970-01-01 00:26:39.407280  Am Kapitalmarkt hatten viele damit gerechnet, ...
# 1970-01-01 00:26:39.406920  Am Kapitalmarkt hatten viele damit gerechnet, ...
# 1970-01-01 00:26:39.406226  In this video I make a brief overview of fair ...
# 1970-01-01 00:26:39.406020  More than half of the days in August saw more ...
#
#                            related  \
# datetime
# 1970-01-01 00:26:39.413705   SP500
# 1970-01-01 00:26:39.407280   SP500
# 1970-01-01 00:26:39.406920   SP500
# 1970-01-01 00:26:39.406226   SP500
# 1970-01-01 00:26:39.406020   SP500
#
#                                                                         image  \
# datetime
# 1970-01-01 00:26:39.413705  https://cloud.iexapis.com/v1/news/image/72b2e8...
# 1970-01-01 00:26:39.407280  https://cloud.iexapis.com/v1/news/image/3d5032...
# 1970-01-01 00:26:39.406920  https://cloud.iexapis.com/v1/news/image/f4f5ab...
# 1970-01-01 00:26:39.406226  https://cloud.iexapis.com/v1/news/image/289e87...
# 1970-01-01 00:26:39.406020  https://cloud.iexapis.com/v1/news/image/715883...
#
#                            lang  hasPaywall
# datetime
# 1970-01-01 00:26:39.413705   en       False
# 1970-01-01 00:26:39.407280   de       False
# 1970-01-01 00:26:39.406920   de       False
# 1970-01-01 00:26:39.406226   en       False
# 1970-01-01 00:26:39.406020   en       False

# %% [markdown]
# ## OHLC

# %%
c.ohlc(symbol)
# Out:
# {'open': {'price': 120, 'time': 1599226202030},
#  'close': {'price': 120.96, 'time': 1599249600801},
#  'high': 123.7,
#  'low': 110.89,
#  'volume': 332607163,
#  'symbol': 'AAPL'}

# %%
c.ohlcDF(symbol)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pyEX/stocks/prices.py:322: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   df = pd.io.json.json_normalize(o)
#     high     low     volume symbol  open.price               open.time  \
# 0  123.7  110.89  332607163   AAPL         120 2020-09-04 13:30:02.030
#
#    close.price              close.time
# 0       120.96 2020-09-04 20:00:00.801

# %% [markdown]
# ## Open/Close Price

# %%
c.ohlc(symbol)
# Out:
# {'open': {'price': 120, 'time': 1599226202030},
#  'close': {'price': 120.96, 'time': 1599249600801},
#  'high': 123.7,
#  'low': 110.89,
#  'volume': 332607163,
#  'symbol': 'AAPL'}

# %%
c.ohlcDF(symbol)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pyEX/stocks/prices.py:322: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   df = pd.io.json.json_normalize(o)
#     high     low     volume symbol  open.price               open.time  \
# 0  123.7  110.89  332607163   AAPL         120 2020-09-04 13:30:02.030
#
#    close.price              close.time
# 0       120.96 2020-09-04 20:00:00.801

# %% [markdown]
# ## Options

# %%
exps = c.optionExpirations(symbol)
exps
# Out:
# ['202009',
#  '202010',
#  '202011',
#  '202012',
#  '202101',
#  '202103',
#  '202104',
#  '202106',
#  '202109',
#  '202201',
#  '202206',
#  '202209']

# %%
c.options(symbol, exps[0])[:5]
# Out:
# [{'symbol': 'AAPL',
#   'id': 'AAPL20200925C00113750',
#   'expirationDate': '20200925',
#   'contractSize': 100,
#   'strikePrice': 113.75,
#   'closingPrice': 12.25,
#   'side': 'call',
#   'type': 'equity',
#   'volume': 44,
#   'openInterest': 1593,
#   'bid': 9.2,
#   'ask': 13.7,
#   'lastUpdated': '2020-09-03',
#   'isAdjusted': False},
#  {'symbol': 'AAPL',
#   'id': 'AAPL20200918C00071250',
#   'expirationDate': '20200918',
#   'contractSize': 100,
#   'strikePrice': 71.25,
#   'closingPrice': 52.639999,
#   'side': 'call',
#   'type': 'equity',
#   'volume': 12,
#   'openInterest': 36,
#   'bid': 47.900002,
#   'ask': 52.200001,
#   'lastUpdated': '2020-09-03',
#   'isAdjusted': False},
#  {'symbol': 'AAPL',
#   'id': 'AAPL20200904C00047500',
#   'expirationDate': '20200904',
#   'contractSize': 100,
#   'strikePrice': 47.5,
#   'closingPrice': 73.900002,
#   'side': 'call',
#   'type': 'equity',
#   'volume': 20,
#   'openInterest': 79,
#   'bid': 71.25,
#   'ask': 75.900002,
#   'lastUpdated': '2020-09-03',
#   'isAdjusted': False},
#  {'symbol': 'AAPL',
#   'id': 'AAPL20200918C00151250',
#   'expirationDate': '20200918',
#   'contractSize': 100,
#   'strikePrice': 151.25,
#   'closingPrice': 0.61,
#   'side': 'call',
#   'type': 'equity',
#   'volume': 456,
#   'openInterest': 2134,
#   'bid': 0.5,
#   'ask': 0.67,
#   'lastUpdated': '2020-09-03',
#   'isAdjusted': False},
#  {'symbol': 'AAPL',
#   'id': 'AAPL20200904C00111250',
#   'expirationDate': '20200904',
#   'contractSize': 100,
#   'strikePrice': 111.25,
#   'closingPrice': 10.09,
#   'side': 'call',
#   'type': 'equity',
#   'volume': 752,
#   'openInterest': 2417,
#   'bid': 7.7,
#   'ask': 12.4,
#   'lastUpdated': '2020-09-03',
#   'isAdjusted': False}]

# %%
c.optionsDF(symbol, exps[0]).head()
# Out:
#   symbol                     id expirationDate  contractSize  strikePrice  \
# 0   AAPL  AAPL20200925C00113750     2020-09-25           100       113.75
# 1   AAPL  AAPL20200918C00071250     2020-09-18           100        71.25
# 2   AAPL  AAPL20200904C00047500     2020-09-04           100        47.50
# 3   AAPL  AAPL20200918C00151250     2020-09-18           100       151.25
# 4   AAPL  AAPL20200904C00111250     2020-09-04           100       111.25
#
#    closingPrice  side    type  volume  openInterest        bid        ask  \
# 0     12.250000  call  equity      44          1593   9.200000  13.700000
# 1     52.639999  call  equity      12            36  47.900002  52.200001
# 2     73.900002  call  equity      20            79  71.250000  75.900002
# 3      0.610000  call  equity     456          2134   0.500000   0.670000
# 4     10.090000  call  equity     752          2417   7.700000  12.400000
#
#   lastUpdated  isAdjusted
# 0  2020-09-03       False
# 1  2020-09-03       False
# 2  2020-09-03       False
# 3  2020-09-03       False
# 4  2020-09-03       False

# %% [markdown]
# ## Peers

# %%
c.peers(symbol)
# Out:
# ['MSFT', 'HPQ', 'GOOG', 'AMZN', 'NFLX']

# %%
c.peersDF(symbol)
# Out:
#         peer
# symbol
# MSFT    MSFT
# HPQ      HPQ
# GOOG    GOOG
# AMZN    AMZN
# NFLX    NFLX

# %% [markdown]
# ## Previous Day Price

# %%
c.yesterday(symbol)
# Out:
# {'date': '2020-09-04',
#  'open': 120.07,
#  'close': 120.96,
#  'high': 123.7,
#  'low': 110.89,
#  'volume': 332607163,
#  'uOpen': 120.07,
#  'uClose': 120.96,
#  'uHigh': 123.7,
#  'uLow': 110.89,
#  'uVolume': 332607163,
#  'change': 0.08,
#  'changePercent': 0.0662,
#  'changeOverTime': 0,
#  'symbol': 'AAPL'}

# %%
c.yesterdayDF(symbol)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pyEX/stocks/prices.py:366: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   df = pd.io.json.json_normalize(y)
#              date    open   close   high     low     volume   uOpen  uClose  \
# symbol
# AAPL   2020-09-04  120.07  120.96  123.7  110.89  332607163  120.07  120.96
#
#         uHigh    uLow    uVolume  change  changePercent  changeOverTime
# symbol
# AAPL    123.7  110.89  332607163    0.08         0.0662               0

# %%
c.marketYesterday()
# Out:
# [{'date': '2020-09-04',
#   'open': 5.35,
#   'close': 5.47,
#   'high': 5.55,
#   'low': 5.15,
#   'volume': 130741,
#   'uOpen': 5.35,
#   'uClose': 5.47,
#   'uHigh': 5.55,
#   'uLow': 5.15,
#   'uVolume': 130741,
#   'change': 0.23,
#   'changePercent': 4.3893,
#   'changeOverTime': 0,
#   'symbol': 'CMLS'},
#  {'date': '2020-09-04',
#   'open': 55.55,
#   'close': 55.47,
#   'high': 55.56,
#   'low': 55.43,
#   'volume': 114753,
#   'uOpen': 55.55,
#   'uClose': 55.47,
#   'uHigh': 55.56,
#   'uLow': 55.43,
#   'uVolume': 114753,
#   'change': -0.12,
#   'changePercent': -0.2159,
#   'changeOverTime': 0,
#   'symbol': 'IAGG'},
#  {'date': '2020-09-04',
#   'open': 3.44,
#   'close': 3.55,
#   'high': 3.55,
#   'low': 3.31,
#   'volume': 15142,
#   'uOpen': 3.44,
#   'uClose': 3.55,
#   'uHigh': 3.55,
#   'uLow': 3.31,
#   'uVolume': 15142,
#   'change': 0.04,
#   'changePercent': 0.9957,
#   'changeOverTime': 0,
#   'symbol': 'MAGS'},
#  {'date': '2020-09-04',
#   'open': 25.82,
#   'close': 25.96,
#   'high': 25.96,
#   'low': 25.5,
#   'volume': 86029,
#   'uOpen': 25.82,
#   'uClose': 25.96,
#   'uHigh': 25.96,
#   'uLow': 25.5,
#   'uVolume': 86029,
#   'change': 0.16,
#   'changePercent': 0.6202,
#   'changeOverTime': 0,
#   'symbol': 'AMH-E'},
#  {'date': '2020-09-04',
#   'open': 26.15,
#   'close': 26.16,
#   'high': 26.19,
#   'low': 26.15,
#   'volume': 1188,
#   'uOpen': 26.15,
#   'uClose': 26.16,
#   'uHigh': 26.19,
#   'uLow': 26.15,
#   'uVolume': 1188,
#   'change': 0.04,
#   'changePercent': 0.1531,
#   'changeOverTime': 0,
#   'symbol': 'GRX-B'},
#  {'date': '2020-09-04',
#   'open': 25.71,
#   'close': 25.76,
#   'high': 25.76,
#   'low': 25.45,
#   'volume': 883,
#   'uOpen': 25.71,
#   'uClose': 25.76,
#   'uHigh': 25.76,
#   'uLow': 25.45,
#   'uVolume': 883,
#   'change': -0.14,
#   'changePercent': -0.5405,
#   'changeOverTime': 0,
#   'symbol': 'AUGZ'},
#  {'date': '2020-08-21',
#   'open': 33.41,
#   'close': 33.48,
#   'high': 33.48,
#   'low': 33.38,
#   'volume': 1602,
#   'uOpen': 33.41,
#   'uClose': 33.48,
#   'uHigh': 33.48,
#   'uLow': 33.38,
#   'uVolume': 1602,
#   'change': -0.02,
#   'changePercent': -0.0597,
#   'changeOverTime': 0,
#   'symbol': 'SCIU'},
#  {'date': '2020-09-04',
#   'open': 27.7,
#   'close': 27.38,
#   'high': 27.7,
#   'low': 27.34,
#   'volume': 4353,
#   'uOpen': 27.7,
#   'uClose': 27.38,
#   'uHigh': 27.7,
#   'uLow': 27.34,
#   'uVolume': 4353,
#   'change': -0.27,
#   'changePercent': -0.9765,
#   'changeOverTime': 0,
#   'symbol': 'AQNA'},
#  {'date': '2020-09-04',
#   'open': 8.32,
#   'close': 8.3,
#   'high': 8.34,
#   'low': 8.19,
#   'volume': 154918,
#   'uOpen': 8.32,
#   'uClose': 8.3,
#   'uHigh': 8.34,
#   'uLow': 8.19,
#   'uVolume': 154918,
#   'change': -0.03,
#   'changePercent': -0.3601,
#   'changeOverTime': 0,
#   'symbol': 'HYB'},
#  {'date': '2020-09-04',
#   'open': 8.25,
#   'close': 7.99,
#   'high': 8.34,
#   'low': 7.65,
#   'volume': 236024,
#   'uOpen': 8.25,
#   'uClose': 7.99,
#   'uHigh': 8.34,
#   'uLow': 7.65,
#   'uVolume': 236024,
#   'change': -0.1,
#   'changePercent': -1.2361,
#   'changeOverTime': 0,
#   'symbol': 'CURO'},
#  {'date': '2020-09-04',
#   'open': 120.91,
#   'close': 122.87,
#   'high': 123.08,
#   'low': 119.77,
#   'volume': 3144594,
#   'uOpen': 120.91,
#   'uClose': 122.87,
#   'uHigh': 123.08,
#   'uLow': 119.77,
#   'uVolume': 3144594,
#   'change': 1.45,
#   'changePercent': 1.1942,
#   'changeOverTime': 0,
#   'symbol': 'BIDU'},
#  {'date': '2020-09-04',
#   'open': 11.25,
#   'close': 11.32,
#   'high': 11.47,
#   'low': 10.89,
#   'volume': 923209,
#   'uOpen': 11.25,
#   'uClose': 11.32,
#   'uHigh': 11.47,
#   'uLow': 10.89,
#   'uVolume': 923209,
#   'change': 0.06,
#   'changePercent': 0.5329,
#   'changeOverTime': 0,
#   'symbol': 'ABR'},
#  {'date': '2020-09-04',
#   'open': 6.88,
#   'close': 6.86,
#   'high': 6.91,
#   'low': 6.74,
#   'volume': 566728,
#   'uOpen': 6.88,
#   'uClose': 6.86,
#   'uHigh': 6.91,
#   'uLow': 6.74,
#   'uVolume': 566728,
#   'change': -0.11,
#   'changePercent': -1.5782,
#   'changeOverTime': 0,
#   'symbol': 'AFIN'},
#  {'date': '2020-09-04',
#   'open': 28.06,
#   'close': 27.81,
#   'high': 28.22,
#   'low': 27.29,
#   'volume': 303862,
#   'uOpen': 28.06,
#   'uClose': 27.81,
#   'uHigh': 28.22,
#   'uLow': 27.29,
#   'uVolume': 303862,
#   'change': -0.13,
#   'changePercent': -0.4653,
#   'changeOverTime': 0,
#   'symbol': 'PTMC'},
#  {'date': '2020-09-04',
#   'open': 5.4,
#   'close': 5.33,
#   'high': 5.46,
#   'low': 5.01,
#   'volume': 169555,
#   'uOpen': 5.4,
#   'uClose': 5.33,
#   'uHigh': 5.46,
#   'uLow': 5.01,
#   'uVolume': 169555,
#   'change': -0.04,
#   'changePercent': -0.7449,
#   'changeOverTime': 0,
#   'symbol': 'QMCO'},
#  {'date': '2020-09-04',
#   'open': 21.43,
#   'close': 21.18,
#   'high': 21.43,
#   'low': 21.11,
#   'volume': 7818,
#   'uOpen': 21.43,
#   'uClose': 21.18,
#   'uHigh': 21.43,
#   'uLow': 21.11,
#   'uVolume': 7818,
#   'change': -0.09,
#   'changePercent': -0.4231,
#   'changeOverTime': 0,
#   'symbol': 'CHMI-B'},
#  {'date': '2020-09-04',
#   'open': 1.86,
#   'close': 1.77,
#   'high': 1.88,
#   'low': 1.6,
#   'volume': 2801531,
#   'uOpen': 1.86,
#   'uClose': 1.77,
#   'uHigh': 1.88,
#   'uLow': 1.6,
#   'uVolume': 2801531,
#   'change': -0.07,
#   'changePercent': -3.8043,
#   'changeOverTime': 0,
#   'symbol': 'AIM'},
#  {'date': '2020-09-04',
#   'open': 27.26,
#   'close': 27.18,
#   'high': 27.48,
#   'low': 26.69,
#   'volume': 165074,
#   'uOpen': 27.26,
#   'uClose': 27.18,
#   'uHigh': 27.48,
#   'uLow': 26.69,
#   'uVolume': 165074,
#   'change': 0.41,
#   'changePercent': 1.5316,
#   'changeOverTime': 0,
#   'symbol': 'FXO'},
#  {'date': '2020-09-04',
#   'open': 1.71,
#   'close': 1.6,
#   'high': 1.73,
#   'low': 1.45,
#   'volume': 948662,
#   'uOpen': 1.71,
#   'uClose': 1.6,
#   'uHigh': 1.73,
#   'uLow': 1.45,
#   'uVolume': 948662,
#   'change': -0.11,
#   'changePercent': -6.4327,
#   'changeOverTime': 0,
#   'symbol': 'CLBS'},
#  {'date': '2020-09-04',
#   'open': 12.47,
#   'close': 12.72,
#   'high': 13.69,
#   'low': 12.47,
#   'volume': 3630,
#   'uOpen': 12.47,
#   'uClose': 12.72,
#   'uHigh': 13.69,
#   'uLow': 12.47,
#   'uVolume': 3630,
#   'change': 0.09,
#   'changePercent': 0.7102,
#   'changeOverTime': 0,
#   'symbol': 'LSBK'},
#  {'date': '2020-09-04',
#   'open': 0.702,
#   'close': 0.73,
#   'high': 1.14,
#   'low': 0.6316,
#   'volume': 31008573,
#   'uOpen': 0.702,
#   'uClose': 0.73,
#   'uHigh': 1.14,
#   'uLow': 0.6316,
#   'uVolume': 31008573,
#   'change': 0.145,
#   'changePercent': 24.7863,
#   'changeOverTime': 0,
#   'symbol': 'RETO'},
#  {'date': '2020-09-04',
#   'open': 22.81,
#   'close': 23,
#   'high': 23.21,
#   'low': 22.47,
#   'volume': 1587858,
#   'uOpen': 22.81,
#   'uClose': 23,
#   'uHigh': 23.21,
#   'uLow': 22.47,
#   'uVolume': 1587858,
#   'change': 0.56,
#   'changePercent': 2.4955,
#   'changeOverTime': 0,
#   'symbol': 'HUN'},
#  {'date': '2020-09-04',
#   'open': 44.17,
#   'close': 44.09,
#   'high': 44.43,
#   'low': 43.37,
#   'volume': 20440198,
#   'uOpen': 44.17,
#   'uClose': 44.09,
#   'uHigh': 44.43,
#   'uLow': 43.37,
#   'uVolume': 20440198,
#   'change': -0.08,
#   'changePercent': -0.1811,
#   'changeOverTime': 0,
#   'symbol': 'VWO'},
#  {'date': '2020-09-04',
#   'open': 6.86,
#   'close': 6.75,
#   'high': 6.95,
#   'low': 6.65,
#   'volume': 390840,
#   'uOpen': 6.86,
#   'uClose': 6.75,
#   'uHigh': 6.95,
#   'uLow': 6.65,
#   'uVolume': 390840,
#   'change': 0.03,
#   'changePercent': 0.4464,
#   'changeOverTime': 0,
#   'symbol': 'TAST'},
#  {'date': '2020-09-04',
#   'open': 15.6,
#   'close': 16.35,
#   'high': 16.46,
#   'low': 15.6,
#   'volume': 1101408,
#   'uOpen': 15.6,
#   'uClose': 16.35,
#   'uHigh': 16.46,
#   'uLow': 15.6,
#   'uVolume': 1101408,
#   'change': 0.91,
#   'changePercent': 5.8938,
#   'changeOverTime': 0,
#   'symbol': 'CHEF'},
#  {'date': '2020-09-04',
#   'open': 13.49,
#   'close': 13.37,
#   'high': 13.5,
#   'low': 13.21,
#   'volume': 30852,
#   'uOpen': 13.49,
#   'uClose': 13.37,
#   'uHigh': 13.5,
#   'uLow': 13.21,
#   'uVolume': 30852,
#   'change': 0.03,
#   'changePercent': 0.2249,
#   'changeOverTime': 0,
#   'symbol': 'JTD'},
#  {'date': '2020-09-04',
#   'open': 25.29,
#   'close': 25.42,
#   'high': 25.42,
#   'low': 25.25,
#   'volume': 1558,
#   'uOpen': 25.29,
#   'uClose': 25.42,
#   'uHigh': 25.42,
#   'uLow': 25.25,
#   'uVolume': 1558,
#   'change': -0.03,
#   'changePercent': -0.1179,
#   'changeOverTime': 0,
#   'symbol': 'FDEV'},
#  {'date': '2020-09-04',
#   'open': 109.65,
#   'close': 108.92,
#   'high': 109.65,
#   'low': 102.53,
#   'volume': 117904,
#   'uOpen': 109.65,
#   'uClose': 108.92,
#   'uHigh': 109.65,
#   'uLow': 102.53,
#   'uVolume': 117904,
#   'change': -0.08,
#   'changePercent': -0.0734,
#   'changeOverTime': 0,
#   'symbol': 'MDGL'},
#  {'date': '2020-09-04',
#   'open': 4.53,
#   'close': 4.5,
#   'high': 4.53,
#   'low': 4.42,
#   'volume': 262614,
#   'uOpen': 4.53,
#   'uClose': 4.5,
#   'uHigh': 4.53,
#   'uLow': 4.42,
#   'uVolume': 262614,
#   'change': -0.03,
#   'changePercent': -0.6623,
#   'changeOverTime': 0,
#   'symbol': 'EOD'},
#  {'date': '2020-09-04',
#   'open': 12.72,
#   'close': 12.25,
#   'high': 12.84,
#   'low': 12.12,
#   'volume': 22767785,
#   'uOpen': 12.72,
#   'uClose': 12.25,
#   'uHigh': 12.84,
#   'uLow': 12.12,
#   'uVolume': 22767785,
#   'change': -0.34,
#   'changePercent': -2.7006,
#   'changeOverTime': 0,
#   'symbol': 'OXY'},
#  {'date': '2020-09-04',
#   'open': 36.73,
#   'close': 35.99,
#   'high': 36.73,
#   'low': 35.61,
#   'volume': 119953,
#   'uOpen': 36.73,
#   'uClose': 35.99,
#   'uHigh': 36.73,
#   'uLow': 35.61,
#   'uVolume': 119953,
#   'change': -0.12,
#   'changePercent': -0.3323,
#   'changeOverTime': 0,
#   'symbol': 'ECOL'},
#  {'date': '2020-09-04',
#   'open': 7.34,
#   'close': 7.49,
#   'high': 7.58,
#   'low': 7.06,
#   'volume': 19959,
#   'uOpen': 7.34,
#   'uClose': 7.49,
#   'uHigh': 7.58,
#   'uLow': 7.06,
#   'uVolume': 19959,
#   'change': 0.23,
#   'changePercent': 3.168,
#   'changeOverTime': 0,
#   'symbol': 'NEXA'},
#  {'date': '2020-09-04',
#   'open': 64.86,
#   'close': 64.13,
#   'high': 64.86,
#   'low': 62.92,
#   'volume': 29208,
#   'uOpen': 64.86,
#   'uClose': 64.13,
#   'uHigh': 64.86,
#   'uLow': 62.92,
#   'uVolume': 29208,
#   'change': -0.38,
#   'changePercent': -0.5891,
#   'changeOverTime': 0,
#   'symbol': 'FEX'},
#  {'date': '2020-09-04',
#   'open': 8.82,
#   'close': 8.23,
#   'high': 8.84,
#   'low': 8.21,
#   'volume': 47621,
#   'uOpen': 8.82,
#   'uClose': 8.23,
#   'uHigh': 8.84,
#   'uLow': 8.21,
#   'uVolume': 47621,
#   'change': -0.42,
#   'changePercent': -4.8555,
#   'changeOverTime': 0,
#   'symbol': 'ASPN'},
#  {'date': '2020-09-04',
#   'open': 2.52,
#   'close': 2.5,
#   'high': 2.64,
#   'low': 2.42,
#   'volume': 15349,
#   'uOpen': 2.52,
#   'uClose': 2.5,
#   'uHigh': 2.64,
#   'uLow': 2.42,
#   'uVolume': 15349,
#   'change': -0.02,
#   'changePercent': -0.7937,
#   'changeOverTime': 0,
#   'symbol': 'SRTS'},
#  {'date': '2020-09-04',
#   'open': 10,
#   'close': 10,
#   'high': 10.06,
#   'low': 10,
#   'volume': 405,
#   'uOpen': 10,
#   'uClose': 10,
#   'uHigh': 10.06,
#   'uLow': 10,
#   'uVolume': 405,
#   'change': 0.05,
#   'changePercent': 0.5025,
#   'changeOverTime': 0,
#   'symbol': 'DFNS'},
#  {'date': '2020-09-04',
#   'open': 25.21,
#   'close': 25.3,
#   'high': 25.43,
#   'low': 25.15,
#   'volume': 2838,
#   'uOpen': 25.21,
#   'uClose': 25.3,
#   'uHigh': 25.43,
#   'uLow': 25.15,
#   'uVolume': 2838,
#   'change': 0.09,
#   'changePercent': 0.357,
#   'changeOverTime': 0,
#   'symbol': 'BRG-A'},
#  {'date': '2020-09-04',
#   'open': 2.57,
#   'close': 2.44,
#   'high': 2.57,
#   'low': 2.3,
#   'volume': 195064,
#   'uOpen': 2.57,
#   'uClose': 2.44,
#   'uHigh': 2.57,
#   'uLow': 2.3,
#   'uVolume': 195064,
#   'change': -0.11,
#   'changePercent': -4.3137,
#   'changeOverTime': 0,
#   'symbol': 'ACER'},
#  {'date': '2020-09-04',
#   'open': 9.84,
#   'close': 9.84,
#   'high': 9.84,
#   'low': 9.84,
#   'volume': 477,
#   'uOpen': 9.84,
#   'uClose': 9.84,
#   'uHigh': 9.84,
#   'uLow': 9.84,
#   'uVolume': 477,
#   'change': 0.04,
#   'changePercent': 0.4082,
#   'changeOverTime': 0,
#   'symbol': 'SSBI'},
#  {'date': '2020-09-04',
#   'open': 0,
#   'close': 2.89,
#   'high': 0,
#   'low': 0,
#   'volume': 188,
#   'uOpen': 0,
#   'uClose': 2.89,
#   'uHigh': 0,
#   'uLow': 0,
#   'uVolume': 188,
#   'change': 0,
#   'changePercent': 0,
#   'changeOverTime': 0,
#   'symbol': 'CNFR'},
#  {'date': '2020-09-04',
#   'open': 27.14,
#   'close': 26.82,
#   'high': 27.22,
#   'low': 26.66,
#   'volume': 13717,
#   'uOpen': 27.15,
#   'uClose': 26.82,
#   'uHigh': 27.22,
#   'uLow': 26.66,
#   'uVolume': 13717,
#   'change': -0.4,
#   'changePercent': -1.4695,
#   'changeOverTime': 0,
#   'symbol': 'APO-B'},
#  {'date': '2020-09-04',
#   'open': 43.53,
#   'close': 43.06,
#   'high': 43.53,
#   'low': 42.31,
#   'volume': 8502,
#   'uOpen': 43.53,
#   'uClose': 43.06,
#   'uHigh': 43.53,
#   'uLow': 42.31,
#   'uVolume': 8502,
#   'change': -0.24,
#   'changePercent': -0.5543,
#   'changeOverTime': 0,
#   'symbol': 'QLV'},
#  {'date': '2020-09-04',
#   'open': 10.55,
#   'close': 10.54,
#   'high': 10.55,
#   'low': 10.45,
#   'volume': 27148,
#   'uOpen': 10.55,
#   'uClose': 10.54,
#   'uHigh': 10.55,
#   'uLow': 10.45,
#   'uVolume': 27148,
#   'change': 0.08,
#   'changePercent': 0.7648,
#   'changeOverTime': 0,
#   'symbol': 'NCA'},
#  {'date': '2020-09-04',
#   'open': 6.81,
#   'close': 6.72,
#   'high': 6.99,
#   'low': 6.25,
#   'volume': 263353,
#   'uOpen': 6.81,
#   'uClose': 6.72,
#   'uHigh': 6.99,
#   'uLow': 6.25,
#   'uVolume': 263353,
#   'change': -0.05,
#   'changePercent': -0.7386,
#   'changeOverTime': 0,
#   'symbol': 'MWK'},
#  {'date': '2020-09-04',
#   'open': 0.8,
#   'close': 0.768,
#   'high': 0.828,
#   'low': 0.69,
#   'volume': 375780,
#   'uOpen': 0.8,
#   'uClose': 0.768,
#   'uHigh': 0.828,
#   'uLow': 0.69,
#   'uVolume': 375780,
#   'change': -0.062,
#   'changePercent': -7.4699,
#   'changeOverTime': 0,
#   'symbol': 'MTC'},
#  {'date': '2020-09-04',
#   'open': 29.15,
#   'close': 29.07,
#   'high': 29.52,
#   'low': 28.22,
#   'volume': 93772,
#   'uOpen': 29.15,
#   'uClose': 29.07,
#   'uHigh': 29.52,
#   'uLow': 28.22,
#   'uVolume': 93772,
#   'change': 0.52,
#   'changePercent': 1.8214,
#   'changeOverTime': 0,
#   'symbol': 'CIR'},
#  {'date': '2020-09-04',
#   'open': 0.85,
#   'close': 0.8096,
#   'high': 0.87,
#   'low': 0.75,
#   'volume': 334424,
#   'uOpen': 0.85,
#   'uClose': 0.8096,
#   'uHigh': 0.87,
#   'uLow': 0.75,
#   'uVolume': 334424,
#   'change': -0.0484,
#   'changePercent': -5.641,
#   'changeOverTime': 0,
#   'symbol': 'SLRX'},
#  {'date': '2020-09-04',
#   'open': 6.3,
#   'close': 6.03,
#   'high': 6.31,
#   'low': 5.75,
#   'volume': 848986,
#   'uOpen': 6.3,
#   'uClose': 6.03,
#   'uHigh': 6.31,
#   'uLow': 5.75,
#   'uVolume': 848986,
#   'change': -0.22,
#   'changePercent': -3.52,
#   'changeOverTime': 0,
#   'symbol': 'EIGI'},
#  {'date': '2020-09-04',
#   'open': 57.13,
#   'close': 56.56,
#   'high': 57.13,
#   'low': 56.55,
#   'volume': 12857,
#   'uOpen': 57.13,
#   'uClose': 56.56,
#   'uHigh': 57.13,
#   'uLow': 56.55,
#   'uVolume': 12857,
#   'change': -1.05,
#   'changePercent': -1.8226,
#   'changeOverTime': 0,
#   'symbol': 'SCHQ'},
#  {'date': '2020-09-04',
#   'open': 48.77,
#   'close': 49.53,
#   'high': 49.8,
#   'low': 45.14,
#   'volume': 543054,
#   'uOpen': 48.77,
#   'uClose': 49.53,
#   'uHigh': 49.8,
#   'uLow': 45.14,
#   'uVolume': 543054,
#   'change': 0.21,
#   'changePercent': 0.4258,
#   'changeOverTime': 0,
#   'symbol': 'FOUR'},
#  {'date': '2020-09-04',
#   'open': 0,
#   'close': 103.6,
#   'high': 0,
#   'low': 0,
#   'volume': 0,
#   'uOpen': 0,
#   'uClose': 103.6,
#   'uHigh': 0,
#   'uLow': 0,
#   'uVolume': 0,
#   'change': 0,
#   'changePercent': 0,
#   'changeOverTime': 0,
#   'symbol': 'NMK-B'},
#  {'date': '2020-09-04',
#   'open': 83.88,
#   'close': 83.27,
#   'high': 84.26,
#   'low': 82.1,
#   'volume': 501609,
#   'uOpen': 83.88,
#   'uClose': 83.27,
#   'uHigh': 84.26,
#   'uLow': 82.1,
#   'uVolume': 501609,
#   'change': -0.11,
#   'changePercent': -0.1319,
#   'changeOverTime': 0,
#   'symbol': 'IWS'},
#  {'date': '2020-09-04',
#   'open': 1.15,
#   'close': 1.19,
#   'high': 1.24,
#   'low': 1.1,
#   'volume': 1478521,
#   'uOpen': 1.15,
#   'uClose': 1.19,
#   'uHigh': 1.24,
#   'uLow': 1.1,
#   'uVolume': 1478521,
#   'change': 0.01,
#   'changePercent': 0.8475,
#   'changeOverTime': 0,
#   'symbol': 'CETX'},
#  {'date': '2020-09-04',
#   'open': 18.85,
#   'close': 19.61,
#   'high': 19.79,
#   'low': 17.5,
#   'volume': 2506219,
#   'uOpen': 18.85,
#   'uClose': 19.61,
#   'uHigh': 19.79,
#   'uLow': 17.5,
#   'uVolume': 2506219,
#   'change': 0.62,
#   'changePercent': 3.2649,
#   'changeOverTime': 0,
#   'symbol': 'RXT'},
#  {'date': '2020-09-04',
#   'open': 14.25,
#   'close': 14.14,
#   'high': 14.25,
#   'low': 13.51,
#   'volume': 3185,
#   'uOpen': 14.25,
#   'uClose': 14.14,
#   'uHigh': 14.25,
#   'uLow': 13.51,
#   'uVolume': 3185,
#   'change': -0.11,
#   'changePercent': -0.7719,
#   'changeOverTime': 0,
#   'symbol': 'HMNF'},
#  {'date': '2020-09-04',
#   'open': 40.32,
#   'close': 39.77,
#   'high': 40.32,
#   'low': 39.29,
#   'volume': 92963,
#   'uOpen': 40.32,
#   'uClose': 39.77,
#   'uHigh': 40.32,
#   'uLow': 39.29,
#   'uVolume': 92963,
#   'change': -0.59,
#   'changePercent': -1.4618,
#   'changeOverTime': 0,
#   'symbol': 'XSMO'},
#  {'date': '2020-09-04',
#   'open': 35.24,
#   'close': 35.04,
#   'high': 35.24,
#   'low': 35.04,
#   'volume': 102,
#   'uOpen': 35.24,
#   'uClose': 35.04,
#   'uHigh': 35.24,
#   'uLow': 35.04,
#   'uVolume': 102,
#   'change': -0.16,
#   'changePercent': -0.4545,
#   'changeOverTime': 0,
#   'symbol': 'VSL'},
#  {'date': '2020-09-04',
#   'open': 5.34,
#   'close': 5.33,
#   'high': 5.51,
#   'low': 5.23,
#   'volume': 25610,
#   'uOpen': 5.34,
#   'uClose': 5.33,
#   'uHigh': 5.51,
#   'uLow': 5.23,
#   'uVolume': 25610,
#   'change': -0.26,
#   'changePercent': -4.6512,
#   'changeOverTime': 0,
#   'symbol': 'TSRI'},
#  {'date': '2020-09-04',
#   'open': 2.46,
#   'close': 2.56,
#   'high': 2.63,
#   'low': 2.29,
#   'volume': 616929,
#   'uOpen': 2.46,
#   'uClose': 2.56,
#   'uHigh': 2.63,
#   'uLow': 2.29,
#   'uVolume': 616929,
#   'change': 0.08,
#   'changePercent': 3.2258,
#   'changeOverTime': 0,
#   'symbol': 'NEPT'},
#  {'date': '2020-09-04',
#   'open': 7.24,
#   'close': 7.15,
#   'high': 7.43,
#   'low': 6.66,
#   'volume': 162844,
#   'uOpen': 7.24,
#   'uClose': 7.15,
#   'uHigh': 7.43,
#   'uLow': 6.66,
#   'uVolume': 162844,
#   'change': -0.14,
#   'changePercent': -1.9204,
#   'changeOverTime': 0,
#   'symbol': 'ALPN'},
#  {'date': '2020-09-04',
#   'open': 13.24,
#   'close': 13.23,
#   'high': 13.26,
#   'low': 13.11,
#   'volume': 77797,
#   'uOpen': 13.24,
#   'uClose': 13.23,
#   'uHigh': 13.26,
#   'uLow': 13.11,
#   'uVolume': 77797,
#   'change': -0.01,
#   'changePercent': -0.0755,
#   'changeOverTime': 0,
#   'symbol': 'PMO'},
#  {'date': '2020-09-04',
#   'open': 151.01,
#   'close': 148,
#   'high': 151.48,
#   'low': 145.85,
#   'volume': 3205565,
#   'uOpen': 151.01,
#   'uClose': 148,
#   'uHigh': 151.48,
#   'uLow': 145.85,
#   'uVolume': 3205565,
#   'change': -2.9,
#   'changePercent': -1.9218,
#   'changeOverTime': 0,
#   'symbol': 'FIS'},
#  {'date': '2020-09-04',
#   'open': 68.12,
#   'close': 67.73,
#   'high': 68.37,
#   'low': 66.89,
#   'volume': 67261,
#   'uOpen': 68.12,
#   'uClose': 67.73,
#   'uHigh': 68.37,
#   'uLow': 66.89,
#   'uVolume': 67261,
#   'change': -0.01,
#   'changePercent': -0.0148,
#   'changeOverTime': 0,
#   'symbol': 'MOO'},
#  {'date': '2020-09-04',
#   'open': 81.72,
#   'close': 81.57,
#   'high': 82.09,
#   'low': 79.59,
#   'volume': 1092596,
#   'uOpen': 81.72,
#   'uClose': 81.57,
#   'uHigh': 82.09,
#   'uLow': 79.59,
#   'uVolume': 1092596,
#   'change': -0.15,
#   'changePercent': -0.1836,
#   'changeOverTime': 0,
#   'symbol': 'BKI'},
#  {'date': '2020-09-04',
#   'open': 6.5,
#   'close': 6.33,
#   'high': 6.5,
#   'low': 6.12,
#   'volume': 16468,
#   'uOpen': 6.5,
#   'uClose': 6.33,
#   'uHigh': 6.5,
#   'uLow': 6.12,
#   'uVolume': 16468,
#   'change': -0.17,
#   'changePercent': -2.6154,
#   'changeOverTime': 0,
#   'symbol': 'TESS'},
#  {'date': '2020-09-04',
#   'open': 4.81,
#   'close': 4.77,
#   'high': 4.88,
#   'low': 4.7,
#   'volume': 11548,
#   'uOpen': 4.81,
#   'uClose': 4.77,
#   'uHigh': 4.88,
#   'uLow': 4.7,
#   'uVolume': 11548,
#   'change': -0.18,
#   'changePercent': -3.5794,
#   'changeOverTime': 0,
#   'symbol': 'GURE'},
#  {'date': '2020-09-04',
#   'open': 26.81,
#   'close': 24.57,
#   'high': 27,
#   'low': 22.56,
#   'volume': 32980790,
#   'uOpen': 26.81,
#   'uClose': 24.57,
#   'uHigh': 27,
#   'uLow': 22.56,
#   'uVolume': 32980790,
#   'change': -1.93,
#   'changePercent': -7.283,
#   'changeOverTime': 0,
#   'symbol': 'RKT'},
#  {'date': '2020-09-04',
#   'open': 11.07,
#   'close': 10.94,
#   'high': 11.07,
#   'low': 10.53,
#   'volume': 2069446,
#   'uOpen': 11.07,
#   'uClose': 10.94,
#   'uHigh': 11.07,
#   'uLow': 10.53,
#   'uVolume': 2069446,
#   'change': -0.14,
#   'changePercent': -1.2635,
#   'changeOverTime': 0,
#   'symbol': 'EGO'},
#  {'date': '2020-09-04',
#   'open': 87.3,
#   'close': 86.68,
#   'high': 87.48,
#   'low': 85.44,
#   'volume': 1529601,
#   'uOpen': 87.3,
#   'uClose': 86.68,
#   'uHigh': 87.48,
#   'uLow': 85.44,
#   'uVolume': 1529601,
#   'change': -0.42,
#   'changePercent': -0.4822,
#   'changeOverTime': 0,
#   'symbol': 'NVS'},
#  {'date': '2020-09-04',
#   'open': 13.43,
#   'close': 13.19,
#   'high': 13.46,
#   'low': 13.15,
#   'volume': 341200,
#   'uOpen': 13.43,
#   'uClose': 13.19,
#   'uHigh': 13.46,
#   'uLow': 13.15,
#   'uVolume': 341200,
#   'change': -0.27,
#   'changePercent': -2.0059,
#   'changeOverTime': 0,
#   'symbol': 'NMZ'},
#  {'date': '2020-09-04',
#   'open': 44.46,
#   'close': 45.59,
#   'high': 46.49,
#   'low': 43.25,
#   'volume': 356713,
#   'uOpen': 44.46,
#   'uClose': 45.59,
#   'uHigh': 46.49,
#   'uLow': 43.25,
#   'uVolume': 356713,
#   'change': 1.37,
#   'changePercent': 3.0981,
#   'changeOverTime': 0,
#   'symbol': 'DCPH'},
#  {'date': '2020-09-04',
#   'open': 11.96,
#   'close': 9.92,
#   'high': 11.96,
#   'low': 9.66,
#   'volume': 763383,
#   'uOpen': 11.96,
#   'uClose': 9.92,
#   'uHigh': 11.96,
#   'uLow': 9.66,
#   'uVolume': 763383,
#   'change': -2.04,
#   'changePercent': -17.0987,
#   'changeOverTime': 0,
#   'symbol': 'SYRS'},
#  {'date': '2020-09-04',
#   'open': 26.87,
#   'close': 26.8,
#   'high': 26.87,
#   'low': 26.54,
#   'volume': 3185,
#   'uOpen': 26.87,
#   'uClose': 26.81,
#   'uHigh': 26.87,
#   'uLow': 26.54,
#   'uVolume': 3185,
#   'change': 0.03,
#   'changePercent': 0.1121,
#   'changeOverTime': 0,
#   'symbol': 'GAA'},
#  {'date': '2020-09-04',
#   'open': 24.75,
#   'close': 24.21,
#   'high': 24.75,
#   'low': 23.89,
#   'volume': 6085,
#   'uOpen': 24.75,
#   'uClose': 24.21,
#   'uHigh': 24.75,
#   'uLow': 23.89,
#   'uVolume': 6085,
#   'change': -0.59,
#   'changePercent': -2.379,
#   'changeOverTime': 0,
#   'symbol': 'LCG'},
#  {'date': '2020-09-04',
#   'open': 4.19,
#   'close': 4.12,
#   'high': 4.2,
#   'low': 3.94,
#   'volume': 5700587,
#   'uOpen': 4.19,
#   'uClose': 4.12,
#   'uHigh': 4.2,
#   'uLow': 3.94,
#   'uVolume': 5700587,
#   'change': -0.12,
#   'changePercent': -2.8302,
#   'changeOverTime': 0,
#   'symbol': 'IAG'},
#  {'date': '2020-09-04',
#   'open': 75.97,
#   'close': 74.23,
#   'high': 77.04,
#   'low': 74.02,
#   'volume': 194398,
#   'uOpen': 75.97,
#   'uClose': 74.23,
#   'uHigh': 77.04,
#   'uLow': 74.02,
#   'uVolume': 194398,
#   'change': -1.47,
#   'changePercent': -1.9419,
#   'changeOverTime': 0,
#   'symbol': 'MANT'},
#  {'date': '2020-09-04',
#   'open': 72.47,
#   'close': 71.95,
#   'high': 73.12,
#   'low': 68.58,
#   'volume': 7898788,
#   'uOpen': 72.47,
#   'uClose': 71.95,
#   'uHigh': 73.12,
#   'uLow': 68.58,
#   'uVolume': 7898788,
#   'change': 1.75,
#   'changePercent': 2.4929,
#   'changeOverTime': 0,
#   'symbol': 'RCL'},
#  {'date': '2020-09-04',
#   'open': 36.08,
#   'close': 35.79,
#   'high': 36.28,
#   'low': 35.21,
#   'volume': 192199,
#   'uOpen': 36.08,
#   'uClose': 35.79,
#   'uHigh': 36.28,
#   'uLow': 35.21,
#   'uVolume': 192199,
#   'change': 0.3,
#   'changePercent': 0.8453,
#   'changeOverTime': 0,
#   'symbol': 'FNCL'},
#  {'date': '2020-09-04',
#   'open': 95.81,
#   'close': 93.79,
#   'high': 95.81,
#   'low': 91.76,
#   'volume': 43894,
#   'uOpen': 95.81,
#   'uClose': 93.79,
#   'uHigh': 95.81,
#   'uLow': 91.76,
#   'uVolume': 43894,
#   'change': -1.65,
#   'changePercent': -1.7288,
#   'changeOverTime': 0,
#   'symbol': 'XHE'},
#  {'date': '2020-09-04',
#   'open': 6.29,
#   'close': 5.75,
#   'high': 6.29,
#   'low': 5.25,
#   'volume': 26725,
#   'uOpen': 6.29,
#   'uClose': 5.75,
#   'uHigh': 6.29,
#   'uLow': 5.25,
#   'uVolume': 26725,
#   'change': -0.53,
#   'changePercent': -8.4395,
#   'changeOverTime': 0,
#   'symbol': 'PEI-B'},
#  {'date': '2020-09-04',
#   'open': 79.31,
#   'close': 78.73,
#   'high': 79.61,
#   'low': 77.87,
#   'volume': 164850,
#   'uOpen': 79.31,
#   'uClose': 78.73,
#   'uHigh': 79.61,
#   'uLow': 77.87,
#   'uVolume': 164850,
#   'change': -0.06,
#   'changePercent': -0.0762,
#   'changeOverTime': 0,
#   'symbol': 'MGV'},
#  {'date': '2020-09-04',
#   'open': 8.81,
#   'close': 8.59,
#   'high': 8.86,
#   'low': 8.5,
#   'volume': 6209,
#   'uOpen': 8.81,
#   'uClose': 8.59,
#   'uHigh': 8.86,
#   'uLow': 8.5,
#   'uVolume': 6209,
#   'change': -0.23,
#   'changePercent': -2.6077,
#   'changeOverTime': 0,
#   'symbol': 'GWGH'},
#  {'date': '2020-09-04',
#   'open': 35.16,
#   'close': 34.6,
#   'high': 35.51,
#   'low': 34.53,
#   'volume': 345974,
#   'uOpen': 35.16,
#   'uClose': 34.6,
#   'uHigh': 35.51,
#   'uLow': 34.53,
#   'uVolume': 345974,
#   'change': -0.36,
#   'changePercent': -1.0297,
#   'changeOverTime': 0,
#   'symbol': 'PSN'},
#  {'date': '2020-09-04',
#   'open': 27.53,
#   'close': 27.26,
#   'high': 27.57,
#   'low': 27.02,
#   'volume': 7458,
#   'uOpen': 27.53,
#   'uClose': 27.26,
#   'uHigh': 27.57,
#   'uLow': 27.02,
#   'uVolume': 7458,
#   'change': 0.05,
#   'changePercent': 0.1838,
#   'changeOverTime': 0,
#   'symbol': 'DURA'},
#  {'date': '2020-09-04',
#   'open': 41.2,
#   'close': 41,
#   'high': 41.39,
#   'low': 40.39,
#   'volume': 140394,
#   'uOpen': 41.2,
#   'uClose': 41,
#   'uHigh': 41.39,
#   'uLow': 40.39,
#   'uVolume': 140394,
#   'change': -0.14,
#   'changePercent': -0.3403,
#   'changeOverTime': 0,
#   'symbol': 'RWO'},
#  {'date': '2020-09-04',
#   'open': 46.5,
#   'close': 45.01,
#   'high': 47.92,
#   'low': 42.2,
#   'volume': 677939,
#   'uOpen': 46.5,
#   'uClose': 45.01,
#   'uHigh': 47.92,
#   'uLow': 42.2,
#   'uVolume': 677939,
#   'change': -7.53,
#   'changePercent': -14.3319,
#   'changeOverTime': 0,
#   'symbol': 'OXM'},
#  {'date': '2020-09-04',
#   'open': 20.99,
#   'close': 22.75,
#   'high': 22.85,
#   'low': 20.73,
#   'volume': 37381,
#   'uOpen': 20.99,
#   'uClose': 22.75,
#   'uHigh': 22.85,
#   'uLow': 20.73,
#   'uVolume': 37381,
#   'change': 2.29,
#   'changePercent': 11.1926,
#   'changeOverTime': 0,
#   'symbol': 'ACNB'},
#  {'date': '2020-09-04',
#   'open': 29.55,
#   'close': 30.47,
#   'high': 30.47,
#   'low': 29.55,
#   'volume': 436,
#   'uOpen': 29.55,
#   'uClose': 30.47,
#   'uHigh': 30.47,
#   'uLow': 29.55,
#   'uVolume': 436,
#   'change': -0.03,
#   'changePercent': -0.0984,
#   'changeOverTime': 0,
#   'symbol': 'MVRL'},
#  {'date': '2020-09-04',
#   'open': 119.59,
#   'close': 118.81,
#   'high': 120.08,
#   'low': 117.31,
#   'volume': 802465,
#   'uOpen': 119.59,
#   'uClose': 118.81,
#   'uHigh': 120.08,
#   'uLow': 117.31,
#   'uVolume': 802465,
#   'change': -0.31,
#   'changePercent': -0.2602,
#   'changeOverTime': 0,
#   'symbol': 'DTE'},
#  {'date': '2020-09-04',
#   'open': 19.86,
#   'close': 20.05,
#   'high': 20.16,
#   'low': 19.19,
#   'volume': 199232,
#   'uOpen': 19.86,
#   'uClose': 20.05,
#   'uHigh': 20.16,
#   'uLow': 19.19,
#   'uVolume': 199232,
#   'change': 0.4,
#   'changePercent': 2.0356,
#   'changeOverTime': 0,
#   'symbol': 'SGRY'},
#  {'date': '2020-09-04',
#   'open': 5.64,
#   'close': 5.6,
#   'high': 5.82,
#   'low': 5.55,
#   'volume': 580320,
#   'uOpen': 5.64,
#   'uClose': 5.6,
#   'uHigh': 5.82,
#   'uLow': 5.55,
#   'uVolume': 580320,
#   'change': 0,
#   'changePercent': 0,
#   'changeOverTime': 0,
#   'symbol': 'EZPW'},
#  {'date': '2020-09-04',
#   'open': 3.39,
#   'close': 3.22,
#   'high': 3.4,
#   'low': 3.01,
#   'volume': 236238,
#   'uOpen': 3.39,
#   'uClose': 3.22,
#   'uHigh': 3.4,
#   'uLow': 3.01,
#   'uVolume': 236238,
#   'change': -0.23,
#   'changePercent': -6.6667,
#   'changeOverTime': 0,
#   'symbol': 'TLSA'},
#  {'date': '2020-09-04',
#   'open': 34.18,
#   'close': 33.62,
#   'high': 34.22,
#   'low': 33.4,
#   'volume': 96594,
#   'uOpen': 34.18,
#   'uClose': 33.62,
#   'uHigh': 34.22,
#   'uLow': 33.4,
#   'uVolume': 96594,
#   'change': -0.41,
#   'changePercent': -1.2048,
#   'changeOverTime': 0,
#   'symbol': 'PHDG'},
#  {'date': '2020-09-04',
#   'open': 78.3,
#   'close': 77.91,
#   'high': 79.13,
#   'low': 76.2,
#   'volume': 311696,
#   'uOpen': 78.3,
#   'uClose': 77.91,
#   'uHigh': 79.13,
#   'uLow': 76.2,
#   'uVolume': 311696,
#   'change': -0.39,
#   'changePercent': -0.4981,
#   'changeOverTime': 0,
#   'symbol': 'ZLAB'},
#  {'date': '2020-09-04',
#   'open': 133.12,
#   'close': 133.09,
#   'high': 134.14,
#   'low': 130,
#   'volume': 270652,
#   'uOpen': 133.12,
#   'uClose': 133.09,
#   'uHigh': 134.14,
#   'uLow': 130,
#   'uVolume': 270652,
#   'change': 0.56,
#   'changePercent': 0.4225,
#   'changeOverTime': 0,
#   'symbol': 'LSTR'},
#  {'date': '2020-08-17',
#   'open': None,
#   'close': 21.96,
#   'high': None,
#   'low': None,
#   'volume': 0,
#   'uOpen': None,
#   'uClose': 21.96,
#   'uHigh': None,
#   'uLow': None,
#   'uVolume': 0,
#   'change': 0,
#   'changePercent': 0,
#   'changeOverTime': 0,
#   'symbol': 'ISDS'},
#  {'date': '2020-09-04',
#   'open': 2.02,
#   'close': 2.04,
#   'high': 2.08,
#   'low': 1.9,
#   'volume': 705142,
#   'uOpen': 2.02,
#   'uClose': 2.04,
#   'uHigh': 2.08,
#   'uLow': 1.9,
#   'uVolume': 705142,
#   'change': 0.03,
#   'changePercent': 1.4925,
#   'changeOverTime': 0,
#   'symbol': 'SLNO'},
#  {'date': '2020-09-04',
#   'open': 20.77,
#   'close': 21.31,
#   'high': 21.38,
#   'low': 20.08,
#   'volume': 5583398,
#   'uOpen': 20.77,
#   'uClose': 21.31,
#   'uHigh': 21.38,
#   'uLow': 20.08,
#   'uVolume': 5583398,
#   'change': 0.74,
#   'changePercent': 3.5975,
#   'changeOverTime': 0,
#   'symbol': 'SPR'},
#  {'date': '2020-09-04',
#   'open': 6.76,
#   'close': 7.02,
#   'high': 7.02,
#   'low': 6.23,
#   'volume': 9328807,
#   'uOpen': 6.76,
#   'uClose': 7.02,
#   'uHigh': 7.02,
#   'uLow': 6.23,
#   'uVolume': 9328807,
#   'change': 0.42,
#   'changePercent': 6.3636,
#   'changeOverTime': 0,
#   'symbol': 'AMC'},
#  {'date': '2020-09-04',
#   'open': 23.23,
#   'close': 23.06,
#   'high': 23.46,
#   'low': 22.58,
#   'volume': 256771,
#   'uOpen': 23.23,
#   'uClose': 23.06,
#   'uHigh': 23.46,
#   'uLow': 22.58,
#   'uVolume': 256771,
#   'change': -0.18,
#   'changePercent': -0.7745,
#   'changeOverTime': 0,
#   'symbol': 'UTF'},
#  {'date': '2020-09-04',
#   'open': 64.58,
#   'close': 63.71,
#   'high': 64.6,
#   'low': 63.39,
#   'volume': 375509,
#   'uOpen': 64.58,
#   'uClose': 63.71,
#   'uHigh': 64.6,
#   'uLow': 63.39,
#   'uVolume': 375509,
#   'change': -0.44,
#   'changePercent': -0.6859,
#   'changeOverTime': 0,
#   'symbol': 'SWX'},
#  {'date': '2020-09-04',
#   'open': 12.49,
#   'close': 12.26,
#   'high': 12.5,
#   'low': 12.07,
#   'volume': 886386,
#   'uOpen': 12.49,
#   'uClose': 12.26,
#   'uHigh': 12.5,
#   'uLow': 12.07,
#   'uVolume': 886386,
#   'change': 0,
#   'changePercent': 0,
#   'changeOverTime': 0,
#   'symbol': 'TGNA'},
#  {'date': '2020-09-04',
#   'open': 9.37,
#   'close': 9.51,
#   'high': 9.55,
#   'low': 9.2,
#   'volume': 3889260,
#   'uOpen': 9.37,
#   'uClose': 9.51,
#   'uHigh': 9.55,
#   'uLow': 9.2,
#   'uVolume': 3889260,
#   'change': 0.14,
#   'changePercent': 1.4941,
#   'changeOverTime': 0,
#   'symbol': 'PSLV'},
#  {'date': '2020-09-04',
#   'open': 77.9,
#   'close': 76.35,
#   'high': 79.69,
#   'low': 73.18,
#   'volume': 2192139,
#   'uOpen': 77.9,
#   'uClose': 76.35,
#   'uHigh': 79.69,
#   'uLow': 73.18,
#   'uVolume': 2192139,
#   'change': -0.73,
#   'changePercent': -0.9471,
#   'changeOverTime': 0,
#   'symbol': 'LITE'},
#  {'date': '2020-09-04',
#   'open': 65.98,
#   'close': 64.25,
#   'high': 66.56,
#   'low': 64.04,
#   'volume': 706668,
#   'uOpen': 65.98,
#   'uClose': 64.25,
#   'uHigh': 66.56,
#   'uLow': 64.04,
#   'uVolume': 706668,
#   'change': -1.12,
#   'changePercent': -1.7133,
#   'changeOverTime': 0,
#   'symbol': 'TXRH'},
#  {'date': '2020-09-04',
#   'open': 3.08,
#   'close': 3.06,
#   'high': 3.2,
#   'low': 3.01,
#   'volume': 153405,
#   'uOpen': 3.08,
#   'uClose': 3.06,
#   'uHigh': 3.2,
#   'uLow': 3.01,
#   'uVolume': 153405,
#   'change': -0.06,
#   'changePercent': -1.9231,
#   'changeOverTime': 0,
#   'symbol': 'HALL'},
#  {'date': '2020-09-04',
#   'open': 2.31,
#   'close': 2.3,
#   'high': 2.31,
#   'low': 2.3,
#   'volume': 17840,
#   'uOpen': 2.31,
#   'uClose': 2.3,
#   'uHigh': 2.31,
#   'uLow': 2.3,
#   'uVolume': 17840,
#   'change': -0.01,
#   'changePercent': -0.368,
#   'changeOverTime': 0,
#   'symbol': 'FORK'},
#  {'date': '2020-09-04',
#   'open': 27.62,
#   'close': 27.76,
#   'high': 27.76,
#   'low': 27.18,
#   'volume': 3863,
#   'uOpen': 27.63,
#   'uClose': 27.76,
#   'uHigh': 27.76,
#   'uLow': 27.18,
#   'uVolume': 3863,
#   'change': 0.11,
#   'changePercent': 0.3978,
#   'changeOverTime': 0,
#   'symbol': 'EUDG'},
#  {'date': '2020-09-04',
#   'open': 19.25,
#   'close': 19.35,
#   'high': 19.5,
#   'low': 18.63,
#   'volume': 54849,
#   'uOpen': 19.25,
#   'uClose': 19.35,
#   'uHigh': 19.5,
#   'uLow': 18.63,
#   'uVolume': 54849,
#   'change': 0.3,
#   'changePercent': 1.5748,
#   'changeOverTime': 0,
#   'symbol': 'ESTA'},
#  {'date': '2020-09-04',
#   'open': 53.48,
#   'close': 54.11,
#   'high': 54.62,
#   'low': 51,
#   'volume': 13202,
#   'uOpen': 53.48,
#   'uClose': 54.11,
#   'uHigh': 54.62,
#   'uLow': 51,
#   'uVolume': 13202,
#   'change': 0.52,
#   'changePercent': 0.9703,
#   'changeOverTime': 0,
#   'symbol': 'LBJ'},
#  {'date': '2020-09-04',
#   'open': 21.9,
#   'close': 21.42,
#   'high': 22.09,
#   'low': 20.56,
#   'volume': 320032,
#   'uOpen': 21.9,
#   'uClose': 21.42,
#   'uHigh': 22.09,
#   'uLow': 20.56,
#   'uVolume': 320032,
#   'change': -0.09,
#   'changePercent': -0.4184,
#   'changeOverTime': 0,
#   'symbol': 'GFF'},
#  {'date': '2020-09-04',
#   'open': 52.19,
#   'close': 51.02,
#   'high': 52.19,
#   'low': 50.23,
#   'volume': 10488,
#   'uOpen': 52.19,
#   'uClose': 51.02,
#   'uHigh': 52.19,
#   'uLow': 50.23,
#   'uVolume': 10488,
#   'change': -0.59,
#   'changePercent': -1.1432,
#   'changeOverTime': 0,
#   'symbol': 'JSMD'},
#  {'date': '2020-09-04',
#   'open': 15.69,
#   'close': 15.21,
#   'high': 15.69,
#   'low': 15.17,
#   'volume': 313971,
#   'uOpen': 15.69,
#   'uClose': 15.21,
#   'uHigh': 15.69,
#   'uLow': 15.17,
#   'uVolume': 313971,
#   'change': -0.58,
#   'changePercent': -3.6732,
#   'changeOverTime': 0,
#   'symbol': 'USL'},
#  {'date': '2020-09-04',
#   'open': 52.21,
#   'close': 51.98,
#   'high': 52.84,
#   'low': 51.35,
#   'volume': 1042757,
#   'uOpen': 52.21,
#   'uClose': 51.98,
#   'uHigh': 52.84,
#   'uLow': 51.35,
#   'uVolume': 1042757,
#   'change': 0.48,
#   'changePercent': 0.932,
#   'changeOverTime': 0,
#   'symbol': 'PWR'},
#  {'date': '2020-09-04',
#   'open': 2.57,
#   'close': 2.7,
#   'high': 2.72,
#   'low': 2.51,
#   'volume': 243267,
#   'uOpen': 2.57,
#   'uClose': 2.7,
#   'uHigh': 2.72,
#   'uLow': 2.51,
#   'uVolume': 243267,
#   'change': 0.12,
#   'changePercent': 4.6512,
#   'changeOverTime': 0,
#   'symbol': 'TWI'},
#  {'date': '2020-09-04',
#   'open': 26.38,
#   'close': 26.23,
#   'high': 26.38,
#   'low': 26.1,
#   'volume': 16471,
#   'uOpen': 26.38,
#   'uClose': 26.23,
#   'uHigh': 26.38,
#   'uLow': 26.1,
#   'uVolume': 16471,
#   'change': -0.12,
#   'changePercent': -0.4554,
#   'changeOverTime': 0,
#   'symbol': 'PSA-M'},
#  {'date': '2020-09-04',
#   'open': 67.16,
#   'close': 65.99,
#   'high': 67.17,
#   'low': 64.2,
#   'volume': 745814,
#   'uOpen': 67.16,
#   'uClose': 65.99,
#   'uHigh': 67.17,
#   'uLow': 64.2,
#   'uVolume': 745814,
#   'change': 0.08,
#   'changePercent': 0.1214,
#   'changeOverTime': 0,
#   'symbol': 'OC'},
#  {'date': '2020-09-04',
#   'open': 32.4,
#   'close': 31.56,
#   'high': 32.4,
#   'low': 31.37,
#   'volume': 295381,
#   'uOpen': 32.4,
#   'uClose': 31.56,
#   'uHigh': 32.4,
#   'uLow': 31.37,
#   'uVolume': 295381,
#   'change': -0.28,
#   'changePercent': -0.8794,
#   'changeOverTime': 0,
#   'symbol': 'MC'},
#  {'date': '2020-09-04',
#   'open': 9.78,
#   'close': 9.78,
#   'high': 9.78,
#   'low': 9.78,
#   'volume': 283,
#   'uOpen': 9.78,
#   'uClose': 9.78,
#   'uHigh': 9.78,
#   'uLow': 9.78,
#   'uVolume': 283,
#   'change': -0.01,
#   'changePercent': -0.1021,
#   'changeOverTime': 0,
#   'symbol': 'NHA'},
#  {'date': '2020-09-04',
#   'open': 0.42,
#   'close': 0.4367,
#   'high': 0.44,
#   'low': 0.41,
#   'volume': 299722,
#   'uOpen': 0.42,
#   'uClose': 0.4367,
#   'uHigh': 0.44,
#   'uLow': 0.41,
#   'uVolume': 299722,
#   'change': -0.0148,
#   'changePercent': -3.278,
#   'changeOverTime': 0,
#   'symbol': 'RIBT'},
#  {'date': '2020-09-04',
#   'open': 32.05,
#   'close': 31.8,
#   'high': 32.18,
#   'low': 31.15,
#   'volume': 2117980,
#   'uOpen': 32.05,
#   'uClose': 31.8,
#   'uHigh': 32.18,
#   'uLow': 31.15,
#   'uVolume': 2117980,
#   'change': 0.19,
#   'changePercent': 0.6011,
#   'changeOverTime': 0,
#   'symbol': 'LKQ'},
#  {'date': '2020-09-04',
#   'open': 14.83,
#   'close': 14.76,
#   'high': 14.87,
#   'low': 14.68,
#   'volume': 391498,
#   'uOpen': 14.83,
#   'uClose': 14.76,
#   'uHigh': 14.87,
#   'uLow': 14.68,
#   'uVolume': 391498,
#   'change': -0.06,
#   'changePercent': -0.4049,
#   'changeOverTime': 0,
#   'symbol': 'NZF'},
#  {'date': '2020-09-04',
#   'open': 67.87,
#   'close': 67.31,
#   'high': 68,
#   'low': 66.88,
#   'volume': 311209,
#   'uOpen': 67.87,
#   'uClose': 67.31,
#   'uHigh': 68,
#   'uLow': 66.88,
#   'uVolume': 311209,
#   'change': 0.24,
#   'changePercent': 0.3578,
#   'changeOverTime': 0,
#   'symbol': 'MSM'},
#  {'date': '2020-09-04',
#   'open': 14.74,
#   'close': 14.7,
#   'high': 14.74,
#   'low': 14.65,
#   'volume': 3909,
#   'uOpen': 14.74,
#   'uClose': 14.7,
#   'uHigh': 14.74,
#   'uLow': 14.65,
#   'uVolume': 3909,
#   'change': 0,
#   'changePercent': 0,
#   'changeOverTime': 0,
#   'symbol': 'NAZ'},
#  {'date': '2020-09-04',
#   'open': 26.95,
#   'close': 26.82,
#   'high': 26.95,
#   'low': 26.65,
#   'volume': 14032,
#   'uOpen': 26.95,
#   'uClose': 26.82,
#   'uHigh': 26.95,
#   'uLow': 26.65,
#   'uVolume': 14032,
#   'change': -0.06,
#   'changePercent': -0.2232,
#   'changeOverTime': 0,
#   'symbol': 'HTLFP'},
#  {'date': '2020-09-04',
#   'open': 9.51,
#   'close': 9.15,
#   'high': 9.51,
#   'low': 9.05,
#   'volume': 39393,
#   'uOpen': 9.51,
#   'uClose': 9.15,
#   'uHigh': 9.51,
#   'uLow': 9.05,
#   'uVolume': 39393,
#   'change': -0.29,
#   'changePercent': -3.072,
#   'changeOverTime': 0,
#   'symbol': 'NVGS'},
#  {'date': '2020-09-04',
#   'open': 46.2,
#   'close': 45.44,
#   'high': 47.33,
#   'low': 43.78,
#   'volume': 2434230,
#   'uOpen': 46.2,
#   'uClose': 45.44,
#   'uHigh': 47.33,
#   'uLow': 43.78,
#   'uVolume': 2434230,
#   'change': -1.25,
#   'changePercent': -2.6772,
#   'changeOverTime': 0,
#   'symbol': 'BEKE'},
#  {'date': '2020-09-04',
#   'open': 25.48,
#   'close': 25.28,
#   'high': 27.03,
#   'low': 22.94,
#   'volume': 74532,
#   'uOpen': 25.48,
#   'uClose': 25.28,
#   'uHigh': 27.03,
#   'uLow': 22.94,
#   'uVolume': 74532,
#   'change': -0.2,
#   'changePercent': -0.7849,
#   'changeOverTime': 0,
#   'symbol': 'NRIX'},
#  {'date': '2020-09-04',
#   'open': 142.7,
#   'close': 143.17,
#   'high': 144.02,
#   'low': 141.63,
#   'volume': 954231,
#   'uOpen': 142.7,
#   'uClose': 143.17,
#   'uHigh': 144.02,
#   'uLow': 141.63,
#   'uVolume': 954231,
#   'change': 0.69,
#   'changePercent': 0.4843,
#   'changeOverTime': 0,
#   'symbol': 'AWK'},
#  {'date': '2020-09-04',
#   'open': 25.26,
#   'close': 25.27,
#   'high': 25.36,
#   'low': 25.23,
#   'volume': 3542,
#   'uOpen': 25.26,
#   'uClose': 25.27,
#   'uHigh': 25.36,
#   'uLow': 25.23,
#   'uVolume': 3542,
#   'change': -0.04,
#   'changePercent': -0.158,
#   'changeOverTime': 0,
#   'symbol': 'FLIA'},
#  {'date': '2020-09-04',
#   'open': 8.1,
#   'close': 8.05,
#   'high': 8.1,
#   'low': 7.37,
#   'volume': 82616,
#   'uOpen': 8.1,
#   'uClose': 8.05,
#   'uHigh': 8.1,
#   'uLow': 7.37,
#   'uVolume': 82616,
#   'change': -0.14,
#   'changePercent': -1.7094,
#   'changeOverTime': 0,
#   'symbol': 'IMRN'},
#  {'date': '2020-09-04',
#   'open': 18.26,
#   'close': 18.31,
#   'high': 18.52,
#   'low': 17.84,
#   'volume': 194641,
#   'uOpen': 18.26,
#   'uClose': 18.31,
#   'uHigh': 18.52,
#   'uLow': 17.84,
#   'uVolume': 194641,
#   'change': 0.56,
#   'changePercent': 3.1549,
#   'changeOverTime': 0,
#   'symbol': 'VBTX'},
#  {'date': '2020-09-04',
#   'open': 19.74,
#   'close': 19.68,
#   'high': 19.77,
#   'low': 19.4,
#   'volume': 13093,
#   'uOpen': 19.74,
#   'uClose': 19.68,
#   'uHigh': 19.77,
#   'uLow': 19.4,
#   'uVolume': 13093,
#   'change': 0.18,
#   'changePercent': 0.9231,
#   'changeOverTime': 0,
#   'symbol': 'WBIY'},
#  {'date': '2020-09-04',
#   'open': 26.61,
#   'close': 26.58,
#   'high': 26.61,
#   'low': 26.26,
#   'volume': 7651,
#   'uOpen': 26.61,
#   'uClose': 26.58,
#   'uHigh': 26.61,
#   'uLow': 26.26,
#   'uVolume': 7651,
#   'change': -0.03,
#   'changePercent': -0.1127,
#   'changeOverTime': 0,
#   'symbol': 'BEP-A'},
#  {'date': '2020-09-04',
#   'open': 15.27,
#   'close': 14.92,
#   'high': 15.69,
#   'low': 14.1,
#   'volume': 190872,
#   'uOpen': 15.27,
#   'uClose': 14.92,
#   'uHigh': 15.69,
#   'uLow': 14.1,
#   'uVolume': 190872,
#   'change': -0.26,
#   'changePercent': -1.7128,
#   'changeOverTime': 0,
#   'symbol': 'PASG'},
#  {'date': '2020-09-04',
#   'open': 18.5,
#   'close': 18.5,
#   'high': 18.5,
#   'low': 18.5,
#   'volume': 364,
#   'uOpen': 18.5,
#   'uClose': 18.5,
#   'uHigh': 18.5,
#   'uLow': 18.5,
#   'uVolume': 364,
#   'change': -0.23,
#   'changePercent': -1.228,
#   'changeOverTime': 0,
#   'symbol': 'AI-B'},
#  {'date': '2020-09-04',
#   'open': 27.52,
#   'close': 27.1,
#   'high': 27.52,
#   'low': 27.05,
#   'volume': 30969,
#   'uOpen': 27.52,
#   'uClose': 27.1,
#   'uHigh': 27.52,
#   'uLow': 27.05,
#   'uVolume': 30969,
#   'change': -0.24,
#   'changePercent': -0.8778,
#   'changeOverTime': 0,
#   'symbol': 'HIG-G'},
#  {'date': '2020-09-04',
#   'open': 25.48,
#   'close': 25.4,
#   'high': 25.55,
#   'low': 25.24,
#   'volume': 79087,
#   'uOpen': 25.48,
#   'uClose': 25.4,
#   'uHigh': 25.55,
#   'uLow': 25.24,
#   'uVolume': 79087,
#   'change': -0.06,
#   'changePercent': -0.2357,
#   'changeOverTime': 0,
#   'symbol': 'AEFC'},
#  {'date': '2020-09-04',
#   'open': 16.61,
#   'close': 15.96,
#   'high': 16.61,
#   'low': 15.45,
#   'volume': 188103,
#   'uOpen': 16.61,
#   'uClose': 15.96,
#   'uHigh': 16.61,
#   'uLow': 15.45,
#   'uVolume': 188103,
#   'change': -0.58,
#   'changePercent': -3.5067,
#   'changeOverTime': 0,
#   'symbol': 'ANAB'},
#  {'date': '2020-09-04',
#   'open': 372.39,
#   'close': 361.41,
#   'high': 376.4,
#   'low': 345.97,
#   'volume': 3111650,
#   'uOpen': 372.39,
#   'uClose': 361.41,
#   'uHigh': 376.4,
#   'uLow': 345.97,
#   'uVolume': 3111650,
#   'change': -16.46,
#   'changePercent': -4.356,
#   'changeOverTime': 0,
#   'symbol': 'LULU'},
#  {'date': '2020-09-04',
#   'open': 52.82,
#   'close': 52.54,
#   'high': 53.33,
#   'low': 50.95,
#   'volume': 9971559,
#   'uOpen': 52.82,
#   'uClose': 52.54,
#   'uHigh': 53.33,
#   'uLow': 50.95,
#   'uVolume': 9971559,
#   'change': -0.62,
#   'changePercent': -1.1663,
#   'changeOverTime': 0,
#   'symbol': 'EBAY'},
#  {'date': '2020-09-04',
#   'open': 18.66,
#   'close': 18.6,
#   'high': 18.68,
#   'low': 18.23,
#   'volume': 23513,
#   'uOpen': 18.66,
#   'uClose': 18.6,
#   'uHigh': 18.68,
#   'uLow': 18.23,
#   'uVolume': 23513,
#   'change': 0.42,
#   'changePercent': 2.3102,
#   'changeOverTime': 0,
#   'symbol': 'FTXO'},
#  {'date': '2020-09-04',
#   'open': 40.93,
#   'close': 41.61,
#   'high': 41.61,
#   'low': 40.93,
#   'volume': 101,
#   'uOpen': 40.93,
#   'uClose': 41.61,
#   'uHigh': 41.61,
#   'uLow': 40.93,
#   'uVolume': 101,
#   'change': 0.46,
#   'changePercent': 1.1179,
#   'changeOverTime': 0,
#   'symbol': 'NRGZ'},
#  {'date': '2020-09-04',
#   'open': 31.1,
#   'close': 31.13,
#   'high': 31.19,
#   'low': 30.78,
#   'volume': 106770,
#   'uOpen': 31.1,
#   'uClose': 31.13,
#   'uHigh': 31.19,
#   'uLow': 30.78,
#   'uVolume': 106770,
#   'change': 0.07,
#   'changePercent': 0.2254,
#   'changeOverTime': 0,
#   'symbol': 'DFEB'},
#  {'date': '2020-09-04',
#   'open': 3.67,
#   'close': 3.53,
#   'high': 3.68,
#   'low': 3.44,
#   'volume': 497149,
#   'uOpen': 3.67,
#   'uClose': 3.53,
#   'uHigh': 3.68,
#   'uLow': 3.44,
#   'uVolume': 497149,
#   'change': -0.03,
#   'changePercent': -0.8427,
#   'changeOverTime': 0,
#   'symbol': 'MESA'},
#  {'date': '2020-09-04',
#   'open': 24.65,
#   'close': 24.68,
#   'high': 24.75,
#   'low': 24.5,
#   'volume': 9319,
#   'uOpen': 24.65,
#   'uClose': 24.68,
#   'uHigh': 24.75,
#   'uLow': 24.5,
#   'uVolume': 9319,
#   'change': -0.09,
#   'changePercent': -0.3633,
#   'changeOverTime': 0,
#   'symbol': 'GNL-B'},
#  {'date': '2020-09-04',
#   'open': 34.3,
#   'close': 34.35,
#   'high': 35.08,
#   'low': 33.49,
#   'volume': 603474,
#   'uOpen': 34.3,
#   'uClose': 34.35,
#   'uHigh': 35.08,
#   'uLow': 33.49,
#   'uVolume': 603474,
#   'change': -0.07,
#   'changePercent': -0.2034,
#   'changeOverTime': 0,
#   'symbol': 'EPR'},
#  {'date': '2020-09-04',
#   'open': 16.45,
#   'close': 15.97,
#   'high': 16.47,
#   'low': 15.84,
#   'volume': 1702896,
#   'uOpen': 16.45,
#   'uClose': 15.97,
#   'uHigh': 16.47,
#   'uLow': 15.84,
#   'uVolume': 1702896,
#   'change': -0.01,
#   'changePercent': -0.0626,
#   'changeOverTime': 0,
#   'symbol': 'RDN'},
#  {'date': '2020-09-04',
#   'open': 54.4,
#   'close': 53.19,
#   'high': 54.66,
#   'low': 52.2,
#   'volume': 615360,
#   'uOpen': 54.4,
#   'uClose': 53.19,
#   'uHigh': 54.66,
#   'uLow': 52.2,
#   'uVolume': 615360,
#   'change': -0.86,
#   'changePercent': -1.5911,
#   'changeOverTime': 0,
#   'symbol': 'TW'},
#  {'date': '2020-09-04',
#   'open': 4.52,
#   'close': 4.46,
#   'high': 4.56,
#   'low': 4.22,
#   'volume': 540936,
#   'uOpen': 4.52,
#   'uClose': 4.46,
#   'uHigh': 4.56,
#   'uLow': 4.22,
#   'uVolume': 540936,
#   'change': -0.03,
#   'changePercent': -0.6682,
#   'changeOverTime': 0,
#   'symbol': 'ISEE'},
#  {'date': '2020-09-04',
#   'open': 6.37,
#   'close': 6.25,
#   'high': 6.81,
#   'low': 6.07,
#   'volume': 210265,
#   'uOpen': 6.37,
#   'uClose': 6.25,
#   'uHigh': 6.81,
#   'uLow': 6.07,
#   'uVolume': 210265,
#   'change': -0.13,
#   'changePercent': -2.0376,
#   'changeOverTime': 0,
#   'symbol': 'CYCN'},
#  {'date': '2020-09-04',
#   'open': 1.34,
#   'close': 1.37,
#   'high': 1.37,
#   'low': 1.34,
#   'volume': 624,
#   'uOpen': 1.34,
#   'uClose': 1.37,
#   'uHigh': 1.37,
#   'uLow': 1.34,
#   'uVolume': 624,
#   'change': 0.01,
#   'changePercent': 0.7353,
#   'changeOverTime': 0,
#   'symbol': 'EQS'},
#  {'date': '2020-09-04',
#   'open': 4.01,
#   'close': 4.04,
#   'high': 4.04,
#   'low': 3.95,
#   'volume': 36167,
#   'uOpen': 4.01,
#   'uClose': 4.04,
#   'uHigh': 4.04,
#   'uLow': 3.95,
#   'uVolume': 36167,
#   'change': 0,
#   'changePercent': -0.005,
#   'changeOverTime': 0,
#   'symbol': 'LOAN'},
#  {'date': '2020-09-04',
#   'open': 38.59,
#   'close': 37.98,
#   'high': 38.8,
#   'low': 37.65,
#   'volume': 547473,
#   'uOpen': 38.59,
#   'uClose': 37.98,
#   'uHigh': 38.8,
#   'uLow': 37.65,
#   'uVolume': 547473,
#   'change': -0.41,
#   'changePercent': -1.068,
#   'changeOverTime': 0,
#   'symbol': 'FWONK'},
#  {'date': '2020-09-04',
#   'open': 25.84,
#   'close': 25.84,
#   'high': 25.84,
#   'low': 25.65,
#   'volume': 8589,
#   'uOpen': 25.84,
#   'uClose': 25.84,
#   'uHigh': 25.84,
#   'uLow': 25.65,
#   'uVolume': 8589,
#   'change': 0,
#   'changePercent': 0,
#   'changeOverTime': 0,
#   'symbol': 'FRC-G'},
#  {'date': '2020-09-04',
#   'open': 11.64,
#   'close': 11.07,
#   'high': 11.83,
#   'low': 10.82,
#   'volume': 621264,
#   'uOpen': 11.64,
#   'uClose': 11.07,
#   'uHigh': 11.83,
#   'uLow': 10.82,
#   'uVolume': 621264,
#   'change': -0.47,
#   'changePercent': -4.0728,
#   'changeOverTime': 0,
#   'symbol': 'OPCH'},
#  {'date': '2020-09-04',
#   'open': 116.58,
#   'close': 113.84,
#   'high': 116.58,
#   'low': 112.94,
#   'volume': 63946,
#   'uOpen': 116.58,
#   'uClose': 113.84,
#   'uHigh': 116.58,
#   'uLow': 112.94,
#   'uVolume': 63946,
#   'change': -0.94,
#   'changePercent': -0.819,
#   'changeOverTime': 0,
#   'symbol': 'ROG'},
#  {'date': '2020-09-04',
#   'open': 4.74,
#   'close': 4.57,
#   'high': 4.76,
#   'low': 4.44,
#   'volume': 310485,
#   'uOpen': 4.74,
#   'uClose': 4.57,
#   'uHigh': 4.76,
#   'uLow': 4.44,
#   'uVolume': 310485,
#   'change': -0.14,
#   'changePercent': -2.9724,
#   'changeOverTime': 0,
#   'symbol': 'KIN'},
#  {'date': '2020-09-04',
#   'open': 40.69,
#   'close': 40.4,
#   'high': 41.42,
#   'low': 38.58,
#   'volume': 782116,
#   'uOpen': 40.69,
#   'uClose': 40.4,
#   'uHigh': 41.42,
#   'uLow': 38.58,
#   'uVolume': 782116,
#   'change': -0.12,
#   'changePercent': -0.2962,
#   'changeOverTime': 0,
#   'symbol': 'HASI'},
#  {'date': '2020-09-04',
#   'open': 28.14,
#   'close': 28.41,
#   'high': 28.51,
#   'low': 28.14,
#   'volume': 2908,
#   'uOpen': 28.14,
#   'uClose': 28.41,
#   'uHigh': 28.51,
#   'uLow': 28.14,
#   'uVolume': 2908,
#   'change': -0.01,
#   'changePercent': -0.0352,
#   'changeOverTime': 0,
#   'symbol': 'FLQD'},
#  {'date': '2020-09-04',
#   'open': 16.32,
#   'close': 16.34,
#   'high': 16.49,
#   'low': 15.68,
#   'volume': 898179,
#   'uOpen': 16.32,
#   'uClose': 16.34,
#   'uHigh': 16.49,
#   'uLow': 15.68,
#   'uVolume': 898179,
#   'change': -0.04,
#   'changePercent': -0.2442,
#   'changeOverTime': 0,
#   'symbol': 'ALKS'},
#  {'date': '2020-09-04',
#   'open': 443.96,
#   'close': 441.25,
#   'high': 448.75,
#   'low': 421.4,
#   'volume': 228973,
#   'uOpen': 443.96,
#   'uClose': 441.25,
#   'uHigh': 448.75,
#   'uLow': 421.4,
#   'uVolume': 228973,
#   'change': -5.08,
#   'changePercent': -1.1382,
#   'changeOverTime': 0,
#   'symbol': 'ONEQ'},
#  {'date': '2020-09-04',
#   'open': 8.87,
#   'close': 8.8,
#   'high': 8.96,
#   'low': 8.46,
#   'volume': 624844,
#   'uOpen': 8.87,
#   'uClose': 8.8,
#   'uHigh': 8.96,
#   'uLow': 8.46,
#   'uVolume': 624844,
#   'change': 0.2,
#   'changePercent': 2.3256,
#   'changeOverTime': 0,
#   'symbol': 'TEN'},
#  {'date': '2020-09-04',
#   'open': 13.41,
#   'close': 13.2,
#   'high': 13.51,
#   'low': 12.56,
#   'volume': 506613,
#   'uOpen': 13.41,
#   'uClose': 13.2,
#   'uHigh': 13.51,
#   'uLow': 12.56,
#   'uVolume': 506613,
#   'change': -0.02,
#   'changePercent': -0.1513,
#   'changeOverTime': 0,
#   'symbol': 'REZI'},
#  {'date': '2020-09-04',
#   'open': 11.31,
#   'close': 10.7,
#   'high': 11.35,
#   'low': 10.66,
#   'volume': 10343,
#   'uOpen': 11.31,
#   'uClose': 10.7,
#   'uHigh': 11.35,
#   'uLow': 10.66,
#   'uVolume': 10343,
#   'change': -0.47,
#   'changePercent': -4.2077,
#   'changeOverTime': 0,
#   'symbol': 'NRP'},
#  {'date': '2020-09-04',
#   'open': 44.21,
#   'close': 44.34,
#   'high': 45.06,
#   'low': 43.77,
#   'volume': 1878852,
#   'uOpen': 44.21,
# ...
#   'uHigh': 100.4,
#   'uLow': 99.14,
#   'uVolume': 398958,
#   'change': -1.84,
#   'changePercent': -1.8187,
#   'changeOverTime': 0,
#   'symbol': 'VGLT'},
#  {'date': '2020-09-04',
#   'open': 18,
#   'close': 17.85,
#   'high': 18.06,
#   'low': 17.47,
#   'volume': 1071299,
#   'uOpen': 18,
#   'uClose': 17.85,
#   'uHigh': 18.06,
#   'uLow': 17.47,
#   'uVolume': 1071299,
#   'change': 0.12,
#   'changePercent': 0.6768,
#   'changeOverTime': 0,
#   'symbol': 'JEF'},
#  {'date': '2020-09-04',
#   'open': 18.76,
#   'close': 18.85,
#   'high': 19.24,
#   'low': 17.9,
#   'volume': 6846594,
#   'uOpen': 18.76,
#   'uClose': 18.85,
#   'uHigh': 19.24,
#   'uLow': 17.9,
#   'uVolume': 6846594,
#   'change': 0.39,
#   'changePercent': 2.085,
#   'changeOverTime': 0,
#   'symbol': 'PLAY'},
#  {'date': '2020-09-04',
#   'open': 13.84,
#   'close': 13.66,
#   'high': 14,
#   'low': 13.4,
#   'volume': 230665,
#   'uOpen': 13.84,
#   'uClose': 13.66,
#   'uHigh': 14,
#   'uLow': 13.4,
#   'uVolume': 230665,
#   'change': -0.16,
#   'changePercent': -1.1577,
#   'changeOverTime': 0,
#   'symbol': 'AMSWA'},
#  {'date': '2020-09-04',
#   'open': 28.18,
#   'close': 28.16,
#   'high': 28.18,
#   'low': 28.16,
#   'volume': 207,
#   'uOpen': 28.18,
#   'uClose': 28.16,
#   'uHigh': 28.18,
#   'uLow': 28.16,
#   'uVolume': 207,
#   'change': 0.04,
#   'changePercent': 0.1422,
#   'changeOverTime': 0,
#   'symbol': 'BMAY'},
#  {'date': '2020-09-04',
#   'open': 9.53,
#   'close': 9.52,
#   'high': 9.55,
#   'low': 9.5,
#   'volume': 55845,
#   'uOpen': 9.53,
#   'uClose': 9.52,
#   'uHigh': 9.55,
#   'uLow': 9.5,
#   'uVolume': 55845,
#   'change': -0.07,
#   'changePercent': -0.7299,
#   'changeOverTime': 0,
#   'symbol': 'JHY'},
#  {'date': '2020-09-04',
#   'open': 149.1,
#   'close': 145.69,
#   'high': 149.7,
#   'low': 143.52,
#   'volume': 413500,
#   'uOpen': 149.1,
#   'uClose': 145.69,
#   'uHigh': 149.7,
#   'uLow': 143.52,
#   'uVolume': 413500,
#   'change': -3.12,
#   'changePercent': -2.0966,
#   'changeOverTime': 0,
#   'symbol': 'SUI'},
#  {'date': '2020-09-04',
#   'open': 5.27,
#   'close': 5.3,
#   'high': 5.33,
#   'low': 5.27,
#   'volume': 421056,
#   'uOpen': 5.27,
#   'uClose': 5.3,
#   'uHigh': 5.33,
#   'uLow': 5.27,
#   'uVolume': 421056,
#   'change': -0.02,
#   'changePercent': -0.3759,
#   'changeOverTime': 0,
#   'symbol': 'GIM'},
#  {'date': '2020-09-04',
#   'open': 8.23,
#   'close': 8.42,
#   'high': 8.42,
#   'low': 8.23,
#   'volume': 111,
#   'uOpen': 8.23,
#   'uClose': 8.42,
#   'uHigh': 8.42,
#   'uLow': 8.23,
#   'uVolume': 111,
#   'change': -0.02,
#   'changePercent': -0.237,
#   'changeOverTime': 0,
#   'symbol': 'IMLP'},
#  {'date': '2020-09-04',
#   'open': 25.55,
#   'close': 25.59,
#   'high': 25.6,
#   'low': 25.55,
#   'volume': 1311,
#   'uOpen': 25.55,
#   'uClose': 25.59,
#   'uHigh': 25.6,
#   'uLow': 25.55,
#   'uVolume': 1311,
#   'change': -0.04,
#   'changePercent': -0.1561,
#   'changeOverTime': 0,
#   'symbol': 'NUSA'},
#  {'date': '2020-09-04',
#   'open': 17.61,
#   'close': 17.98,
#   'high': 17.98,
#   'low': 17.61,
#   'volume': 100,
#   'uOpen': 17.61,
#   'uClose': 17.98,
#   'uHigh': 17.98,
#   'uLow': 17.61,
#   'uVolume': 100,
#   'change': -0.16,
#   'changePercent': -0.882,
#   'changeOverTime': 0,
#   'symbol': 'AFSM'},
#  {'date': '2020-09-04',
#   'open': 23.37,
#   'close': 23.86,
#   'high': 23.86,
#   'low': 23.28,
#   'volume': 3358,
#   'uOpen': 23.37,
#   'uClose': 23.86,
#   'uHigh': 23.86,
#   'uLow': 23.28,
#   'uVolume': 3358,
#   'change': 0.49,
#   'changePercent': 2.0967,
#   'changeOverTime': 0,
#   'symbol': 'AJXA'},
#  {'date': '2020-09-04',
#   'open': 65.2,
#   'close': 64.59,
#   'high': 65.56,
#   'low': 62.9,
#   'volume': 93998,
#   'uOpen': 65.2,
#   'uClose': 64.59,
#   'uHigh': 65.56,
#   'uLow': 62.9,
#   'uVolume': 93998,
#   'change': -0.76,
#   'changePercent': -1.163,
#   'changeOverTime': 0,
#   'symbol': 'QQQE'},
#  {'date': '2020-09-04',
#   'open': 33.31,
#   'close': 33.62,
#   'high': 33.94,
#   'low': 33.22,
#   'volume': 270541,
#   'uOpen': 33.31,
#   'uClose': 33.62,
#   'uHigh': 33.94,
#   'uLow': 33.22,
#   'uVolume': 270541,
#   'change': 0.44,
#   'changePercent': 1.3261,
#   'changeOverTime': 0,
#   'symbol': 'JW.A'},
#  {'date': '2020-09-04',
#   'open': 0.9675,
#   'close': 0.9202,
#   'high': 0.9891,
#   'low': 0.85,
#   'volume': 554552,
#   'uOpen': 0.9675,
#   'uClose': 0.9202,
#   'uHigh': 0.9891,
#   'uLow': 0.85,
#   'uVolume': 554552,
#   'change': -0.0378,
#   'changePercent': -3.9457,
#   'changeOverTime': 0,
#   'symbol': 'SALM'},
#  {'date': '2020-09-04',
#   'open': 26.45,
#   'close': 26.27,
#   'high': 26.45,
#   'low': 26.21,
#   'volume': 9122,
#   'uOpen': 26.45,
#   'uClose': 26.27,
#   'uHigh': 26.45,
#   'uLow': 26.21,
#   'uVolume': 9122,
#   'change': -0.08,
#   'changePercent': -0.3036,
#   'changeOverTime': 0,
#   'symbol': 'FMBIO'},
#  {'date': '2020-09-04',
#   'open': 221.71,
#   'close': 220.74,
#   'high': 222.7,
#   'low': 213.84,
#   'volume': 273107,
#   'uOpen': 221.71,
#   'uClose': 220.74,
#   'uHigh': 222.7,
#   'uLow': 213.84,
#   'uVolume': 273107,
#   'change': -1.67,
#   'changePercent': -0.7509,
#   'changeOverTime': 0,
#   'symbol': 'NICE'},
#  {'date': '2020-09-04',
#   'open': 3.62,
#   'close': 3.53,
#   'high': 3.67,
#   'low': 3.41,
#   'volume': 411803,
#   'uOpen': 3.62,
#   'uClose': 3.53,
#   'uHigh': 3.67,
#   'uLow': 3.41,
#   'uVolume': 411803,
#   'change': -0.08,
#   'changePercent': -2.2161,
#   'changeOverTime': 0,
#   'symbol': 'SBBP'},
#  {'date': '2020-09-04',
#   'open': 6.96,
#   'close': 6.9,
#   'high': 7,
#   'low': 6.75,
#   'volume': 20377,
#   'uOpen': 6.96,
#   'uClose': 6.9,
#   'uHigh': 7,
#   'uLow': 6.75,
#   'uVolume': 20377,
#   'change': -0.03,
#   'changePercent': -0.4329,
#   'changeOverTime': 0,
#   'symbol': 'USAP'},
#  {'date': '2020-09-04',
#   'open': 2.83,
#   'close': 2.84,
#   'high': 2.91,
#   'low': 2.57,
#   'volume': 201303,
#   'uOpen': 2.83,
#   'uClose': 2.84,
#   'uHigh': 2.91,
#   'uLow': 2.57,
#   'uVolume': 201303,
#   'change': -0.09,
#   'changePercent': -3.0717,
#   'changeOverTime': 0,
#   'symbol': 'IDXG'},
#  {'date': '2020-09-04',
#   'open': 41.7,
#   'close': 41.56,
#   'high': 41.76,
#   'low': 40.81,
#   'volume': 1089599,
#   'uOpen': 41.7,
#   'uClose': 41.56,
#   'uHigh': 41.76,
#   'uLow': 40.81,
#   'uVolume': 1089599,
#   'change': 0.1,
#   'changePercent': 0.2412,
#   'changeOverTime': 0,
#   'symbol': 'EWL'},
#  {'date': '2020-09-04',
#   'open': 46.09,
#   'close': 45.09,
#   'high': 46.09,
#   'low': 43.34,
#   'volume': 793640,
#   'uOpen': 46.09,
#   'uClose': 45.09,
#   'uHigh': 46.09,
#   'uLow': 43.34,
#   'uVolume': 793640,
#   'change': -0.42,
#   'changePercent': -0.9229,
#   'changeOverTime': 0,
#   'symbol': 'LIVN'},
#  {'date': '2020-09-04',
#   'open': 8.46,
#   'close': 8.57,
#   'high': 8.6,
#   'low': 8.32,
#   'volume': 51271,
#   'uOpen': 8.46,
#   'uClose': 8.57,
#   'uHigh': 8.6,
#   'uLow': 8.32,
#   'uVolume': 51271,
#   'change': 0.2,
#   'changePercent': 2.3895,
#   'changeOverTime': 0,
#   'symbol': 'NGS'},
#  {'date': '2020-09-04',
#   'open': 3.63,
#   'close': 3.7,
#   'high': 3.75,
#   'low': 3.61,
#   'volume': 6784,
#   'uOpen': 3.63,
#   'uClose': 3.7,
#   'uHigh': 3.75,
#   'uLow': 3.61,
#   'uVolume': 6784,
#   'change': 0,
#   'changePercent': 0,
#   'changeOverTime': 0,
#   'symbol': 'PMBC'},
#  {'date': '2020-09-04',
#   'open': 25.58,
#   'close': 25.57,
#   'high': 25.59,
#   'low': 25.57,
#   'volume': 1312,
#   'uOpen': 25.58,
#   'uClose': 25.57,
#   'uHigh': 25.59,
#   'uLow': 25.57,
#   'uVolume': 1312,
#   'change': -0.01,
#   'changePercent': -0.0391,
#   'changeOverTime': 0,
#   'symbol': 'BSMN'},
#  {'date': '2020-09-04',
#   'open': 25.01,
#   'close': 25.02,
#   'high': 25.02,
#   'low': 25.01,
#   'volume': 935,
#   'uOpen': 25.01,
#   'uClose': 25.02,
#   'uHigh': 25.02,
#   'uLow': 25.01,
#   'uVolume': 935,
#   'change': 0.02,
#   'changePercent': 0.08,
#   'changeOverTime': 0,
#   'symbol': 'SAF'},
#  {'date': '2020-09-04',
#   'open': 25.83,
#   'close': 25.88,
#   'high': 25.9,
#   'low': 25.7,
#   'volume': 7629,
#   'uOpen': 25.83,
#   'uClose': 25.88,
#   'uHigh': 25.9,
#   'uLow': 25.7,
#   'uVolume': 7629,
#   'change': -0.05,
#   'changePercent': -0.1928,
#   'changeOverTime': 0,
#   'symbol': 'PSB-W'},
#  {'date': '2020-09-04',
#   'open': 21.63,
#   'close': 21,
#   'high': 21.63,
#   'low': 21,
#   'volume': 2689,
#   'uOpen': 21.63,
#   'uClose': 21,
#   'uHigh': 21.63,
#   'uLow': 21,
#   'uVolume': 2689,
#   'change': 0,
#   'changePercent': 0,
#   'changeOverTime': 0,
#   'symbol': 'INN-E'},
#  {'date': '2020-09-04',
#   'open': 48.72,
#   'close': 48.69,
#   'high': 48.83,
#   'low': 48.3,
#   'volume': 7140,
#   'uOpen': 48.72,
#   'uClose': 48.69,
#   'uHigh': 48.83,
#   'uLow': 48.3,
#   'uVolume': 7140,
#   'change': -0.03,
#   'changePercent': -0.0616,
#   'changeOverTime': 0,
#   'symbol': 'GHYG'},
#  {'date': '2020-09-04',
#   'open': 40.67,
#   'close': 40.99,
#   'high': 41.61,
#   'low': 38.96,
#   'volume': 42841,
#   'uOpen': 40.67,
#   'uClose': 40.99,
#   'uHigh': 41.61,
#   'uLow': 38.96,
#   'uVolume': 42841,
#   'change': 0.6,
#   'changePercent': 1.4855,
#   'changeOverTime': 0,
#   'symbol': 'EIDX'},
#  {'date': '2020-09-04',
#   'open': 23.12,
#   'close': 23.6,
#   'high': 23.6,
#   'low': 23.08,
#   'volume': 14774,
#   'uOpen': 23.12,
#   'uClose': 23.6,
#   'uHigh': 23.6,
#   'uLow': 23.08,
#   'uVolume': 14774,
#   'change': 0.54,
#   'changePercent': 2.3417,
#   'changeOverTime': 0,
#   'symbol': 'RILYP'},
#  {'date': '2020-09-04',
#   'open': 2.03,
#   'close': 2.1,
#   'high': 2.12,
#   'low': 2.03,
#   'volume': 1877,
#   'uOpen': 2.03,
#   'uClose': 2.1,
#   'uHigh': 2.12,
#   'uLow': 2.03,
#   'uVolume': 1877,
#   'change': -0.01,
#   'changePercent': -0.4739,
#   'changeOverTime': 0,
#   'symbol': 'CCM'},
#  {'date': '2020-09-04',
#   'open': 40.78,
#   'close': 39.93,
#   'high': 40.83,
#   'low': 38.47,
#   'volume': 242701,
#   'uOpen': 40.78,
#   'uClose': 39.93,
#   'uHigh': 40.83,
#   'uLow': 38.47,
#   'uVolume': 242701,
#   'change': -0.56,
#   'changePercent': -1.3831,
#   'changeOverTime': 0,
#   'symbol': 'ALTR'},
#  {'date': '2020-09-04',
#   'open': 26.64,
#   'close': 26.1,
#   'high': 26.71,
#   'low': 25.32,
#   'volume': 42526,
#   'uOpen': 26.64,
#   'uClose': 26.1,
#   'uHigh': 26.71,
#   'uLow': 25.32,
#   'uVolume': 42526,
#   'change': -0.84,
#   'changePercent': -3.118,
#   'changeOverTime': 0,
#   'symbol': 'TCHP'},
#  {'date': '2020-09-04',
#   'open': 45.89,
#   'close': 45.63,
#   'high': 46.03,
#   'low': 44.91,
#   'volume': 334620,
#   'uOpen': 45.89,
#   'uClose': 45.63,
#   'uHigh': 46.03,
#   'uLow': 44.91,
#   'uVolume': 334620,
#   'change': 0.12,
#   'changePercent': 0.2637,
#   'changeOverTime': 0,
#   'symbol': 'IART'},
#  {'date': '2020-09-04',
#   'open': 23.62,
#   'close': 22.77,
#   'high': 23.78,
#   'low': 21.68,
#   'volume': 596432,
#   'uOpen': 23.62,
#   'uClose': 22.77,
#   'uHigh': 23.78,
#   'uLow': 21.68,
#   'uVolume': 596432,
#   'change': -0.91,
#   'changePercent': -3.8429,
#   'changeOverTime': 0,
#   'symbol': 'UCTT'},
#  {'date': '2020-09-04',
#   'open': 0,
#   'close': 27.85,
#   'high': 0,
#   'low': 0,
#   'volume': 0,
#   'uOpen': 0,
#   'uClose': 27.85,
#   'uHigh': 0,
#   'uLow': 0,
#   'uVolume': 0,
#   'change': 0,
#   'changePercent': 0,
#   'changeOverTime': 0,
#   'symbol': 'DWCR'},
#  {'date': '2020-09-04',
#   'open': 22.3,
#   'close': 21.96,
#   'high': 22.49,
#   'low': 21.09,
#   'volume': 1073909,
#   'uOpen': 22.3,
#   'uClose': 21.96,
#   'uHigh': 22.49,
#   'uLow': 21.09,
#   'uVolume': 1073909,
#   'change': -0.18,
#   'changePercent': -0.813,
#   'changeOverTime': 0,
#   'symbol': 'YELP'},
#  {'date': '2020-09-04',
#   'open': 33.8,
#   'close': 32.12,
#   'high': 34.38,
#   'low': 29.2,
#   'volume': 3839334,
#   'uOpen': 33.8,
#   'uClose': 32.12,
#   'uHigh': 34.38,
#   'uLow': 29.2,
#   'uVolume': 3839334,
#   'change': -2.21,
#   'changePercent': -6.4375,
#   'changeOverTime': 0,
#   'symbol': 'NVTA'},
#  {'date': '2020-09-04',
#   'open': 0.646,
#   'close': 0.6317,
#   'high': 0.6749,
#   'low': 0.5727,
#   'volume': 592355,
#   'uOpen': 0.646,
#   'uClose': 0.6317,
#   'uHigh': 0.6749,
#   'uLow': 0.5727,
#   'uVolume': 592355,
#   'change': -0.0038,
#   'changePercent': -0.598,
#   'changeOverTime': 0,
#   'symbol': 'ISR'},
#  {'date': '2020-09-04',
#   'open': 27.21,
#   'close': 27.1,
#   'high': 27.21,
#   'low': 27.1,
#   'volume': 413,
#   'uOpen': 27.21,
#   'uClose': 27.1,
#   'uHigh': 27.21,
#   'uLow': 27.1,
#   'uVolume': 413,
#   'change': -0.11,
#   'changePercent': -0.4043,
#   'changeOverTime': 0,
#   'symbol': 'EAOR'},
#  {'date': '2020-09-04',
#   'open': 21.01,
#   'close': 20.11,
#   'high': 21.19,
#   'low': 19.1,
#   'volume': 1548439,
#   'uOpen': 21.01,
#   'uClose': 20.11,
#   'uHigh': 21.19,
#   'uLow': 19.1,
#   'uVolume': 1548439,
#   'change': -0.3,
#   'changePercent': -1.4699,
#   'changeOverTime': 0,
#   'symbol': 'JKS'},
#  {'date': '2020-09-04',
#   'open': 84.93,
#   'close': 84.32,
#   'high': 85.37,
#   'low': 83.74,
#   'volume': 71183,
#   'uOpen': 84.93,
#   'uClose': 84.32,
#   'uHigh': 85.37,
#   'uLow': 83.74,
#   'uVolume': 71183,
#   'change': 0.31,
#   'changePercent': 0.369,
#   'changeOverTime': 0,
#   'symbol': 'CRVL'},
#  {'date': '2020-09-04',
#   'open': 1.03,
#   'close': 1.02,
#   'high': 1.03,
#   'low': 0.9997,
#   'volume': 18960,
#   'uOpen': 1.03,
#   'uClose': 1.02,
#   'uHigh': 1.03,
#   'uLow': 0.9997,
#   'uVolume': 18960,
#   'change': 0,
#   'changePercent': 0,
#   'changeOverTime': 0,
#   'symbol': 'SSY'},
#  {'date': '2020-09-04',
#   'open': 71.4,
#   'close': 69.02,
#   'high': 71.6,
#   'low': 68.68,
#   'volume': 191913,
#   'uOpen': 71.4,
#   'uClose': 69.02,
#   'uHigh': 71.6,
#   'uLow': 68.68,
#   'uVolume': 191913,
#   'change': -1.68,
#   'changePercent': -2.3762,
#   'changeOverTime': 0,
#   'symbol': 'ITGR'},
#  {'date': '2020-09-04',
#   'open': 0,
#   'close': 9.96,
#   'high': 0,
#   'low': 0,
#   'volume': 0,
#   'uOpen': 0,
#   'uClose': 9.96,
#   'uHigh': 0,
#   'uLow': 0,
#   'uVolume': 0,
#   'change': 0,
#   'changePercent': 0,
#   'changeOverTime': 0,
#   'symbol': 'GLEO'},
#  {'date': '2020-09-04',
#   'open': 4.43,
#   'close': 4.35,
#   'high': 4.43,
#   'low': 4.14,
#   'volume': 489644,
#   'uOpen': 4.43,
#   'uClose': 4.35,
#   'uHigh': 4.43,
#   'uLow': 4.14,
#   'uVolume': 489644,
#   'change': -0.05,
#   'changePercent': -1.1364,
#   'changeOverTime': 0,
#   'symbol': 'PRTK'},
#  {'date': '2020-09-04',
#   'open': 13.57,
#   'close': 13.56,
#   'high': 13.61,
#   'low': 13.43,
#   'volume': 100150,
#   'uOpen': 13.57,
#   'uClose': 13.56,
#   'uHigh': 13.61,
#   'uLow': 13.43,
#   'uVolume': 100150,
#   'change': -0.02,
#   'changePercent': -0.1473,
#   'changeOverTime': 0,
#   'symbol': 'GHY'},
#  {'date': '2020-09-04',
#   'open': 25.83,
#   'close': 25.93,
#   'high': 25.93,
#   'low': 25.78,
#   'volume': 773,
#   'uOpen': 25.83,
#   'uClose': 25.93,
#   'uHigh': 25.93,
#   'uLow': 25.78,
#   'uVolume': 773,
#   'change': -0.39,
#   'changePercent': -1.4818,
#   'changeOverTime': 0,
#   'symbol': 'PAMC'},
#  {'date': '2020-09-04',
#   'open': 5.1,
#   'close': 4.9,
#   'high': 5.1,
#   'low': 4.9,
#   'volume': 34674,
#   'uOpen': 5.1,
#   'uClose': 4.9,
#   'uHigh': 5.1,
#   'uLow': 4.9,
#   'uVolume': 34674,
#   'change': -0.15,
#   'changePercent': -2.9703,
#   'changeOverTime': 0,
#   'symbol': 'CTK'},
#  {'date': '2020-09-04',
#   'open': 9.45,
#   'close': 9.3,
#   'high': 9.59,
#   'low': 9.1,
#   'volume': 197649,
#   'uOpen': 9.45,
#   'uClose': 9.3,
#   'uHigh': 9.59,
#   'uLow': 9.1,
#   'uVolume': 197649,
#   'change': -0.23,
#   'changePercent': -2.4134,
#   'changeOverTime': 0,
#   'symbol': 'PSTX'},
#  {'date': '2020-09-04',
#   'open': 110.78,
#   'close': 109.96,
#   'high': 110.78,
#   'low': 108.46,
#   'volume': 4616,
#   'uOpen': 110.78,
#   'uClose': 109.96,
#   'uHigh': 110.78,
#   'uLow': 108.46,
#   'uVolume': 4616,
#   'change': 0.96,
#   'changePercent': 0.8807,
#   'changeOverTime': 0,
#   'symbol': 'APTV-A'},
#  {'date': '2020-09-04',
#   'open': 77.67,
#   'close': 76.62,
#   'high': 78.5,
#   'low': 75.59,
#   'volume': 595019,
#   'uOpen': 77.67,
#   'uClose': 76.62,
#   'uHigh': 78.5,
#   'uLow': 75.59,
#   'uVolume': 595019,
#   'change': 0.52,
#   'changePercent': 0.6833,
#   'changeOverTime': 0,
#   'symbol': 'RJF'},
#  {'date': '2020-09-04',
#   'open': 77.58,
#   'close': 75.59,
#   'high': 77.58,
#   'low': 74.8,
#   'volume': 72862,
#   'uOpen': 77.58,
#   'uClose': 75.59,
#   'uHigh': 77.58,
#   'uLow': 74.8,
#   'uVolume': 72862,
#   'change': -0.32,
#   'changePercent': -0.4216,
#   'changeOverTime': 0,
#   'symbol': 'PIPR'},
#  {'date': '2020-09-04',
#   'open': 11.8,
#   'close': 11.28,
#   'high': 12.06,
#   'low': 10.88,
#   'volume': 45528,
#   'uOpen': 11.8,
#   'uClose': 11.28,
#   'uHigh': 12.06,
#   'uLow': 10.88,
#   'uVolume': 45528,
#   'change': -0.58,
#   'changePercent': -4.8904,
#   'changeOverTime': 0,
#   'symbol': 'LYRA'},
#  {'date': '2020-09-04',
#   'open': 7.97,
#   'close': 8.44,
#   'high': 9,
#   'low': 7.95,
#   'volume': 11258315,
#   'uOpen': 7.97,
#   'uClose': 8.44,
#   'uHigh': 9,
#   'uLow': 7.95,
#   'uVolume': 11258315,
#   'change': 0.17,
#   'changePercent': 2.0556,
#   'changeOverTime': 0,
#   'symbol': 'SRTY'},
#  ...]

# %%
c.marketYesterdayDF().head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-100-2c976eeffaf6> in <module>
# ----> 1 c.marketYesterdayDF().head()
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pyEX/client.py in bind(self, *args, **kwargs)
#     670         if not meth:
#     671             raise PyEXception('Must provide method!')
# --> 672         return meth(token=self._token, version=self._version, *args, **kwargs)
#     673
#     674     def account(self):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pyEX/stocks/marketInfo.py in marketYesterdayDF(token, version, filter)
#     347     data = []
#     348     for key in x:
# --> 349         data.append(x[key])
#     350         data[-1]['symbol'] = key
#     351     df = pd.DataFrame(data)
#
# TypeError: list indices must be integers or slices, not dict

# %% [markdown]
# ## Price

# %%
c.price(symbol)
# Out:
# 120.96

# %%
c.priceDF(symbol)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pyEX/stocks/prices.py:408: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   df = pd.io.json.json_normalize({'price': price(symbol, token, version, filter)})
#     price
# 0  120.96

# %% [markdown]
# ## Price Target

# %%
c.priceTarget(symbol)
# Out:
# {'symbol': 'AAPL',
#  'updatedDate': '2020-09-01',
#  'priceTargetAverage': 113.62,
#  'priceTargetHigh': 150,
#  'priceTargetLow': 78.5,
#  'numberOfAnalysts': 37,
#  'currency': 'USD'}

# %%
c.priceTargetDF(symbol)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pyEX/stocks/research.py:380: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   df = pd.io.json.json_normalize(priceTarget(symbol, token, version, filter))
#   symbol updatedDate  priceTargetAverage  priceTargetHigh  priceTargetLow  \
# 0   AAPL  2020-09-01              113.62              150            78.5
#
#    numberOfAnalysts currency
# 0                37      USD

# %% [markdown]
# ## Quote

# %%
c.quote(symbol)
# Out:
# {'symbol': 'AAPL',
#  'companyName': 'Apple, Inc.',
#  'primaryExchange': 'NASDAQ',
#  'calculationPrice': 'close',
#  'open': 120,
#  'openTime': 1599226202030,
#  'openSource': 'official',
#  'close': 120.96,
#  'closeTime': 1599249600801,
#  'closeSource': 'official',
#  'high': 123.7,
#  'highTime': 1599263998145,
#  'highSource': '15 minute delayed price',
#  'low': 110.89,
#  'lowTime': 1599230668001,
#  'lowSource': '15 minute delayed price',
#  'latestPrice': 120.96,
#  'latestSource': 'Close',
#  'latestTime': 'September 4, 2020',
#  'latestUpdate': 1599249600801,
#  'latestVolume': 332607163,
#  'iexRealtimePrice': None,
#  'iexRealtimeSize': None,
#  'iexLastUpdated': None,
#  'delayedPrice': 120,
#  'delayedPriceTime': 1599263998145,
#  'oddLotDelayedPrice': 453.263,
#  'oddLotDelayedPriceTime': 1599252382500,
#  'extendedPrice': 120.01,
#  'extendedChange': -0.95,
#  'extendedChangePercent': -0.00785,
#  'extendedPriceTime': 1599263998144,
#  'previousClose': 120.88,
#  'previousVolume': 257599640,
#  'change': 0.08,
#  'changePercent': 0.00066,
#  'volume': 332607163,
#  'iexMarketPercent': None,
#  'iexVolume': None,
#  'avgTotalVolume': 195357804,
#  'iexBidPrice': None,
#  'iexBidSize': None,
#  'iexAskPrice': None,
#  'iexAskSize': None,
#  'iexOpen': None,
#  'iexOpenTime': None,
#  'iexClose': 121.11,
#  'iexCloseTime': 1599249591040,
#  'marketCap': 2068718400000,
#  'peRatio': 36.45,
#  'week52High': 137.98,
#  'week52Low': 52.77,
#  'ytdChange': 0.63396,
#  'lastTradeTime': 1599249600801,
#  'isUSMarketOpen': False}

# %%
c.quoteDF(symbol)
# Out:
#         avgTotalVolume calculationPrice  change  changePercent   close  \
# symbol
# AAPL          27470518            close   -5.62       -0.02696  202.86
#
#                      closeTime  companyName  delayedPrice  \
# symbol
# AAPL   2019-05-07 20:00:00.243  Apple, Inc.        203.08
#
#               delayedPriceTime  extendedChange  ...  latestVolume      low  \
# symbol                                          ...
# AAPL   2019-05-07 20:15:00.013           0.175  ...      38391956  200.825
#
#            marketCap    open                openTime  peRatio  previousClose  \
# symbol
# AAPL    933375088800  205.86 2019-05-07 13:30:00.311    16.92         208.48
#
#         week52High week52Low  ytdChange
# symbol
# AAPL        233.47       142   0.293202
#
# [1 rows x 37 columns]

# %% [markdown]
# # Recommendation Trends

# %% [markdown]
# # Sector Performance

# %%
c.sectorPerformance()
# Out:
# ---------------------------------------------------------------------------
# PyEXception                               Traceback (most recent call last)
# <ipython-input-63-4980925d0493> in <module>
# ----> 1 c.sectorPerformance()
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pyEX/client.py in bind(self, *args, **kwargs)
#     670         if not meth:
#     671             raise PyEXception('Must provide method!')
# --> 672         return meth(token=self._token, version=self._version, *args, **kwargs)
#     673
#     674     def account(self):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pyEX/stocks/marketInfo.py in sectorPerformance(token, version, filter)
#     369         dict: result
#     370     '''
# --> 371     return _getJson('stock/market/sector-performance', token, version, filter)
#     372
#     373
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pyEX/common.py in _getJson(url, token, version, filter)
#     383         if version == 'sandbox':
#     384             return _getJsonIEXCloudSandbox(url, token, version, filter)
# --> 385         return _getJsonIEXCloud(url, token, version, filter)
#     386     return _getJsonOrig(url)
#     387
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pyEX/common.py in _getJsonIEXCloud(url, token, version, filter)
#     400     if resp.status_code == 200:
#     401         return resp.json()
# --> 402     raise PyEXception('Response %d - ' % resp.status_code, resp.text)
#     403
#     404
#
# PyEXception: ('Response 402 - ', 'The requested data is not available to free tier accounts. Please upgrade for access to this data.')

# %%
c.sectorPerformanceDF()
# Out:
#                                    lastUpdated  performance    type
# name
# Utilities              2019-05-07 20:00:00.308     -0.00310  sector
# Energy                 2019-05-07 20:00:00.354     -0.00871  sector
# Consumer Staples       2019-05-07 20:00:00.271     -0.00994  sector
# Consumer Discretionary 2019-05-07 20:00:00.279     -0.01516  sector
# Communication Services 2019-05-07 20:00:00.247     -0.01620  sector
# Financials             2019-05-07 20:00:00.339     -0.01650  sector
# Real Estate            2019-05-07 20:00:00.244     -0.01713  sector
# Materials              2019-05-07 20:00:00.264     -0.01754  sector
# Health Care            2019-05-07 20:00:00.331     -0.01920  sector
# Industrials            2019-05-07 20:00:00.022     -0.02022  sector
# Technology             2019-05-07 20:00:00.308     -0.02148  sector

# %% [markdown]
# ## Splits

# %%
c.splits(symbol)
# Out:
# ---------------------------------------------------------------------------
# PyEXception                               Traceback (most recent call last)
# <ipython-input-64-26f37c88e75f> in <module>
# ----> 1 c.splits(symbol)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pyEX/client.py in bind(self, *args, **kwargs)
#     670         if not meth:
#     671             raise PyEXception('Must provide method!')
# --> 672         return meth(token=self._token, version=self._version, *args, **kwargs)
#     673
#     674     def account(self):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pyEX/stocks/corporateActions.py in splits(symbol, refid, token, version, filter)
#     385         return _getJson('time-series/advanced_splits/' + symbol + '/' + refid, token, version, filter)
#     386     elif symbol:
# --> 387         return _getJson('time-series/advanced_splits/' + symbol, token, version, filter)
#     388     return _getJson('time-series/advanced_splits', token, version, filter)
#     389
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pyEX/common.py in _getJson(url, token, version, filter)
#     383         if version == 'sandbox':
#     384             return _getJsonIEXCloudSandbox(url, token, version, filter)
# --> 385         return _getJsonIEXCloud(url, token, version, filter)
#     386     return _getJsonOrig(url)
#     387
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pyEX/common.py in _getJsonIEXCloud(url, token, version, filter)
#     400     if resp.status_code == 200:
#     401         return resp.json()
# --> 402     raise PyEXception('Response %d - ' % resp.status_code, resp.text)
#     403
#     404
#
# PyEXception: ('Response 402 - ', 'The requested data is not available to free tier accounts. Please upgrade for access to this data.')

# %%
c.splitsDF(symbol)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## Upcoming Events

# %% [markdown]
# ## Volume By Venue

# %%
c.volumeByVenue(symbol)
# Out:
# [{'volume': 58855,
#   'venue': 'XASE',
#   'venueName': 'NYSE American',
#   'date': '2019-05-07',
#   'marketPercent': 0.001550432278327238,
#   'avgMarketPercent': 0.0013988667649070885},
#  {'volume': 128014,
#   'venue': 'XCIS',
#   'venueName': 'NYSE National',
#   'date': '2019-05-07',
#   'marketPercent': 0.003372305457102762,
#   'avgMarketPercent': 0.0027233833629648333},
#  {'volume': 104690,
#   'venue': 'XCHI',
#   'venueName': 'CHX',
#   'date': '2019-05-07',
#   'marketPercent': 0.0035884340065768876,
#   'avgMarketPercent': 0.019839707033233366},
#  {'volume': 274061,
#   'venue': 'XPHL',
#   'venueName': 'Nasdaq PSX',
#   'date': '2019-05-07',
#   'marketPercent': 0.007219658833245114,
#   'avgMarketPercent': 0.00758794843446839},
#  {'volume': 366666,
#   'venue': 'EDGA',
#   'venueName': 'Cboe EDGA',
#   'date': '2019-05-07',
#   'marketPercent': 0.009659175970862884,
#   'avgMarketPercent': 0.012147458463215965},
#  {'volume': 372534,
#   'venue': 'BATY',
#   'venueName': 'Cboe BYX',
#   'date': '2019-05-07',
#   'marketPercent': 0.009813758191731532,
#   'avgMarketPercent': 0.02030662022159324},
#  {'volume': 409110,
#   'venue': 'XBOS',
#   'venueName': 'Nasdaq BX',
#   'date': '2019-05-07',
#   'marketPercent': 0.010777289089906657,
#   'avgMarketPercent': 0.01684399071131908},
#  {'volume': 869563,
#   'venue': 'IEXG',
#   'venueName': 'IEX',
#   'date': '2019-05-07',
#   'marketPercent': 0.022907119925903798,
#   'avgMarketPercent': 0.02803983675894908},
#  {'volume': 1304584,
#   'venue': 'XNYS',
#   'venueName': 'NYSE',
#   'date': '2019-05-07',
#   'marketPercent': 0.03722274089130869,
#   'avgMarketPercent': 0.022422897396352538},
#  {'volume': 1576346,
#   'venue': 'EDGX',
#   'venueName': 'Cboe EDGX',
#   'date': '2019-05-07',
#   'marketPercent': 0.04107767067556842,
#   'avgMarketPercent': 0.03890235960676351},
#  {'volume': 2378623,
#   'venue': 'BATS',
#   'venueName': 'Cboe BZX',
#   'date': '2019-05-07',
#   'marketPercent': 0.06198421041385122,
#   'avgMarketPercent': 0.0683246566594053},
#  {'volume': 2782747,
#   'venue': 'ARCX',
#   'venueName': 'NYSE Arca',
#   'date': '2019-05-07',
#   'marketPercent': 0.07251343848555453,
#   'avgMarketPercent': 0.08024871602164509},
#  {'volume': 13039388,
#   'venue': 'XNGS',
#   'venueName': 'Nasdaq',
#   'date': '2019-05-07',
#   'marketPercent': 0.339789958255991,
#   'avgMarketPercent': 0.28313339012738925},
#  {'volume': 14710396,
#   'venue': 'TRF',
#   'venueName': 'Off Exchange',
#   'date': '2019-05-07',
#   'marketPercent': 0.38332673148336127,
#   'avgMarketPercent': 0.39808016843779326}]

# %%
c.volumeByVenueDF(symbol)
# Out:
#        avgMarketPercent       date  marketPercent      venueName    volume
# venue
# XASE           0.001399 2019-05-07       0.001550  NYSE American     58855
# XCIS           0.002723 2019-05-07       0.003372  NYSE National    128014
# XCHI           0.019840 2019-05-07       0.003588            CHX    104690
# XPHL           0.007588 2019-05-07       0.007220     Nasdaq PSX    274061
# EDGA           0.012147 2019-05-07       0.009659      Cboe EDGA    366666
# BATY           0.020307 2019-05-07       0.009814       Cboe BYX    372534
# XBOS           0.016844 2019-05-07       0.010777      Nasdaq BX    409110
# IEXG           0.028040 2019-05-07       0.022907            IEX    869563
# XNYS           0.022423 2019-05-07       0.037223           NYSE   1304584
# EDGX           0.038902 2019-05-07       0.041078      Cboe EDGX   1576346
# BATS           0.068325 2019-05-07       0.061984       Cboe BZX   2378623
# ARCX           0.080249 2019-05-07       0.072513      NYSE Arca   2782747
# XNGS           0.283133 2019-05-07       0.339790         Nasdaq  13039388
# TRF            0.398080 2019-05-07       0.383327   Off Exchange  14710396

# %% [markdown]
# # Alternative

# %% [markdown]
# ## crypto

# %%
# c.crypto()

# %%
# c.cryptoDF()

# %% [markdown]
# ## sentiment

# %%
c.sentiment(symbol)
# Out:
# ---------------------------------------------------------------------------
# PyEXception                               Traceback (most recent call last)
# <ipython-input-65-23836fae8643> in <module>
# ----> 1 c.sentiment(symbol)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pyEX/client.py in bind(self, *args, **kwargs)
#     670         if not meth:
#     671             raise PyEXception('Must provide method!')
# --> 672         return meth(token=self._token, version=self._version, *args, **kwargs)
#     673
#     674     def account(self):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pyEX/alternative/alternative.py in sentiment(symbol, type, date, token, version, filter)
#      60         date = _strOrDate(date)
#      61         return _getJson('stock/{symbol}/sentiment/{type}/{date}'.format(symbol=symbol, type=type, date=date), token, version, filter)
# ---> 62     return _getJson('stock/{symbol}/sentiment/{type}/'.format(symbol=symbol, type=type), token, version, filter)
#      63
#      64
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pyEX/common.py in _getJson(url, token, version, filter)
#     383         if version == 'sandbox':
#     384             return _getJsonIEXCloudSandbox(url, token, version, filter)
# --> 385         return _getJsonIEXCloud(url, token, version, filter)
#     386     return _getJsonOrig(url)
#     387
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pyEX/common.py in _getJsonIEXCloud(url, token, version, filter)
#     400     if resp.status_code == 200:
#     401         return resp.json()
# --> 402     raise PyEXception('Response %d - ' % resp.status_code, resp.text)
#     403
#     404
#
# PyEXception: ('Response 451 - ', 'The requested data requires permission to access.')

# %%
c.sentimentDF(symbol)
# Out:
#    negative  positive  sentiment  totalScores
# 0      0.31      0.69  -0.031521          838

# %% [markdown]
# ## CEO Compensation

# %%
c.ceoCompensation(symbol)
# Out:
# ---------------------------------------------------------------------------
# PyEXception                               Traceback (most recent call last)
# <ipython-input-66-54d54569de37> in <module>
# ----> 1 c.ceoCompensation(symbol)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pyEX/client.py in bind(self, *args, **kwargs)
#     670         if not meth:
#     671             raise PyEXception('Must provide method!')
# --> 672         return meth(token=self._token, version=self._version, *args, **kwargs)
#     673
#     674     def account(self):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/temporalcache/expire.py in _wrapped_foo(*args, **kwargs)
#      77             kwargs = {k: frozendict(v) if isinstance(v, dict) else tuple(v) if isinstance(v, list) else v for k, v in kwargs.items()}
#      78
# ---> 79             return foo(*args, **kwargs)
#      80         return _wrapped_foo
#      81     return _wrapper
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/temporalcache/persistent_lru_cache.py in wrapper(*args, **kwds)
#     202                         hits += 1
#     203                         return result
# --> 204                 result = user_function(*args, **kwds)
#     205                 with lock:
#     206                     if key in cache:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pyEX/alternative/alternative.py in ceoCompensation(symbol, token, version, filter)
#     105     '''
#     106     _raiseIfNotStr(symbol)
# --> 107     return _getJson('stock/{symbol}/ceo-compensation'.format(symbol=symbol), token, version, filter)
#     108
#     109
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pyEX/common.py in _getJson(url, token, version, filter)
#     383         if version == 'sandbox':
#     384             return _getJsonIEXCloudSandbox(url, token, version, filter)
# --> 385         return _getJsonIEXCloud(url, token, version, filter)
#     386     return _getJsonOrig(url)
#     387
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pyEX/common.py in _getJsonIEXCloud(url, token, version, filter)
#     400     if resp.status_code == 200:
#     401         return resp.json()
# --> 402     raise PyEXception('Response %d - ' % resp.status_code, resp.text)
#     403
#     404
#
# PyEXception: ('Response 402 - ', 'The requested data is not available to free tier accounts. Please upgrade for access to this data.')

# %%
c.ceoCompensationDF(symbol)
# Out:
#    bonus companyName       location      name  nonEquityIncentives  \
# 0      0              Cupertino, CA  Tim Cook              9327000
#
#    optionAwards  otherComp  pensionAndDeferred   salary  stockAwards symbol  \
# 0             0     440374                   0  3057692            0   AAPL
#
#       total  year
# 0  12825066  2017

# %% [markdown]
# # Forex

# %% [markdown]
# ## Exchange Rates

# %% [markdown]
# # IEX Data

# %% [markdown]
# ## TOPS

# %% [markdown]
# ## Last

# %% [markdown]
# ## DEEP

# %% [markdown]
# ## DEEP Auction

# %% [markdown]
# ## DEEP Book

# %% [markdown]
# ## DEEP Operational Halt Status

# %% [markdown]
# ## DEEP Official Price

# %% [markdown]
# ## DEEP Security Event

# %% [markdown]
# ## DEEP Short Sale Price Test Status

# %% [markdown]
# ## DEEP System Event

# %% [markdown]
# ## DEEP Trades

# %% [markdown]
# ## DEEP Trade Break

# %% [markdown]
# ## DEEP Trading Status

# %% [markdown]
# ## Listed Regulation SHO Threshold Securities List In Dev

# %% [markdown]
# ## Listed Short Interest List In Dev

# %% [markdown]
# ## Stats Historical Daily In Dev

# %% [markdown]
# ## Stats Historical Summary

# %% [markdown]
# ## Stats Intraday

# %% [markdown]
# ## Stats Recent

# %% [markdown]
# ## Stats Records

# %% [markdown]
# # API Metadata
