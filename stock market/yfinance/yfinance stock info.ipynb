# %%
import numpy as np
import pandas as pd
import datetime
from pandas_datareader import data as web
import yfinance as yf
yf.pdr_override() # <== that's all it takes :-)
# from dateutil import parser
# from datetime import datetime as dt
# import yfinance as yf
# data = yf.download("SPY AAPL", start="2019-01-01", end="2019-01-02", group_by=True)
# data
start_date = '2019-01-01'
end_date = '2019-01-31'
print(start_date,'\t',end_date)
# Set the ticker
ticker = 'AMZN NFLX'
# Get the data
data = web.get_data_yahoo(ticker, start_date, end_date)
print(data.head())
print(data.tail())
# Out:
# 2019-01-01 	 2019-01-31
# [*********************100%***********************]  2 of 2 downloaded
#            Adj Close            Close             High              Low  \
#                 AMZN    NFLX     AMZN    NFLX     AMZN    NFLX     AMZN
# Date
# 2019-01-02   1539.13  267.66  1539.13  267.66  1553.36  269.75  1460.93
# 2019-01-03   1500.28  271.20  1500.28  271.20  1538.00  275.79  1497.11
# 2019-01-04   1575.39  297.57  1575.39  297.57  1594.00  297.80  1518.31
# 2019-01-07   1629.51  315.34  1629.51  315.34  1634.56  316.80  1589.19
# 2019-01-08   1656.58  320.27  1656.58  320.27  1676.61  320.59  1616.61
#
#                        Open           Volume
#               NFLX     AMZN    NFLX     AMZN      NFLX
# Date
# 2019-01-02  256.58  1465.20  259.28  7983100  11679500
# 2019-01-03  264.43  1520.01  270.20  6975600  14969600
# 2019-01-04  278.54  1530.00  281.88  9182600  19330100
# 2019-01-07  301.65  1602.31  302.10  7993200  18620100
# ...

# %%
msft = yf.Ticker("MSFT")

# get stock info
msft.info['language']
msft.info['fiftyTwoWeekHigh']
msft.info
# Out:
# {'language': 'en-US',
#  'region': 'US',
#  'quoteType': 'EQUITY',
#  'triggerable': True,
#  'quoteSourceName': 'Nasdaq Real Time Price',
#  'currency': 'USD',
#  'marketState': 'CLOSED',
#  'sharesOutstanding': 7695349760,
#  'bookValue': 13.893,
#  'fiftyDayAverage': 140.025,
#  'fiftyDayAverageChange': 5.935013,
#  'fiftyDayAverageChangePercent': 0.04238538,
#  'twoHundredDayAverage': 135.17369,
#  'twoHundredDayAverageChange': 10.786316,
#  'forwardPE': 24.08581,
#  'priceToBook': 10.506011,
#  'sourceInterval': 15,
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EST',
#  'gmtOffSetMilliseconds': -18000000,
#  'trailingAnnualDividendYield': 0.013101345,
#  'fiftyTwoWeekHighChangePercent': -0.00020548516,
#  'fiftyTwoWeekLow': 93.96,
#  'fiftyTwoWeekHigh': 145.99,
#  'dividendDate': 1576108800,
#  'earningsTimestamp': 1571846919,
#  'earningsTimestampStart': 1580209140,
#  'earningsTimestampEnd': 1580731200,
#  'trailingAnnualDividendRate': 1.89,
# ...

# %%
msft.info['fiftyTwoWeekHigh']
# Out:
# 145.67

# %%
# get historical market data
hist = msft.history(period="max")
print(hist.tail())
# Out:
#                   Open        High         Low       Close      Volume  \
# Date
# 2019-10-28  144.399994  145.669998  143.509995  144.190002    35280100
# 2019-10-29  144.080002  144.500000  142.649994  142.830002    20519700
# 2019-10-30  143.520004  145.000000  142.789993  144.610001    18471700
# 2019-10-31  144.899994  144.929993  142.990005  143.369995  2459620000
# 2019-11-01  144.259995  144.419998  142.970001  143.720001    33119200
#
#             Dividends  Stock Splits
# Date
# 2019-10-28        0.0           0.0
# 2019-10-29        0.0           0.0
# 2019-10-30        0.0           0.0
# 2019-10-31        0.0           0.0
# 2019-11-01        0.0           0.0

# %%
# show actions (dividends, splits)
msft.actions.tail()
# Out:
#             Dividends  Stock Splits
# Date
# 2018-08-15       0.42           0.0
# 2018-11-14       0.46           0.0
# 2019-02-20       0.46           0.0
# 2019-05-15       0.46           0.0
# 2019-08-14       0.46           0.0

# %%
# show dividends
msft.dividends.tail()
# Out:
# Date
# 2018-08-15    0.42
# 2018-11-14    0.46
# 2019-02-20    0.46
# 2019-05-15    0.46
# 2019-08-14    0.46
# Name: Dividends, dtype: float64

# %%
# show splits
msft.splits
# Out:
# Date
# 1987-09-21    2.0
# 1990-04-16    2.0
# 1991-06-27    1.5
# 1992-06-15    1.5
# 1994-05-23    2.0
# 1996-12-09    2.0
# 1998-02-23    2.0
# 1999-03-29    2.0
# 2003-02-18    2.0
# Name: Stock Splits, dtype: float64

# %%
# show financials
msft.financials
# Out:
#                                         6/30/2019  6/30/2018 6/30/2017  \
#
# Total Revenue                           125843000  110360000  96571000
# Cost of Revenue                          42910000   38353000  34261000
# Gross Profit                             82933000   72007000  62310000
# Operating Expenses                              -          -         -
# Research Development                     16876000   14726000  13037000
# Selling General and Administrative       23098000   22223000  19942000
# Non Recurring                                 NaN        NaN       NaN
# Others                                        NaN        NaN       NaN
# Total Operating Expenses                 82884000   75302000  67240000
# Operating Income or Loss                 42959000   35058000  29331000
# Income from Continuing Operations               -          -         -
# Total Other Income/Expenses Net            729000    1416000    570000
# ...

# %%
# show sustainability
msft.sustainability
# Out:
#       Products and Activities  Significant Involvement
# 0         Alcoholic Beverages                    False
# 1         Adult Entertainment                    False
# 2                    Gambling                    False
# 3            Tobacco Products                    False
# 4              Animal Testing                    False
# 5   Fur and Specialty Leather                    False
# 6       Controversial Weapons                    False
# 7                  Small Arms                    False
# 8             Catholic Values                    False
# 9                         GMO                    False
# 10       Military Contracting                    False
# 11                 Pesticides                    False
# 12               Thermal Coal                    False
# 13                   Palm Oil                    False

# %%
# show options expirations
msft.options[0]
# Out:
# '2019-11-14'

# %%
# get option chain for specific expiration
opt = msft.option_chain(msft.options[0])
# data available via: opt.calls, opt.puts
print(opt)
# Out:
# Options(calls=         contractSymbol  lastTradeDate  strike  lastPrice    bid    ask  \
# 0   MSFT191108C00100000     1572547332   100.0      43.35  41.30  45.00
# 1   MSFT191108C00101000     1572478050   101.0      42.15  40.30  44.00
# 2   MSFT191108C00102000     1572478051   102.0      41.15  39.30  42.35
# 3   MSFT191108C00115000     1572020920   115.0      25.86  26.35  30.35
# 4   MSFT191108C00120000     1572546842   120.0      22.89  21.30  25.00
# 5   MSFT191108C00122000     1572638268   122.0      21.54  19.30  22.45
# 6   MSFT191108C00123000     1572551023   123.0      20.45  18.55  21.80
# 7   MSFT191108C00124000     1572372549   124.0      19.05  17.60  20.35
# 8   MSFT191108C00125000     1572537150   125.0      19.15  16.30  20.00
# 9   MSFT191108C00126000     1572033498   126.0      14.80  15.30  19.00
# 10  MSFT191108C00127000     1572629956   127.0      16.17  14.60  17.40
# 11  MSFT191108C00128000     1571843449   128.0      12.20  13.30  16.95
# ...

# %%
type(opt.calls)
# Out:
# pandas.core.frame.DataFrame

# %%
df =opt.calls
df1 = df[df.loc[:,'volume'] > 100][['strike', 'volume', 'ask',  'bid', 'percentChange',   'lastPrice', 'inTheMoney']]
#lastTradeDate	strike	lastPrice	bid	ask	change	percentChange	volume	openInterest	impliedVolatility	inTheMoney	contractSize	currency
df1.sort_values(by=['strike'], ascending=False)
# Out:
#     strike   volume   ask   bid  percentChange  lastPrice  inTheMoney  \
# 35   155.0    206.0  0.01  0.00       0.000000       0.01       False
# 33   150.0    237.0  0.04  0.03     -20.000004       0.04       False
# 32   149.0    167.0  0.07  0.04     -50.000000       0.04       False
# 31   148.0    599.0  0.10  0.08     -35.714283       0.09       False
# 30   147.0   1214.0  0.17  0.16     -31.818178       0.15       False
# 29   146.0   1706.0  0.36  0.32     -28.205126       0.31       False
# 28   145.0   5234.0  0.60  0.56     -16.176472       0.58       False
# 27   144.0  10326.0  1.04  0.97      -9.433959       1.00       False
# 26   143.0   2983.0  1.60  1.53      -5.454548       1.56        True
# 25   142.0   5298.0  2.38  2.24       4.285722       2.25        True
# 24   141.0    355.0  3.20  2.96       4.593644       3.04        True
# 23   140.0    561.0  4.00  3.80      -2.739730       3.55        True
#
#    contractSize
# 35      REGULAR
# 33      REGULAR
# ...

# %%
opt.calls
# Out:
#          contractSymbol  lastTradeDate  strike  lastPrice    bid    ask  \
# 0   MSFT191108C00100000     1572547332   100.0      43.35  41.30  45.00
# 1   MSFT191108C00101000     1572478050   101.0      42.15  40.30  44.00
# 2   MSFT191108C00102000     1572478051   102.0      41.15  39.30  42.35
# 3   MSFT191108C00115000     1572020920   115.0      25.86  26.35  30.35
# 4   MSFT191108C00120000     1572546842   120.0      22.89  21.30  25.00
# 5   MSFT191108C00122000     1572638268   122.0      21.54  19.30  22.45
# 6   MSFT191108C00123000     1572551023   123.0      20.45  18.55  21.80
# 7   MSFT191108C00124000     1572372549   124.0      19.05  17.60  20.35
# 8   MSFT191108C00125000     1572537150   125.0      19.15  16.30  20.00
# 9   MSFT191108C00126000     1572033498   126.0      14.80  15.30  19.00
# 10  MSFT191108C00127000     1572629956   127.0      16.17  14.60  17.40
# 11  MSFT191108C00128000     1571843449   128.0      12.20  13.30  16.95
# ...
