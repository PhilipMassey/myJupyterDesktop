# %%
from alpha_vantage.timeseries import TimeSeries
from alpha_vantage.techindicators import TechIndicators
from alpha_vantage.sectorperformance import SectorPerformances
from alpha_vantage.cryptocurrencies import CryptoCurrencies
import matplotlib

import matplotlib.pyplot as plt

# %matplotlib inline
import os
# Make plots bigger
matplotlib.rcParams['figure.figsize'] = (12, 8)
sp = SectorPerformances(key='LJQX8580YS8GDLSL', output_format='pandas')

data, meta_data = sp.get_sector()
print(data.columns[0])
data[data.columns[0]].plot(kind='bar')
plt.title(data.columns[0] + ' - (%) per Sector')
plt.tight_layout()
plt.grid()
plt.show();
data.columns
# Out:
# Rank A: Real-Time Performance
# Index(['Rank A: Real-Time Performance', 'Rank B: Day Performance',
#        'Rank C: Day Performance', 'Rank D: Month Performance',
#        'Rank E: Month Performance', 'Rank F: Year-to-Date (YTD) Performance',
#        'Rank G: Year Performance', 'Rank H: Year Performance',
#        'Rank I: Year Performance', 'Rank J: Year Performance'],
#       dtype='object')

# %%
data
# Out:
#                             Rank A: Real-Time Performance  \
# Consumer Discretionary                            -0.0023
# Consumer Staples                                  -0.0174
# Energy                                             0.0095
# Financials                                        -0.0052
# Health Care                                       -0.0093
# Industrials                                        0.0007
# Information Technology                             0.0053
# Materials                                          0.0020
# Real Estate                                       -0.0011
# Telecommunication Services                        -0.0162
# Utilities                                          0.0004
#
#                             Rank B: Day Performance  Rank C: Day Performance  \
# Consumer Discretionary                       0.0016                   0.0227
# Consumer Staples                            -0.0088                  -0.0021
# Energy                                      -0.0055                   0.0048
# Financials                                   0.0009                  -0.0076
# Health Care                                  0.0003                   0.0058
# Industrials                                 -0.0046                  -0.0207
# Information Technology                       0.0146                   0.0279
# Materials                                   -0.0001                  -0.0044
# Real Estate                                  0.0068                   0.0254
# Telecommunication Services                  -0.0077                  -0.0413
# Utilities                                   -0.0028                   0.0146
#
#                             Rank D: Month Performance  \
# Consumer Discretionary                         0.0244
# Consumer Staples                              -0.0536
# Energy                                         0.0868
# Financials                                    -0.0039
# Health Care                                    0.0115
# Industrials                                   -0.0329
# Information Technology                         0.0150
# Materials                                      0.0009
# Real Estate                                   -0.0008
# Telecommunication Services                    -0.0300
# Utilities                                      0.0176
#
#                             Rank E: Month Performance  \
# Consumer Discretionary                        -0.0364
# Consumer Staples                              -0.1393
# Energy                                        -0.0215
# Financials                                    -0.0764
# Health Care                                   -0.0663
# Industrials                                   -0.0997
# Information Technology                        -0.0262
# Materials                                     -0.0959
# Real Estate                                   -0.0401
# Telecommunication Services                    -0.1085
# Utilities                                      0.0061
#
#                             Rank F: Year-to-Date (YTD) Performance  \
# Consumer Discretionary                                      0.0526
# Consumer Staples                                           -0.1272
# Energy                                                      0.0152
# Financials                                                 -0.0177
# Health Care                                                -0.0050
# Industrials                                                -0.0524
# Information Technology                                      0.0475
# Materials                                                  -0.0588
# Real Estate                                                -0.0587
# Telecommunication Services                                 -0.1142
# Utilities                                                  -0.0251
#
#                             Rank G: Year Performance  \
# Consumer Discretionary                        0.1533
# Consumer Staples                             -0.0951
# Energy                                        0.0854
# Financials                                    0.1663
# Health Care                                   0.0909
# Industrials                                   0.0619
# Information Technology                        0.2482
# Materials                                     0.0705
# Real Estate                                  -0.0178
# Telecommunication Services                   -0.0825
# Utilities                                    -0.0057
#
#                             Rank H: Year Performance  \
# Consumer Discretionary                        0.3840
# Consumer Staples                              0.0326
# Energy                                       -0.1018
# Financials                                    0.4014
# Health Care                                   0.1480
# Industrials                                   0.2611
# Information Technology                        0.6345
# Materials                                     0.1290
# Real Estate                                      NaN
# Telecommunication Services                   -0.0811
# Utilities                                     0.1607
#
#                             Rank I: Year Performance  Rank J: Year Performance
# Consumer Discretionary                        0.9109                    2.2596
# Consumer Staples                              0.2138                    0.7673
# Energy                                       -0.0644                   -0.1241
# Financials                                    0.8085                    0.2810
# Health Care                                   0.7355                    1.6004
# Industrials                                   0.6842                    0.7619
# Information Technology                        1.3775                    2.1113
# Materials                                     0.4332                    0.3512
# Real Estate                                      NaN                       NaN
# Telecommunication Services                   -0.1217                   -0.0150
# Utilities                                     0.2389                    0.2835

# %%
for idx in range(len(data.columns)-1):
    column = data.columns[idx]
    print(column)
    data[column].plot(kind='bar')
    plt.title(column + ' (%) per Sector')
    plt.tight_layout()
    plt.grid()
    plt.show();
# Out:
# Rank A: Real-Time Performance
# Rank B: Day Performance
# Rank C: Day Performance
# Rank D: Month Performance
# Rank E: Month Performance
# Rank F: Year-to-Date (YTD) Performance
# Rank G: Year Performance
# Rank H: Year Performance
# Rank I: Year Performance
