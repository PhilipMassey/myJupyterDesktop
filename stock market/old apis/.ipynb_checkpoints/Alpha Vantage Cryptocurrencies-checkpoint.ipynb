# %% [markdown]
# ### Working with Crypto Currencies
#
# To just get the current exchange rate

# %%
# %matplotlib inline
from alpha_vantage.timeseries import TimeSeries
from alpha_vantage.techindicators import TechIndicators
from alpha_vantage.sectorperformance import SectorPerformances
from alpha_vantage.cryptocurrencies import CryptoCurrencies
import matplotlib
import matplotlib.pyplot as plt
matplotlib.rcParams['figure.figsize'] = (12, 8)
import pandas as pd

cc = CryptoCurrencies(key='LJQX8580YS8GDLSL')

# %%
#I changed the internal format of the the class to be our friendly data frame.
cc.output_format='pandas'
data, meta_data = cc.get_digital_currency_intraday(symbol='BTC', market='CNY')
data.index = pd.to_datetime(data.index)
data['1b. price (USD)'].plot()
plt.tight_layout()
plt.title('Intraday value for bitcoin (BTC)')
plt.grid()
plt.show();
data.head(5)
data.describe()
# Out:
# Text(0.5,1,'Intraday value for bitcoin (BTC)')
#                      1a. price (CNY)  1b. price (USD)   2. volume  \
# date
# 2018-04-18 01:55:00     50926.308130      8107.993652  503.053128
# 2018-04-18 02:00:00     50926.144566      8107.967611  502.845991
# 2018-04-18 02:05:00     50922.919851      8100.103369  503.790972
# 2018-04-18 02:10:00     50923.474716      8100.191629  502.610972
# 2018-04-18 02:15:00     50923.362663      8100.173806  502.511925
#
#                      3. market cap (USD)
# date
# 2018-04-18 01:55:00         4.078752e+06
# 2018-04-18 02:00:00         4.077059e+06
# 2018-04-18 02:05:00         4.080759e+06
# 2018-04-18 02:10:00         4.071245e+06
# 2018-04-18 02:15:00         4.070434e+06
#        1a. price (CNY)  1b. price (USD)   2. volume  3. market cap (USD)
# count       462.000000       462.000000  462.000000         4.620000e+02
# mean      51100.341597      8139.240181  723.703714         5.892908e+06
# std         160.201357        28.763173  137.473586         1.129329e+06
# min       50896.401904      8089.592918  493.680845         4.006847e+06
# 25%       50998.628596      8116.258804  512.439027         4.149105e+06
# 50%       51065.732904      8136.141471  798.819320         6.509468e+06
# 75%       51081.456277      8150.121687  821.566968         6.682534e+06
# max       51435.168928      8191.878851  833.284498         6.777027e+06
