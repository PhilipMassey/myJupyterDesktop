# %%
import requests
import json
response = requests.get('https://sandbox.iexapis.com/stable/time-series/REPORTED_FINANCIALS/AAPL?token=Tsk_e58894c17777490b9ae302b04a526781')
jData = json.loads(response.content)
jData
# Out:
# [{'AccountsPayableCurrent': 48154033388,
#   'formFiscalYear': 2117,
#   'version': 'apu-gsa',
#   'periodStart': 1613920429729,
#   'periodEnd': 1616080179422,
#   'dateFiled': 1627783653237,
#   'formFiscalQuarter': None,
#   'reportLink': '1d0h3//roa/s0h903ewe0tv1ac:/r10v./t00/000/2wd0awsg3g0i0A12p.t99e9s/c13',
#   'AccountsReceivableNetCurrent': 23431479419,
#   'AccruedIncomeTaxesNoncurrent': 29983545646,
#   'AccumulatedDepreciationDepletionAndAmortizationPropertyPlantAndEquipment': 60103867391,
#   'AccumulatedOtherComprehensiveIncomeLossNetOfTax': -603251791,
#   'AdjustmentsToAdditionalPaidInCapitalTaxEffectFromShareBasedCompensationIncludingTransferPricing': 643514625,
#   'AllocatedShareBasedCompensationExpense': 6080593480,
#   'AmountUtilizedUnderShareRepurchaseProgram': 99042032714,
#   'AntidilutiveSecuritiesExcludedFromComputationOfEarningsPerShareAmount': 15986504,
#   'Assets': 345148714403,
#   'AssetsCurrent': 162824638242,
#   'AssetsNoncurrent': 179528685983,
#   'AvailableForSaleDebtSecuritiesAccumulatedGrossUnrealizedGainBeforeTax': 1224660558,
#   'AvailableForSaleDebtSecuritiesAccumulatedGrossUnrealizedLossBeforeTax': 283674904,
#   'AvailableForSaleDebtSecuritiesAmortizedCostBasis': 211363354297,
#   'AvailableForSaleSecuritiesDebtSecurities': 206292019410,
#   'CashAndCashEquivalentsAtCarryingValue': 51011453039,
#   'CashCashEquivalentsRestrictedCashAndRestrictedCashEquivalents': 50364226122,
#   'CashCashEquivalentsRestrictedCashAndRestrictedCashEquivalentsPeriodIncreaseDecreaseIncludingExchangeRateEffect': 24768191785,
#   'CommercialPaper': 6027888354,
#   'CommitmentsAndContingencies': 0,
#   'CommonStockDividendsPerShareDeclared': 3,
#   'CommonStockParOrStatedValuePerShare': 0,
#   'CommonStockSharesAuthorized': 12961624263,
#   'CommonStockSharesIssued': 4651344753,
#   'CommonStockSharesOutstanding': 4535051032,
#   'CommonStocksIncludingAdditionalPaidInCapital': 45736740760,
#   'ComprehensiveIncomeNetOfTax': 60087026463,
#   'ContractWithCustomerLiability': 8496033315,
#   'ContractWithCustomerLiabilityCurrent': 5733997489,
#   'ContractWithCustomerLiabilityRevenueRecognized': 6181573490,
#   'CostOfGoodsAndServicesSold': 162918162296,
#   'CurrentFederalTaxExpenseBenefit': 6583591337,
#   'CurrentForeignTaxExpenseBenefit': 4125587430,
#   'CurrentStateAndLocalTaxExpenseBenefit': 475070710,
#   'DebtInstrumentCarryingAmount': 105583037527,
#   'DebtInstrumentUnamortizedDiscountPremiumAndDebtIssuanceCostsNet': 224913603,
#   'DebtSecuritiesAvailableForSaleContinuousUnrealizedLossPosition12MonthsOrLonger': 28830572410,
#   'DebtSecuritiesAvailableForSaleContinuousUnrealizedLossPosition12MonthsOrLongerAccumulatedLoss': 148273954,
#   'DebtSecuritiesAvailableForSaleContinuousUnrealizedLossPositionLessThan12Months': 28724671014,
#   'DebtSecuritiesAvailableForSaleContinuousUnrealizedLossPositionLessThan12MonthsAccumulatedLoss': 141901023,
#   'DebtSecuritiesAvailableForSaleUnrealizedLossPosition': 57079078409,
#   'DebtSecuritiesAvailableForSaleUnrealizedLossPositionAccumulatedLoss': 285479424,
#   'DecreaseInUnrecognizedTaxBenefitsIsReasonablyPossible': 2071704943,
#   'DeferredFederalIncomeTaxExpenseBenefit': -3023010071,
#   'DeferredForeignIncomeTaxExpenseBenefit': 2765930170,
#   'DeferredIncomeTaxExpenseBenefit': -343004172,
#   'DeferredIncomeTaxLiabilities': 11681330930,
#   'DeferredStateAndLocalIncomeTaxExpenseBenefit': -69218966,
#   'DeferredTaxAssetsDeferredIncome': 1395750030,
#   'DeferredTaxAssetsGoodwillAndIntangibleAssets': 11435712575,
#   'DeferredTaxAssetsLiabilitiesNet': 8326206701,
#   'DeferredTaxAssetsNet': 20229056623,
#   'DeferredTaxAssetsOther': 699849175,
#   'DeferredTaxAssetsPropertyPlantAndEquipment': 137904608,
#   'DeferredTaxAssetsTaxDeferredExpenseCompensationAndBenefitsShareBasedCompensationCost': 767399089,
#   'DeferredTaxAssetsTaxDeferredExpenseReservesAndAccruals': 5460466565,
#   'DeferredTaxAssetsUnrealizedLossesOnAvailableforSaleSecuritiesGross': 0,
#   'DeferredTaxLiabilitiesMinimumTaxonForeignEarnings': 11147392851,
#   'DeferredTaxLiabilitiesOther': 458022977,
#   'DeferredTaxLiabilitiesUndistributedForeignEarnings': 340699558,
#   'DefinedContributionPlanMaximumAnnualContributionsPerEmployeeAmount': 19503,
#   'Depreciation': 11735483336,
#   'DepreciationDepletionAndAmortization': 13166564614,
#   'DerivativeAssetsReductionforMasterNettingArrangements': 2766371698,
#   'DerivativeFairValueOfDerivativeNet': -426896046,
#   'DerivativeLiabilitiesReductionforMasterNettingArrangements': 2730338395,
#   'EarningsPerShareBasic': 12.15,
#   'EarningsPerShareDiluted': 12.21,
#   'EffectiveIncomeTaxRateContinuingOperations': 0.161,
#   'EffectiveIncomeTaxRateReconciliationAtFederalStatutoryIncomeTaxRate': 0.22,
#   'EffectiveIncomeTaxRateReconciliationShareBasedCompensationExcessTaxBenefitAmount': -655054815,
#   'EffectiveIncomeTaxRateReconciliationTaxCutsAndJobsActOf2017Amount': 0,
#   'EmployeeServiceShareBasedCompensationNonvestedAwardsTotalCompensationCostNotYetRecognized': 10625715189,
#   'EmployeeServiceShareBasedCompensationTaxBenefitFromCompensationExpense': 1982270632,
#   'EntityCommonStockSharesOutstanding': 4499672402,
#   'EntityPublicFloat': 896289958261,
#   'EquitySecuritiesWithoutReadilyDeterminableFairValueAmount': 3017481753,
#   'FederalIncomeTaxExpenseBenefitContinuingOperations': 3538170048,
#   'ForeignIncomeTaxExpenseBenefitContinuingOperations': 6759006155,
#   'GainLossFromComponentsExcludedFromAssessmentOfFairValueHedgeEffectivenessNet': 779879856,
#   'GrossProfit': 102198713710,
#   'HedgeAccountingAdjustmentsRelatedToLongTermDebt': 638229160,
#   'IncomeLossFromContinuingOperationsBeforeIncomeTaxesExtraordinaryItemsNoncontrollingInterest': 65753221401,
#   'IncomeLossFromContinuingOperationsBeforeIncomeTaxesForeign': 46033113562,
#   'IncomeTaxesPaidNet': 15328751626,
#   'IncomeTaxExpenseBenefit': 10829178786,
#   'IncomeTaxReconciliationForeignIncomeTaxRateDifferential': -2628414777,
#   'IncomeTaxReconciliationIncomeTaxExpenseBenefitAtFederalStatutoryIncomeTaxRate': 13894960032,
#   'IncomeTaxReconciliationOtherAdjustments': 65673856,
#   'IncomeTaxReconciliationStateAndLocalIncomeTaxes': 443087745,
#   'IncomeTaxReconciliationTaxCreditsResearch': 572566104,
#   'IncreaseDecreaseInAccountsPayable': -1990618401,
#   'IncreaseDecreaseInAccountsReceivable': -253080805,
#   'IncreaseDecreaseInContractWithCustomerLiability': -655117886,
#   'IncreaseDecreaseInInventories': 293308525,
#   'IncreaseDecreaseInOtherOperatingAssets': -905713611,
#   'IncreaseDecreaseInOtherOperatingLiabilities': -4822747796,
#   'IncreaseDecreaseInOtherReceivables': -2997970508,
#   'InterestCostsIncurred': 3213485065,
#   'InterestExpense': 3579700565,
#   'InterestPaidNet': 3552819170,
#   'InventoryNet': 4143135829,
#   'InvestmentIncomeInterestAndDividend': 4977647391,
#   'Liabilities': 253577028108,
#   'LiabilitiesAndStockholdersEquity': 351201519907,
#   'LiabilitiesCurrent': 107775300110,
#   'LiabilitiesNoncurrent': 145392531678,
#   'LongTermDebtCurrent': 10264153861,
#   'LongTermDebtMaturitiesRepaymentsOfPrincipalAfterYearFive': 54111590645,
#   'LongTermDebtMaturitiesRepaymentsOfPrincipalInNextTwelveMonths': 10739264517,
#   'LongTermDebtMaturitiesRepaymentsOfPrincipalInYearFive': 10250750783,
#   'LongTermDebtMaturitiesRepaymentsOfPrincipalInYearFour': 9549179899,
#   'LongTermDebtMaturitiesRepaymentsOfPrincipalInYearThree': 9640374153,
#   'LongTermDebtMaturitiesRepaymentsOfPrincipalInYearTwo': 8979643111,
#   'LongTermDebtNoncurrent': 94196941636,
#   'MarketableSecuritiesCurrent': 53701758693,
#   'MarketableSecuritiesNoncurrent': 109198900104,
#   'NetCashProvidedByUsedInFinancingActivities': -95001917110,
#   'NetCashProvidedByUsedInInvestingActivities': 46044317596,
#   'NetCashProvidedByUsedInOperatingActivities': 69522354440,
#   'NetIncomeLoss': 56577194719,
#   'NonCashActivitiesInvolvingPropertyPlantandEquipmentNetIncreaseDecreasetoAccountsPayableandOtherCurrentLiabilities': -3038207990,
#   'NoncurrentAssets': 38036256465,
#   'NonoperatingIncomeExpense': 1896497845,
#   'NontradeReceivablesCurrent': 23024613474,
#   'OperatingExpenses': 34683023126,
#   'OperatingIncomeLoss': 66659375523,
#   'OperatingLeasesFutureMinimumPaymentsDue': 11065157387,
#   'OperatingLeasesFutureMinimumPaymentsDueCurrent': 1333048299,
#   'OperatingLeasesFutureMinimumPaymentsDueInFiveYears': 851595516,
#   'OperatingLeasesFutureMinimumPaymentsDueInFourYears': 935679332,
#   'OperatingLeasesFutureMinimumPaymentsDueInThreeYears': 1163796342,
#   'OperatingLeasesFutureMinimumPaymentsDueInTwoYears': 1276993939,
#   'OperatingLeasesFutureMinimumPaymentsDueThereafter': 5401585754,
#   'OperatingLeasesRentExpenseNet': 1328707913,
#   'OtherAccruedLiabilitiesNoncurrent': 21834133871,
#   'OtherAssetsCurrent': 12772356648,
#   'OtherAssetsNoncurrent': 33495051216,
#   'OtherComprehensiveIncomeLossAvailableForSaleSecuritiesAdjustmentNetOfTax': 3973132285,
#   'OtherComprehensiveIncomeLossDerivativesQualifyingAsHedgesNetOfTax': -638777856,
#   'OtherComprehensiveIncomeLossForeignCurrencyTransactionAndTranslationAdjustmentNetOfTax': -415885203,
#   'OtherComprehensiveIncomeLossNetOfTaxPortionAttributableToParent': 2830397264,
#   'OtherComprehensiveIncomeLossReclassificationAdjustmentFromAOCIForSaleOfSecuritiesNetOfTax': -25724700,
#   'OtherComprehensiveIncomeLossReclassificationAdjustmentFromAOCIOnDerivativesNetOfTax': -23162342,
#   'OtherComprehensiveIncomeUnrealizedGainLossOnDerivativesArisingDuringPeriodNetOfTax': -664905238,
#   'OtherComprehensiveIncomeUnrealizedHoldingGainLossOnSecuritiesArisingDuringPeriodNetOfTax': 3903148752,
#   'OtherLiabilitiesCurrent': 37790570056,
#   'OtherLiabilitiesNoncurrent': 52598378329,
#   'OtherNoncashIncomeExpense': 657288980,
#   'OtherNonoperatingIncomeExpense': 431066517,
#   'PaymentsForProceedsFromOtherInvestingActivities': 1099877667,
#   'PaymentsForRepurchaseOfCommonStock': 68693924528,
#   'PaymentsOfDividends': 14340593826,
#   'PaymentsRelatedToTaxWithholdingForShareBasedCompensation': 2925799427,
#   'PaymentsToAcquireAvailableForSaleSecuritiesDebt': 40157462364,
#   'PaymentsToAcquireBusinessesNetOfCashAcquired': 631642995,
#   'PaymentsToAcquireOtherInvestments': 1029609106,
#   'PaymentsToAcquirePropertyPlantAndEquipment': 10503948641,
#   'PerformanceObligationsinArrangements': 3,
#   'ProceedsFromIssuanceOfCommonStock': 784984299,
#   'ProceedsFromIssuanceOfLongTermDebt': 6992688584,
#   'ProceedsFromMaturitiesPrepaymentsAndCallsOfAvailableForSaleSecurities': 40184766066,
#   'ProceedsFromPaymentsForOtherFinancingActivities': -110197949,
#   'ProceedsFromRepaymentsOfCommercialPaper': -6117243528,
#   'ProceedsFromRepaymentsOfShortTermDebtMaturingInMoreThanThreeMonths': -2839017538,
#   'ProceedsFromRepaymentsOfShortTermDebtMaturingInThreeMonthsOrLess': -3399398205,
#   'ProceedsFromSaleAndMaturityOfOtherInvestments': 1634152820,
#   'ProceedsFromSaleOfAvailableForSaleSecuritiesDebt': 57885320590,
#   'ProceedsFromShortTermDebtMaturingInMoreThanThreeMonths': 14337445001,
#   'PropertyPlantAndEquipmentGross': 96327943194,
#   'PropertyPlantAndEquipmentNet': 38151420784,
#   'RepaymentsOfLongTermDebt': 9152379180,
#   'RepaymentsOfShortTermDebtMaturingInMoreThanThreeMonths': 17365457158,
#   'ResearchAndDevelopmentExpense': 16224911438,
#   'RestrictedCashAndCashEquivalentsAtCarryingValue': 23013661,
#   'RestrictedCashAndCashEquivalentsNoncurrent': 1358220411,
#   'RestrictedInvestments': 19185166398,
#   'RetainedEarningsAccumulatedDeficit': 47743070520,
#   'RevenueFromContractWithCustomerExcludingAssessedTax': 264551601591,
#   'SellingGeneralAndAdministrativeExpense': 18297927167,
#   'ShareBasedCompensation': 6327196944,
#   'ShortTermDebtWeightedAverageInterestRate': 0.0234,
#   'StandardProductWarrantyAccrual': 3591766934,
#   'StandardProductWarrantyAccrualPayments': 4015417009,
#   'StandardProductWarrantyAccrualWarrantiesIssued': 3754837148,
#   'StateAndLocalIncomeTaxExpenseBenefitContinuingOperations': 412883435,
#   'StockholdersEquity': 90713940707,
#   'StockRepurchasedAndRetiredDuringPeriodShares': 357446377,
#   'StockRepurchasedAndRetiredDuringPeriodValue': 69307804339,
#   'StockRepurchaseProgramAuthorizedAmount1': 176729148431,
#   'UnrecognizedTaxBenefits': 15927393882,
#   'UnrecognizedTaxBenefitsDecreasesResultingFromPriorPeriodTaxPositions': 695342700,
#   'UnrecognizedTaxBenefitsDecreasesResultingFromSettlementsWithTaxingAuthorities': 870759979,
#   'UnrecognizedTaxBenefitsIncomeTaxPenaltiesAndInterestAccrued': 1346207502,
#   'UnrecognizedTaxBenefitsIncomeTaxPenaltiesAndInterestExpense': 75022101,
#   'UnrecognizedTaxBenefitsIncreasesResultingFromCurrentPeriodTaxPositions': 1772590467,
#   'UnrecognizedTaxBenefitsIncreasesResultingFromPriorPeriodTaxPositions': 6103995574,
#   'UnrecognizedTaxBenefitsReductionsResultingFromLapseOfApplicableStatuteOfLimitations': 81781519,
#   'UnrecognizedTaxBenefitsThatWouldImpactEffectiveTaxRate': 8617315638,
#   'UnrecordedUnconditionalPurchaseObligationBalanceOnFifthAnniversary': 224072492,
#   'UnrecordedUnconditionalPurchaseObligationBalanceOnFirstAnniversary': 2525334987,
#   'UnrecordedUnconditionalPurchaseObligationBalanceOnFourthAnniversary': 1212911685,
#   'UnrecordedUnconditionalPurchaseObligationBalanceOnSecondAnniversary': 2403729404,
#   'UnrecordedUnconditionalPurchaseObligationBalanceOnThirdAnniversary': 1877951917,
#   'UnrecordedUnconditionalPurchaseObligationBalanceSheetAmount': 8421743353,
#   'UnrecordedUnconditionalPurchaseObligationDueAfterFiveYears': 110569637,
#   'WeightedAverageNumberDilutedSharesOutstandingAdjustment': 31512976,
#   'WeightedAverageNumberOfDilutedSharesOutstanding': 4679561598,
#   'WeightedAverageNumberOfSharesOutstandingBasic': 4635402022,
#   'id': 'ICRAELRIDTSPEONA_FN',
#   'source': 'CES',
#   'key': 'LAPA',
#   'subkey': '-0K1',
#   'updated': 1634026499082}]

# %%
from iex import reference
reference.symbols() # Returns a Pandas Dataframe of all stock symbols, names, and more.
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-53acc3ab46f8> in <module>
# ----> 1 from iex import reference
#       2 reference.symbols() # Returns a Pandas Dataframe of all stock symbols, names, and more.
#
# ModuleNotFoundError: No module named 'iex'
