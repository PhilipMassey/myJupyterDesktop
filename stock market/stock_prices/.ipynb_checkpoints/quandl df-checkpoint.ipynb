# %%
import quandl
quandl.ApiConfig.api_key ="7s8cchLy59CiAjkDb_oo"
#df = quandl.get_table('WIKI/PRICES', qopts = { 'columns': ['ticker', 'date', 'close'] }, ticker = ['AAPL', 'MSFT'], date = { 'gte': '2016-01-01', 'lte': '2016-12-31' })
df = quandl.get_table('WIKI/PRICES', ticker = ['AAPL', 'MSFT'], date = { 'gte': '2017-10-01', 'lte': '2019-10-31' })

print(df.columns)
df.tail()
# Out:
# Index(['ticker', 'date', 'open', 'high', 'low', 'close', 'volume',
#        'ex-dividend', 'split_ratio', 'adj_open', 'adj_high', 'adj_low',
#        'adj_close', 'adj_volume'],
#       dtype='object')
#      ticker       date    open    high     low     close      volume  \
# None
# 237    AAPL 2017-10-06  154.97  155.49  154.56  155.3000  16423749.0
# 238    AAPL 2017-10-05  154.18  155.44  154.05  155.3900  21032800.0
# 239    AAPL 2017-10-04  153.63  153.86  152.46  153.4508  19844177.0
# 240    AAPL 2017-10-03  154.01  155.09  153.91  154.4800  16146388.0
# 241    AAPL 2017-10-02  154.26  154.45  152.72  153.8100  18524860.0
#
#       ex-dividend  split_ratio  adj_open  adj_high  adj_low  adj_close  \
# None
# 237           0.0          1.0    154.97    155.49   154.56   155.3000
# 238           0.0          1.0    154.18    155.44   154.05   155.3900
# 239           0.0          1.0    153.63    153.86   152.46   153.4508
# ...

# %%
aapl = quandl.get("WIKI/AAPL")
aapl.head()
# Out:
#              Open   High    Low  Close     Volume  Ex-Dividend  Split Ratio  \
# Date
# 1980-12-12  28.75  28.87  28.75  28.75  2093900.0          0.0          1.0
# 1980-12-15  27.38  27.38  27.25  27.25   785200.0          0.0          1.0
# 1980-12-16  25.37  25.37  25.25  25.25   472000.0          0.0          1.0
# 1980-12-17  25.87  26.00  25.87  25.87   385900.0          0.0          1.0
# 1980-12-18  26.63  26.75  26.63  26.63   327900.0          0.0          1.0
#
#             Adj. Open  Adj. High  Adj. Low  Adj. Close  Adj. Volume
# Date
# 1980-12-12   0.422706   0.424470  0.422706    0.422706  117258400.0
# 1980-12-15   0.402563   0.402563  0.400652    0.400652   43971200.0
# 1980-12-16   0.373010   0.373010  0.371246    0.371246   26432000.0
# 1980-12-17   0.380362   0.382273  0.380362    0.380362   21610400.0
# 1980-12-18   0.391536   0.393300  0.391536    0.391536   18362400.0

# %%
aapl.tail()
# Out:
#               Open    High     Low    Close      Volume  Ex-Dividend  \
# Date
# 2018-03-21  175.04  175.09  171.26  171.270  35247358.0          0.0
# 2018-03-22  170.00  172.68  168.60  168.845  41051076.0          0.0
# 2018-03-23  168.39  169.92  164.94  164.940  40248954.0          0.0
# 2018-03-26  168.07  173.10  166.44  172.770  36272617.0          0.0
# 2018-03-27  173.68  175.15  166.92  168.340  38962839.0          0.0
#
#             Split Ratio  Adj. Open  Adj. High  Adj. Low  Adj. Close  \
# Date
# 2018-03-21          1.0     175.04     175.09    171.26     171.270
# 2018-03-22          1.0     170.00     172.68    168.60     168.845
# 2018-03-23          1.0     168.39     169.92    164.94     164.940
# 2018-03-26          1.0     168.07     173.10    166.44     172.770
# 2018-03-27          1.0     173.68     175.15    166.92     168.340
#
#             Adj. Volume
# Date
# 2018-03-21   35247358.0
# 2018-03-22   41051076.0
# 2018-03-23   40248954.0
# ...
