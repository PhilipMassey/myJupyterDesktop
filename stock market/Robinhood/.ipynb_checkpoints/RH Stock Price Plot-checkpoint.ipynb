# %%
import robin_stocks as r 
from datetime import datetime
from dateutil import tz
import pandas as pd
import plotly.express as px

from_zone = tz.tzutc()
to_zone = tz.tzlocal()
def utcToLocal(strDate):
    utc = datetime.strptime(strDate, '%Y-%m-%dT%H:%M:%SZ')
    utc = utc.replace(tzinfo=from_zone)
    return utc.astimezone(to_zone)

import configparser
config = configparser.RawConfigParser()
configFilePath = '/Users/philipmassey/.tokens/robinhood.cfg'
config.read(configFilePath)
rhuser = config.get('login', 'user')
rhpwd = config.get('login', 'pwd')
login = r.login(rhuser,rhpwd)

# %% [markdown]
# <pre>
# :param inputSymbols: May be a single stock ticker or a list of stock tickers.
# :type inputSymbols: str or list
# :param span: Sets the range of the data to be either 'day', 'week', 'year', or '5year'. Default is 'week'.
# :type span: Optional[str]
# :param bounds: Represents if graph will include extended trading hours or just regular trading hours. Values are 'extended' or 'regular'.
# :type bounds: Optional[str]
# :returns: Returns a list of dictionaries where each dictionary is for a different time. If multiple stocks are provided     the historical data is listed one after another.
# </pre>

# %%
symbol = 'SPG'
df = pd.DataFrame(r.get_historicals(symbol,span='year',bounds='regular')) # 'day', 'week', 'year', or '5year'. Default is 'week'.
local = utcToLocal(df.iloc[-1:].begins_at.values[-1])
df.set_index('begins_at',inplace=True)
title = '{} {}'.format(symbol, local)
fig = px.line(x=df.index, y=df.high_price)
fig.update_layout(
    title=title,
    xaxis_title="Date",
    yaxis_title="Stock price",
    font=dict(
        family="Courier New, monospace",
        size=18,
        color="#7f7f7f"
    ))
fig.show()
# Out:
# <div>
#
#
#             <div id="0c92f21a-ae4a-489a-a5da-f0ef8aca894b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0c92f21a-ae4a-489a-a5da-f0ef8aca894b")) {
#                     Plotly.newPlot(
#                         '0c92f21a-ae4a-489a-a5da-f0ef8aca894b',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "x=%{x}<br>y=%{y}", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "showlegend": false, "type": "scatter", "x": ["2019-05-14T00:00:00Z", "2019-05-15T00:00:00Z", "2019-05-16T00:00:00Z", "2019-05-17T00:00:00Z", "2019-05-20T00:00:00Z", "2019-05-21T00:00:00Z", "2019-05-22T00:00:00Z", "2019-05-23T00:00:00Z", "2019-05-24T00:00:00Z", "2019-05-28T00:00:00Z", "2019-05-29T00:00:00Z", "2019-05-30T00:00:00Z", "2019-05-31T00:00:00Z", "2019-06-03T00:00:00Z", "2019-06-04T00:00:00Z", "2019-06-05T00:00:00Z", "2019-06-06T00:00:00Z", "2019-06-07T00:00:00Z", "2019-06-10T00:00:00Z", "2019-06-11T00:00:00Z", "2019-06-12T00:00:00Z", "2019-06-13T00:00:00Z", "2019-06-14T00:00:00Z", "2019-06-17T00:00:00Z", "2019-06-18T00:00:00Z", "2019-06-19T00:00:00Z", "2019-06-20T00:00:00Z", "2019-06-21T00:00:00Z", "2019-06-24T00:00:00Z", "2019-06-25T00:00:00Z", "2019-06-26T00:00:00Z", "2019-06-27T00:00:00Z", "2019-06-28T00:00:00Z", "2019-07-01T00:00:00Z", "2019-07-02T00:00:00Z", "2019-07-03T00:00:00Z", "2019-07-05T00:00:00Z", "2019-07-08T00:00:00Z", "2019-07-09T00:00:00Z", "2019-07-10T00:00:00Z", "2019-07-11T00:00:00Z", "2019-07-12T00:00:00Z", "2019-07-15T00:00:00Z", "2019-07-16T00:00:00Z", "2019-07-17T00:00:00Z", "2019-07-18T00:00:00Z", "2019-07-19T00:00:00Z", "2019-07-22T00:00:00Z", "2019-07-23T00:00:00Z", "2019-07-24T00:00:00Z", "2019-07-25T00:00:00Z", "2019-07-26T00:00:00Z", "2019-07-29T00:00:00Z", "2019-07-30T00:00:00Z", "2019-07-31T00:00:00Z", "2019-08-01T00:00:00Z", "2019-08-02T00:00:00Z", "2019-08-05T00:00:00Z", "2019-08-06T00:00:00Z", "2019-08-07T00:00:00Z", "2019-08-08T00:00:00Z", "2019-08-09T00:00:00Z", "2019-08-12T00:00:00Z", "2019-08-13T00:00:00Z", "2019-08-14T00:00:00Z", "2019-08-15T00:00:00Z", "2019-08-16T00:00:00Z", "2019-08-19T00:00:00Z", "2019-08-20T00:00:00Z", "2019-08-21T00:00:00Z", "2019-08-22T00:00:00Z", "2019-08-23T00:00:00Z", "2019-08-26T00:00:00Z", "2019-08-27T00:00:00Z", "2019-08-28T00:00:00Z", "2019-08-29T00:00:00Z", "2019-08-30T00:00:00Z", "2019-09-03T00:00:00Z", "2019-09-04T00:00:00Z", "2019-09-05T00:00:00Z", "2019-09-06T00:00:00Z", "2019-09-09T00:00:00Z", "2019-09-10T00:00:00Z", "2019-09-11T00:00:00Z", "2019-09-12T00:00:00Z", "2019-09-13T00:00:00Z", "2019-09-16T00:00:00Z", "2019-09-17T00:00:00Z", "2019-09-18T00:00:00Z", "2019-09-19T00:00:00Z", "2019-09-20T00:00:00Z", "2019-09-23T00:00:00Z", "2019-09-24T00:00:00Z", "2019-09-25T00:00:00Z", "2019-09-26T00:00:00Z", "2019-09-27T00:00:00Z", "2019-09-30T00:00:00Z", "2019-10-01T00:00:00Z", "2019-10-02T00:00:00Z", "2019-10-03T00:00:00Z", "2019-10-04T00:00:00Z", "2019-10-07T00:00:00Z", "2019-10-08T00:00:00Z", "2019-10-09T00:00:00Z", "2019-10-10T00:00:00Z", "2019-10-11T00:00:00Z", "2019-10-14T00:00:00Z", "2019-10-15T00:00:00Z", "2019-10-16T00:00:00Z", "2019-10-17T00:00:00Z", "2019-10-18T00:00:00Z", "2019-10-21T00:00:00Z", "2019-10-22T00:00:00Z", "2019-10-23T00:00:00Z", "2019-10-24T00:00:00Z", "2019-10-25T00:00:00Z", "2019-10-28T00:00:00Z", "2019-10-29T00:00:00Z", "2019-10-30T00:00:00Z", "2019-10-31T00:00:00Z", "2019-11-01T00:00:00Z", "2019-11-04T00:00:00Z", "2019-11-05T00:00:00Z", "2019-11-06T00:00:00Z", "2019-11-07T00:00:00Z", "2019-11-08T00:00:00Z", "2019-11-11T00:00:00Z", "2019-11-12T00:00:00Z", "2019-11-13T00:00:00Z", "2019-11-14T00:00:00Z", "2019-11-15T00:00:00Z", "2019-11-18T00:00:00Z", "2019-11-19T00:00:00Z", "2019-11-20T00:00:00Z", "2019-11-21T00:00:00Z", "2019-11-22T00:00:00Z", "2019-11-25T00:00:00Z", "2019-11-26T00:00:00Z", "2019-11-27T00:00:00Z", "2019-11-29T00:00:00Z", "2019-12-02T00:00:00Z", "2019-12-03T00:00:00Z", "2019-12-04T00:00:00Z", "2019-12-05T00:00:00Z", "2019-12-06T00:00:00Z", "2019-12-09T00:00:00Z", "2019-12-10T00:00:00Z", "2019-12-11T00:00:00Z", "2019-12-12T00:00:00Z", "2019-12-13T00:00:00Z", "2019-12-16T00:00:00Z", "2019-12-17T00:00:00Z", "2019-12-18T00:00:00Z", "2019-12-19T00:00:00Z", "2019-12-20T00:00:00Z", "2019-12-23T00:00:00Z", "2019-12-24T00:00:0 ...

# %%
r.get_quotes(symbol)
# Out:
# [{'ask_price': '231.240000',
#   'ask_size': 300,
#   'bid_price': '231.050000',
#   'bid_size': 200,
#   'last_trade_price': '231.110000',
#   'last_extended_hours_trade_price': None,
#   'previous_close': '230.100000',
#   'adjusted_previous_close': '230.100000',
#   'previous_close_date': '2020-05-13',
#   'symbol': 'HD',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'updated_at': '2020-05-14T18:00:15Z',
#   'instrument': 'https://api.robinhood.com/instruments/599dd133-44d3-4c1e-b992-eb08b7ab7faa/'}]

# %%
r.get_pricebook_by_symbol(symbol)
# Out:
# {'asks': [{'side': 'ask',
#    'price': {'amount': '231.150000', 'currency_code': 'USD'},
#    'quantity': 110},
#   {'side': 'ask',
#    'price': {'amount': '231.180000', 'currency_code': 'USD'},
#    'quantity': 100},
#   {'side': 'ask',
#    'price': {'amount': '231.240000', 'currency_code': 'USD'},
#    'quantity': 100},
#   {'side': 'ask',
#    'price': {'amount': '231.320000', 'currency_code': 'USD'},
#    'quantity': 200},
#   {'side': 'ask',
#    'price': {'amount': '231.360000', 'currency_code': 'USD'},
#    'quantity': 19},
#   {'side': 'ask',
#    'price': {'amount': '231.370000', 'currency_code': 'USD'},
#    'quantity': 100},
#   {'side': 'ask',
#    'price': {'amount': '231.380000', 'currency_code': 'USD'},
#    'quantity': 100},
#   {'side': 'ask',
#    'price': {'amount': '231.390000', 'currency_code': 'USD'},
#    'quantity': 61},
#   {'side': 'ask',
#    'price': {'amount': '231.400000', 'currency_code': 'USD'},
#    'quantity': 100},
#   {'side': 'ask',
#    'price': {'amount': '231.420000', 'currency_code': 'USD'},
#    'quantity': 100},
#   {'side': 'ask',
#    'price': {'amount': '231.430000', 'currency_code': 'USD'},
#    'quantity': 113},
#   {'side': 'ask',
#    'price': {'amount': '231.460000', 'currency_code': 'USD'},
#    'quantity': 100},
#   {'side': 'ask',
#    'price': {'amount': '231.510000', 'currency_code': 'USD'},
#    'quantity': 19},
#   {'side': 'ask',
#    'price': {'amount': '231.620000', 'currency_code': 'USD'},
#    'quantity': 121},
#   {'side': 'ask',
#    'price': {'amount': '231.640000', 'currency_code': 'USD'},
#    'quantity': 19},
#   {'side': 'ask',
#    'price': {'amount': '231.690000', 'currency_code': 'USD'},
#    'quantity': 100},
#   {'side': 'ask',
#    'price': {'amount': '231.780000', 'currency_code': 'USD'},
#    'quantity': 19},
#   {'side': 'ask',
#    'price': {'amount': '231.840000', 'currency_code': 'USD'},
#    'quantity': 43},
#   {'side': 'ask',
#    'price': {'amount': '231.910000', 'currency_code': 'USD'},
#    'quantity': 19},
#   {'side': 'ask',
#    'price': {'amount': '232.000000', 'currency_code': 'USD'},
#    'quantity': 15},
#   {'side': 'ask',
#    'price': {'amount': '232.040000', 'currency_code': 'USD'},
#    'quantity': 1},
#   {'side': 'ask',
#    'price': {'amount': '232.160000', 'currency_code': 'USD'},
#    'quantity': 100},
#   {'side': 'ask',
#    'price': {'amount': '232.500000', 'currency_code': 'USD'},
#    'quantity': 40},
#   {'side': 'ask',
#    'price': {'amount': '233.730000', 'currency_code': 'USD'},
#    'quantity': 100},
#   {'side': 'ask',
#    'price': {'amount': '233.740000', 'currency_code': 'USD'},
#    'quantity': 100},
#   {'side': 'ask',
#    'price': {'amount': '234.000000', 'currency_code': 'USD'},
#    'quantity': 21},
#   {'side': 'ask',
#    'price': {'amount': '234.280000', 'currency_code': 'USD'},
#    'quantity': 300},
#   {'side': 'ask',
#    'price': {'amount': '235.000000', 'currency_code': 'USD'},
#    'quantity': 130},
#   {'side': 'ask',
#    'price': {'amount': '235.330000', 'currency_code': 'USD'},
#    'quantity': 5},
#   {'side': 'ask',
#    'price': {'amount': '235.550000', 'currency_code': 'USD'},
#    'quantity': 100},
#   {'side': 'ask',
#    'price': {'amount': '235.810000', 'currency_code': 'USD'},
#    'quantity': 100},
#   {'side': 'ask',
#    'price': {'amount': '236.000000', 'currency_code': 'USD'},
#    'quantity': 666},
#   {'side': 'ask',
#    'price': {'amount': '236.100000', 'currency_code': 'USD'},
#    'quantity': 1},
#   {'side': 'ask',
#    'price': {'amount': '236.510000', 'currency_code': 'USD'},
#    'quantity': 10},
#   {'side': 'ask',
#    'price': {'amount': '236.990000', 'currency_code': 'USD'},
#    'quantity': 100},
#   {'side': 'ask',
#    'price': {'amount': '237.260000', 'currency_code': 'USD'},
#    'quantity': 300},
#   {'side': 'ask',
#    'price': {'amount': '237.590000', 'currency_code': 'USD'},
#    'quantity': 100},
#   {'side': 'ask',
#    'price': {'amount': '238.000000', 'currency_code': 'USD'},
#    'quantity': 438},
#   {'side': 'ask',
#    'price': {'amount': '238.110000', 'currency_code': 'USD'},
#    'quantity': 402},
#   {'side': 'ask',
#    'price': {'amount': '238.480000', 'currency_code': 'USD'},
#    'quantity': 5},
#   {'side': 'ask',
#    'price': {'amount': '239.000000', 'currency_code': 'USD'},
#    'quantity': 11},
#   {'side': 'ask',
#    'price': {'amount': '239.250000', 'currency_code': 'USD'},
#    'quantity': 75},
#   {'side': 'ask',
#    'price': {'amount': '239.520000', 'currency_code': 'USD'},
#    'quantity': 2},
#   {'side': 'ask',
#    'price': {'amount': '240.000000', 'currency_code': 'USD'},
#    'quantity': 615},
#   {'side': 'ask',
#    'price': {'amount': '240.030000', 'currency_code': 'USD'},
#    'quantity': 300},
#   {'side': 'ask',
#    'price': {'amount': '240.250000', 'currency_code': 'USD'},
#    'quantity': 25},
#   {'side': 'ask',
#    'price': {'amount': '241.070000', 'currency_code': 'USD'},
#    'quantity': 100},
#   {'side': 'ask',
#    'price': {'amount': '241.100000', 'currency_code': 'USD'},
#    'quantity': 100},
#   {'side': 'ask',
#    'price': {'amount': '241.120000', 'currency_code': 'USD'},
#    'quantity': 200},
#   {'side': 'ask',
#    'price': {'amount': '241.710000', 'currency_code': 'USD'},
#    'quantity': 300},
#   {'side': 'ask',
#    'price': {'amount': '242.000000', 'currency_code': 'USD'},
#    'quantity': 215},
#   {'side': 'ask',
#    'price': {'amount': '242.250000', 'currency_code': 'USD'},
#    'quantity': 75},
#   {'side': 'ask',
#    'price': {'amount': '242.370000', 'currency_code': 'USD'},
#    'quantity': 100},
#   {'side': 'ask',
#    'price': {'amount': '242.440000', 'currency_code': 'USD'},
#    'quantity': 100},
#   {'side': 'ask',
#    'price': {'amount': '243.000000', 'currency_code': 'USD'},
#    'quantity': 9},
#   {'side': 'ask',
#    'price': {'amount': '243.200000', 'currency_code': 'USD'},
#    'quantity': 100},
#   {'side': 'ask',
#    'price': {'amount': '244.960000', 'currency_code': 'USD'},
#    'quantity': 200},
#   {'side': 'ask',
#    'price': {'amount': '245.000000', 'currency_code': 'USD'},
#    'quantity': 209},
#   {'side': 'ask',
#    'price': {'amount': '245.340000', 'currency_code': 'USD'},
#    'quantity': 100},
#   {'side': 'ask',
#    'price': {'amount': '245.370000', 'currency_code': 'USD'},
#    'quantity': 3400},
#   {'side': 'ask',
#    'price': {'amount': '245.650000', 'currency_code': 'USD'},
#    'quantity': 100},
#   {'side': 'ask',
#    'price': {'amount': '245.780000', 'currency_code': 'USD'},
#    'quantity': 100},
#   {'side': 'ask',
#    'price': {'amount': '246.840000', 'currency_code': 'USD'},
#    'quantity': 200},
#   {'side': 'ask',
#    'price': {'amount': '246.860000', 'currency_code': 'USD'},
#    'quantity': 100},
#   {'side': 'ask',
#    'price': {'amount': '247.000000', 'currency_code': 'USD'},
#    'quantity': 222},
#   {'side': 'ask',
#    'price': {'amount': '248.000000', 'currency_code': 'USD'},
#    'quantity': 57},
#   {'side': 'ask',
#    'price': {'amount': '249.000000', 'currency_code': 'USD'},
#    'quantity': 12},
#   {'side': 'ask',
#    'price': {'amount': '249.160000', 'currency_code': 'USD'},
#    'quantity': 100},
#   {'side': 'ask',
#    'price': {'amount': '250.000000', 'currency_code': 'USD'},
#    'quantity': 417},
#   {'side': 'ask',
#    'price': {'amount': '250.080000', 'currency_code': 'USD'},
#    'quantity': 7},
#   {'side': 'ask',
#    'price': {'amount': '250.260000', 'currency_code': 'USD'},
#    'quantity': 394},
#   {'side': 'ask',
#    'price': {'amount': '251.000000', 'currency_code': 'USD'},
#    'quantity': 17},
#   {'side': 'ask',
#    'price': {'amount': '253.200000', 'currency_code': 'USD'},
#    'quantity': 38},
#   {'side': 'ask',
#    'price': {'amount': '255.000000', 'currency_code': 'USD'},
#    'quantity': 1934},
#   {'side': 'ask',
#    'price': {'amount': '256.020000', 'currency_code': 'USD'},
#    'quantity': 227},
#   {'side': 'ask',
#    'price': {'amount': '258.930000', 'currency_code': 'USD'},
#    'quantity': 100},
#   {'side': 'ask',
#    'price': {'amount': '260.000000', 'currency_code': 'USD'},
#    'quantity': 20},
#   {'side': 'ask',
#    'price': {'amount': '263.000000', 'currency_code': 'USD'},
#    'quantity': 150},
#   {'side': 'ask',
#    'price': {'amount': '263.760000', 'currency_code': 'USD'},
#    'quantity': 4},
#   {'side': 'ask',
#    'price': {'amount': '271.000000', 'currency_code': 'USD'},
#    'quantity': 100},
#   {'side': 'ask',
#    'price': {'amount': '275.000000', 'currency_code': 'USD'},
#    'quantity': 1},
#   {'side': 'ask',
#    'price': {'amount': '280.000000', 'currency_code': 'USD'},
#    'quantity': 10},
#   {'side': 'ask',
#    'price': {'amount': '300.000000', 'currency_code': 'USD'},
#    'quantity': 119},
#   {'side': 'ask',
#    'price': {'amount': '345.000000', 'currency_code': 'USD'},
#    'quantity': 2},
#   {'side': 'ask',
#    'price': {'amount': '350.000000', 'currency_code': 'USD'},
#    'quantity': 100},
#   {'side': 'ask',
#    'price': {'amount': '405.000000', 'currency_code': 'USD'},
#    'quantity': 300},
#   {'side': 'ask',
#    'price': {'amount': '12233.490000', 'currency_code': 'USD'},
#    'quantity': 1}],
#  'bids': [{'side': 'bid',
#    'price': {'amount': '231.090000', 'currency_code': 'USD'},
#    'quantity': 300},
#   {'side': 'bid',
#    'price': {'amount': '231.010000', 'currency_code': 'USD'},
#    'quantity': 100},
#   {'side': 'bid',
#    'price': {'amount': '231.000000', 'currency_code': 'USD'},
#    'quantity': 361},
#   {'side': 'bid',
#    'price': {'amount': '230.920000', 'currency_code': 'USD'},
#    'quantity': 119},
#   {'side': 'bid',
#    'price': {'amount': '230.910000', 'currency_code': 'USD'},
#    'quantity': 200},
#   {'side': 'bid',
#    'price': {'amount': '230.860000', 'currency_code': 'USD'},
#    'quantity': 35},
#   {'side': 'bid',
#    'price': {'amount': '230.800000', 'currency_code': 'USD'},
#    'quantity': 123},
#   {'side': 'bid',
#    'price': {'amount': '230.790000', 'currency_code': 'USD'},
#    'quantity': 100},
#   {'side': 'bid',
#    'price': {'amount': '230.590000', 'currency_code': 'USD'},
#    'quantity': 100},
#   {'side': 'bid',
#    'price': {'amount': '230.560000', 'currency_code': 'USD'},
#    'quantity': 62},
#   {'side': 'bid',
#    'price': {'amount': '230.400000', 'currency_code': 'USD'},
#    'quantity': 50},
#   {'side': 'bid',
#    'price': {'amount': '230.160000', 'currency_code': 'USD'},
#    'quantity': 150},
#   {'side': 'bid',
#    'price': {'amount': '230.000000', 'currency_code': 'USD'},
#    'quantity': 41},
#   {'side': 'bid',
#    'price': {'amount': '229.970000', 'currency_code': 'USD'},
#    'quantity': 100},
#   {'side': 'bid',
#    'price': {'amount': '229.770000', 'currency_code': 'USD'},
#    'quantity': 1},
#   {'side': 'bid',
#    'price': {'amount': '228.860000', 'currency_code': 'USD'},
#    'quantity': 100},
#   {'side': 'bid',
#    'price': {'amount': '228.820000', 'currency_code': 'USD'},
#    'quantity': 3},
#   {'side': 'bid',
#    'price': {'amount': '228.500000', 'currency_code': 'USD'},
#    'quantity': 69},
#   {'side': 'bid',
#    'price': {'amount': '228.100000', 'currency_code': 'USD'},
#    'quantity': 100},
#   {'side': 'bid',
#    'price': {'amount': '228.000000', 'currency_code': 'USD'},
#    'quantity': 51},
#   {'side': 'bid',
#    'price': {'amount': '227.600000', 'currency_code': 'USD'},
#    'quantity': 3},
#   {'side': 'bid',
#    'price': {'amount': '227.510000', 'currency_code': 'USD'},
#    'quantity': 2300},
#   {'side': 'bid',
#    'price': {'amount': '227.250000', 'currency_code': 'USD'},
#    'quantity': 15},
#   {'side': 'bid',
#    'price': {'amount': '227.200000', 'currency_code': 'USD'},
#    'quantity': 50},
#   {'side': 'bid',
#    'price': {'amount': '227.060000', 'currency_code': 'USD'},
#    'quantity': 44},
#   {'side': 'bid',
#    'price': {'amount': '227.050000', 'currency_code': 'USD'},
#    'quantity': 50},
#   {'side': 'bid',
#    'price': {'amount': '227.000000', 'currency_code': 'USD'},
#    'quantity': 427},
#   {'side': 'bid',
#    'price': {'amount': '226.950000', 'currency_code': 'USD'},
#    'quantity': 10},
#   {'side': 'bid',
#    'price': {'amount': '226.750000', 'currency_code': 'USD'},
#    'quantity': 10},
#   {'side': 'bid',
#    'price': {'amount': '226.550000', 'currency_code': 'USD'},
#    'quantity': 100},
#   {'side': 'bid',
#    'price': {'amount': '226.500000', 'currency_code': 'USD'},
#    'quantity': 105},
#   {'side': 'bid',
#    'price': {'amount': '226.300000', 'currency_code': 'USD'},
#    'quantity': 200},
#   {'side': 'bid',
#    'price': {'amount': '226.200000', 'currency_code': 'USD'},
#    'quantity': 1},
#   {'side': 'bid',
#    'price': {'amount': '226.140000', 'currency_code': 'USD'},
#    'quantity': 300},
#   {'side': 'bid',
#    'price': {'amount': '226.100000', 'currency_code': 'USD'},
#    'quantity': 400},
#   {'side': 'bid',
#    'price': {'amount': '226.000000', 'currency_code': 'USD'},
#    'quantity': 5490},
#   {'side': 'bid',
#    'price': {'amount': '225.890000', 'currency_code': 'USD'},
#    'quantity': 100},
#   {'side': 'bid',
#    'price': {'amount': '225.000000', 'currency_code': 'USD'},
#    'quantity': 1627},
#   {'side': 'bid',
#    'price': {'amount': '224.430000', 'currency_code': 'USD'},
#    'quantity': 300},
#   {'side': 'bid',
#    'price': {'amount': '224.000000', 'currency_code': 'USD'},
#    'quantity': 300},
#   {'side': 'bid',
#    'price': {'amount': '222.310000', 'currency_code': 'USD'},
#    'quantity': 300},
#   {'side': 'bid',
#    'price': {'amount': '222.260000', 'currency_code': 'USD'},
#    'quantity': 300},
#   {'side': 'bid',
#    'price': {'amount': '222.220000', 'currency_code': 'USD'},
#    'quantity': 1},
#   {'side': 'bid',
#    'price': {'amount': '222.100000', 'currency_code': 'USD'},
#    'quantity': 100},
#   {'side': 'bid',
#    'price': {'amount': '222.000000', 'currency_code': 'USD'},
#    'quantity': 53},
#   {'side': 'bid',
#    'price': {'amount': '221.000000', 'currency_code': 'USD'},
#    'quantity': 100},
#   {'side': 'bid',
#    'price': {'amount': '220.900000', 'currency_code': 'USD'},
#    'quantity': 500},
#   {'side': 'bid',
#    'price': {'amount': '220.520000', 'currency_code': 'USD'},
#    'quantity': 300},
#   {'side': 'bid',
#    'price': {'amount': '220.440000', 'currency_code': 'USD'},
#    'quantity': 100},
#   {'side': 'bid',
#    'price': {'amount': '220.100000', 'currency_code': 'USD'},
#    'quantity': 95},
#   {'side': 'bid',
#    'price': {'amount': '220.000000', 'currency_code': 'USD'},
#    'quantity': 377},
#   {'side': 'bid',
#    'price': {'amount': '219.530000', 'currency_code': 'USD'},
#    'quantity': 200},
#   {'side': 'bid',
#    'price': {'amount': '218.060000', 'currency_code': 'USD'},
#    'quantity': 100},
#   {'side': 'bid',
#    'price': {'amount': '217.800000', 'currency_code': 'USD'},
#    'quantity': 100},
#   {'side': 'bid',
#    'price': {'amount': '217.390000', 'currency_code': 'USD'},
#    'quantity': 200},
#   {'side': 'bid',
#    'price': {'amount': '217.220000', 'currency_code': 'USD'},
#    'quantity': 1},
#   {'side': 'bid',
#    'price': {'amount': '216.780000', 'currency_code': 'USD'},
#    'quantity': 100},
#   {'side': 'bid',
#    'price': {'amount': '216.750000', 'currency_code': 'USD'},
#    'quantity': 300},
#   {'side': 'bid',
#    'price': {'amount': '216.350000', 'currency_code': 'USD'},
#    'quantity': 100},
#   {'side': 'bid',
#    'price': {'amount': '215.770000', 'currency_code': 'USD'},
#    'quantity': 3},
#   {'side': 'bid',
#    'price': {'amount': '215.050000', 'currency_code': 'USD'},
#    'quantity': 100},
#   {'side': 'bid',
#    'price': {'amount': '215.000000', 'currency_code': 'USD'},
#    'quantity': 59},
#   {'side': 'bid',
#    'price': {'amount': '214.770000', 'currency_code': 'USD'},
#    'quantity': 45},
#   {'side': 'bid',
#    'price': {'amount': '213.140000', 'currency_code': 'USD'},
#    'quantity': 100},
#   {'side': 'bid',
#    'price': {'amount': '212.440000', 'currency_code': 'USD'},
#    'quantity': 3500},
#   {'side': 'bid',
#    'price': {'amount': '212.000000', 'currency_code': 'USD'},
#    'quantity': 11},
#   {'side': 'bid',
#    'price': {'amount': '210.860000', 'currency_code': 'USD'},
#    'quantity': 45},
#   {'side': 'bid',
#    'price': {'amount': '210.720000', 'currency_code': 'USD'},
#    'quantity': 31},
#   {'side': 'bid',
#    'price': {'amount': '210.540000', 'currency_code': 'USD'},
#    'quantity': 2},
#   {'side': 'bid',
#    'price': {'amount': '210.220000', 'currency_code': 'USD'},
#    'quantity': 10},
#   {'side': 'bid',
#    'price': {'amount': '210.000000', 'currency_code': 'USD'},
#    'quantity': 178},
#   {'side': 'bid',
#    'price': {'amount': '209.790000', 'currency_code': 'USD'},
#    'quantity': 25},
#   {'side': 'bid',
#    'price': {'amount': '209.610000', 'currency_code': 'USD'},
#    'quantity': 25},
#   {'side': 'bid',
#    'price': {'amount': '208.000000', 'currency_code': 'USD'},
#    'quantity': 65},
#   {'side': 'bid',
#    'price': {'amount': '205.170000', 'currency_code': 'USD'},
#    'quantity': 25},
#   {'side': 'bid',
#    'price': {'amount': '205.000000', 'currency_code': 'USD'},
#    'quantity': 16},
#   {'side': 'bid',
#    'price': {'amount': '204.900000', 'currency_code': 'USD'},
#    'quantity': 3},
#   {'side': 'bid',
#    'price': {'amount': '204.120000', 'currency_code': 'USD'},
#    'quantity': 5},
#   {'side': 'bid',
#    'price': {'amount': '203.000000', 'currency_code': 'USD'},
#    'quantity': 100},
#   {'side': 'bid',
#    'price': {'amount': '202.230000', 'currency_code': 'USD'},
#    'quantity': 1},
#   {'side': 'bid',
#    'price': {'amount': '202.220000', 'currency_code': 'USD'},
#    'quantity': 5},
#   {'side': 'bid',
#    'price': {'amount': '201.010000', 'currency_code': 'USD'},
#    'quantity': 15},
#   {'side': 'bid',
#    'price': {'amount': '201.000000', 'currency_code': 'USD'},
#    'quantity': 17},
#   {'side': 'bid',
#    'price': {'amount': '200.000000', 'currency_code': 'USD'},
#    'quantity': 395},
#   {'side': 'bid',
#    'price': {'amount': '199.210000', 'currency_code': 'USD'},
#    'quantity': 1},
#   {'side': 'bid',
#    'price': {'amount': '199.010000', 'currency_code': 'USD'},
#    'quantity': 25},
#   {'side': 'bid',
#    'price': {'amount': '199.000000', 'currency_code': 'USD'},
#    'quantity': 200},
#   {'side': 'bid',
#    'price': {'amount': '198.000000', 'currency_code': 'USD'},
#    'quantity': 48},
#   {'side': 'bid',
#    'price': {'amount': '197.000000', 'currency_code': 'USD'},
#    'quantity': 497},
#   {'side': 'bid',
#    'price': {'amount': '196.250000', 'currency_code': 'USD'},
#    'quantity': 15},
#   {'side': 'bid',
#    'price': {'amount': '195.990000', 'currency_code': 'USD'},
#    'quantity': 100},
#   {'side': 'bid',
#    'price': {'amount': '195.550000', 'currency_code': 'USD'},
#    'quantity': 100},
#   {'side': 'bid',
#    'price': {'amount': '195.100000', 'currency_code': 'USD'},
#    'quantity': 10},
#   {'side': 'bid',
#    'price': {'amount': '195.000000', 'currency_code': 'USD'},
#    'quantity': 205},
#   {'side': 'bid',
#    'price': {'amount': '194.000000', 'currency_code': 'USD'},
#    'quantity': 270},
#   {'side': 'bid',
#    'price': {'amount': '193.230000', 'currency_code': 'USD'},
#    'quantity': 25},
#   {'side': 'bid',
#    'price': {'amount': '193.000000', 'currency_code': 'USD'},
#    'quantity': 100},
#   {'side': 'bid',
#    'price': {'amount': '192.000000', 'currency_code': 'USD'},
#    'quantity': 71},
#   {'side': 'bid',
#    'price': {'amount': '191.100000', 'currency_code': 'USD'},
#    'quantity': 10},
#   {'side': 'bid',
#    'price': {'amount': '190.010000', 'currency_code': 'USD'},
#    'quantity': 10},
#   {'side': 'bid',
#    'price': {'amount': '190.000000', 'currency_code': 'USD'},
#    'quantity': 71},
#   {'side': 'bid',
#    'price': {'amount': '189.000000', 'currency_code': 'USD'},
#    'quantity': 110},
#   {'side': 'bid',
#    'price': {'amount': '185.050000', 'currency_code': 'USD'},
#    'quantity': 10},
#   {'side': 'bid',
#    'price': {'amount': '185.000000', 'currency_code': 'USD'},
#    'quantity': 6},
#   {'side': 'bid',
#    'price': {'amount': '182.000000', 'currency_code': 'USD'},
#    'quantity': 40},
#   {'side': 'bid',
#    'price': {'amount': '181.000000', 'currency_code': 'USD'},
#    'quantity': 30},
#   {'side': 'bid',
#    'price': {'amount': '180.000000', 'currency_code': 'USD'},
#    'quantity': 1486},
#   {'side': 'bid',
#    'price': {'amount': '179.630000', 'currency_code': 'USD'},
#    'quantity': 50},
#   {'side': 'bid',
#    'price': {'amount': '179.120000', 'currency_code': 'USD'},
#    'quantity': 1},
#   {'side': 'bid',
#    'price': {'amount': '178.500000', 'currency_code': 'USD'},
#    'quantity': 50},
#   {'side': 'bid',
#    'price': {'amount': '178.000000', 'currency_code': 'USD'},
#    'quantity': 76},
#   {'side': 'bid',
#    'price': {'amount': '177.010000', 'currency_code': 'USD'},
#    'quantity': 17},
#   {'side': 'bid',
#    'price': {'amount': '176.000000', 'currency_code': 'USD'},
#    'quantity': 510},
#   {'side': 'bid',
#    'price': {'amount': '175.010000', 'currency_code': 'USD'},
#    'quantity': 25},
#   {'side': 'bid',
#    'price': {'amount': '175.000000', 'currency_code': 'USD'},
#    'quantity': 944},
#   {'side': 'bid',
#    'price': {'amount': '174.000000', 'currency_code': 'USD'},
#    'quantity': 1},
#   {'side': 'bid',
#    'price': {'amount': '173.230000', 'currency_code': 'USD'},
#    'quantity': 25},
#   {'side': 'bid',
#    'price': {'amount': '172.000000', 'currency_code': 'USD'},
#    'quantity': 3},
#   {'side': 'bid',
#    'price': {'amount': '171.000000', 'currency_code': 'USD'},
#    'quantity': 19},
#   {'side': 'bid',
#    'price': {'amount': '170.000000', 'currency_code': 'USD'},
#    'quantity': 958},
#   {'side': 'bid',
#    'price': {'amount': '169.000000', 'currency_code': 'USD'},
#    'quantity': 6},
#   {'side': 'bid',
#    'price': {'amount': '168.000000', 'currency_code': 'USD'},
#    'quantity': 145},
#   {'side': 'bid',
#    'price': {'amount': '167.230000', 'currency_code': 'USD'},
#    'quantity': 6},
#   {'side': 'bid',
#    'price': {'amount': '167.000000', 'currency_code': 'USD'},
#    'quantity': 2},
#   {'side': 'bid',
#    'price': {'amount': '166.700000', 'currency_code': 'USD'},
#    'quantity': 9},
#   {'side': 'bid',
#    'price': {'amount': '166.000000', 'currency_code': 'USD'},
#    'quantity': 1183},
#   {'side': 'bid',
#    'price': {'amount': '165.110000', 'currency_code': 'USD'},
#    'quantity': 10},
#   {'side': 'bid',
#    'price': {'amount': '165.000000', 'currency_code': 'USD'},
#    'quantity': 158},
#   {'side': 'bid',
#    'price': {'amount': '164.000000', 'currency_code': 'USD'},
#    'quantity': 16},
#   {'side': 'bid',
#    'price': {'amount': '163.980000', 'currency_code': 'USD'},
#    'quantity': 10},
#   {'side': 'bid',
#    'price': {'amount': '163.630000', 'currency_code': 'USD'},
#    'quantity': 10},
#   {'side': 'bid',
#    'price': {'amount': '162.390000', 'currency_code': 'USD'},
#    'quantity': 10},
#   {'side': 'bid',
#    'price': {'amount': '162.000000', 'currency_code': 'USD'},
#    'quantity': 5},
#   {'side': 'bid',
#    'price': {'amount': '161.500000', 'currency_code': 'USD'},
#    'quantity': 10},
#   {'side': 'bid',
#    'price': {'amount': '160.500000', 'currency_code': 'USD'},
#    'quantity': 10},
#   {'side': 'bid',
#    'price': {'amount': '160.000000', 'currency_code': 'USD'},
#    'quantity': 6299},
#   {'side': 'bid',
#    'price': {'amount': '155.800000', 'currency_code': 'USD'},
#    'quantity': 10},
#   {'side': 'bid',
#    'price': {'amount': '155.070000', 'currency_code': 'USD'},
#    'quantity': 15},
#   {'side': 'bid',
#    'price': {'amount': '155.000000', 'currency_code': 'USD'},
#    'quantity': 254},
#   {'side': 'bid',
#    'price': {'amount': '152.270000', 'currency_code': 'USD'},
#    'quantity': 13},
#   {'side': 'bid',
#    'price': {'amount': '152.000000', 'currency_code': 'USD'},
#    'quantity': 20},
#   {'side': 'bid',
#    'price': {'amount': '151.250000', 'currency_code': 'USD'},
#    'quantity': 75},
#   {'side': 'bid',
#    'price': {'amount': '151.000000', 'currency_code': 'USD'},
#    'quantity': 103},
#   {'side': 'bid',
#    'price': {'amount': '150.890000', 'currency_code': 'USD'},
#    'quantity': 9},
#   {'side': 'bid',
#    'price': {'amount': '150.600000', 'currency_code': 'USD'},
#    'quantity': 40},
#   {'side': 'bid',
#    'price': {'amount': '150.110000', 'currency_code': 'USD'},
#    'quantity': 3},
#   {'side': 'bid',
#    'price': {'amount': '150.050000', 'currency_code': 'USD'},
#    'quantity': 50},
#   {'side': 'bid',
#    'price': {'amount': '150.000000', 'currency_code': 'USD'},
#    'quantity': 607},
#   {'side': 'bid',
#    'price': {'amount': '149.490000', 'currency_code': 'USD'},
#    'quantity': 100},
#   {'side': 'bid',
#    'price': {'amount': '149.120000', 'currency_code': 'USD'},
#    'quantity': 67},
#   {'side': 'bid',
#    'price': {'amount': '148.290000', 'currency_code': 'USD'},
#    'quantity': 10},
#   {'side': 'bid',
#    'price': {'amount': '148.000000', 'currency_code': 'USD'},
#    'quantity': 5},
#   {'side': 'bid',
#    'price': {'amount': '147.500000', 'currency_code': 'USD'},
#    'quantity': 1},
#   {'side': 'bid',
#    'price': {'amount': '147.120000', 'currency_code': 'USD'},
#    'quantity': 10},
#   {'side': 'bid',
#    'price': {'amount': '147.000000', 'currency_code': 'USD'},
#    'quantity': 30},
#   {'side': 'bid',
#    'price': {'amount': '146.000000', 'currency_code': 'USD'},
#    'quantity': 10},
#   {'side': 'bid',
#    'price': {'amount': '145.000000', 'currency_code': 'USD'},
#    'quantity': 181},
#   {'side': 'bid',
#    'price': {'amount': '143.330000', 'currency_code': 'USD'},
#    'quantity': 3},
#   {'side': 'bid',
#    'price': {'amount': '143.300000', 'currency_code': 'USD'},
#    'quantity': 1},
#   {'side': 'bid',
#    'price': {'amount': '143.290000', 'currency_code': 'USD'},
#    'quantity': 70},
#   {'side': 'bid',
#    'price': {'amount': '143.200000', 'currency_code': 'USD'},
#    'quantity': 13},
#   {'side': 'bid',
#    'price': {'amount': '142.500000', 'currency_code': 'USD'},
#    'quantity': 50},
#   {'side': 'bid',
#    'price': {'amount': '142.000000', 'currency_code': 'USD'},
#    'quantity': 250},
#   {'side': 'bid',
#    'price': {'amount': '141.530000', 'currency_code': 'USD'},
#    'quantity': 2},
#   {'side': 'bid',
#    'price': {'amount': '141.000000', 'currency_code': 'USD'},
#    'quantity': 194},
#   {'side': 'bid',
#    'price': {'amount': '140.750000', 'currency_code': 'USD'},
#    'quantity': 35},
#   {'side': 'bid',
#    'price': {'amount': '140.730000', 'currency_code': 'USD'},
#    'quantity': 29},
#   {'side': 'bid',
#    'price': {'amount': '140.020000', 'currency_code': 'USD'},
#    'quantity': 13},
#   {'side': 'bid',
#    'price': {'amount': '140.000000', 'currency_code': 'USD'},
#    'quantity': 691},
#   {'side': 'bid',
#    'price': {'amount': '139.000000', 'currency_code': 'USD'},
#    'quantity': 25},
#   {'side': 'bid',
#    'price': {'amount': '135.050000', 'currency_code': 'USD'},
#    'quantity': 35},
#   {'side': 'bid',
#    'price': {'amount': '135.000000', 'currency_code': 'USD'},
#    'quantity': 51},
#   {'side': 'bid',
#    'price': {'amount': '134.680000', 'currency_code': 'USD'},
#    'quantity': 20},
#   {'side': 'bid',
#    'price': {'amount': '130.010000', 'currency_code': 'USD'},
#    'quantity': 87},
#   {'side': 'bid',
#    'price': {'amount': '130.000000', 'currency_code': 'USD'},
#    'quantity': 290},
#   {'side': 'bid',
#    'price': {'amount': '128.000000', 'currency_code': 'USD'},
#    'quantity': 2},
#   {'side': 'bid',
#    'price': {'amount': '127.000000', 'currency_code': 'USD'},
#    'quantity': 40},
#   {'side': 'bid',
#    'price': {'amount': '126.670000', 'currency_code': 'USD'},
#    'quantity': 4},
#   {'side': 'bid',
#    'price': {'amount': '125.100000', 'currency_code': 'USD'},
#    'quantity': 1},
#   {'side': 'bid',
#    'price': {'amount': '125.000000', 'currency_code': 'USD'},
#    'quantity': 31},
#   {'side': 'bid',
#    'price': {'amount': '120.000000', 'currency_code': 'USD'},
#    'quantity': 57},
#   {'side': 'bid',
#    'price': {'amount': '115.000000', 'currency_code': 'USD'},
#    'quantity': 10},
#   {'side': 'bid',
#    'price': {'amount': '111.000000', 'currency_code': 'USD'},
#    'quantity': 30},
#   {'side': 'bid',
#    'price': {'amount': '110.000000', 'currency_code': 'USD'},
#    'quantity': 1},
#   {'side': 'bid',
#    'price': {'amount': '103.000000', 'currency_code': 'USD'},
#    'quantity': 100},
#   {'side': 'bid',
#    'price': {'amount': '100.000000', 'currency_code': 'USD'},
#    'quantity': 244},
#   {'side': 'bid',
#    'price': {'amount': '77.340000', 'currency_code': 'USD'},
#    'quantity': 50},
#   {'side': 'bid',
#    'price': {'amount': '15.000000', 'currency_code': 'USD'},
#    'quantity': 300},
#   {'side': 'bid',
#    'price': {'amount': '1.000000', 'currency_code': 'USD'},
#    'quantity': 2},
#   {'side': 'bid',
#    'price': {'amount': '0.050000', 'currency_code': 'USD'},
#    'quantity': 1}],
#  'instrument_id': '599dd133-44d3-4c1e-b992-eb08b7ab7faa',
#  'updated_at': '2020-05-14T13:58:42.037924621-04:00'}

# %%
r.find_instrument_data(symbol)
# Out:
# Found 5 results
# [{'id': 'ecc706d4-d40f-413d-8a3d-55169be36121',
#   'url': 'https://api.robinhood.com/instruments/ecc706d4-d40f-413d-8a3d-55169be36121/',
#   'quote': 'https://api.robinhood.com/quotes/SPG/',
#   'fundamentals': 'https://api.robinhood.com/fundamentals/SPG/',
#   'splits': 'https://api.robinhood.com/instruments/ecc706d4-d40f-413d-8a3d-55169be36121/splits/',
#   'state': 'active',
#   'market': 'https://api.robinhood.com/markets/XNYS/',
#   'simple_name': 'Simon Property Group',
#   'name': 'Simon Property Group, Inc.',
#   'tradeable': True,
#   'tradability': 'tradable',
#   'symbol': 'SPG',
#   'bloomberg_unique': 'EQ0012655100001000',
#   'margin_initial_ratio': '0.5000',
#   'maintenance_ratio': '0.2500',
#   'country': 'US',
#   'day_trade_ratio': '0.2500',
#   'list_date': '1993-12-14',
#   'min_tick_size': None,
#   'type': 'reit',
#   'tradable_chain_id': '5d0932e3-ad84-4002-80da-9889c330ff4a',
#   'rhs_tradability': 'tradable',
#   'fractional_tradability': 'tradable',
#   'default_collar_fraction': '0.05'},
#  {'id': 'e425f3ca-8aa2-47c5-ab92-5e7ec59d1e83',
#   'url': 'https://api.robinhood.com/instruments/e425f3ca-8aa2-47c5-ab92-5e7ec59d1e83/',
#   'quote': 'https://api.robinhood.com/quotes/SPGI/',
#   'fundamentals': 'https://api.robinhood.com/fundamentals/SPGI/',
#   'splits': 'https://api.robinhood.com/instruments/e425f3ca-8aa2-47c5-ab92-5e7ec59d1e83/splits/',
#   'state': 'active',
#   'market': 'https://api.robinhood.com/markets/XNYS/',
#   'simple_name': 'S&P Global',
#   'name': 'S&P Global Inc.',
#   'tradeable': True,
#   'tradability': 'tradable',
#   'symbol': 'SPGI',
#   'bloomberg_unique': 'EQ0010096200001000',
#   'margin_initial_ratio': '0.5000',
#   'maintenance_ratio': '0.2500',
#   'country': 'US',
#   'day_trade_ratio': '0.2500',
#   'list_date': '1990-01-02',
#   'min_tick_size': None,
#   'type': 'stock',
#   'tradable_chain_id': '05bf8f8b-d31e-4dce-8f77-023488ce2f41',
#   'rhs_tradability': 'tradable',
#   'fractional_tradability': 'tradable',
#   'default_collar_fraction': '0.05'},
#  {'id': 'cb148703-9c0c-439d-8fe4-f46d6a27a7a6',
#   'url': 'https://api.robinhood.com/instruments/cb148703-9c0c-439d-8fe4-f46d6a27a7a6/',
#   'quote': 'https://api.robinhood.com/quotes/SPG-J/',
#   'fundamentals': 'https://api.robinhood.com/fundamentals/SPG-J/',
#   'splits': 'https://api.robinhood.com/instruments/cb148703-9c0c-439d-8fe4-f46d6a27a7a6/splits/',
#   'state': 'active',
#   'market': 'https://api.robinhood.com/markets/XNYS/',
#   'simple_name': 'Simon Property Group (Preferred)',
#   'name': 'Simon Property Group, Inc. 8 3/8% Series J',
#   'tradeable': False,
#   'tradability': 'untradable',
#   'symbol': 'SPG-J',
#   'bloomberg_unique': 'PFEP0133298',
#   'margin_initial_ratio': '0.8000',
#   'maintenance_ratio': '0.7500',
#   'country': 'US',
#   'day_trade_ratio': '0.2500',
#   'list_date': '2004-12-16',
#   'min_tick_size': None,
#   'type': 'pfd',
#   'tradable_chain_id': None,
#   'rhs_tradability': 'untradable',
#   'fractional_tradability': 'untradable',
#   'default_collar_fraction': '0.05'},
#  {'id': 'f26f0f54-f783-4193-8802-7fb551c41e4c',
#   'url': 'https://api.robinhood.com/instruments/f26f0f54-f783-4193-8802-7fb551c41e4c/',
#   'quote': 'https://api.robinhood.com/quotes/SPGM/',
#   'fundamentals': 'https://api.robinhood.com/fundamentals/SPGM/',
#   'splits': 'https://api.robinhood.com/instruments/f26f0f54-f783-4193-8802-7fb551c41e4c/splits/',
#   'state': 'active',
#   'market': 'https://api.robinhood.com/markets/ARCX/',
#   'simple_name': None,
#   'name': 'SPDR Portfolio MSCI Global Stock Market ETF',
#   'tradeable': True,
#   'tradability': 'tradable',
#   'symbol': 'SPGM',
#   'bloomberg_unique': 'EQ0000000022371099',
#   'margin_initial_ratio': '0.6800',
#   'maintenance_ratio': '0.6000',
#   'country': 'US',
#   'day_trade_ratio': '0.2500',
#   'list_date': '2012-02-28',
#   'min_tick_size': None,
#   'type': 'etp',
#   'tradable_chain_id': None,
#   'rhs_tradability': 'tradable',
#   'fractional_tradability': 'tradable',
#   'default_collar_fraction': '0.05'},
#  {'id': 'f1583030-b806-462b-a742-85709e82f8c2',
#   'url': 'https://api.robinhood.com/instruments/f1583030-b806-462b-a742-85709e82f8c2/',
#   'quote': 'https://api.robinhood.com/quotes/SPGP/',
#   'fundamentals': 'https://api.robinhood.com/fundamentals/SPGP/',
#   'splits': 'https://api.robinhood.com/instruments/f1583030-b806-462b-a742-85709e82f8c2/splits/',
#   'state': 'active',
#   'market': 'https://api.robinhood.com/markets/ARCX/',
#   'simple_name': None,
#   'name': 'Invesco S&P 500 GARP ETF',
#   'tradeable': True,
#   'tradability': 'tradable',
#   'symbol': 'SPGP',
#   'bloomberg_unique': 'EQ0000000017829950',
#   'margin_initial_ratio': '1.0000',
#   'maintenance_ratio': '1.0000',
#   'country': 'US',
#   'day_trade_ratio': '0.2500',
#   'list_date': '2011-06-16',
#   'min_tick_size': None,
#   'type': 'etp',
#   'tradable_chain_id': None,
#   'rhs_tradability': 'tradable',
#   'fractional_tradability': 'tradable',
#   'default_collar_fraction': '0.05'}]

# %%
r.get_fundamentals(symbol)
# Out:
# [{'open': '50.020000',
#   'high': '53.490000',
#   'low': '47.250000',
#   'volume': '8095583.000000',
#   'average_volume_2_weeks': '10331656.300000',
#   'average_volume': '10331656.300000',
#   'high_52_weeks': '177.930000',
#   'dividend_yield': '15.309900',
#   'float': '302628380.600000',
#   'low_52_weeks': '42.250000',
#   'market_cap': '15501147840.000000',
#   'pb_ratio': '7.795160',
#   'pe_ratio': '8.502610',
#   'shares_outstanding': '305622000.000000',
#   'description': 'Simon Property Group, Inc. operates as a self-administered and self-managed real estate investment trust. It owns, develops and manages retail real estate properties which primarily consist of regional malls, premium outlets and mills. Simon Property Group specializes in the ownership, development, management, leasing, acquisition and expansion of income-producing retail real estate assets. The company was founded by Fred Simon, Herbert Simon and Melvin Simon in December 1993 and is headquartered in Indianapolis, IN.',
#   'instrument': 'https://api.robinhood.com/instruments/ecc706d4-d40f-413d-8a3d-55169be36121/',
#   'ceo': 'David E. Simon',
#   'headquarters_city': 'Indianapolis',
#   'headquarters_state': 'Indiana',
#   'sector': 'Finance',
#   'industry': 'Real Estate Investment Trusts',
#   'num_employees': 4500,
#   'year_founded': 1993}]
