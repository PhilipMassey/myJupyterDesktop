# %%
import pandas as pd
import pymongo
from pymongo import MongoClient
client = MongoClient()
print(client)
db = client['robinhood_data']
print(db)
print(db.list_collections())
print(db.list_collection_names())
#db.drop_collection('ERIC')

import robin_stocks as r 
login = r.login('philip0massey','Rie1Hnd2*#')
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'robinhood_data')
# <pymongo.command_cursor.CommandCursor object at 0x1132fa8d0>
# ['QQQ', 'SPY']

# %%
symbol_list = ['SPY','QQQ','TECL']
expirationDate='2020-02-21'

# %%
nSymbols = len(symbol_list)
i = 0
while i < nSymbols:
    symbol = symbol_list[i]
    i += 1
    quotes = r.get_quotes(symbol)
    last_trade_price = quotes[0]['last_trade_price']
    updated_at = quotes[0]['updated_at']

    optionData = r.find_options_for_list_of_stocks_by_expiration_date([symbol], expirationDate=expirationDate,optionType='both') 
    l =  list(filter(lambda x:x['delta'] is not None and float(x['delta'])>0.01,optionData))
    df = pd.DataFrame(l)
    df['_id'] = df['expiration_date']+'_'+df['strike_price']+'_'+df['updated_at']
    df['last_trade_price'] = last_trade_price
    df['updated_at'] = updated_at
    data_dict = df.to_dict(orient='records')  # Here's our added param..
    try:
        db[symbol].insert_many(data_dict)
    except pymongo.errors.DuplicateKeyError as e:
        print(e.error_document)
    except Exception as ee:
        print(ee)


    symbol_records = len(list(db[symbol].find({'chain_symbol':symbol})))
    print(symbol,symbol_records,sep='\t')

print("Completed")
# Out:
# Found Additional pages.
# Loading page 2 ...
# Loading page 3 ...
# Loading page 4 ...
# Loading page 5 ...
# Loading page 6 ...
# Loading page 7 ...
# Loading page 8 ...
# Loading page 9 ...
# Loading page 10 ...
# Loading page 11 ...
# Loading page 12 ...
# Loading page 13 ...
# TECL	18
# Completed

# %%
symbol = 'TECL'
symbol_records = len(list(db[symbol].find({'chain_symbol':symbol})))
print(symbol,symbol_records,sep='\t')
# Out:
# TECL	0

# %%
list(db[symbol].find({'chain_symbol':symbol}))
#list(db['ERIC.A'].find({'chain_symbol':symbol}))
# Out:
# [{'_id': '2020-02-21_337.5000_2020-01-18T10:54:00.817123Z',
#   'adjusted_mark_price': '1.860000',
#   'ask_price': '1.870000',
#   'ask_size': 44,
#   'bid_price': '1.840000',
#   'bid_size': 204,
#   'break_even_price': '339.360000',
#   'chain_id': 'c277b118-58d9-4060-8dc5-a3b5898955cb',
#   'chain_symbol': 'SPY',
#   'chance_of_profit_long': '0.360937',
#   'chance_of_profit_short': '0.639063',
#   'created_at': '2020-01-18T10:54:00.817115Z',
#   'delta': '0.542176',
#   'expiration_date': '2020-02-21',
#   'gamma': '0.096096',
#   'high_fill_rate_buy_price': '1.870000',
#   'high_fill_rate_sell_price': '1.840000',
#   'high_price': '2.000000',
#   'id': 'c1462b4c-4719-4826-a4eb-d91dc3cfac2a',
#   'implied_volatility': '0.088261',
#   'instrument': 'https://api.robinhood.com/options/instruments/c1462b4c-4719-4826-a4eb-d91dc3cfac2a/',
#   'issue_date': '2005-01-06',
#   'last_trade_price': '337.600000',
#   'last_trade_size': 8,
#   'low_fill_rate_buy_price': '1.850000',
#   'low_fill_rate_sell_price': '1.860000',
#   'low_price': '1.350000',
#   'mark_price': '1.855000',
#   'min_ticks': {'above_tick': '0.01',
#    'below_tick': '0.01',
#    'cutoff_price': '0.00'},
#   'open_interest': 11086,
#   'previous_close_date': '2020-02-13',
#   'previous_close_price': '1.900000',
#   'rho': '0.034762',
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '337.5000',
#   'theta': '-0.129395',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-02-15T01:00:00Z',
#   'url': 'https://api.robinhood.com/options/instruments/c1462b4c-4719-4826-a4eb-d91dc3cfac2a/',
#   'vega': '0.185555',
#   'volume': 9937},
#  {'_id': '2020-02-21_332.5000_2020-01-18T10:54:00.816224Z',
#   'adjusted_mark_price': '5.780000',
#   'ask_price': '5.850000',
#   'ask_size': 61,
#   'bid_price': '5.700000',
#   'bid_size': 40,
#   'break_even_price': '338.280000',
#   'chain_id': 'c277b118-58d9-4060-8dc5-a3b5898955cb',
#   'chain_symbol': 'SPY',
#   'chance_of_profit_long': '0.468304',
#   'chance_of_profit_short': '0.531696',
#   'created_at': '2020-01-18T10:54:00.816215Z',
#   'delta': '0.858831',
#   'expiration_date': '2020-02-21',
#   'gamma': '0.043819',
#   'high_fill_rate_buy_price': '5.830000',
#   'high_fill_rate_sell_price': '5.710000',
#   'high_price': '5.840000',
#   'id': 'dbd39c6f-9b84-48bb-9c37-352515a1d86c',
#   'implied_volatility': '0.109213',
#   'instrument': 'https://api.robinhood.com/options/instruments/dbd39c6f-9b84-48bb-9c37-352515a1d86c/',
#   'issue_date': '2005-01-06',
#   'last_trade_price': '337.600000',
#   'last_trade_size': 1,
#   'low_fill_rate_buy_price': '5.760000',
#   'low_fill_rate_sell_price': '5.780000',
#   'low_price': '4.980000',
#   'mark_price': '5.775000',
#   'min_ticks': {'above_tick': '0.01',
#    'below_tick': '0.01',
#    'cutoff_price': '0.00'},
#   'open_interest': 10707,
#   'previous_close_date': '2020-02-13',
#   'previous_close_price': '5.580000',
#   'rho': '0.054521',
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '332.5000',
#   'theta': '-0.101145',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-02-15T01:00:00Z',
#   'url': 'https://api.robinhood.com/options/instruments/dbd39c6f-9b84-48bb-9c37-352515a1d86c/',
#   'vega': '0.104696',
#   'volume': 561},
#  {'_id': '2020-02-21_347.5000_2020-01-18T10:54:00.815195Z',
#   'adjusted_mark_price': '0.020000',
#   'ask_price': '0.020000',
#   'ask_size': 6594,
#   'bid_price': '0.010000',
#   'bid_size': 7490,
#   'break_even_price': '347.520000',
#   'chain_id': 'c277b118-58d9-4060-8dc5-a3b5898955cb',
#   'chain_symbol': 'SPY',
#   'chance_of_profit_long': '0.012882',
#   'chance_of_profit_short': '0.987118',
#   'created_at': '2020-01-18T10:54:00.815187Z',
#   'delta': '0.013464',
#   'expiration_date': '2020-02-21',
#   'gamma': '0.008102',
#   'high_fill_rate_buy_price': '0.020000',
#   'high_fill_rate_sell_price': '0.010000',
#   'high_price': '0.020000',
#   'id': '739d1762-7575-4d58-bbe1-9258277e4449',
#   'implied_volatility': '0.091054',
#   'instrument': 'https://api.robinhood.com/options/instruments/739d1762-7575-4d58-bbe1-9258277e4449/',
#   'issue_date': '2005-01-06',
#   'last_trade_price': '337.600000',
#   'last_trade_size': 34,
#   'low_fill_rate_buy_price': '0.010000',
#   'low_fill_rate_sell_price': '0.020000',
#   'low_price': '0.010000',
#   'mark_price': '0.015000',
#   'min_ticks': {'above_tick': '0.01',
#    'below_tick': '0.01',
#    'cutoff_price': '0.00'},
#   'open_interest': 2049,
#   'previous_close_date': '2020-02-13',
#   'previous_close_price': '0.040000',
#   'rho': '0.000868',
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '347.5000',
#   'theta': '-0.010807',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-02-15T01:00:00Z',
#   'url': 'https://api.robinhood.com/options/instruments/739d1762-7575-4d58-bbe1-9258277e4449/',
#   'vega': '0.016139',
#   'volume': 87},
#  {'_id': '2020-02-21_342.5000_2020-01-18T10:54:00.815142Z',
#   'adjusted_mark_price': '0.180000',
#   'ask_price': '0.190000',
#   'ask_size': 3217,
#   'bid_price': '0.170000',
#   'bid_size': 2365,
#   'break_even_price': '342.680000',
#   'chain_id': 'c277b118-58d9-4060-8dc5-a3b5898955cb',
#   'chain_symbol': 'SPY',
#   'chance_of_profit_long': '0.094250',
#   'chance_of_profit_short': '0.905750',
#   'created_at': '2020-01-18T10:54:00.815134Z',
#   'delta': '0.104699',
#   'expiration_date': '2020-02-21',
#   'gamma': '0.050218',
#   'high_fill_rate_buy_price': '0.190000',
#   'high_fill_rate_sell_price': '0.170000',
#   'high_price': '0.270000',
#   'id': '1570c63f-93dd-4655-8871-9f213a872fc1',
#   'implied_volatility': '0.077254',
#   'instrument': 'https://api.robinhood.com/options/instruments/1570c63f-93dd-4655-8871-9f213a872fc1/',
#   'issue_date': '2005-01-06',
#   'last_trade_price': '337.600000',
#   'last_trade_size': 30,
#   'low_fill_rate_buy_price': '0.170000',
#   'low_fill_rate_sell_price': '0.180000',
#   'low_price': '0.150000',
#   'mark_price': '0.180000',
#   'min_ticks': {'above_tick': '0.01',
#    'below_tick': '0.01',
#    'cutoff_price': '0.00'},
#   'open_interest': 2875,
#   'previous_close_date': '2020-02-13',
#   'previous_close_price': '0.280000',
#   'rho': '0.006747',
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '342.5000',
#   'theta': '-0.049244',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-02-15T01:00:00Z',
#   'url': 'https://api.robinhood.com/options/instruments/1570c63f-93dd-4655-8871-9f213a872fc1/',
#   'vega': '0.084874',
#   'volume': 1644},
#  {'_id': '2020-02-21_349.0000_2019-11-12T01:04:20.115099Z',
#   'adjusted_mark_price': '0.020000',
#   'ask_price': '0.020000',
#   'ask_size': 8822,
#   'bid_price': '0.010000',
#   'bid_size': 2957,
#   'break_even_price': '349.020000',
#   'chain_id': 'c277b118-58d9-4060-8dc5-a3b5898955cb',
#   'chain_symbol': 'SPY',
#   'chance_of_profit_long': '0.011491',
#   'chance_of_profit_short': '0.988509',
#   'created_at': '2019-11-12T01:04:20.115091Z',
#   'delta': '0.012053',
#   'expiration_date': '2020-02-21',
#   'gamma': '0.006505',
#   'high_fill_rate_buy_price': '0.020000',
#   'high_fill_rate_sell_price': '0.010000',
#   'high_price': '0.020000',
#   'id': '934719ea-6822-4d28-88fb-6c74b860c104',
#   'implied_volatility': '0.103042',
#   'instrument': 'https://api.robinhood.com/options/instruments/934719ea-6822-4d28-88fb-6c74b860c104/',
#   'issue_date': '2005-01-06',
#   'last_trade_price': '337.600000',
#   'last_trade_size': 67,
#   'low_fill_rate_buy_price': '0.010000',
#   'low_fill_rate_sell_price': '0.020000',
#   'low_price': '0.010000',
#   'mark_price': '0.015000',
#   'min_ticks': {'above_tick': '0.01',
#    'below_tick': '0.01',
#    'cutoff_price': '0.00'},
#   'open_interest': 10642,
#   'previous_close_date': '2020-02-13',
#   'previous_close_price': '0.030000',
#   'rho': '0.000777',
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '349.0000',
#   'theta': '-0.011071',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-02-15T01:00:00Z',
#   'url': 'https://api.robinhood.com/options/instruments/934719ea-6822-4d28-88fb-6c74b860c104/',
#   'vega': '0.014665',
#   'volume': 381},
#  {'_id': '2020-02-21_348.0000_2019-11-12T01:04:20.114998Z',
#   'adjusted_mark_price': '0.020000',
#   'ask_price': '0.020000',
#   'ask_size': 10148,
#   'bid_price': '0.010000',
#   'bid_size': 8595,
#   'break_even_price': '348.020000',
#   'chain_id': 'c277b118-58d9-4060-8dc5-a3b5898955cb',
#   'chain_symbol': 'SPY',
#   'chance_of_profit_long': '0.012379',
#   'chance_of_profit_short': '0.987621',
#   'created_at': '2019-11-12T01:04:20.114991Z',
#   'delta': '0.012953',
#   'expiration_date': '2020-02-21',
#   'gamma': '0.007504',
#   'high_fill_rate_buy_price': '0.020000',
#   'high_fill_rate_sell_price': '0.010000',
#   'high_price': '0.030000',
#   'id': '141912ea-41ad-4617-bb86-46b569b4cd27',
#   'implied_volatility': '0.095077',
#   'instrument': 'https://api.robinhood.com/options/instruments/141912ea-41ad-4617-bb86-46b569b4cd27/',
#   'issue_date': '2005-01-06',
#   'last_trade_price': '337.600000',
#   'last_trade_size': 51,
#   'low_fill_rate_buy_price': '0.010000',
#   'low_fill_rate_sell_price': '0.020000',
#   'low_price': '0.010000',
#   'mark_price': '0.015000',
#   'min_ticks': {'above_tick': '0.01',
#    'below_tick': '0.01',
#    'cutoff_price': '0.00'},
#   'open_interest': 2377,
#   'previous_close_date': '2020-02-13',
#   'previous_close_price': '0.030000',
#   'rho': '0.000835',
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '348.0000',
#   'theta': '-0.010898',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-02-15T01:00:00Z',
#   'url': 'https://api.robinhood.com/options/instruments/141912ea-41ad-4617-bb86-46b569b4cd27/',
#   'vega': '0.015609',
#   'volume': 684},
#  {'_id': '2020-02-21_347.0000_2019-11-12T01:04:20.114886Z',
#   'adjusted_mark_price': '0.020000',
#   'ask_price': '0.020000',
#   'ask_size': 5000,
#   'bid_price': '0.010000',
#   'bid_size': 8621,
#   'break_even_price': '347.020000',
#   'chain_id': 'c277b118-58d9-4060-8dc5-a3b5898955cb',
#   'chain_symbol': 'SPY',
#   'chance_of_profit_long': '0.013432',
#   'chance_of_profit_short': '0.986568',
#   'created_at': '2019-11-12T01:04:20.114879Z',
#   'delta': '0.014023',
#   'expiration_date': '2020-02-21',
#   'gamma': '0.008782',
#   'high_fill_rate_buy_price': '0.020000',
#   'high_fill_rate_sell_price': '0.010000',
#   'high_price': '0.040000',
#   'id': '4d327d76-b3da-4b8d-988e-a64c88119d5c',
#   'implied_volatility': '0.087004',
#   'instrument': 'https://api.robinhood.com/options/instruments/4d327d76-b3da-4b8d-988e-a64c88119d5c/',
#   'issue_date': '2005-01-06',
#   'last_trade_price': '337.600000',
#   'last_trade_size': 51,
#   'low_fill_rate_buy_price': '0.010000',
#   'low_fill_rate_sell_price': '0.020000',
#   'low_price': '0.020000',
#   'mark_price': '0.015000',
#   'min_ticks': {'above_tick': '0.01',
#    'below_tick': '0.01',
#    'cutoff_price': '0.00'},
#   'open_interest': 1661,
#   'previous_close_date': '2020-02-13',
#   'previous_close_price': '0.040000',
#   'rho': '0.000904',
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '347.0000',
#   'theta': '-0.010711',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-02-15T01:00:00Z',
#   'url': 'https://api.robinhood.com/options/instruments/4d327d76-b3da-4b8d-988e-a64c88119d5c/',
#   'vega': '0.016715',
#   'volume': 254},
#  {'_id': '2020-02-21_346.0000_2019-11-12T01:04:20.114791Z',
#   'adjusted_mark_price': '0.030000',
#   'ask_price': '0.030000',
#   'ask_size': 7361,
#   'bid_price': '0.020000',
#   'bid_size': 8095,
#   'break_even_price': '346.030000',
#   'chain_id': 'c277b118-58d9-4060-8dc5-a3b5898955cb',
#   'chain_symbol': 'SPY',
#   'chance_of_profit_long': '0.019919',
#   'chance_of_profit_short': '0.980081',
#   'created_at': '2019-11-12T01:04:20.114784Z',
#   'delta': '0.020858',
#   'expiration_date': '2020-02-21',
#   'gamma': '0.012825',
#   'high_fill_rate_buy_price': '0.030000',
#   'high_fill_rate_sell_price': '0.020000',
#   'high_price': '0.050000',
#   'id': '695b2082-e610-46d6-b759-20c0c99d58ee',
#   'implied_volatility': '0.083638',
#   'instrument': 'https://api.robinhood.com/options/instruments/695b2082-e610-46d6-b759-20c0c99d58ee/',
#   'issue_date': '2005-01-06',
#   'last_trade_price': '337.600000',
#   'last_trade_size': 31,
#   'low_fill_rate_buy_price': '0.020000',
#   'low_fill_rate_sell_price': '0.030000',
#   'low_price': '0.030000',
#   'mark_price': '0.025000',
#   'min_ticks': {'above_tick': '0.01',
#    'below_tick': '0.01',
#    'cutoff_price': '0.00'},
#   'open_interest': 5467,
#   'previous_close_date': '2020-02-13',
#   'previous_close_price': '0.060000',
#   'rho': '0.001345',
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '346.0000',
#   'theta': '-0.014500',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-02-15T01:00:00Z',
#   'url': 'https://api.robinhood.com/options/instruments/695b2082-e610-46d6-b759-20c0c99d58ee/',
#   'vega': '0.023467',
#   'volume': 349},
#  {'_id': '2020-02-21_345.0000_2019-11-12T01:04:20.114697Z',
#   'adjusted_mark_price': '0.050000',
#   'ask_price': '0.050000',
#   'ask_size': 5976,
#   'bid_price': '0.040000',
#   'bid_size': 1376,
#   'break_even_price': '345.050000',
#   'chain_id': 'c277b118-58d9-4060-8dc5-a3b5898955cb',
#   'chain_symbol': 'SPY',
#   'chance_of_profit_long': '0.031704',
#   'chance_of_profit_short': '0.968296',
#   'created_at': '2019-11-12T01:04:20.114690Z',
#   'delta': '0.033461',
#   'expiration_date': '2020-02-21',
#   'gamma': '0.019519',
#   'high_fill_rate_buy_price': '0.050000',
#   'high_fill_rate_sell_price': '0.040000',
#   'high_price': '0.080000',
#   'id': 'fce7a0d8-cf58-42b9-8d9f-9b0f44340d54',
#   'implied_volatility': '0.081563',
#   'instrument': 'https://api.robinhood.com/options/instruments/fce7a0d8-cf58-42b9-8d9f-9b0f44340d54/',
#   'issue_date': '2005-01-06',
#   'last_trade_price': '337.600000',
#   'last_trade_size': 5,
#   'low_fill_rate_buy_price': '0.040000',
#   'low_fill_rate_sell_price': '0.050000',
#   'low_price': '0.040000',
#   'mark_price': '0.045000',
#   'min_ticks': {'above_tick': '0.01',
#    'below_tick': '0.01',
#    'cutoff_price': '0.00'},
#   'open_interest': 11472,
#   'previous_close_date': '2020-02-13',
#   'previous_close_price': '0.090000',
#   'rho': '0.002158',
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '345.0000',
#   'theta': '-0.021063',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-02-15T01:00:00Z',
#   'url': 'https://api.robinhood.com/options/instruments/fce7a0d8-cf58-42b9-8d9f-9b0f44340d54/',
#   'vega': '0.034830',
#   'volume': 5740},
#  {'_id': '2020-02-21_344.0000_2019-11-12T01:04:20.114602Z',
#   'adjusted_mark_price': '0.080000',
#   'ask_price': '0.080000',
#   'ask_size': 6660,
#   'bid_price': '0.070000',
#   'bid_size': 1383,
#   'break_even_price': '344.080000',
#   'chain_id': 'c277b118-58d9-4060-8dc5-a3b5898955cb',
#   'chain_symbol': 'SPY',
#   'chance_of_profit_long': '0.048447',
#   'chance_of_profit_short': '0.951553',
#   'created_at': '2019-11-12T01:04:20.114584Z',
#   'delta': '0.051773',
#   'expiration_date': '2020-02-21',
#   'gamma': '0.028718',
#   'high_fill_rate_buy_price': '0.080000',
#   'high_fill_rate_sell_price': '0.070000',
#   'high_price': '0.130000',
#   'id': 'da761372-e4de-4477-8121-e1a0428408f4',
#   'implied_volatility': '0.078941',
#   'instrument': 'https://api.robinhood.com/options/instruments/da761372-e4de-4477-8121-e1a0428408f4/',
#   'issue_date': '2005-01-06',
#   'last_trade_price': '337.600000',
#   'last_trade_size': 300,
#   'low_fill_rate_buy_price': '0.070000',
#   'low_fill_rate_sell_price': '0.080000',
#   'low_price': '0.060000',
#   'mark_price': '0.075000',
#   'min_ticks': {'above_tick': '0.01',
#    'below_tick': '0.01',
#    'cutoff_price': '0.00'},
#   'open_interest': 22515,
#   'previous_close_date': '2020-02-13',
#   'previous_close_price': '0.140000',
#   'rho': '0.003338',
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '344.0000',
#   'theta': '-0.029158',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-02-15T01:00:00Z',
#   'url': 'https://api.robinhood.com/options/instruments/da761372-e4de-4477-8121-e1a0428408f4/',
#   'vega': '0.049597',
#   'volume': 22315},
#  {'_id': '2020-02-21_343.0000_2019-11-12T01:04:20.114490Z',
#   'adjusted_mark_price': '0.140000',
#   'ask_price': '0.140000',
#   'ask_size': 3931,
#   'bid_price': '0.130000',
#   'bid_size': 1984,
#   'break_even_price': '343.140000',
#   'chain_id': 'c277b118-58d9-4060-8dc5-a3b5898955cb',
#   'chain_symbol': 'SPY',
#   'chance_of_profit_long': '0.076924',
#   'chance_of_profit_short': '0.923076',
#   'created_at': '2019-11-12T01:04:20.114483Z',
#   'delta': '0.084178',
#   'expiration_date': '2020-02-21',
#   'gamma': '0.042322',
#   'high_fill_rate_buy_price': '0.140000',
#   'high_fill_rate_sell_price': '0.130000',
#   'high_price': '0.230000',
#   'id': '4166c992-42f8-4e9f-a317-f88ff0e711e9',
#   'implied_volatility': '0.078037',
#   'instrument': 'https://api.robinhood.com/options/instruments/4166c992-42f8-4e9f-a317-f88ff0e711e9/',
#   'issue_date': '2005-01-06',
#   'last_trade_price': '337.600000',
#   'last_trade_size': 15,
#   'low_fill_rate_buy_price': '0.130000',
#   'low_fill_rate_sell_price': '0.140000',
#   'low_price': '0.100000',
#   'mark_price': '0.135000',
#   'min_ticks': {'above_tick': '0.01',
#    'below_tick': '0.01',
#    'cutoff_price': '0.00'},
#   'open_interest': 18482,
#   'previous_close_date': '2020-02-13',
#   'previous_close_price': '0.230000',
#   'rho': '0.005426',
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '343.0000',
#   'theta': '-0.042213',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-02-15T01:00:00Z',
#   'url': 'https://api.robinhood.com/options/instruments/4166c992-42f8-4e9f-a317-f88ff0e711e9/',
#   'vega': '0.072255',
#   'volume': 3336},
#  {'_id': '2020-02-21_338.0000_2019-11-12T01:04:20.114440Z',
#   'adjusted_mark_price': '1.570000',
#   'ask_price': '1.580000',
#   'ask_size': 5,
#   'bid_price': '1.550000',
#   'bid_size': 230,
#   'break_even_price': '339.570000',
#   'chain_id': 'c277b118-58d9-4060-8dc5-a3b5898955cb',
#   'chain_symbol': 'SPY',
#   'chance_of_profit_long': '0.339158',
#   'chance_of_profit_short': '0.660842',
#   'created_at': '2019-11-12T01:04:20.114432Z',
#   'delta': '0.493711',
#   'expiration_date': '2020-02-21',
#   'gamma': '0.098633',
#   'high_fill_rate_buy_price': '1.580000',
#   'high_fill_rate_sell_price': '1.550000',
#   'high_price': '1.700000',
#   'id': '4beca2ad-9a25-4ff8-993d-662ff0567e18',
#   'implied_volatility': '0.086464',
#   'instrument': 'https://api.robinhood.com/options/instruments/4beca2ad-9a25-4ff8-993d-662ff0567e18/',
#   'issue_date': '2005-01-06',
#   'last_trade_price': '337.600000',
#   'last_trade_size': 1,
#   'low_fill_rate_buy_price': '1.560000',
#   'low_fill_rate_sell_price': '1.570000',
#   'low_price': '1.120000',
#   'mark_price': '1.565000',
#   'min_ticks': {'above_tick': '0.01',
#    'below_tick': '0.01',
#    'cutoff_price': '0.00'},
#   'open_interest': 12954,
#   'previous_close_date': '2020-02-13',
#   'previous_close_price': '1.650000',
#   'rho': '0.031679',
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '338.0000',
#   'theta': '-0.126543',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-02-15T01:00:00Z',
#   'url': 'https://api.robinhood.com/options/instruments/4beca2ad-9a25-4ff8-993d-662ff0567e18/',
#   'vega': '0.186575',
#   'volume': 19108},
#  {'_id': '2020-02-21_337.0000_2019-11-12T01:04:20.114338Z',
#   'adjusted_mark_price': '2.170000',
#   'ask_price': '2.180000',
#   'ask_size': 10,
#   'bid_price': '2.150000',
#   'bid_size': 44,
#   'break_even_price': '339.170000',
#   'chain_id': 'c277b118-58d9-4060-8dc5-a3b5898955cb',
#   'chain_symbol': 'SPY',
#   'chance_of_profit_long': '0.380273',
#   'chance_of_profit_short': '0.619727',
#   'created_at': '2019-11-12T01:04:20.114330Z',
#   'delta': '0.588364',
#   'expiration_date': '2020-02-21',
#   'gamma': '0.092557',
#   'high_fill_rate_buy_price': '2.180000',
#   'high_fill_rate_sell_price': '2.150000',
#   'high_price': '2.310000',
#   'id': 'ed224252-c33a-407a-b8bc-686bb1dcfae6',
#   'implied_volatility': '0.089882',
#   'instrument': 'https://api.robinhood.com/options/instruments/ed224252-c33a-407a-b8bc-686bb1dcfae6/',
#   'issue_date': '2005-01-06',
#   'last_trade_price': '337.600000',
#   'last_trade_size': 1,
#   'low_fill_rate_buy_price': '2.160000',
#   'low_fill_rate_sell_price': '2.170000',
#   'low_price': '1.590000',
#   'mark_price': '2.165000',
#   'min_ticks': {'above_tick': '0.01',
#    'below_tick': '0.01',
#    'cutoff_price': '0.00'},
#   'open_interest': 24070,
#   'previous_close_date': '2020-02-13',
#   'previous_close_price': '2.200000',
#   'rho': '0.037695',
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '337.0000',
#   'theta': '-0.130310',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-02-15T01:00:00Z',
#   'url': 'https://api.robinhood.com/options/instruments/ed224252-c33a-407a-b8bc-686bb1dcfae6/',
#   'vega': '0.182002',
#   'volume': 15497},
#  {'_id': '2020-02-21_336.0000_2019-11-12T01:04:20.114227Z',
#   'adjusted_mark_price': '2.860000',
#   'ask_price': '2.880000',
#   'ask_size': 33,
#   'bid_price': '2.840000',
#   'bid_size': 33,
#   'break_even_price': '338.860000',
#   'chain_id': 'c277b118-58d9-4060-8dc5-a3b5898955cb',
#   'chain_symbol': 'SPY',
#   'chance_of_profit_long': '0.411844',
#   'chance_of_profit_short': '0.588156',
#   'created_at': '2019-11-12T01:04:20.114218Z',
#   'delta': '0.671701',
#   'expiration_date': '2020-02-21',
#   'gamma': '0.082621',
#   'high_fill_rate_buy_price': '2.880000',
#   'high_fill_rate_sell_price': '2.840000',
#   'high_price': '3.000000',
#   'id': 'b33de674-4145-439a-9615-487e7fe0147d',
#   'implied_volatility': '0.093518',
#   'instrument': 'https://api.robinhood.com/options/instruments/b33de674-4145-439a-9615-487e7fe0147d/',
#   'issue_date': '2005-01-06',
#   'last_trade_price': '337.600000',
#   'last_trade_size': 5,
#   'low_fill_rate_buy_price': '2.850000',
#   'low_fill_rate_sell_price': '2.860000',
#   'low_price': '2.170000',
#   'mark_price': '2.860000',
#   'min_ticks': {'above_tick': '0.01',
#    'below_tick': '0.01',
#    'cutoff_price': '0.00'},
#   'open_interest': 22687,
#   'previous_close_date': '2020-02-13',
#   'previous_close_price': '2.850000',
#   'rho': '0.042960',
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '336.0000',
#   'theta': '-0.128257',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-02-15T01:00:00Z',
#   'url': 'https://api.robinhood.com/options/instruments/b33de674-4145-439a-9615-487e7fe0147d/',
#   'vega': '0.169037',
#   'volume': 9550},
#  {'_id': '2020-02-21_334.0000_2019-11-12T01:04:20.114113Z',
#   'adjusted_mark_price': '4.430000',
#   'ask_price': '4.450000',
#   'ask_size': 1,
#   'bid_price': '4.410000',
#   'bid_size': 1,
#   'break_even_price': '338.430000',
#   'chain_id': 'c277b118-58d9-4060-8dc5-a3b5898955cb',
#   'chain_symbol': 'SPY',
#   'chance_of_profit_long': '0.453218',
#   'chance_of_profit_short': '0.546782',
#   'created_at': '2019-11-12T01:04:20.114106Z',
#   'delta': '0.801708',
#   'expiration_date': '2020-02-21',
#   'gamma': '0.059544',
#   'high_fill_rate_buy_price': '4.450000',
#   'high_fill_rate_sell_price': '4.410000',
#   'high_price': '4.580000',
#   'id': 'c4cdc17a-951e-4c81-a078-a66012c7aed4',
#   'implied_volatility': '0.100004',
#   'instrument': 'https://api.robinhood.com/options/instruments/c4cdc17a-951e-4c81-a078-a66012c7aed4/',
#   'issue_date': '2005-01-06',
#   'last_trade_price': '337.600000',
#   'last_trade_size': 2,
#   'low_fill_rate_buy_price': '4.420000',
#   'low_fill_rate_sell_price': '4.440000',
#   'low_price': '3.580000',
#   'mark_price': '4.430000',
#   'min_ticks': {'above_tick': '0.01',
#    'below_tick': '0.01',
#    'cutoff_price': '0.00'},
#   'open_interest': 29098,
#   'previous_close_date': '2020-02-13',
#   'previous_close_price': '4.330000',
#   'rho': '0.051080',
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '334.0000',
#   'theta': '-0.111299',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-02-15T01:00:00Z',
#   'url': 'https://api.robinhood.com/options/instruments/c4cdc17a-951e-4c81-a078-a66012c7aed4/',
#   'vega': '0.130273',
#   'volume': 1337},
#  {'_id': '2020-02-21_333.0000_2019-11-12T01:04:20.114018Z',
#   'adjusted_mark_price': '5.360000',
#   'ask_price': '5.460000',
#   'ask_size': 193,
#   'bid_price': '5.250000',
#   'bid_size': 60,
#   'break_even_price': '338.360000',
#   'chain_id': 'c277b118-58d9-4060-8dc5-a3b5898955cb',
#   'chain_symbol': 'SPY',
#   'chance_of_profit_long': '0.462132',
#   'chance_of_profit_short': '0.537868',
#   'created_at': '2019-11-12T01:04:20.114011Z',
#   'delta': '0.835090',
#   'expiration_date': '2020-02-21',
#   'gamma': '0.048514',
#   'high_fill_rate_buy_price': '5.430000',
#   'high_fill_rate_sell_price': '5.260000',
#   'high_price': '5.380000',
#   'id': '376fa841-5a7c-4885-b635-c7cfe544872a',
#   'implied_volatility': '0.109356',
#   'instrument': 'https://api.robinhood.com/options/instruments/376fa841-5a7c-4885-b635-c7cfe544872a/',
#   'issue_date': '2005-01-06',
#   'last_trade_price': '337.600000',
#   'last_trade_size': 1,
#   'low_fill_rate_buy_price': '5.340000',
#   'low_fill_rate_sell_price': '5.350000',
#   'low_price': '4.330000',
#   'mark_price': '5.355000',
#   'min_ticks': {'above_tick': '0.01',
#    'below_tick': '0.01',
#    'cutoff_price': '0.00'},
#   'open_interest': 50322,
#   'previous_close_date': '2020-02-13',
#   'previous_close_price': '5.160000',
#   'rho': '0.053064',
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '333.0000',
#   'theta': '-0.109612',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-02-15T01:00:00Z',
#   'url': 'https://api.robinhood.com/options/instruments/376fa841-5a7c-4885-b635-c7cfe544872a/',
#   'vega': '0.116066',
#   'volume': 1221},
#  {'_id': '2020-02-21_332.0000_2019-11-12T01:04:20.113923Z',
#   'adjusted_mark_price': '6.220000',
#   'ask_price': '6.290000',
#   'ask_size': 60,
#   'bid_price': '6.150000',
#   'bid_size': 60,
#   'break_even_price': '338.220000',
#   'chain_id': 'c277b118-58d9-4060-8dc5-a3b5898955cb',
#   'chain_symbol': 'SPY',
#   'chance_of_profit_long': '0.473113',
#   'chance_of_profit_short': '0.526887',
#   'created_at': '2019-11-12T01:04:20.113915Z',
#   'delta': '0.878332',
#   'expiration_date': '2020-02-21',
#   'gamma': '0.039273',
#   'high_fill_rate_buy_price': '6.270000',
#   'high_fill_rate_sell_price': '6.160000',
#   'high_price': '6.280000',
#   'id': '6d36be5e-e403-4d92-af8f-cd3661db103c',
#   'implied_volatility': '0.109962',
#   'instrument': 'https://api.robinhood.com/options/instruments/6d36be5e-e403-4d92-af8f-cd3661db103c/',
#   'issue_date': '2005-01-06',
#   'last_trade_price': '337.600000',
#   'last_trade_size': 10,
#   'low_fill_rate_buy_price': '6.210000',
#   'low_fill_rate_sell_price': '6.220000',
#   'low_price': '5.210000',
#   'mark_price': '6.220000',
#   'min_ticks': {'above_tick': '0.01',
#    'below_tick': '0.01',
#    'cutoff_price': '0.00'},
#   'open_interest': 62356,
#   'previous_close_date': '2020-02-13',
#   'previous_close_price': '5.990000',
#   'rho': '0.055700',
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '332.0000',
#   'theta': '-0.094101',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-02-15T01:00:00Z',
#   'url': 'https://api.robinhood.com/options/instruments/6d36be5e-e403-4d92-af8f-cd3661db103c/',
#   'vega': '0.094479',
#   'volume': 1426},
#  {'_id': '2020-02-21_331.0000_2019-11-12T01:04:20.113826Z',
#   'adjusted_mark_price': '7.130000',
#   'ask_price': '7.200000',
#   'ask_size': 200,
#   'bid_price': '7.050000',
#   'bid_size': 40,
#   'break_even_price': '338.130000',
#   'chain_id': 'c277b118-58d9-4060-8dc5-a3b5898955cb',
#   'chain_symbol': 'SPY',
#   'chance_of_profit_long': '0.480342',
#   'chance_of_profit_short': '0.519658',
#   'created_at': '2019-11-12T01:04:20.113819Z',
#   'delta': '0.909629',
#   'expiration_date': '2020-02-21',
#   'gamma': '0.031053',
#   'high_fill_rate_buy_price': '7.180000',
#   'high_fill_rate_sell_price': '7.060000',
#   'high_price': '7.190000',
#   'id': 'c3088c38-dcaf-4d08-80fc-ac181cc32f0f',
#   'implied_volatility': '0.112148',
#   'instrument': 'https://api.robinhood.com/options/instruments/c3088c38-dcaf-4d08-80fc-ac181cc32f0f/',
#   'issue_date': '2005-01-06',
#   'last_trade_price': '337.600000',
#   'last_trade_size': 3,
#   'low_fill_rate_buy_price': '7.110000',
#   'low_fill_rate_sell_price': '7.120000',
#   'low_price': '6.180000',
#   'mark_price': '7.125000',
#   'min_ticks': {'above_tick': '0.01',
#    'below_tick': '0.01',
#    'cutoff_price': '0.00'},
#   'open_interest': 34711,
#   'previous_close_date': '2020-02-13',
#   'previous_close_price': '6.880000',
#   'rho': '0.057553',
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '331.0000',
#   'theta': '-0.081585',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-02-15T01:00:00Z',
#   'url': 'https://api.robinhood.com/options/instruments/c3088c38-dcaf-4d08-80fc-ac181cc32f0f/',
#   'vega': '0.076188',
#   'volume': 470},
#  {'_id': '2020-02-21_342.0000_2019-11-12T01:04:20.113206Z',
#   'adjusted_mark_price': '0.250000',
#   'ask_price': '0.250000',
#   'ask_size': 778,
#   'bid_price': '0.240000',
#   'bid_size': 327,
#   'break_even_price': '342.250000',
#   'chain_id': 'c277b118-58d9-4060-8dc5-a3b5898955cb',
#   'chain_symbol': 'SPY',
#   'chance_of_profit_long': '0.119120',
#   'chance_of_profit_short': '0.880880',
#   'created_at': '2019-11-12T01:04:20.113199Z',
#   'delta': '0.135387',
#   'expiration_date': '2020-02-21',
#   'gamma': '0.059278',
#   'high_fill_rate_buy_price': '0.250000',
#   'high_fill_rate_sell_price': '0.240000',
#   'high_price': '0.340000',
#   'id': 'ed9a2b0d-9d50-4251-a5ca-2335260d080f',
#   'implied_volatility': '0.078462',
#   'instrument': 'https://api.robinhood.com/options/instruments/ed9a2b0d-9d50-4251-a5ca-2335260d080f/',
#   'issue_date': '2005-01-06',
#   'last_trade_price': '337.600000',
#   'last_trade_size': 5,
#   'low_fill_rate_buy_price': '0.240000',
#   'low_fill_rate_sell_price': '0.250000',
#   'low_price': '0.180000',
#   'mark_price': '0.245000',
#   'min_ticks': {'above_tick': '0.01',
#    'below_tick': '0.01',
#    'cutoff_price': '0.00'},
#   'open_interest': 26071,
#   'previous_close_date': '2020-02-13',
#   'previous_close_price': '0.350000',
#   'rho': '0.008722',
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '342.0000',
#   'theta': '-0.060142',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-02-15T01:00:00Z',
#   'url': 'https://api.robinhood.com/options/instruments/ed9a2b0d-9d50-4251-a5ca-2335260d080f/',
#   'vega': '0.101753',
#   'volume': 7820},
#  {'_id': '2020-02-21_341.0000_2019-11-12T01:04:20.113111Z',
#   'adjusted_mark_price': '0.430000',
#   'ask_price': '0.430000',
#   'ask_size': 386,
#   'bid_price': '0.420000',
#   'bid_size': 367,
#   'break_even_price': '341.430000',
#   'chain_id': 'c277b118-58d9-4060-8dc5-a3b5898955cb',
#   'chain_symbol': 'SPY',
#   'chance_of_profit_long': '0.172326',
#   'chance_of_profit_short': '0.827674',
#   'created_at': '2019-11-12T01:04:20.113104Z',
#   'delta': '0.206200',
#   'expiration_date': '2020-02-21',
#   'gamma': '0.076573',
#   'high_fill_rate_buy_price': '0.430000',
#   'high_fill_rate_sell_price': '0.420000',
#   'high_price': '0.540000',
#   'id': 'bfa6e738-3569-45ca-a50b-80beefb6eba0',
#   'implied_volatility': '0.079606',
#   'instrument': 'https://api.robinhood.com/options/instruments/bfa6e738-3569-45ca-a50b-80beefb6eba0/',
#   'issue_date': '2005-01-06',
#   'last_trade_price': '337.600000',
#   'last_trade_size': 4,
#   'low_fill_rate_buy_price': '0.420000',
#   'low_fill_rate_sell_price': '0.430000',
#   'low_price': '0.290000',
#   'mark_price': '0.425000',
#   'min_ticks': {'above_tick': '0.01',
#    'below_tick': '0.01',
#    'cutoff_price': '0.00'},
#   'open_interest': 28189,
#   'previous_close_date': '2020-02-13',
#   'previous_close_price': '0.540000',
#   'rho': '0.013274',
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '341.0000',
#   'theta': '-0.080569',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-02-15T01:00:00Z',
#   'url': 'https://api.robinhood.com/options/instruments/bfa6e738-3569-45ca-a50b-80beefb6eba0/',
#   'vega': '0.133356',
#   'volume': 19246},
#  {'_id': '2020-02-21_339.0000_2019-11-12T01:04:20.113000Z',
#   'adjusted_mark_price': '1.080000',
#   'ask_price': '1.080000',
#   'ask_size': 800,
#   'bid_price': '1.070000',
#   'bid_size': 288,
#   'break_even_price': '340.080000',
#   'chain_id': 'c277b118-58d9-4060-8dc5-a3b5898955cb',
#   'chain_symbol': 'SPY',
#   'chance_of_profit_long': '0.288532',
#   'chance_of_profit_short': '0.711468',
#   'created_at': '2019-11-12T01:04:20.112993Z',
#   'delta': '0.392961',
#   'expiration_date': '2020-02-21',
#   'gamma': '0.098236',
#   'high_fill_rate_buy_price': '1.080000',
#   'high_fill_rate_sell_price': '1.070000',
#   'high_price': '1.210000',
#   'id': 'bd052d63-c9aa-4d76-b78c-77d6da0eff20',
#   'implied_volatility': '0.083680',
#   'instrument': 'https://api.robinhood.com/options/instruments/bd052d63-c9aa-4d76-b78c-77d6da0eff20/',
#   'issue_date': '2005-01-06',
#   'last_trade_price': '337.600000',
#   'last_trade_size': 3,
#   'low_fill_rate_buy_price': '1.070000',
#   'low_fill_rate_sell_price': '1.080000',
#   'low_price': '0.770000',
#   'mark_price': '1.075000',
#   'min_ticks': {'above_tick': '0.01',
#    'below_tick': '0.01',
#    'cutoff_price': '0.00'},
#   'open_interest': 28742,
#   'previous_close_date': '2020-02-13',
#   'previous_close_price': '1.180000',
#   'rho': '0.025247',
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '339.0000',
#   'theta': '-0.116510',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-02-15T01:00:00Z',
#   'url': 'https://api.robinhood.com/options/instruments/bd052d63-c9aa-4d76-b78c-77d6da0eff20/',
#   'vega': '0.179841',
#   'volume': 12051},
#  {'_id': '2020-02-21_329.0000_2019-11-05T02:07:28.601238Z',
#   'adjusted_mark_price': '8.960000',
#   'ask_price': '9.000000',
#   'ask_size': 1,
#   'bid_price': '8.920000',
#   'bid_size': 60,
#   'break_even_price': '337.960000',
#   'chain_id': 'c277b118-58d9-4060-8dc5-a3b5898955cb',
#   'chain_symbol': 'SPY',
#   'chance_of_profit_long': '0.493166',
#   'chance_of_profit_short': '0.506834',
#   'created_at': '2019-11-05T02:07:28.601231Z',
#   'delta': '0.971553',
#   'expiration_date': '2020-02-21',
#   'gamma': '0.013681',
#   'high_fill_rate_buy_price': '9.000000',
#   'high_fill_rate_sell_price': '8.930000',
#   'high_price': '9.070000',
#   'id': '30fc884a-103d-4354-bd05-62fa2103c608',
#   'implied_volatility': '0.101736',
#   'instrument': 'https://api.robinhood.com/options/instruments/30fc884a-103d-4354-bd05-62fa2103c608/',
#   'issue_date': '2005-01-06',
#   'last_trade_price': '337.600000',
#   'last_trade_size': 7,
#   'low_fill_rate_buy_price': '8.960000',
#   'low_fill_rate_sell_price': '8.970000',
#   'low_price': '8.000000',
#   'mark_price': '8.960000',
#   'min_ticks': {'above_tick': '0.01',
#    'below_tick': '0.01',
#    'cutoff_price': '0.00'},
#   'open_interest': 15293,
#   'previous_close_date': '2020-02-13',
#   'previous_close_price': '8.650000',
#   'rho': '0.061213',
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '329.0000',
#   'theta': '-0.043990',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-02-15T01:00:00Z',
#   'url': 'https://api.robinhood.com/options/instruments/30fc884a-103d-4354-bd05-62fa2103c608/',
#   'vega': '0.030451',
#   'volume': 314},
#  {'_id': '2020-02-21_328.0000_2019-11-05T02:07:28.601143Z',
#   'adjusted_mark_price': '9.970000',
#   'ask_price': '10.060000',
#   'ask_size': 54,
#   'bid_price': '9.880000',
#   'bid_size': 50,
#   'break_even_price': '337.970000',
#   'chain_id': 'c277b118-58d9-4060-8dc5-a3b5898955cb',
#   'chain_symbol': 'SPY',
#   'chance_of_profit_long': '0.492521',
#   'chance_of_profit_short': '0.507479',
#   'created_at': '2019-11-05T02:07:28.601136Z',
#   'delta': '0.969983',
#   'expiration_date': '2020-02-21',
#   'gamma': '0.012677',
#   'high_fill_rate_buy_price': '10.030000',
#   'high_fill_rate_sell_price': '9.900000',
#   'high_price': '10.080000',
#   'id': 'ca763f1a-297c-40af-9d14-cac69ce5b6d2',
#   'implied_volatility': '0.114805',
#   'instrument': 'https://api.robinhood.com/options/instruments/ca763f1a-297c-40af-9d14-cac69ce5b6d2/',
#   'issue_date': '2005-01-06',
#   'last_trade_price': '337.600000',
#   'last_trade_size': 1,
#   'low_fill_rate_buy_price': '9.960000',
#   'low_fill_rate_sell_price': '9.970000',
#   'low_price': '9.070000',
#   'mark_price': '9.970000',
#   'min_ticks': {'above_tick': '0.01',
#    'below_tick': '0.01',
#    'cutoff_price': '0.00'},
#   'open_interest': 52838,
#   'previous_close_date': '2020-02-13',
#   'previous_close_price': '9.630000',
#   'rho': '0.060918',
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '328.0000',
#   'theta': '-0.047867',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-02-15T01:00:00Z',
#   'url': 'https://api.robinhood.com/options/instruments/ca763f1a-297c-40af-9d14-cac69ce5b6d2/',
#   'vega': '0.031841',
#   'volume': 218},
#  {'_id': '2020-02-21_327.0000_2019-11-02T02:14:24.362712Z',
#   'adjusted_mark_price': '10.920000',
#   'ask_price': '11.010000',
#   'ask_size': 53,
#   'bid_price': '10.820000',
#   'bid_size': 60,
#   'break_even_price': '337.920000',
#   'chain_id': 'c277b118-58d9-4060-8dc5-a3b5898955cb',
#   'chain_symbol': 'SPY',
#   'chance_of_profit_long': '0.496562',
#   'chance_of_profit_short': '0.503438',
#   'created_at': '2019-11-02T02:14:24.362704Z',
#   'delta': '0.991495',
#   'expiration_date': '2020-02-21',
#   'gamma': '0.004965',
#   'high_fill_rate_buy_price': '10.980000',
#   'high_fill_rate_sell_price': '10.840000',
#   'high_price': '11.060000',
#   'id': 'e4145fa7-c363-4ff2-b961-5fcf995ca5cc',
#   'implied_volatility': '0.099610',
#   'instrument': 'https://api.robinhood.com/options/instruments/e4145fa7-c363-4ff2-b961-5fcf995ca5cc/',
#   'issue_date': '2005-01-06',
#   'last_trade_price': '337.600000',
#   'last_trade_size': 3,
#   'low_fill_rate_buy_price': '10.900000',
#   'low_fill_rate_sell_price': '10.920000',
#   'low_price': '9.550000',
#   'mark_price': '10.915000',
#   'min_ticks': {'above_tick': '0.01',
#    'below_tick': '0.01',
#    'cutoff_price': '0.00'},
#   'open_interest': 20146,
#   'previous_close_date': '2020-02-13',
#   'previous_close_price': '10.560000',
#   'rho': '0.062129',
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '327.0000',
#   'theta': '-0.029887',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-02-15T01:00:00Z',
#   'url': 'https://api.robinhood.com/options/instruments/e4145fa7-c363-4ff2-b961-5fcf995ca5cc/',
#   'vega': '0.010819',
#   'volume': 888},
#  {'_id': '2020-02-21_326.0000_2019-11-02T02:14:24.362436Z',
#   'adjusted_mark_price': '11.920000',
#   'ask_price': '12.030000',
#   'ask_size': 193,
#   'bid_price': '11.800000',
#   'bid_size': 50,
#   'break_even_price': '337.920000',
#   'chain_id': 'c277b118-58d9-4060-8dc5-a3b5898955cb',
#   'chain_symbol': 'SPY',
#   'chance_of_profit_long': '0.496379',
#   'chance_of_profit_short': '0.503621',
#   'created_at': '2019-11-02T02:14:24.362428Z',
#   'delta': '0.991854',
#   'expiration_date': '2020-02-21',
#   'gamma': '0.004400',
#   'high_fill_rate_buy_price': '11.990000',
#   'high_fill_rate_sell_price': '11.810000',
#   'high_price': '11.870000',
#   'id': 'c277a255-ee54-4613-b94a-85c9bdaf5716',
#   'implied_volatility': '0.108211',
#   'instrument': 'https://api.robinhood.com/options/instruments/c277a255-ee54-4613-b94a-85c9bdaf5716/',
#   'issue_date': '2005-01-06',
#   'last_trade_price': '337.600000',
#   'last_trade_size': 10,
#   'low_fill_rate_buy_price': '11.890000',
#   'low_fill_rate_sell_price': '11.910000',
#   'low_price': '10.650000',
#   'mark_price': '11.915000',
#   'min_ticks': {'above_tick': '0.01',
#    'below_tick': '0.01',
#    'cutoff_price': '0.00'},
#   'open_interest': 24747,
#   'previous_close_date': '2020-02-13',
#   'previous_close_price': '11.490000',
#   'rho': '0.061960',
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '326.0000',
#   'theta': '-0.030180',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-02-15T01:00:00Z',
#   'url': 'https://api.robinhood.com/options/instruments/c277a255-ee54-4613-b94a-85c9bdaf5716/',
#   'vega': '0.010416',
#   'volume': 92},
#  {'_id': '2020-02-21_335.0000_2019-09-25T01:04:52.791688Z',
#   'adjusted_mark_price': '3.630000',
#   'ask_price': '3.660000',
#   'ask_size': 14,
#   'bid_price': '3.600000',
#   'bid_size': 20,
#   'break_even_price': '338.630000',
#   'chain_id': 'c277b118-58d9-4060-8dc5-a3b5898955cb',
#   'chain_symbol': 'SPY',
#   'chance_of_profit_long': '0.435016',
#   'chance_of_profit_short': '0.564984',
#   'created_at': '2019-09-25T01:04:52.791680Z',
#   'delta': '0.740964',
#   'expiration_date': '2020-02-21',
#   'gamma': '0.070831',
#   'high_fill_rate_buy_price': '3.650000',
#   'high_fill_rate_sell_price': '3.600000',
#   'high_price': '3.760000',
#   'id': '5371fa10-362d-47cc-972d-d07dcac9522e',
#   'implied_volatility': '0.097720',
#   'instrument': 'https://api.robinhood.com/options/instruments/5371fa10-362d-47cc-972d-d07dcac9522e/',
#   'issue_date': '2005-01-06',
#   'last_trade_price': '337.600000',
#   'last_trade_size': 6,
#   'low_fill_rate_buy_price': '3.620000',
#   'low_fill_rate_sell_price': '3.640000',
#   'low_price': '2.840000',
#   'mark_price': '3.630000',
#   'min_ticks': {'above_tick': '0.01',
#    'below_tick': '0.01',
#    'cutoff_price': '0.00'},
#   'open_interest': 56008,
#   'previous_close_date': '2020-02-13',
#   'previous_close_price': '3.570000',
#   'rho': '0.047299',
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '335.0000',
#   'theta': '-0.122588',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-02-15T01:00:00Z',
#   'url': 'https://api.robinhood.com/options/instruments/5371fa10-362d-47cc-972d-d07dcac9522e/',
#   'vega': '0.151426',
#   'volume': 6088},
#  {'_id': '2020-02-21_330.0000_2019-09-19T00:05:35.519132Z',
#   'adjusted_mark_price': '8.080000',
#   'ask_price': '8.180000',
#   'ask_size': 56,
#   'bid_price': '7.980000',
#   'bid_size': 40,
#   'break_even_price': '338.080000',
#   'chain_id': 'c277b118-58d9-4060-8dc5-a3b5898955cb',
#   'chain_symbol': 'SPY',
#   'chance_of_profit_long': '0.484522',
#   'chance_of_profit_short': '0.515478',
#   'created_at': '2019-09-19T00:05:35.519123Z',
#   'delta': '0.929485',
#   'expiration_date': '2020-02-21',
#   'gamma': '0.024701',
#   'high_fill_rate_buy_price': '8.150000',
#   'high_fill_rate_sell_price': '8.000000',
#   'high_price': '8.150000',
#   'id': '2a175d31-e637-4b1c-ab71-6862db8c976e',
#   'implied_volatility': '0.116872',
#   'instrument': 'https://api.robinhood.com/options/instruments/2a175d31-e637-4b1c-ab71-6862db8c976e/',
#   'issue_date': '2005-01-06',
#   'last_trade_price': '337.600000',
#   'last_trade_size': 1,
#   'low_fill_rate_buy_price': '8.060000',
#   'low_fill_rate_sell_price': '8.080000',
#   'low_price': '6.990000',
#   'mark_price': '8.080000',
#   'min_ticks': {'above_tick': '0.01',
#    'below_tick': '0.01',
#    'cutoff_price': '0.00'},
#   'open_interest': 107873,
#   'previous_close_date': '2020-02-13',
#   'previous_close_price': '7.760000',
#   'rho': '0.058657',
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '330.0000',
#   'theta': '-0.073672',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-02-15T01:00:00Z',
#   'url': 'https://api.robinhood.com/options/instruments/2a175d31-e637-4b1c-ab71-6862db8c976e/',
#   'vega': '0.063157',
#   'volume': 1876},
#  {'_id': '2020-02-21_350.0000_2019-09-19T00:05:35.516791Z',
#   'adjusted_mark_price': '0.020000',
#   'ask_price': '0.020000',
#   'ask_size': 10353,
#   'bid_price': '0.010000',
#   'bid_size': 977,
#   'break_even_price': '350.020000',
#   'chain_id': 'c277b118-58d9-4060-8dc5-a3b5898955cb',
#   'chain_symbol': 'SPY',
#   'chance_of_profit_long': '0.010731',
#   'chance_of_profit_short': '0.989269',
#   'created_at': '2019-09-19T00:05:35.516777Z',
#   'delta': '0.011283',
#   'expiration_date': '2020-02-21',
#   'gamma': '0.005707',
#   'high_fill_rate_buy_price': '0.020000',
#   'high_fill_rate_sell_price': '0.010000',
#   'high_price': '0.020000',
#   'id': 'd6059d8d-09bc-49de-ab99-20dbfd9b1283',
#   'implied_volatility': '0.110910',
#   'instrument': 'https://api.robinhood.com/options/instruments/d6059d8d-09bc-49de-ab99-20dbfd9b1283/',
#   'issue_date': '2005-01-06',
#   'last_trade_price': '337.600000',
#   'last_trade_size': 41,
#   'low_fill_rate_buy_price': '0.010000',
#   'low_fill_rate_sell_price': '0.020000',
#   'low_price': '0.010000',
#   'mark_price': '0.015000',
#   'min_ticks': {'above_tick': '0.01',
#    'below_tick': '0.01',
#    'cutoff_price': '0.00'},
#   'open_interest': 19402,
#   'previous_close_date': '2020-02-13',
#   'previous_close_price': '0.020000',
#   'rho': '0.000727',
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '350.0000',
#   'theta': '-0.011231',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-02-15T01:00:00Z',
#   'url': 'https://api.robinhood.com/options/instruments/d6059d8d-09bc-49de-ab99-20dbfd9b1283/',
#   'vega': '0.013849',
#   'volume': 1298},
#  {'_id': '2020-02-21_340.0000_2019-09-19T00:05:35.516696Z',
#   'adjusted_mark_price': '0.700000',
#   'ask_price': '0.700000',
#   'ask_size': 100,
#   'bid_price': '0.690000',
#   'bid_size': 399,
#   'break_even_price': '340.700000',
#   'chain_id': 'c277b118-58d9-4060-8dc5-a3b5898955cb',
#   'chain_symbol': 'SPY',
#   'chance_of_profit_long': '0.230955',
#   'chance_of_profit_short': '0.769045',
#   'created_at': '2019-09-19T00:05:35.516682Z',
#   'delta': '0.294009',
#   'expiration_date': '2020-02-21',
#   'gamma': '0.090626',
#   'high_fill_rate_buy_price': '0.700000',
#   'high_fill_rate_sell_price': '0.690000',
#   'high_price': '0.840000',
#   'id': '8949aa51-0584-411c-abf8-d60b8d81d799',
#   'implied_volatility': '0.081271',
#   'instrument': 'https://api.robinhood.com/options/instruments/8949aa51-0584-411c-abf8-d60b8d81d799/',
#   'issue_date': '2005-01-06',
#   'last_trade_price': '337.600000',
#   'last_trade_size': 1,
#   'low_fill_rate_buy_price': '0.690000',
#   'low_fill_rate_sell_price': '0.700000',
#   'low_price': '0.490000',
#   'mark_price': '0.695000',
#   'min_ticks': {'above_tick': '0.01',
#    'below_tick': '0.01',
#    'cutoff_price': '0.00'},
#   'open_interest': 77544,
#   'previous_close_date': '2020-02-13',
#   'previous_close_price': '0.820000',
#   'rho': '0.018910',
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '340.0000',
#   'theta': '-0.100293',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-02-15T01:00:00Z',
#   'url': 'https://api.robinhood.com/options/instruments/8949aa51-0584-411c-abf8-d60b8d81d799/',
#   'vega': '0.161134',
#   'volume': 33020}]

# %%
# Out:
# {'nIndexesWas': 1, 'ns': 'robinhood_data.ERIC.A', 'ok': 1.0}
