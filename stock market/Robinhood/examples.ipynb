# %%
import robin_stocks as r 
login = r.login('philip0massey','Rie1Hnd2*#')
ticker = 'ERIC'

# %%
r.get_historicals(ticker)
# Out:
# [{'begins_at': '2020-02-18T14:30:00Z',
#   'open_price': '8.990000',
#   'close_price': '8.982000',
#   'high_price': '9.000000',
#   'low_price': '8.970000',
#   'volume': 382981,
#   'session': 'reg',
#   'interpolated': False},
#  {'begins_at': '2020-02-18T14:40:00Z',
#   'open_price': '8.982200',
#   'close_price': '8.970000',
#   'high_price': '8.990000',
#   'low_price': '8.960000',
#   'volume': 104313,
#   'session': 'reg',
#   'interpolated': False},
#  {'begins_at': '2020-02-18T14:50:00Z',
#   'open_price': '8.970000',
#   'close_price': '8.955000',
#   'high_price': '8.980000',
#   'low_price': '8.954100',
#   'volume': 122630,
#   'session': 'reg',
#   'interpolated': False},
#  {'begins_at': '2020-02-18T15:00:00Z',
#   'open_price': '8.955000',
#   'close_price': '8.970000',
#   'high_price': '8.980000',
#   'low_price': '8.955000',
#   'volume': 95608,
#   'session': 'reg',
#   'interpolated': False},
#  {'begins_at': '2020-02-18T15:10:00Z',
# ...

# %%
r.get_pricebook_by_symbol(ticker)
# Out:
# {'asks': [],
#  'bids': [],
#  'instrument_id': 'ec79caa7-a327-47d7-8b9e-5dee219a5811',
#  'updated_at': '2020-02-16T20:08:53.491422139-05:00'}

# %%
r.find_instrument_data(ticker)
# Out:
# Found 1 results
# [{'id': 'ec79caa7-a327-47d7-8b9e-5dee219a5811',
#   'url': 'https://api.robinhood.com/instruments/ec79caa7-a327-47d7-8b9e-5dee219a5811/',
#   'quote': 'https://api.robinhood.com/quotes/ERIC/',
#   'fundamentals': 'https://api.robinhood.com/fundamentals/ERIC/',
#   'splits': 'https://api.robinhood.com/instruments/ec79caa7-a327-47d7-8b9e-5dee219a5811/splits/',
#   'state': 'active',
#   'market': 'https://api.robinhood.com/markets/XNAS/',
#   'simple_name': 'Ericsson',
#   'name': 'Ericsson American Depositary Shares',
#   'tradeable': True,
#   'tradability': 'tradable',
#   'symbol': 'ERIC',
#   'bloomberg_unique': 'EQ0011570500009000',
#   'margin_initial_ratio': '0.5000',
#   'maintenance_ratio': '0.2500',
#   'country': 'SE',
#   'day_trade_ratio': '0.2500',
#   'list_date': '1990-01-02',
#   'min_tick_size': None,
#   'type': 'adr',
#   'tradable_chain_id': 'c6290d12-0c75-437a-8daa-e1d233a66347',
#   'rhs_tradability': 'tradable',
# ...

# %%
r.get_news(ticker)
# Out:
# [{'api_source': '',
#   'author': '',
#   'num_clicks': 186,
#   'preview_image_url': 'https://images.robinhood.com/Q_',
#   'published_at': '2020-02-13T16:39:00Z',
#   'relay_url': 'https://news.robinhood.com/bd91bd75-a207-326f-9588-4171c2c5f50a/',
#   'source': 'VentureBeat',
#   'summary': '',
#   'title': 'Ericsson breaks 5G millimeter wave speed record with 4.3Gbps downloads',
#   'updated_at': '2020-02-13T17:10:54.761100Z',
#   'url': 'https://venturebeat.com/2020/02/13/ericsson-breaks-5g-millimeter-wave-speed-record-with-4-3gbps-downloads/',
#   'uuid': 'bd91bd75-a207-326f-9588-4171c2c5f50a',
#   'related_instruments': ['ec79caa7-a327-47d7-8b9e-5dee219a5811'],
# ...

# %%
r.get_events(ticker)
# Out:
# []

# %%
r.get_popularity(ticker)
# Out:
# {'instrument': 'https://api.robinhood.com/instruments/ec79caa7-a327-47d7-8b9e-5dee219a5811/',
#  'num_open_positions': 13085}

# %%
r.get_ratings(ticker)
# Out:
# {'summary': {'num_buy_ratings': 16,
#   'num_hold_ratings': 10,
#   'num_sell_ratings': 0},
#  'ratings': [{'published_at': '2020-02-01T01:07:34Z',
#    'type': 'sell',
#    'text': b"Software and service firms may attempt to undercut Ericsson's offerings during contract renewals. If CSPs view hardware as commodities, then differentiation may become increasingly difficult."},
#   {'published_at': '2020-02-01T01:07:34Z',
#    'type': 'buy',
#    'text': b"Income sources could diversify as licensing revenue from 5G patents may grow through applications outside of Ericsson's handset manufacturer agreements."},
#   {'published_at': '2020-02-01T01:07:34Z',
#    'type': 'sell',
#    'text': b"Pricing erosion may occur as aggressive competitors like Huawei, ZTE, and Samsung vie for CSP contracts. Ericsson's margin expansion aspirations could be thwarted in a combative pricing environment."},
#   {'published_at': '2020-02-01T01:07:34Z',
#    'type': 'sell',
# ...

# %%
r.get_quotes(ticker)[0]['last_trade_price']
r.get_quotes(ticker)
# Out:
# [{'ask_price': '9.350000',
#   'ask_size': 25,
#   'bid_price': '9.000000',
#   'bid_size': 50,
#   'last_trade_price': '9.080000',
#   'last_extended_hours_trade_price': '9.050000',
#   'previous_close': '9.080000',
#   'adjusted_previous_close': '9.080000',
#   'previous_close_date': '2020-02-13',
#   'symbol': 'ERIC',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-02-15T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/ec79caa7-a327-47d7-8b9e-5dee219a5811/'}]

# %%
r.get_fundamentals(ticker)
# Out:
# [{'open': '8.540000',
#   'high': '8.880000',
#   'low': '8.510000',
#   'volume': '26623312.000000',
#   'average_volume_2_weeks': '10861028.300000',
#   'average_volume': '10861028.300000',
#   'high_52_weeks': '10.460000',
#   'dividend_yield': '0.746860',
#   'float': '3052400000.000000',
#   'low_52_weeks': '7.580000',
#   'market_cap': '27227004428.000000',
#   'pb_ratio': '3.461400',
#   'pe_ratio': None,
#   'shares_outstanding': '3052400000.000000',
# ...
