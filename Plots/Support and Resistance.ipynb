# %% [markdown]
# # Support & Resistance

# %%
import sys; print('Python %s on %s' % (sys.version, sys.platform))
sys.path.extend(['/Users/philipmassey/PycharmProjects/stock_market'])
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import matplotlib.dates as mpl_dates
import matplotlib.pyplot as plt

plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = [15, 8]
plt.rc('font', size=14)

import plots as p
# Out:
# Python 3.7.3 (v3.7.3:ef4ec6ed12, Mar 25 2019, 16:52:21)
# [Clang 6.0 (clang-600.0.57)] on darwin

# %%
# period :   1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,ytd,max
name = 'ENPH'
p.plotSupportAndResistance(name,'3mo')
p.plotSupportAndResistance(name,'6mo')
p.plotSupportAndResistance(name,'1y')

# %%
import yfinance as yf
ticker = yf.Ticker(name)
longName = ticker.info['longName']
title = '{} suport and resistance for last {}'.format(longName,'6mo')
title
# Out:
# 'The Home Depot, Inc. suport and resistance for last 6mo'
