# %%
import sys; print('Python %s on %s' % (sys.version, sys.platform))
sys.path.extend(['/Users/philipmassey/PycharmProjects/stock_market'])
import portfolio as pf
import pandas as pd
import plots as pl
# Out:
# Python 3.7.3 (v3.7.3:ef4ec6ed12, Mar 25 2019, 16:52:21)
# [Clang 6.0 (clang-600.0.57)] on darwin

# %%
ndays=0
df_stock,enddt = pf.getStockPercentVolPort(ndays)
df_stock.groupby(['portfolio']).agg({'percent': ['mean', 'count']})
# Out:
# Tuesday 2020-11-10 Tuesday 2020-11-10
#                        percent
#                           mean count
# portfolio
# 5G                         0.0    17
# ATACKX                     0.0     4
# Alternate Medicine         0.0    17
# Artificial Inteligence     0.0     5
# Basic Material             0.0     8
# Biotech Breakthough        0.0     1
# Biotech Emerging           0.0    15
# Biotechnology              0.0    12
# Bonds                      0.0     8
# CEF                        0.0    13
# Cannabis                   0.0    11
# Cloud Enterprise Apps      0.0     6
# Cloud Retail Apps          0.0     6
# Communication Services     0.0     7
# Corporate Bonds            0.0     6
# Dividend                   0.0     2
# ESG                        0.0     7
# Electric Vehicles          0.0     8
# Electricity                0.0     6
# Electricity Solar          0.0    10
# Electricity Wind           0.0     9
# Emerging Markets           0.0     6
# ...

# %%
df_stock[df_stock['portfolio']=='World Stock Markets']
# Out:
#       percent     volume            portfolio
# EDEN      0.0   230817.0  World Stock Markets
# EFNL      0.0   203573.0  World Stock Markets
# EIRL      0.0     4004.0  World Stock Markets
# EWK       0.0    10103.0  World Stock Markets
# EWN       0.0   211048.0  World Stock Markets
# EWO       0.0    13319.0  World Stock Markets
# EWT       0.0  4717928.0  World Stock Markets
# EWY       0.0  4168464.0  World Stock Markets
# GXC       0.0   443079.0  World Stock Markets

# %%
l = df_stock[df_stock['portfolio']=='World Stock Markets'].percent.values
print(sum(l),len(l),sum(l)/len(l))
[print(i) for i in l]
