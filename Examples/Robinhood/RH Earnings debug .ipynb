# %% [markdown]
# # RH Earnings

# %%
import sys; print('Python %s on %s' % (sys.version, sys.platform))
sys.path.extend(['/Users/philipmassey/PycharmProjects/stock_market'])
import portfolio as pf
import market_data as md
import robin_stocks as r

import pandas as pd
import rh
r = rh.r
# Out:
# Python 3.7.3 (v3.7.3:ef4ec6ed12, Mar 25 2019, 16:52:21)
# [Clang 6.0 (clang-600.0.57)] on darwin

# %%
def fltrempty(e):
    return True if len(e[1])>0 else False

def getEarnings(positions):
    #symbols = list(map(lambda e: e.upper(), symbols))
    current_year_dates = []
    for symbol in positions:
        try:
            earnings = r.get_earnings(symbol=symbol)
            # print(earnings)
            if len(earnings) > 0:
                # current_year = list(filter(lambda e:e['year']==2020, earnings))
                earnings = list(filter(lambda e: e['report'] != None, earnings))
                current_year = list(filter(lambda e: e['report']['date'][0:4] == '2021', earnings))
                earnings_dates = list(map(lambda e: e['report']['date'], current_year))
                earnings_dates = list(filter(lambda e: e[5:7] > '00', earnings_dates))
                # print(earnings_date)
                current_year_dates.append((symbol, earnings_dates))
            else:
                print(symbol, 'no earnings')
        except Exception as e:
            print('skipped', symbol, e)
        
        current_year_dates= list(filter(filteremptyearn,current_year_dates))
        current_year_dates = sorted(current_year_dates, key=lambda x: x[1][0])
    return current_year_dates

#     for e in current_year_dates:
#         print(e[0], '\t', e[1])

# %%
symbols = md.getPortfoliosSymbols()
#symbols = ['AAPL','ENPH']
#s = pd.Series(np.random.randn(5), index=["a", "b", "c", "d", "e"])
current_year_dates = getEarnings(symbols)
# Out:
# WUGI no earnings
# ARKF no earnings
# ARKG no earnings
# ARKK no earnings
# ARKQ no earnings
# ARKW no earnings
# IJR no earnings
# SCHA no earnings
# SPSM no earnings
# URTY no earnings
# 400 Client Error: Bad Request for url: https://api.robinhood.com/marketdata/earnings/?symbol=BKLLF
# BKLLF no earnings
# EHVVF no earnings
# 400 Client Error: Bad Request for url: https://api.robinhood.com/marketdata/earnings/?symbol=FTRPF
# FTRPF no earnings
# 400 Client Error: Bad Request for url: https://api.robinhood.com/marketdata/earnings/?symbol=GTSIF
# GTSIF no earnings
# 400 Client Error: Bad Request for url: https://api.robinhood.com/marketdata/earnings/?symbol=HAVLF
# HAVLF no earnings
# 400 Client Error: Bad Request for url: https://api.robinhood.com/marketdata/earnings/?symbol=HSTRF
# HSTRF no earnings
# 400 Client Error: Bad Request for url: https://api.robinhood.com/marketdata/earnings/?symbol=LKYSF
# LKYSF no earnings
# 400 Client Error: Bad Request for url: https://api.robinhood.com/marketdata/earnings/?symbol=MMEDF
# MMEDF no earnings
# 400 Client Error: Bad Request for url: https://api.robinhood.com/marketdata/earnings/?symbol=MMNFF
# MMNFF no earnings
# 400 Client Error: Bad Request for url: https://api.robinhood.com/marketdata/earnings/?symbol=MYCOF
# MYCOF no earnings
# 400 Client Error: Bad Request for url: https://api.robinhood.com/marketdata/earnings/?symbol=PEMTF
# PEMTF no earnings
# 400 Client Error: Bad Request for url: https://api.robinhood.com/marketdata/earnings/?symbol=RVVTF
# RVVTF no earnings
# 400 Client Error: Bad Request for url: https://api.robinhood.com/marketdata/earnings/?symbol=SHRMF
# SHRMF no earnings
# 400 Client Error: Bad Request for url: https://api.robinhood.com/marketdata/earnings/?symbol=SPLIF
# SPLIF no earnings
# 400 Client Error: Bad Request for url: https://api.robinhood.com/marketdata/earnings/?symbol=TRMNF
# TRMNF no earnings
# 400 Client Error: Bad Request for url: https://api.robinhood.com/marketdata/earnings/?symbol=TRUFF
# TRUFF no earnings
# 400 Client Error: Bad Request for url: https://api.robinhood.com/marketdata/earnings/?symbol=VEGGF
# VEGGF no earnings
# PALL no earnings
# BIL no earnings
# ICVT no earnings
# IEF no earnings
# SHV no earnings
# TLT no earnings
# USHY no earnings
# VGSH no earnings
# ZROZ no earnings
# AOD no earnings
# BME no earnings
# CHY no earnings
# CRF no earnings
# DFP no earnings
# FPE no earnings
# HQH no earnings
# HQL no earnings
# PTY no earnings
# THQ no earnings
# THW no earnings
# 400 Client Error: Bad Request for url: https://api.robinhood.com/marketdata/earnings/?symbol=CRLBF
# CRLBF no earnings
# 400 Client Error: Bad Request for url: https://api.robinhood.com/marketdata/earnings/?symbol=CURLF
# CURLF no earnings
# 400 Client Error: Bad Request for url: https://api.robinhood.com/marketdata/earnings/?symbol=GTBIF
# GTBIF no earnings
# 400 Client Error: Bad Request for url: https://api.robinhood.com/marketdata/earnings/?symbol=NXGB
# NXGB no earnings
# 400 Client Error: Bad Request for url: https://api.robinhood.com/marketdata/earnings/?symbol=TCNNF
# TCNNF no earnings
# 400 Client Error: Bad Request for url: https://api.robinhood.com/marketdata/earnings/?symbol=VREOF
# VREOF no earnings
# TCEHY no earnings
# TDF no earnings
# 400 Client Error: Bad Request for url: https://api.robinhood.com/marketdata/earnings/?symbol=DOCRF
# DOCRF no earnings
# ANGL no earnings
# FDHY no earnings
# FLDR no earnings
# LQD no earnings
# VCLT no earnings
# VCSH no earnings
# FFC no earnings
# FLC no earnings
# EAGG no earnings
# ESGD no earnings
# ESGE no earnings
# ESGU no earnings
# ESML no earnings
# SUSB no earnings
# SUSC no earnings
# 400 Client Error: Bad Request for url: https://api.robinhood.com/marketdata/earnings/?symbol=BYDDF
# BYDDF no earnings
# 400 Client Error: Bad Request for url: https://api.robinhood.com/marketdata/earnings/?symbol=DDAIF
# DDAIF no earnings
# SIEGY no earnings
# TAN no earnings
# 400 Client Error: Bad Request for url: https://api.robinhood.com/marketdata/earnings/?symbol=DNNGY
# DNNGY no earnings
# FAN no earnings
# 400 Client Error: Bad Request for url: https://api.robinhood.com/marketdata/earnings/?symbol=GCTAF
# GCTAF no earnings
# 400 Client Error: Bad Request for url: https://api.robinhood.com/marketdata/earnings/?symbol=GCTAY
# GCTAY no earnings
# VWDRY no earnings
# PZD no earnings
# FTCS no earnings
# FVC no earnings
# IFV no earnings
# QQQ no earnings
# RORO no earnings
# SPHB no earnings
# SPHD no earnings
# SPY no earnings
# SWAN no earnings
# VEGA no earnings
# FHLC no earnings
# ITB no earnings
# TTNDY no earnings
# BOTZ no earnings
# SNSR no earnings
# VUG no earnings
# EIDO no earnings
# EWT no earnings
# EWY no earnings
# GXC no earnings
# INDA no earnings
# THD no earnings
# EEM no earnings
# EEMA no earnings
# EEMO no earnings
# EMQQ no earnings
# IEMG no earnings
# VWO no earnings
# EDEN no earnings
# EFNL no earnings
# EIRL no earnings
# EWK no earnings
# EWN no earnings
# EWUS no earnings
# EWO no earnings
# JETS no earnings

# %%
current_year_dates

#current_year_dates = sorted(current_year_dates, key=lambda x: x[1][0])
for e in current_year_dates:
    print(e[0], '\t', e[1])
# Out:
# DCT 	 ['2021-01-07']
# MU 	 ['2021-01-07', '2021-03-24', '2021-06-28']
# OGI 	 ['2021-01-12', '2021-04-13']
# KBH 	 ['2021-01-12', '2021-03-25', '2021-06-23']
# TSM 	 ['2021-01-14', '2021-04-15']
# DAL 	 ['2021-01-14', '2021-04-21']
# C 	 ['2021-01-15', '2021-04-15']
# JPM 	 ['2021-01-15', '2021-04-14']
# BAC 	 ['2021-01-19', '2021-04-14']
# CCL 	 ['2021-01-19', '2021-01-30', '2021-03-18', '2021-06-17']
# UNH 	 ['2021-01-20', '2021-04-14']
# UAL 	 ['2021-01-20', '2021-04-29']
# FCEL 	 ['2021-01-21', '2021-02-01', '2021-03-15', '2021-06-08']
# INTC 	 ['2021-01-21', '2021-04-22']
# STX 	 ['2021-01-21', '2021-04-21']
# XLNX 	 ['2021-01-25', '2021-04-21']
# AGNC 	 ['2021-01-25', '2021-04-28']
# SALT 	 ['2021-01-25', '2021-05-10']
# FCX 	 ['2021-01-26', '2021-04-23']
# NVS 	 ['2021-01-26', '2021-04-27']
# NEE 	 ['2021-01-26', '2021-04-21']
# NEP 	 ['2021-01-26', '2021-04-21']
# AXP 	 ['2021-01-26', '2021-04-23']
# DHI 	 ['2021-01-26', '2021-04-27']
# ROK 	 ['2021-01-26', '2021-04-27']
# GE 	 ['2021-01-26', '2021-04-28']
# MSFT 	 ['2021-01-26', '2021-04-28']
# AMD 	 ['2021-01-26', '2021-04-27']
# TXN 	 ['2021-01-26', '2021-04-20']
# CMRE 	 ['2021-01-26', '2021-04-28']
# CALX 	 ['2021-01-27', '2021-04-27']
# ILMN 	 ['2021-01-27', '2021-04-29']
# TSLA 	 ['2021-01-27', '2021-04-28']
# ANTM 	 ['2021-01-27', '2021-04-28']
# APH 	 ['2021-01-27', '2021-04-21']
# CREE 	 ['2021-01-27', '2021-04-28']
# AAPL 	 ['2021-01-27', '2021-04-29']
# CCI 	 ['2021-01-27', '2021-04-28']
# SLG 	 ['2021-01-27', '2021-04-21']
# LRCX 	 ['2021-01-27', '2021-04-21']
# DHR 	 ['2021-01-28', '2021-05-05']
# MA 	 ['2021-01-28', '2021-04-28']
# V 	 ['2021-01-28', '2021-04-29']
# NVR 	 ['2021-01-28', '2021-04-22']
# PHM 	 ['2021-01-28', '2021-04-22']
# AMZN 	 ['2021-01-28', '2021-04-29']
# SWKS 	 ['2021-01-28', '2021-05-03']
# LUV 	 ['2021-01-28', '2021-04-27']
# ERIC 	 ['2021-01-29', '2021-04-21']
# PLG 	 ['2021-01-29', '2021-04-07']
# LLY 	 ['2021-01-29', '2021-04-22']
# HON 	 ['2021-01-29', '2021-04-30']
# JCI 	 ['2021-01-29', '2021-04-30']
# ROP 	 ['2021-01-29', '2021-04-27']
# NXPI 	 ['2021-02-01', '2021-04-26']
# SSD 	 ['2021-02-01', '2021-04-26']
# IPHI 	 ['2021-02-02', '2021-05-06']
# LITE 	 ['2021-02-02', '2021-05-04']
# PKI 	 ['2021-02-02', '2021-05-04']
# AMGN 	 ['2021-02-02', '2021-04-29']
# GILD 	 ['2021-02-02', '2021-04-29']
# PFE 	 ['2021-02-02', '2021-04-27']
# BPY 	 ['2021-02-02', '2021-05-07']
# ST 	 ['2021-02-02', '2021-04-28']
# GOOG 	 ['2021-02-02', '2021-04-27']
# RCL 	 ['2021-02-02', '2021-05-19']
# ADTN 	 ['2021-02-03', '2021-05-05']
# MXL 	 ['2021-02-03', '2021-04-28']
# QRVO 	 ['2021-02-03', '2021-05-06']
# ALGN 	 ['2021-02-03', '2021-04-28']
# ABBV 	 ['2021-02-03', '2021-04-30']
# INVA 	 ['2021-02-03', '2021-04-28']
# NVO 	 ['2021-02-03', '2021-05-05']
# TWLO 	 ['2021-02-03', '2021-05-05']
# PAYC 	 ['2021-02-03', '2021-04-27']
# BIP 	 ['2021-02-03', '2021-05-07']
# HUM 	 ['2021-02-03', '2021-04-28']
# DGII 	 ['2021-02-03', '2021-05-06']
# MPWR 	 ['2021-02-03', '2021-04-27']
# TWO 	 ['2021-02-03', '2021-05-05']
# KLAC 	 ['2021-02-03', '2021-05-04']
# QCOM 	 ['2021-02-03', '2021-04-28']
# CPLP 	 ['2021-02-03', '2021-05-05']
# TZOO 	 ['2021-02-03', '2021-02-19', '2021-06-24']
# AVNW 	 ['2021-02-04', '2021-05-11']
# BMY 	 ['2021-02-04', '2021-05-06']
# REGN 	 ['2021-02-04', '2021-05-04']
# PCTY 	 ['2021-02-04', '2021-05-06']
# BEP 	 ['2021-02-04', '2021-05-05']
# CI 	 ['2021-02-04', '2021-04-29']
# MRK 	 ['2021-02-04', '2021-04-27']
# DX 	 ['2021-02-04']
# CLSK 	 ['2021-02-05', '2021-05-05']
# NUAN 	 ['2021-02-08', '2021-05-06']
# AMKR 	 ['2021-02-08', '2021-04-26']
# DAC 	 ['2021-02-08', '2021-05-17']
# IIVI 	 ['2021-02-09', '2021-05-10']
# CGC 	 ['2021-02-09', '2021-05-28']
# AYX 	 ['2021-02-09', '2021-05-05']
# CNC 	 ['2021-02-09', '2021-04-27']
# THC 	 ['2021-02-09', '2021-05-03']
# MAS 	 ['2021-02-09', '2021-04-28']
# JLL 	 ['2021-02-09', '2021-05-04']
# UDR 	 ['2021-02-09', '2021-05-05']
# MMYT 	 ['2021-02-09', '2021-06-25']
# CRSP 	 ['2021-02-10', '2021-04-27']
# EXEL 	 ['2021-02-10', '2021-05-04']
# GM 	 ['2021-02-10', '2021-05-05']
# BE 	 ['2021-02-10', '2021-05-10']
# SPWR 	 ['2021-02-10', '2021-05-06']
# LTRX 	 ['2021-02-10', '2021-05-13']
# PI 	 ['2021-02-10', '2021-04-26']
# EQIX 	 ['2021-02-10', '2021-05-05']
# NLY 	 ['2021-02-10', '2021-04-28']
# TRIP 	 ['2021-02-10', '2021-05-06']
# AZN 	 ['2021-02-11', '2021-04-28']
# BIO 	 ['2021-02-11', '2021-05-05']
# SHOP 	 ['2021-02-11', '2021-05-05']
# NET 	 ['2021-02-11', '2021-05-06']
# GNRC 	 ['2021-02-11', '2021-04-29']
# AZRE 	 ['2021-02-11', '2021-06-11']
# BAM 	 ['2021-02-11', '2021-05-13']
# DXCM 	 ['2021-02-11', '2021-04-27']
# SWIR 	 ['2021-02-11', '2021-05-06']
# DIS 	 ['2021-02-11', '2021-05-04']
# EXPE 	 ['2021-02-11', '2021-05-19']
# MGM 	 ['2021-02-11', '2021-04-29']
# IPGP 	 ['2021-02-12', '2021-05-04']
# WWR 	 ['2021-02-12', '2021-05-13']
# CEVA 	 ['2021-02-16', '2021-05-10']
# TXG 	 ['2021-02-16', '2021-05-10']
# ENPH 	 ['2021-02-16', '2021-05-04']
# ALB 	 ['2021-02-17', '2021-05-05']
# FSLY 	 ['2021-02-17', '2021-05-05']
# SEDG 	 ['2021-02-17', '2021-05-05']
# UFPI 	 ['2021-02-17', '2021-04-21']
# ARR 	 ['2021-02-17', '2021-04-29']
# NVDA 	 ['2021-02-17', '2021-05-20']
# ATCO 	 ['2021-02-17', '2021-05-04']
# SBLK 	 ['2021-02-17', '2021-05-25']
# SBAC 	 ['2021-02-18', '2021-05-04']
# EGO 	 ['2021-02-18', '2021-04-29']
# HBM 	 ['2021-02-18', '2021-05-13']
# RGEN 	 ['2021-02-18', '2021-05-05']
# ZS 	 ['2021-02-18', '2021-05-27']
# BAND 	 ['2021-02-18', '2021-04-29']
# VG 	 ['2021-02-18', '2021-05-06']
# FSLR 	 ['2021-02-18', '2021-05-06']
# HASI 	 ['2021-02-18', '2021-05-06']
# CNDT 	 ['2021-02-18', '2021-05-06']
# FND 	 ['2021-02-18', '2021-04-29']
# IDCC 	 ['2021-02-18', '2021-05-06']
# ORC 	 ['2021-02-18', '2021-04-07']
# NCLH 	 ['2021-02-18', '2021-05-13']
# EVER 	 ['2021-02-22', '2021-05-03']
# INFN 	 ['2021-02-23', '2021-05-11']
# HALO 	 ['2021-02-23', '2021-05-10']
# IOVA 	 ['2021-02-23', '2021-05-04']
# SQ 	 ['2021-02-23', '2021-05-05']
# ORA 	 ['2021-02-23', '2021-05-10']
# BLD 	 ['2021-02-23', '2021-05-04']
# TOL 	 ['2021-02-23', '2021-05-26']
# HD 	 ['2021-02-23', '2021-05-18']
# ALRM 	 ['2021-02-23', '2021-05-06']
# DMRC 	 ['2021-02-24', '2021-04-28']
# ACAD 	 ['2021-02-24', '2021-05-06']
# MRNA 	 ['2021-02-24', '2021-05-06']
# ETSY 	 ['2021-02-24', '2021-05-05']
# LYG 	 ['2021-02-24', '2021-04-29']
# LOW 	 ['2021-02-24', '2021-05-19']
# LMND 	 ['2021-02-24', '2021-05-10']
# BKNG 	 ['2021-02-24', '2021-05-06']
# AMRN 	 ['2021-02-25', '2021-04-12']
# RUN 	 ['2021-02-25', '2021-05-05']
# BWEN 	 ['2021-02-25', '2021-05-07']
# TPIC 	 ['2021-02-25', '2021-05-06']
# CWEN 	 ['2021-02-25', '2021-05-06']
# NPTN 	 ['2021-02-25', '2021-04-29']
# AMT 	 ['2021-02-25', '2021-04-28']
# SABR 	 ['2021-02-25', '2021-05-07']
# ROCK 	 ['2021-02-26', '2021-05-05']
# CRON 	 ['2021-03-01', '2021-05-07']
# LU 	 ['2021-03-01', '2021-05-25']
# AMBA 	 ['2021-03-02', '2021-06-01']
# VEEV 	 ['2021-03-02', '2021-05-27']
# CDLX 	 ['2021-03-02', '2021-05-10']
# ZM 	 ['2021-03-03', '2021-06-01']
# BLDP 	 ['2021-03-03', '2021-05-04']
# PING 	 ['2021-03-03', '2021-05-05']
# FTHM 	 ['2021-03-03', '2021-05-11']
# MRVL 	 ['2021-03-04', '2021-05-27']
# OKTA 	 ['2021-03-04', '2021-05-27']
# PLUG 	 ['2021-03-04', '2021-05-06']
# GSL 	 ['2021-03-04', '2021-05-11']
# WPM 	 ['2021-03-10', '2021-05-05']
# WKHS 	 ['2021-03-10', '2021-05-05']
# DQ 	 ['2021-03-10', '2021-05-19']
# AVGO 	 ['2021-03-11', '2021-06-03']
# INO 	 ['2021-03-11', '2021-05-10']
# NVAX 	 ['2021-03-11', '2021-05-10']
# KIRK 	 ['2021-03-11', '2021-06-03']
# MDLA 	 ['2021-03-11', '2021-06-01']
# JKS 	 ['2021-03-12', '2021-06-14']
# CMPS 	 ['2021-03-15', '2021-04-29']
# AVRO 	 ['2021-03-15', '2021-05-06']
# HEXO 	 ['2021-03-15', '2021-03-29', '2021-06-10']
# LI 	 ['2021-03-15', '2021-05-14']
# XPEV 	 ['2021-03-15', '2021-05-08']
# SEEL 	 ['2021-03-16', '2021-05-06']
# SDGR 	 ['2021-03-16', '2021-05-12']
# BEKE 	 ['2021-03-16', '2021-05-14']
# NIO 	 ['2021-03-17', '2021-05-27']
# FUTU 	 ['2021-03-17', '2021-03-17']
# CRWD 	 ['2021-03-18', '2021-06-01']
# LEN 	 ['2021-03-18', '2021-06-14']
# PXS 	 ['2021-03-18', '2021-06-02']
# ADBE 	 ['2021-03-23', '2021-06-10']
# SOLO 	 ['2021-03-24', '2021-05-15']
# HOME 	 ['2021-03-24', '2021-06-17']
# CSIQ 	 ['2021-03-25', '2021-05-27']
# RH 	 ['2021-03-30', '2021-06-03']
# BLNK 	 ['2021-03-31', '2021-05-12']
# FVRR 	 ['2021-05-06', '2021-02-18']

# %%
for e in current_year_dates:
         print(e[0], '\t', e[1])
# Out:
# DCT 	 ['2021-01-07']
# MU 	 ['2021-01-07', '2021-03-24', '2021-06-28']
# KBH 	 ['2021-01-12', '2021-03-25', '2021-06-23']
# OGI 	 ['2021-01-12', '2021-04-13']
# TSM 	 ['2021-01-14', '2021-04-15']
# DAL 	 ['2021-01-14', '2021-04-21']
# JPM 	 ['2021-01-15', '2021-04-14']
# C 	 ['2021-01-15', '2021-04-15']
# CCL 	 ['2021-01-19', '2021-01-30', '2021-03-18', '2021-06-17']
# BAC 	 ['2021-01-19', '2021-04-14']
# UNH 	 ['2021-01-20', '2021-04-14']
# UAL 	 ['2021-01-20', '2021-04-29']
# FCEL 	 ['2021-01-21', '2021-02-01', '2021-03-15', '2021-06-08']
# STX 	 ['2021-01-21', '2021-04-21']
# INTC 	 ['2021-01-21', '2021-04-22']
# XLNX 	 ['2021-01-25', '2021-04-21']
# AGNC 	 ['2021-01-25', '2021-04-28']
# SALT 	 ['2021-01-25', '2021-05-10']
# TXN 	 ['2021-01-26', '2021-04-20']
# NEE 	 ['2021-01-26', '2021-04-21']
# NEP 	 ['2021-01-26', '2021-04-21']
# FCX 	 ['2021-01-26', '2021-04-23']
# AXP 	 ['2021-01-26', '2021-04-23']
# NVS 	 ['2021-01-26', '2021-04-27']
# DHI 	 ['2021-01-26', '2021-04-27']
# ROK 	 ['2021-01-26', '2021-04-27']
# AMD 	 ['2021-01-26', '2021-04-27']
# GE 	 ['2021-01-26', '2021-04-28']
# MSFT 	 ['2021-01-26', '2021-04-28']
# CMRE 	 ['2021-01-26', '2021-04-28']
# APH 	 ['2021-01-27', '2021-04-21']
# SLG 	 ['2021-01-27', '2021-04-21']
# LRCX 	 ['2021-01-27', '2021-04-21']
# CALX 	 ['2021-01-27', '2021-04-27']
# TSLA 	 ['2021-01-27', '2021-04-28']
# ANTM 	 ['2021-01-27', '2021-04-28']
# CREE 	 ['2021-01-27', '2021-04-28']
# CCI 	 ['2021-01-27', '2021-04-28']
# ILMN 	 ['2021-01-27', '2021-04-29']
# AAPL 	 ['2021-01-27', '2021-04-29']
# NVR 	 ['2021-01-28', '2021-04-22']
# PHM 	 ['2021-01-28', '2021-04-22']
# LUV 	 ['2021-01-28', '2021-04-27']
# MA 	 ['2021-01-28', '2021-04-28']
# V 	 ['2021-01-28', '2021-04-29']
# AMZN 	 ['2021-01-28', '2021-04-29']
# SWKS 	 ['2021-01-28', '2021-05-03']
# DHR 	 ['2021-01-28', '2021-05-05']
# PLG 	 ['2021-01-29', '2021-04-07']
# ERIC 	 ['2021-01-29', '2021-04-21']
# LLY 	 ['2021-01-29', '2021-04-22']
# ROP 	 ['2021-01-29', '2021-04-27']
# HON 	 ['2021-01-29', '2021-04-30']
# JCI 	 ['2021-01-29', '2021-04-30']
# NXPI 	 ['2021-02-01', '2021-04-26']
# SSD 	 ['2021-02-01', '2021-04-26']
# PFE 	 ['2021-02-02', '2021-04-27']
# GOOG 	 ['2021-02-02', '2021-04-27']
# ST 	 ['2021-02-02', '2021-04-28']
# AMGN 	 ['2021-02-02', '2021-04-29']
# GILD 	 ['2021-02-02', '2021-04-29']
# LITE 	 ['2021-02-02', '2021-05-04']
# PKI 	 ['2021-02-02', '2021-05-04']
# IPHI 	 ['2021-02-02', '2021-05-06']
# BPY 	 ['2021-02-02', '2021-05-07']
# RCL 	 ['2021-02-02', '2021-05-19']
# TZOO 	 ['2021-02-03', '2021-02-19', '2021-06-24']
# PAYC 	 ['2021-02-03', '2021-04-27']
# MPWR 	 ['2021-02-03', '2021-04-27']
# MXL 	 ['2021-02-03', '2021-04-28']
# ALGN 	 ['2021-02-03', '2021-04-28']
# INVA 	 ['2021-02-03', '2021-04-28']
# HUM 	 ['2021-02-03', '2021-04-28']
# QCOM 	 ['2021-02-03', '2021-04-28']
# ABBV 	 ['2021-02-03', '2021-04-30']
# KLAC 	 ['2021-02-03', '2021-05-04']
# ADTN 	 ['2021-02-03', '2021-05-05']
# NVO 	 ['2021-02-03', '2021-05-05']
# TWLO 	 ['2021-02-03', '2021-05-05']
# TWO 	 ['2021-02-03', '2021-05-05']
# CPLP 	 ['2021-02-03', '2021-05-05']
# QRVO 	 ['2021-02-03', '2021-05-06']
# DGII 	 ['2021-02-03', '2021-05-06']
# BIP 	 ['2021-02-03', '2021-05-07']
# DX 	 ['2021-02-04']
# MRK 	 ['2021-02-04', '2021-04-27']
# CI 	 ['2021-02-04', '2021-04-29']
# REGN 	 ['2021-02-04', '2021-05-04']
# BEP 	 ['2021-02-04', '2021-05-05']
# BMY 	 ['2021-02-04', '2021-05-06']
# PCTY 	 ['2021-02-04', '2021-05-06']
# AVNW 	 ['2021-02-04', '2021-05-11']
# CLSK 	 ['2021-02-05', '2021-05-05']
# AMKR 	 ['2021-02-08', '2021-04-26']
# NUAN 	 ['2021-02-08', '2021-05-06']
# DAC 	 ['2021-02-08', '2021-05-17']
# CNC 	 ['2021-02-09', '2021-04-27']
# MAS 	 ['2021-02-09', '2021-04-28']
# THC 	 ['2021-02-09', '2021-05-03']
# JLL 	 ['2021-02-09', '2021-05-04']
# AYX 	 ['2021-02-09', '2021-05-05']
# UDR 	 ['2021-02-09', '2021-05-05']
# IIVI 	 ['2021-02-09', '2021-05-10']
# CGC 	 ['2021-02-09', '2021-05-28']
# MMYT 	 ['2021-02-09', '2021-06-25']
# PI 	 ['2021-02-10', '2021-04-26']
# CRSP 	 ['2021-02-10', '2021-04-27']
# NLY 	 ['2021-02-10', '2021-04-28']
# EXEL 	 ['2021-02-10', '2021-05-04']
# GM 	 ['2021-02-10', '2021-05-05']
# EQIX 	 ['2021-02-10', '2021-05-05']
# SPWR 	 ['2021-02-10', '2021-05-06']
# TRIP 	 ['2021-02-10', '2021-05-06']
# BE 	 ['2021-02-10', '2021-05-10']
# LTRX 	 ['2021-02-10', '2021-05-13']
# DXCM 	 ['2021-02-11', '2021-04-27']
# AZN 	 ['2021-02-11', '2021-04-28']
# GNRC 	 ['2021-02-11', '2021-04-29']
# MGM 	 ['2021-02-11', '2021-04-29']
# DIS 	 ['2021-02-11', '2021-05-04']
# BIO 	 ['2021-02-11', '2021-05-05']
# SHOP 	 ['2021-02-11', '2021-05-05']
# NET 	 ['2021-02-11', '2021-05-06']
# SWIR 	 ['2021-02-11', '2021-05-06']
# BAM 	 ['2021-02-11', '2021-05-13']
# EXPE 	 ['2021-02-11', '2021-05-19']
# AZRE 	 ['2021-02-11', '2021-06-11']
# IPGP 	 ['2021-02-12', '2021-05-04']
# WWR 	 ['2021-02-12', '2021-05-13']
# ENPH 	 ['2021-02-16', '2021-05-04']
# CEVA 	 ['2021-02-16', '2021-05-10']
# TXG 	 ['2021-02-16', '2021-05-10']
# UFPI 	 ['2021-02-17', '2021-04-21']
# ARR 	 ['2021-02-17', '2021-04-29']
# ATCO 	 ['2021-02-17', '2021-05-04']
# ALB 	 ['2021-02-17', '2021-05-05']
# FSLY 	 ['2021-02-17', '2021-05-05']
# SEDG 	 ['2021-02-17', '2021-05-05']
# NVDA 	 ['2021-02-17', '2021-05-20']
# SBLK 	 ['2021-02-17', '2021-05-25']
# ORC 	 ['2021-02-18', '2021-04-07']
# EGO 	 ['2021-02-18', '2021-04-29']
# BAND 	 ['2021-02-18', '2021-04-29']
# FND 	 ['2021-02-18', '2021-04-29']
# SBAC 	 ['2021-02-18', '2021-05-04']
# RGEN 	 ['2021-02-18', '2021-05-05']
# VG 	 ['2021-02-18', '2021-05-06']
# FSLR 	 ['2021-02-18', '2021-05-06']
# HASI 	 ['2021-02-18', '2021-05-06']
# CNDT 	 ['2021-02-18', '2021-05-06']
# IDCC 	 ['2021-02-18', '2021-05-06']
# HBM 	 ['2021-02-18', '2021-05-13']
# NCLH 	 ['2021-02-18', '2021-05-13']
# ZS 	 ['2021-02-18', '2021-05-27']
# EVER 	 ['2021-02-22', '2021-05-03']
# IOVA 	 ['2021-02-23', '2021-05-04']
# BLD 	 ['2021-02-23', '2021-05-04']
# SQ 	 ['2021-02-23', '2021-05-05']
# ALRM 	 ['2021-02-23', '2021-05-06']
# HALO 	 ['2021-02-23', '2021-05-10']
# ORA 	 ['2021-02-23', '2021-05-10']
# INFN 	 ['2021-02-23', '2021-05-11']
# HD 	 ['2021-02-23', '2021-05-18']
# TOL 	 ['2021-02-23', '2021-05-26']
# DMRC 	 ['2021-02-24', '2021-04-28']
# LYG 	 ['2021-02-24', '2021-04-29']
# ETSY 	 ['2021-02-24', '2021-05-05']
# ACAD 	 ['2021-02-24', '2021-05-06']
# MRNA 	 ['2021-02-24', '2021-05-06']
# BKNG 	 ['2021-02-24', '2021-05-06']
# LMND 	 ['2021-02-24', '2021-05-10']
# LOW 	 ['2021-02-24', '2021-05-19']
# AMRN 	 ['2021-02-25', '2021-04-12']
# AMT 	 ['2021-02-25', '2021-04-28']
# NPTN 	 ['2021-02-25', '2021-04-29']
# RUN 	 ['2021-02-25', '2021-05-05']
# TPIC 	 ['2021-02-25', '2021-05-06']
# CWEN 	 ['2021-02-25', '2021-05-06']
# BWEN 	 ['2021-02-25', '2021-05-07']
# SABR 	 ['2021-02-25', '2021-05-07']
# ROCK 	 ['2021-02-26', '2021-05-05']
# CRON 	 ['2021-03-01', '2021-05-07']
# LU 	 ['2021-03-01', '2021-05-25']
# CDLX 	 ['2021-03-02', '2021-05-10']
# VEEV 	 ['2021-03-02', '2021-05-27']
# AMBA 	 ['2021-03-02', '2021-06-01']
# BLDP 	 ['2021-03-03', '2021-05-04']
# PING 	 ['2021-03-03', '2021-05-05']
# FTHM 	 ['2021-03-03', '2021-05-11']
# ZM 	 ['2021-03-03', '2021-06-01']
# PLUG 	 ['2021-03-04', '2021-05-06']
# GSL 	 ['2021-03-04', '2021-05-11']
# MRVL 	 ['2021-03-04', '2021-05-27']
# OKTA 	 ['2021-03-04', '2021-05-27']
# WPM 	 ['2021-03-10', '2021-05-05']
# WKHS 	 ['2021-03-10', '2021-05-05']
# DQ 	 ['2021-03-10', '2021-05-19']
# INO 	 ['2021-03-11', '2021-05-10']
# NVAX 	 ['2021-03-11', '2021-05-10']
# MDLA 	 ['2021-03-11', '2021-06-01']
# AVGO 	 ['2021-03-11', '2021-06-03']
# KIRK 	 ['2021-03-11', '2021-06-03']
# JKS 	 ['2021-03-12', '2021-06-14']
# HEXO 	 ['2021-03-15', '2021-03-29', '2021-06-10']
# CMPS 	 ['2021-03-15', '2021-04-29']
# AVRO 	 ['2021-03-15', '2021-05-06']
# XPEV 	 ['2021-03-15', '2021-05-08']
# LI 	 ['2021-03-15', '2021-05-14']
# SEEL 	 ['2021-03-16', '2021-05-06']
# SDGR 	 ['2021-03-16', '2021-05-12']
# BEKE 	 ['2021-03-16', '2021-05-14']
# FUTU 	 ['2021-03-17', '2021-03-17']
# NIO 	 ['2021-03-17', '2021-05-27']
# CRWD 	 ['2021-03-18', '2021-06-01']
# PXS 	 ['2021-03-18', '2021-06-02']
# LEN 	 ['2021-03-18', '2021-06-14']
# ADBE 	 ['2021-03-23', '2021-06-10']
# SOLO 	 ['2021-03-24', '2021-05-15']
# HOME 	 ['2021-03-24', '2021-06-17']
# CSIQ 	 ['2021-03-25', '2021-05-27']
# RH 	 ['2021-03-30', '2021-06-03']
# BLNK 	 ['2021-03-31', '2021-05-12']
# FVRR 	 ['2021-05-06', '2021-02-18']
