# %%
import os
os.environ["IEX_TOKEN"] = "pk_9ba866a9c4824ada84d5d51f5042ce41" 
import pyEX
c = pyEX.Client()

# %%
symbol = 'AAPL'
d = c.company(symbol)
print(d['industry'])
print(d['sector'])

#c.companyDF(symbol)
# Out:
# Telecommunications Equipment
# Electronic Technology

# %%
[_ for _ in dir(p) if _.endswith('DF')]
# Out:
# ['accountingQualityAndRiskMatrixDF',
#  'advancedStatsDF',
#  'analystDaysDF',
#  'analystRecommendationsDF',
#  'auctionDF',
#  'balanceSheetDF',
#  'batchDF',
#  'boardOfDirectorsMeetingDF',
#  'bonusIssueDF',
#  'bookDF',
#  'brain10DayMLReturnRankingDF',
#  'brain21DayMLReturnRankingDF',
#  'brain2DayMLReturnRankingDF',
#  'brain30DaySentimentDF',
#  'brain3DayMLReturnRankingDF',
#  'brain5DayMLReturnRankingDF',
#  'brain7DaySentimentDF',
#  'brainLanguageMetricsOnCompanyFilingsAllDF',
#  'brainLanguageMetricsOnCompanyFilingsDF',
#  'brainLanguageMetricsOnCompanyFilingsDifferenceAllDF',
#  'brainLanguageMetricsOnCompanyFilingsDifferenceDF',
#  'bulkBatchDF',
#  'bulkMinuteBarsDF',
#  'businessUpdatesDF',
#  'buybacksDF',
#  'calendarDF',
#  'cam1DF',
#  'capitalMarketsDayDF',
#  'cashFlowDF',
#  'ceoCompensationDF',
#  'chartDF',
#  'collectionsDF',
#  'companyDF',
#  'companyTravelDF',
#  'convertFXDF',
#  'corporateActionsDF',
#  'cryptoBookDF',
#  'cryptoDF',
# ...

# %%
dir(c)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_api_limit',
#  '_token',
#  '_version',
#  'account',
#  'accountingQualityAndRiskMatrix',
#  'accountingQualityAndRiskMatrixDF',
#  'advancedStats',
#  'advancedStatsDF',
#  'analystDays',
#  'analystDaysDF',
#  'analystRecommendations',
#  'analystRecommendationsDF',
#  'auction',
#  'auctionDF',
#  'balanceSheet',
#  'balanceSheetDF',
#  'batch',
#  'batchDF',
#  'bind',
#  'boardOfDirectorsMeeting',
#  'boardOfDirectorsMeetingDF',
#  'bonusIssue',
#  'bonusIssueDF',
#  'book',
#  'bookDF',
#  'bookDeep',
#  'bookDeepDF',
#  'brain10DayMLReturnRanking',
# ...

# %%
c.ohlc(symbol)
# Out:
# {'open': {'price': 120, 'time': 1599226202030},
#  'close': {'price': 120.96, 'time': 1599249600801},
#  'high': 123.7,
#  'low': 110.89,
#  'volume': 332607163,
#  'symbol': 'AAPL'}

# %%
#def chart(symbol, timeframe='1m', date=None, token='', version='', filter=''):
from datetime import datetime
td = '2020-08-01'
c.chartDF(symbol, timeframe='1m',date='20191107')
# Out:
#               open   close    high     low     volume   uOpen  uClose   uHigh  \
# date
# 2020-08-05  109.38  110.06  110.39  108.90  121991952  437.51  440.25  441.57
# 2020-08-06  110.41  113.90  114.41  109.80  202428900  441.62  455.61  457.65
# 2020-08-07  113.21  111.11  113.68  110.29  198045612  452.82  444.45  454.70
# 2020-08-10  112.60  112.73  113.78  110.00  212403424  450.40  450.91  455.10
# 2020-08-11  111.97  109.38  112.48  109.11  187902376  447.88  437.50  449.93
# 2020-08-12  110.50  113.01  113.28  110.30  165944820  441.99  452.04  453.10
# 2020-08-13  114.43  115.01  116.04  113.93  210082064  457.72  460.04  464.17
# 2020-08-14  114.83  114.91  115.00  113.05  165565208  459.32  459.63  460.00
# 2020-08-17  116.06  114.61  116.09  113.96  119561444  464.25  458.43  464.35
# 2020-08-18  114.35  115.56  116.00  114.01  105633540  457.41  462.25  464.00
# 2020-08-19  115.98  115.71  117.16  115.61  145538008  463.93  462.83  468.65
# ...
