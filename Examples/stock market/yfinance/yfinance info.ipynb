# %%
import yfinance as yf
name = 'HD'
stock_data = yf.Ticker(name)
info = stock_data.get_info()
info
# Out:
# {'zip': '30339',
#  'sector': 'Consumer Cyclical',
#  'fullTimeEmployees': 400000,
# ...

# %%
stock_data.calendar
# Out:
#                                 Value
# Earnings Date     2021-02-23 00:00:00
# Earnings Average                 2.56
# Earnings Low                     2.02
# Earnings High                    2.79
# Revenue Average           30013700000
# Revenue Low               25782000000
# Revenue High              31196000000

# %%
info['sector']
def getStockSector(name):
    return yf.Ticker(name).get_info()['sector']
getStockSector('MSFT')
# Out:
# 'Technology'
