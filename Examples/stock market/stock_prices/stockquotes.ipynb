# %%
import stockquotes
stock = stockquotes.Stock('AAPL')
print(stock.current_price)
print(stock.increase_dollars)
print(stock.increase_percent)
# Out:
# 120.96
# 0.08
# 0.07

# %%
stock.historical
# Out:
# [{'date': datetime.datetime(2020, 9, 4, 0, 0),
#   'open': 120.07,
#   'high': 123.7,
#   'low': 110.89,
#   'close': 120.96,
#   'adjusted_close': 120.96,
#   'volume': 332607163},
#  {'date': datetime.datetime(2020, 9, 3, 0, 0),
#   'open': 126.91,
#   'high': 128.84,
#   'low': 120.5,
#   'close': 120.88,
#   'adjusted_close': 120.88,
#   'volume': 254723200},
#  {'date': datetime.datetime(2020, 9, 2, 0, 0),
#   'open': 137.59,
#   'high': 137.98,
#   'low': 127.0,
#   'close': 131.4,
#   'adjusted_close': 131.4,
#   'volume': 200119000},
#  {'date': datetime.datetime(2020, 9, 1, 0, 0),
#   'open': 132.76,
#   'high': 134.8,
#   'low': 130.53,
#   'close': 134.18,
#   'adjusted_close': 134.18,
#   'volume': 152470100},
#  {'date': datetime.datetime(2020, 8, 31, 0, 0),
#   'open': 127.58,
#   'high': 131.0,
#   'low': 126.0,
#   'close': 129.04,
#   'adjusted_close': 129.04,
#   'volume': 225702700},
#  {'date': datetime.datetime(2020, 8, 28, 0, 0),
#   'open': 126.01,
# ...
