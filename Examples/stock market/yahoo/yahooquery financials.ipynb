# %%
from yahooquery import Ticker
import json
def pprint(jsonstr):
    print( json.dumps(jsonstr, indent=4) )
    
yq = Ticker('net')
yq

# %%
yq.company_officers
# Out:
#              age  exercisedValue  fiscalYear  maxAge  \
# symbol row
# net    0    44.0               0      2018.0       1
#        1    40.0               0      2018.0       1
#        2    56.0               0      2018.0       1
#        3    47.0               0      2018.0       1
#        4     NaN               0         NaN       1
#
#                                 name                       title  totalPay  \
# symbol row
# net    0         Mr. Matthew  Prince  Co-Founder, Chairman & CEO  400000.0
#        1        Ms. Michelle  Zatlyn  Co-Founder, COO & Director  400000.0
#        2       Mr. Thomas J. Seifert     Chief Financial Officer  690000.0
#        3    Mr. Douglas James Kramer         Gen. Counsel & Sec.  537708.0
#        4                 Mr. -  John    Chief Technology Officer       NaN
#
#             unexercisedValue  yearBorn
# symbol row
# net    0                   0    1975.0
#        1                   0    1979.0
# ...

# %%
yq.earning_history
# Out:
#            epsActual epsDifference epsEstimate  maxAge period     quarter  \
# symbol row
# net    0          {}            {}          {}       1    -4q          {}
#        1          {}            {}          {}       1    -3q          {}
#        2       -0.15             0       -0.15       1    -2q  2019-09-30
#        3       -0.06          0.01       -0.07       1    -1q  2019-12-31
#
#            surprisePercent
# symbol row
# net    0                {}
#        1                {}
#        2                 0
#        3             0.143

# %%
yq.grading_history
# Out:
#            action epochGradeDate                        firm     fromGrade  \
# symbol row
# net    0     down     2020-04-13              Morgan Stanley  Equal-Weight
#        1     main     2020-03-24              Morgan Stanley
#        2     main     2020-02-13                     Needham
#        3     init     2020-01-09                       Baird
#        4     init     2019-11-03               Piper Jaffray
#        5     init     2019-10-07  SunTrust Robinson Humphrey
#        6     init     2019-10-07                 Wells Fargo
#        7     init     2019-10-07              Morgan Stanley
#        8     init     2019-10-07                 RBC Capital
#        9     init     2019-10-07                 Oppenheimer
#        10    init     2019-10-07              JMP Securities
#        11    init     2019-10-07               Goldman Sachs
#        12    init     2019-10-07          Evercore ISI Group
#
#                       toGrade
# symbol row
# ...

# %%
yq.insider_holders
# Out:
#            latestTransDate  maxAge                                name  \
# symbol row
# net    0        2020-04-01       1                KRAMER DOUGLAS JAMES
#        1        2019-09-17       1                    LEDBETTER CARL S
#        2        2019-09-17       1  NEW ENTERPRISE ASSOCIATES 13, L.P.
#        3        2019-09-17       1             PELION VENTURES V, L.P.
#        4        2019-09-17       1                     SANDELL SCOTT D
#        5        2020-04-14       1                    SEIFERT THOMAS J
#        6        2020-03-25       1                UV PARTNERS IV, L.P.
#        7        2020-03-25       1            VENROCK ASSOCIATES V L P
#        8        2020-04-08       1                     ZATLYN MICHELLE
#
#            positionDirectDate  positionIndirect  positionIndirectDate  \
# symbol row
# net    0           2020-04-01               NaN                   NaN
#        1                  NaN         1295790.0          1.568678e+09
# ...

# %%
yq.insider_transactions
# Out:
#                                      filerName  \
# symbol row
# net    0                      SEIFERT THOMAS J
#        1                      SEIFERT THOMAS J
#        2                       ZATLYN MICHELLE
#        3                       ZATLYN MICHELLE
#        4                  KRAMER DOUGLAS JAMES
#        5                  KRAMER DOUGLAS JAMES
#        6                      SEIFERT THOMAS J
#        7                      SEIFERT THOMAS J
#        8              VENROCK ASSOCIATES V L P
#        9                  UV PARTNERS IV, L.P.
#        10                     SEIFERT THOMAS J
#        11                     SEIFERT THOMAS J
#        12                      ZATLYN MICHELLE
#        13                      ZATLYN MICHELLE
#        14                 UV PARTNERS IV, L.P.
#        15                 UV PARTNERS IV, L.P.
#        16                 KRAMER DOUGLAS JAMES
#        17                     SEIFERT THOMAS J
#        18                     SEIFERT THOMAS J
# ...

# %%
yq.institution_ownership
# Out:
#             maxAge                       organization  pctHeld  position  \
# symbol row
# net    0         1                           FMR, LLC   0.2296  21717538
#        1         1        Greenspring Associates, LLC   0.0752   7115467
#        2         1            Franklin Resources, Inc   0.0627   5925638
#        3         1        NEA Management Company, LLC   0.0429   4059376
#        4         1         Vanguard Group, Inc. (The)   0.0353   3341189
#        5         1         Gilder, Gagnon, Howe & Co.   0.0301   2842938
#        6         1            ETF Managers Group, LLC   0.0242   2292491
#        7         1      Price (T.Rowe) Associates Inc   0.0196   1857427
#        8         1  Norges Bank Investment Management   0.0169   1597219
#        9         1              Wells Fargo & Company   0.0140   1320840
#
#             reportDate      value
# symbol row
# net    0    2019-12-31  370501198
#        1    2019-12-31  121389867
#        2    2019-12-31  101091384
# ...

# %%
yq.recommendation_trend
# Out:
#             buy  hold period  sell  strongBuy  strongSell
# symbol row
# net    0      0     0     0m     0          0           0
#        1      8     3    -1m     0          2           0
#        2      8     3    -2m     0          3           0
#        3      0     0    -3m     0          0           0

# %%
yq.sec_filings
# Out:
# {'net': 'No fundamentals data found for any of the summaryTypes=secFilings'}

# %%
yq.fund_ownership
# Out:
#             maxAge                                       organization  \
# symbol row
# net    0         1                       Fidelity Growth Company Fund
#        1         1     ETF Managers Tr-EFTMG Prime Cyber Security ETF
#        2         1                Price (T.Rowe) Small-Cap Value Fund
#        3         1  Franklin Strategic Series-Franklin Small Cap G...
#        4         1             Vanguard Total Stock Market Index Fund
#        5         1                      Vanguard Small-Cap Index Fund
#        6         1  Franklin Strategic Series-Franklin Small-Mid C...
#        7         1                  Federated Kaufmann Small Cap Fund
#        8         1                Fidelity Series Growth Company Fund
#        9         1                              Wells Fargo Growth Fd
#
#             pctHeld  position  reportDate     value
# symbol row
# net    0     0.0274   2587559  2019-12-31  44143756
#        1     0.0234   2212474  2020-01-31  39514785
# ...

# %%
yq.major_holders
# Out:
# {'net': {'maxAge': 1,
#   'insidersPercentHeld': 0.09066,
#   'institutionsPercentHeld': 0.75892997,
#   'institutionsFloatPercentHeld': 0.83459,
#   'institutionsCount': 149}}

# %%
yq.earnings_trend
# Out:
# {'net': {'trend': [{'maxAge': 1,
#     'period': '0q',
#     'endDate': '2020-03-31',
#     'growth': {},
#     'earningsEstimate': {'avg': -0.06,
#      'low': -0.07,
#      'high': -0.05,
#      'yearAgoEps': {},
#      'numberOfAnalysts': 14,
#      'growth': {}},
#     'revenueEstimate': {'avg': 87020000,
#      'low': 82390000,
#      'high': 88000000,
#      'numberOfAnalysts': 13,
#      'yearAgoRevenue': {},
#      'growth': {}},
#     'epsTrend': {'current': -0.06,
#      '7daysAgo': -0.06,
#      '30daysAgo': -0.06,
#      '60daysAgo': -0.06,
#      '90daysAgo': -0.05},
#     'epsRevisions': {'upLast7days': 0,
#      'upLast30days': 0,
#      'downLast30days': 0,
#      'downLast90days': {}}},
#    {'maxAge': 1,
#     'period': '+1q',
#     'endDate': '2020-06-30',
#     'growth': {},
#     'earningsEstimate': {'avg': -0.05,
#      'low': -0.07,
#      'high': -0.04,
#      'yearAgoEps': {},
#      'numberOfAnalysts': 14,
#      'growth': {}},
# ...

# %%
yq.balance_sheet()  # Defaults to Annual
# Out:
#          asOfDate  AccountsPayable  AccountsReceivable  \
# symbol
# net    2017-12-31        4725000.0          11476000.0
# net    2018-12-31       14285000.0          25155000.0
# net    2019-12-31       11463000.0          33867000.0
#
#         AccumulatedDepreciation  CapitalStock  CashAndCashEquivalents  \
# symbol
# net                 -27736000.0       79000.0              24444000.0
# net                 -39899000.0       85000.0              25055000.0
# net                 -67189000.0      294000.0             138976000.0
#
#         CurrentAccruedExpenses  CurrentAssets  CurrentDebt  \
# symbol
# net                  2332000.0     92024000.0     356000.0
# net                  7527000.0    196737000.0     255000.0
# net                 11355000.0    689872000.0          NaN
#
#         CurrentDeferredRevenue  ...  OtherIntangibleAssets  \
# symbol                          ...
# net                 11927000.0  ...               673000.0
# ...

# %%
yq.balance_sheet(frequency="q")
# Out:
#          asOfDate  AccountsPayable  AccountsReceivable  \
# symbol
# net    2019-06-30       17128000.0          29926000.0
# net    2019-09-30        9517000.0          32205000.0
# net    2019-12-31       11463000.0          33867000.0
#
#         AccumulatedDepreciation  CapitalStock  CashAndCashEquivalents  \
# symbol
# net                 -51391000.0      251000.0              42394000.0
# net                 -58885000.0      294000.0             501706000.0
# net                 -67189000.0      294000.0             138976000.0
#
#         CurrentAccruedExpenses  CurrentAssets  CurrentDebt  \
# symbol
# net                  8688000.0    166006000.0      74000.0
# net                  8858000.0    695678000.0      37000.0
# net                 11355000.0    689872000.0          NaN
#
#         CurrentDeferredRevenue  ...  OtherIntangibleAssets  \
# symbol                          ...
# net                 26757000.0  ...                94000.0
# ...

# %%
yq.balance_sheet("q")
# Out:
#          asOfDate  AccountsPayable  AccountsReceivable  \
# symbol
# net    2019-06-30       17128000.0          29926000.0
# net    2019-09-30        9517000.0          32205000.0
# net    2019-12-31       11463000.0          33867000.0
#
#         AccumulatedDepreciation  CapitalStock  CashAndCashEquivalents  \
# symbol
# net                 -51391000.0      251000.0              42394000.0
# net                 -58885000.0      294000.0             501706000.0
# net                 -67189000.0      294000.0             138976000.0
#
#         CurrentAccruedExpenses  CurrentAssets  CurrentDebt  \
# symbol
# net                  8688000.0    166006000.0      74000.0
# net                  8858000.0    695678000.0      37000.0
# net                 11355000.0    689872000.0          NaN
#
#         CurrentDeferredRevenue  ...  OtherIntangibleAssets  \
# symbol                          ...
# net                 26757000.0  ...                94000.0
# ...

# %%
yq.cash_flow()
# Out:
#          asOfDate  BeginningCashPosition  CapitalExpenditure  \
# symbol
# net    2016-12-31             42475000.0         -18558000.0
# net    2017-12-31             14319000.0         -22975000.0
# net    2018-12-31             26881000.0         -34839000.0
# net    2019-12-31             31426000.0         -57279000.0
#
#         CashFlowFromContinuingFinancingActivities  ChangeInAccountPayable  \
# symbol
# net                                      418000.0               1247000.0
# net                                     -149000.0               -957000.0
# net                                   168621000.0               4386000.0
# net                                   570768000.0              -1328000.0
#
#         ChangeInCashSupplementalAsReported  ChangeInWorkingCapital  \
# symbol
# net                            -28156000.0             -11752000.0
# net                             12562000.0              -5231000.0
# ...

# %%
yq.income_statement()
# Out:
#          asOfDate  BasicAverageShares  BasicEPS  CostOfRevenue  \
# symbol
# net    2016-12-31         237322000.0 -0.073040     23962000.0
# net    2017-12-31         251085000.0 -0.042806     28788000.0
# net    2018-12-31         237322000.0 -0.370000     43537000.0
# net    2019-12-31                 NaN       NaN     63423000.0
#
#         DilutedAverageShares  DilutedEPS      Ebitda  GrossProfit  \
# symbol
# net              237322000.0   -0.073040  -8256000.0   60829000.0
# net              251085000.0   -0.042806   3321000.0  106127000.0
# net              237322000.0   -0.370000 -66190000.0  149137000.0
# net                      NaN         NaN -74122000.0  223599000.0
#
#         InterestExpense    NetIncome  NetIncomeCommonStockholders  \
# symbol
# net            654000.0  -17334000.0                  -17334000.0
# net            862000.0  -10748000.0                  -10748000.0
# net            992000.0  -87164000.0                  -87164000.0
# ...
