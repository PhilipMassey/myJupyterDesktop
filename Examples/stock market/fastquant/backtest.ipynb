# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = [15, 8]

from fastquant import get_stock_data, backtest
df = get_stock_data('AAPL', '2020-01-01', '2020-08-01')
backtest('smac',df,fast_period=15,slow_period=40)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Starting Portfolio Value: 100000.00
# ===Global level arguments===
# init_cash : 100000
# buy_prop : 1
# sell_prop : 1
# ===Strategy level arguments===
# fast_period : 15
# slow_period : 40
# 2020-04-21, BUY CREATE, 268.37
# 2020-04-21, Cash: 100000.0
# 2020-04-21, Price: 268.3699951171875
# 2020-04-21, Buy prop size: 369
# 2020-04-21, Afforded size: 369
# 2020-04-21, Final size: 369
# 2020-04-22, BUY EXECUTED, Price: 268.37, Cost: 99028.53, Comm 742.71
# Final PnL: 57068.52
# ==================================================
# Number of strat runs: 1
# Number of strats per run: 1
# Strat names: [<class 'fastquant.strategies.SMACStrategy'>]
# **************************************************
# --------------------------------------------------
# {'init_cash': 100000, 'buy_prop': 1, 'sell_prop': 1, 'execution_type': 'close', 'fast_period': 15, 'slow_period': 40}
# OrderedDict([('rtot', 0.4515119635962937), ('ravg', 0.003071509956437372), ('rnorm', 1.1684670926743825), ('rnorm100', 116.84670926743826)])
# OrderedDict([('sharperatio', None)])
# Time used (seconds): 0.05445694923400879
# Optimal parameters: {'init_cash': 100000, 'buy_prop': 1, 'sell_prop': 1, 'execution_type': 'close', 'fast_period': 15, 'slow_period': 40}
# Optimal metrics: {'rtot': 0.4515119635962937, 'ravg': 0.003071509956437372, 'rnorm': 1.1684670926743825, 'rnorm100': 116.84670926743826, 'sharperatio': None, 'pnl': 57068.52, 'final_value': 157068.52099334716}
# <img src="data:image/png;base64,..." width="1080">
#    init_cash  buy_prop  sell_prop execution_type  fast_period  slow_period  \
# 0     100000         1          1          close           15           40
#
#        rtot      ravg     rnorm    rnorm100 sharperatio       pnl  \
# 0  0.451512  0.003072  1.168467  116.846709        None  57068.52
#
#      final_value
# 0  157068.520993

# %%
from fastquant import get_stock_data
df = get_stock_data('AAPL', '2019-01-01', end_date='2020-08-01')
df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  close
# dt
# 2019-01-02  157.919998
# 2019-01-03  142.190002
# 2019-01-04  148.259995
# 2019-01-07  147.929993
# 2019-01-08  150.750000
# ...                ...
# 2020-07-27  379.239990
# 2020-07-28  373.010010
# 2020-07-29  380.160004
# 2020-07-30  384.760010
# 2020-07-31  425.040009
#
# [399 rows x 1 columns]
