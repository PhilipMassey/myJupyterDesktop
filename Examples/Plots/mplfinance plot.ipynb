# %%
import pandas as pd
#daily = pd.read_csv('https://github.com/matplotlib/mplfinance/examples/data/SP500_NOV2019_Hist.csv',index_col=0,parse_dates=True)
#daily = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/finance-charts-apple.csv')
#daily = pd.read_csv('https://github.com/matplotlib/mplfinance/tree/master/examples/data/SP500_NOV2019_Hist.csv',index_col=0,parse_dates=True)
daily = pd.read_csv('//Users/Shared/GitHub/mplfinance/examples/data/SP500_NOV2019_Hist.csv',index_col=0,parse_dates=True)
daily.index.name = 'Date'
daily.shape
daily.head(3)

import mplfinance as mpf
mpf.plot(daily)
mpf.plot(daily,type='candle')
mpf.plot(daily,type='line')

# %%
mpf.plot(daily,type='candle',mav=(3,6,9),volume=True)
