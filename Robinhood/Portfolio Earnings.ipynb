# %%
import sys; print('Python %s on %s' % (sys.version, sys.platform))
sys.path.extend(['/Users/philipmassey/PycharmProjects/stock_market'])
import pandas as pd
import portfolio as pf
import robin_stocks as r
import rh
r = rh.r

def getEarningsCurrentMonth(symbol,year,month):
    year_month = year+'-'+month
    earnings = r.get_earnings(symbol=symbol)
    if len(earnings) > 0:
        report_dicts = list(filter(lambda e: e['report'] != None, earnings))
        #print(symbol,report_dict)
        year_month_dicts = list(filter(lambda e: e['report']['date'][0:7] == year_month, report_dicts))
        year_month_date = list(map(lambda e: e['report']['date'], year_month_dicts))
        if len(year_month_date) > 0:
            #print(symbol,year_month_date)
            return symbol,year_month_date[0]
        
df_port = pf.getPortfolios()
symbols = pf.getPortfoliosSymbols()
#symbols = ['AAPL','ATACX','DDOG','ORCL']
year = '2020'
month = '11'
# Out:
# Python 3.7.3 (v3.7.3:ef4ec6ed12, Mar 25 2019, 16:52:21)
# [Clang 6.0 (clang-600.0.57)] on darwin

# %%
earnings = [getEarningsCurrentMonth(e,year,month) for e in symbols]
symbols_earnings = [e for e in earnings if e != None]
df = pd.DataFrame(symbols_earnings,columns=['symbol','earnings'])
df.set_index('symbol',inplace=True)
df_port_earnings = pd.concat([df,df_port],axis=1)
df_port_earnings.reset_index(inplace=True)
df_port_earnings.rename(columns={'index':'symbol','portfolio':'portfolio'},inplace=True)
df_port_earnings.dropna(inplace=True)
df_port_earnings=df_port_earnings[['portfolio','symbol','earnings']]
pd.set_option('display.max_rows', 500)
print(df_port_earnings.sort_values(by='earnings'))
# Out:
# 400 Client Error: Bad Request for url: https://api.robinhood.com/marketdata/earnings/?symbol=MMEDF
# 400 Client Error: Bad Request for url: https://api.robinhood.com/marketdata/earnings/?symbol=RVVTF
# 400 Client Error: Bad Request for url: https://api.robinhood.com/marketdata/earnings/?symbol=LUNMF
# 400 Client Error: Bad Request for url: https://api.robinhood.com/marketdata/earnings/?symbol=CURLF
# 400 Client Error: Bad Request for url: https://api.robinhood.com/marketdata/earnings/?symbol=GTBIF
# 400 Client Error: Bad Request for url: https://api.robinhood.com/marketdata/earnings/?symbol=TCNNF
# 400 Client Error: Bad Request for url: https://api.robinhood.com/marketdata/earnings/?symbol=DOCRF
# 400 Client Error: Bad Request for url: https://api.robinhood.com/marketdata/earnings/?symbol=BYDDF
# 400 Client Error: Bad Request for url: https://api.robinhood.com/marketdata/earnings/?symbol=DNNGY
# 400 Client Error: Bad Request for url: https://api.robinhood.com/marketdata/earnings/?symbol=GCTAF
# 400 Client Error: Bad Request for url: https://api.robinhood.com/marketdata/earnings/?symbol=GCTAY
#    symbol    earnings
# 0    CALX  2020-10-20
# 1    ERIC  2020-10-21
# 2    IPGP  2020-10-30
# 3    IPHI  2020-10-29
# 4    NXPI  2020-10-26
# ..    ...         ...
# 83   MMYT  2020-10-27
# 84    RCL  2020-10-29
# 85   TZOO  2020-10-21
# 86    UAL  2020-10-14
# 87    SWI  2020-10-27
#
# [88 rows x 2 columns]

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %%
pd.set_option('display.max_rows', 500)
print(df_port_earnings.sort_values(by='earnings'))
# Out:
#                  portfolio symbol    earnings
# 80                  Travel    CCL  2020-10-08
# 81                  Travel    DAL  2020-10-13
# 39              Healthcare    UNH  2020-10-14
# 86                  Travel    UAL  2020-10-14
# 24                Cannabis   APHA  2020-10-15
# 73          Semiconductors    TSM  2020-10-15
# 0                       5G   CALX  2020-10-20
# 38              Healthcare    THC  2020-10-20
# 41       Home Construction    NVR  2020-10-20
# 74          Semiconductors    TXN  2020-10-20
# 54               Insurance    DCT  2020-10-20
# 34       Electric Vehicles   TSLA  2020-10-21
# 46           Home Supplies   UFPI  2020-10-21
# 47                     IOT    APH  2020-10-21
# 61                    REIT    CCI  2020-10-21
# 65                    REIT    SLG  2020-10-21
# 67        Renewalbe Energy    NEP  2020-10-21
# 32                Dividend    ARR  2020-10-21
# 71          Semiconductors   LRCX  2020-10-21
# 9         Biotech Emerging   ALGN  2020-10-21
# 5                       5G   XLNX  2020-10-21
# 85                  Travel   TZOO  2020-10-21
# 1                       5G   ERIC  2020-10-21
# 66        Renewalbe Energy    NEE  2020-10-21
# 12        Biotech Emerging    DHR  2020-10-22
# 72          Semiconductors    STX  2020-10-22
# 42       Home Construction    PHM  2020-10-22
# 8           Basic Material    FCX  2020-10-22
# 82                  Travel    LUV  2020-10-22
# 69          Semiconductors   AMKR  2020-10-26
# 31                Dividend   AGNC  2020-10-26
# 43       Home Construction    SSD  2020-10-26
# 29  Communication Services   FEDU  2020-10-26
# 4                       5G   NXPI  2020-10-26
# 26   Cloud Enterprise Apps   TWLO  2020-10-26
# 83                  Travel   MMYT  2020-10-27
# 77            Solar Energy   FSLR  2020-10-27
# 76            Solar Energy   ENPH  2020-10-27
# 75                Shipping   CMRE  2020-10-27
# 68          Semiconductors    AMD  2020-10-27
# 58            Mega Capital    MRK  2020-10-27
# 53                     IOT     ST  2020-10-27
# 52                     IOT    ROP  2020-10-27
# 48                     IOT   DXCM  2020-10-27
# 20           Biotechnology    LLY  2020-10-27
# 59            Mega Capital   MSFT  2020-10-27
# 87             Wind Energy    SWI  2020-10-27
# 22           Biotechnology    NVS  2020-10-27
# 23           Biotechnology    PFE  2020-10-27
# 37              Healthcare    CNC  2020-10-27
# 33                Dividend     DX  2020-10-28
# 6   Artificial Inteligence   DMRC  2020-10-28
# 79            Solar Energy   SPWR  2020-10-28
# 78            Solar Energy   GNRC  2020-10-28
# 36              Healthcare   ANTM  2020-10-28
# 11        Biotech Emerging   CRSP  2020-10-28
# 70          Semiconductors   KLAC  2020-10-28
# 14        Biotech Emerging    PKI  2020-10-28
# 17           Biotechnology   GILD  2020-10-28
# 64                    REIT    NLY  2020-10-28
# 63                    REIT   EQIX  2020-10-28
# 62                    REIT   CONE  2020-10-28
# 16           Biotechnology   AMGN  2020-10-28
# 19           Biotechnology   INVA  2020-10-28
# 30  Communication Services   FSLY  2020-10-28
# 40       Home Construction    MAS  2020-10-28
# 51                     IOT     PI  2020-10-28
# 84                  Travel    RCL  2020-10-29
# 44              Home Decor    FND  2020-10-29
# 3                       5G   IPHI  2020-10-29
# 28  Communication Services   BAND  2020-10-29
# 50                     IOT   MPWR  2020-10-29
# 35             Electricity     BE  2020-10-29
# 25                Cannabis   HEXO  2020-10-29
# 18           Biotechnology   ILMN  2020-10-29
# 60                    REIT    AMT  2020-10-29
# 10        Biotech Emerging    BIO  2020-10-29
# 55            Mega Capital   AAPL  2020-10-29
# 13        Biotech Emerging   MRNA  2020-10-29
# 56            Mega Capital   AMZN  2020-10-29
# 57            Mega Capital   GOOG  2020-10-29
# 27       Cloud Retail Apps   SHOP  2020-10-29
# 45           Home Supplies   ROCK  2020-10-29
# 7           Basic Material    EGO  2020-10-29
# 49                     IOT    HON  2020-10-30
# 15           Biotechnology   ABBV  2020-10-30
# 2                       5G   IPGP  2020-10-30
# 21           Biotechnology    NVO  2020-10-30
